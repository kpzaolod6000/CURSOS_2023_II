# %% [markdown]
# # Read Data

# %%
import pandas as pd
import re
import operator

# %%
def is_number(s):
    try:
        float(s) if '.' in s else int(s)
        return True
    except ValueError:
        return False

# %%
def load_stop_words(stop_word_file):
    """
    Utility function to load stop words from a file and return as a list of words
    @param stop_word_file Path and file name of a file containing stop words.
    @return list A list of stop words.
    """
    stop_words = []
    for line in open(stop_word_file):
        if line.strip()[0:1] != "#":
            for word in line.split():  # in case more than one per line
                stop_words.append(word)
    return stop_words

# %%
def separate_words(text, min_word_return_size):
    """
    Utility function to return a list of all words that are have a length greater than a specified number of characters.
    @param text The text that must be split in to words.
    @param min_word_return_size The minimum no of characters a word must have to be included.
    """
    splitter = re.compile('[^a-zA-Z0-9_\\+\\-/]')
    words = []
    for single_word in splitter.split(text):
        current_word = single_word.strip().lower()
        #leave numbers in phrase, but don't count as words, since they tend to invalidate scores of their phrases
        if len(current_word) > min_word_return_size and current_word != '' and not is_number(current_word):
            words.append(current_word)
    return words

# %%
def split_sentences(text):
    """
    Utility function to return a list of sentences.
    @param text The text that must be split in to sentences.
    """
    sentence_delimiters = re.compile(u'[.!?,;:\t\\\\"\\(\\)\\\'\u2019\u2013]|\\s\\-\\s')
    sentences = sentence_delimiters.split(text)
    return sentences

# %%
def build_stop_word_regex(stop_word_file_path):
    stop_word_list = load_stop_words(stop_word_file_path)
    stop_word_regex_list = []
    for word in stop_word_list:
        word_regex = r'\b' + word + r'(?![\w-])'  # added look ahead for hyphen
        stop_word_regex_list.append(word_regex)
    stop_word_pattern = re.compile('|'.join(stop_word_regex_list), re.IGNORECASE)
    return stop_word_pattern

# %%
def generate_candidate_keywords(sentence_list, stopword_pattern):
    phrase_list = []
    for s in sentence_list:
        tmp = re.sub(stopword_pattern, '|', s.strip())
        phrases = tmp.split("|")
        for phrase in phrases:
            phrase = phrase.strip().lower()
            if phrase != "":
                phrase_list.append(phrase)
    return phrase_list

# %%
def calculate_word_scores(phraseList):
    word_frequency = {}
    word_degree = {}
    for phrase in phraseList:
        word_list = separate_words(phrase, 0)
        word_list_length = len(word_list)
        word_list_degree = word_list_length - 1
        #if word_list_degree > 3: word_list_degree = 3 #exp.
        for word in word_list:
            word_frequency.setdefault(word, 0)
            word_frequency[word] += 1
            word_degree.setdefault(word, 0)
            word_degree[word] += word_list_degree  #orig.
            #word_degree[word] += 1/(word_list_length*1.0) #exp.
    for item in word_frequency:
        word_degree[item] = word_degree[item] + word_frequency[item]

    # Calculate Word scores = deg(w)/frew(w)
    word_score = {}
    for item in word_frequency:
        word_score.setdefault(item, 0)
        word_score[item] = word_degree[item] / (word_frequency[item] * 1.0)  #orig.
    #word_score[item] = word_frequency[item]/(word_degree[item] * 1.0) #exp.
    return word_score

# %%
def generate_candidate_keyword_scores(phrase_list, word_score):
    keyword_candidates = {}
    for phrase in phrase_list:
        keyword_candidates.setdefault(phrase, 0)
        word_list = separate_words(phrase, 0)
        candidate_score = 0
        for word in word_list:
            candidate_score += word_score[word]
        keyword_candidates[phrase] = candidate_score
    return keyword_candidates

# %%
class Rake(object):
    def __init__(self, stop_words_path):
        self.stop_words_path = stop_words_path
        self.__stop_words_pattern = build_stop_word_regex(stop_words_path)

    def run(self, text):
        sentence_list = split_sentences(text)

        phrase_list = generate_candidate_keywords(sentence_list, self.__stop_words_pattern)

        word_scores = calculate_word_scores(phrase_list)

        keyword_candidates = generate_candidate_keyword_scores(phrase_list, word_scores)

        # sorted_keywords = sorted(keyword_candidates.iteritems(), key=operator.itemgetter(1), reverse=True)
        sorted_keywords = sorted(keyword_candidates.items(), key=operator.itemgetter(1), reverse=True)
        
        return sorted_keywords

# %%
# if test:
#     text = "Compatibility of systems of linear constraints over the set of natural numbers. Criteria of compatibility of a system of linear Diophantine equations, strict inequations, and nonstrict inequations are considered. Upper bounds for components of a minimal set of solutions and algorithms of construction of minimal generating sets of solutions for all types of systems are given. These criteria and the corresponding algorithms for constructing a minimal supporting set of solutions can be used in solving all the considered types of systems and systems of mixed types."

#     # Split text into sentences
#     sentenceList = split_sentences(text)
#     #stoppath = "FoxStoplist.txt" #Fox stoplist contains "numbers", so it will not find "natural numbers" like in Table 1.1
#     stoppath = "SmartStoplist.txt"  #SMART stoplist misses some of the lower-scoring keywords in Figure 1.5, which means that the top 1/3 cuts off one of the 4.0 score words in Table 1.1
#     stopwordpattern = build_stop_word_regex(stoppath)

#     # generate candidate keywords
#     phraseList = generate_candidate_keywords(sentenceList, stopwordpattern)

#     # calculate individual word scores
#     wordscores = calculate_word_scores(phraseList)

#     # generate candidate keyword scores
#     keywordcandidates = generate_candidate_keyword_scores(phraseList, wordscores)
#     if debug: print(keywordcandidates)

#     # sortedKeywords = sorted(keywordcandidates.iteritems(), key=operator.itemgetter(1), reverse=True)
#     sortedKeywords = sorted(keywordcandidates, key=operator.itemgetter(1), reverse=True)

#     if debug: print(sortedKeywords)

#     totalKeywords = len(sortedKeywords)
#     if debug: print (totalKeywords)

#     # print (sortedKeywords[0:(totalKeywords / 3)])

#     rake = Rake("SmartStoplist.txt")
#     keywords = rake.run(text)
#     print (keywords)

# %%
df_grouped = pd.read_csv('data/dataClean/newgrouped_df.csv')

# %%
df_grouped
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords  \
# 0     cooperative knowledge generation,knowledge  co...
# 1     professional training,workplace learning,compu...
# 2     Experience-based Information System,wiki,weblo...
# 3     modelling method,introduction method,context-a...
# 4     knowledge visualization,information  visualiza...
# ...                                                 ...
# 1097  virtual environment,accessibility,persons with...
# 1098              learning styles,Web-based application
# 1099    visualization,e-learning,timeline,spiral,Moodle
# 1100    syntax trees,visualization,educational software
# 1101   learning programming,intelligent tutoring system
#
#                  FirstLevel  \
# 0                     ['H']
# 1                 ['H' 'J']
# 2     ['A' 'D' 'H' 'J' 'K']
# 3             ['H' 'I' 'J']
# 4                     ['H']
# ...                     ...
# 1097                  ['K']
# 1098                  ['K']
# 1099              ['L' 'M']
# 1100              ['D' 'K']
# 1101          ['D' 'I' 'L']
#
#                                         titleCleanedLem  \
# 0      integration community process-oriented structure
# 1     outcome synchronously interaction small learni...
# 2     weblogs sharing learning knowledge space using...
# 3     management oriented pre-built implementing met...
# 4     novel visualization transfer project map evalu...
# ...                                                 ...
# 1097  need environment people virtual educational sp...
# 1098  management learning web style development appl...
# 1099   used spiral timeline support e-learning semantic
# 1100  visualization tree course syntax language proc...
# 1101  environment coala learning computer distribute...
#
#                                       keywordCleanedLem  \
# 0     generation community cooperative process-orien...
# 1     cooperative learning workplace computer-suppor...
# 2     information system agent learning experience-b...
# 3     filtering collaborative management business me...
# 4     communication visualization visual storytellin...
# ...                                                 ...
# 1097  environment person virtual disability accessib...
# 1098               application learning web-based style
# 1099    visualization spiral timeline e-learning moodle
# 1100     visualization tree educational software syntax
# 1101   programming system learning tutoring intelligent
#
#                                        titleCleanedStem  \
# 0                    process-ori commun structur integr
# 1     outcom interact small factor synchron learn on...
# 2          knowledg share learn weblog space use inform
# 3     manag knowledg architectur pre-built implement...
# 4     novel evalu visual transfer knowledg project m...
# ...                                                 ...
# 1097  educ need digit inclus environ peopl virtual s...
# 1098               manag develop web learn style applic
# 1099          spiral timelin support semant use e-learn
# 1100           visual tree languag syntax cours process
# 1101  assist coala program environ learn distribut c...
#
#                                      keywordCleanedStem  \
# 0     knowledg knowledge-intens gener wiki process-o...
# 1     assur profession studi empir learn train compu...
# 2     experience-bas system agent pedagog arrang lea...
# 3     manag filter knowledg inform collabor method i...
# 4     manag visual knowledg inform metaphor project ...
# ...                                                 ...
# 1097               environ person virtual disabl access
# 1098                         applic web-bas style learn
# 1099                moodl visual spiral timelin e-learn
# 1100                    educ visual tree syntax softwar
# 1101                system tutor learn intellig program
#
#                                        titleRelevantLem  \
# 0                       integration community structure
# 1     outcome synchronously interaction small learni...
# 2     weblogs sharing learning knowledge space using...
# 3     management oriented implementing method modell...
# 4     novel visualization transfer project map evalu...
# ...                                                 ...
# 1097  need environment people virtual educational sp...
# 1098  management learning web style development appl...
# 1099              used spiral timeline support semantic
# 1100  visualization tree course syntax language proc...
# 1101  environment coala learning computer distribute...
#
#                                      keywordRelevantLem
# 0     generation community cooperative knowledge wik...
# 1     cooperative learning workplace training assura...
# 2     information system agent learning weblog pedag...
# 3     filtering collaborative management business me...
# 4     communication visualization visual storytellin...
# ...                                                 ...
# 1097  environment person virtual disability accessib...
# 1098                         application learning style
# 1099               visualization spiral timeline moodle
# 1100     visualization tree educational software syntax
# 1101   programming system learning tutoring intelligent
#
# [1102 rows x 10 columns]

# %%
c_grouped_t = df_grouped['titleCleanedStem']
c_grouped_k = df_grouped['keywordCleanedStem']

# %%
debug = False
test = True

# %%
def getWordsOfRakeAlgorithm(c_grouped):

    keywordsList = []
    for text in c_grouped:
        # text = "Compatibility of systems of linear constraints over the set of natural numbers. Criteria of compatibility of a system of linear Diophantine equations, strict inequations, and nonstrict inequations are considered. Upper bounds for components of a minimal set of solutions and algorithms of construction of minimal generating sets of solutions for all types of systems are given. These criteria and the corresponding algorithms for constructing a minimal supporting set of solutions can be used in solving all the considered types of systems and systems of mixed types."

        # Split text into sentences
        sentenceList = split_sentences(text)
       
        #stoppath = "FoxStoplist.txt" #Fox stoplist contains "numbers", so it will not find "natural numbers" like in Table 1.1
        stoppath = "SmartStoplist.txt"  #SMART stoplist misses some of the lower-scoring keywords in Figure 1.5, which means that the top 1/3 cuts off one of the 4.0 score words in Table 1.1
        stopwordpattern = build_stop_word_regex(stoppath)

        # generate candidate keywords
        phraseList = generate_candidate_keywords(sentenceList, stopwordpattern)

        # calculate individual word scores
        wordscores = calculate_word_scores(phraseList)

        # generate candidate keyword scores
        keywordcandidates = generate_candidate_keyword_scores(phraseList, wordscores)
        if debug: print(keywordcandidates)

        # sortedKeywords = sorted(keywordcandidates.iteritems(), key=operator.itemgetter(1), reverse=True)
        sortedKeywords = sorted(keywordcandidates.items(), key=operator.itemgetter(1), reverse=True)

        if debug: print(sortedKeywords)

        totalKeywords = len(sortedKeywords)
        if debug: print (totalKeywords)

        # print (sortedKeywords[0:(totalKeywords / 3)])

        rake = Rake("SmartStoplist.txt")
        keywords = rake.run(text)
        # print (keywords)
        keywordsList.append(keywords)
    
    return keywordsList

# %% [markdown]
# ### Cleaned Title using Rake Algorithm

# %%
rakeTitle = getWordsOfRakeAlgorithm(list(c_grouped_t))

# %% [markdown]
# ### Cleaned Keyword using Rake Algorithm

# %%
rakeKeyword = getWordsOfRakeAlgorithm(list(c_grouped_k))

# %%
def setRakeInPreWords(rakeList):
    preWords = []
    for r_title in rakeList:
        print(r_title[0][0])
        preWords.append(r_title[0][0])
    return preWords

# %%
rakeKeyword
# Out:
# [[('knowledg knowledge-intens gener wiki process-ori commun structur process cooper',
#    81.0)],
#  [('assur profession studi empir learn train computer-support qualiti workplac cooper',
#    100.0)],
#  [('experience-bas system agent pedagog arrang learn weblog micro-didact space wiki inform',
#    121.0)],
#  [('manag filter knowledg inform collabor method introduct retriev ontolog context-awar busi process model',
#    169.0)],
#  [('manag visual knowledg inform metaphor project commun storytel', 64.0)],
#  [('manag knowledg workflow', 9.0)],
#  [('manag knowledg inter-organiz network collabor busi', 36.0)],
#  [('manag knowledg knowledge-intens descript k-model languag process-ori busi process model',
#    100.0)],
#  [('knowledg manag research market enterpris tool softwar busi process',
#    81.0)],
#  [('manag knowledg theori busi instrument activ work infrastructur stanc process model',
#    121.0)],
#  [('manag knowledg system data base inform', 36.0)],
#  [('process manag knowledg servic', 16.0)],
#  [('prover formal concurr proof atom refin', 36.0)],
#  [('formal develop method atom observ refin', 36.0)],
#  [('asynchron relax verif atom commun process algebra', 49.0)],
#  [('formal compens ing method languag transact long-runn semant specif',
#    81.0)],
#  [('system isol replic broadcast atom quorum', 36.0)],
#  [('formal depend method languag transact atom hardwar program', 64.0)],
#  [('concurr develop transact atom softwar monitor ocl uml', 64.0)],
#  [('cach transact coher atom memori', 25.0)],
#  [('analysi visual mine subgroup data', 25.0)],
#  [('visual reput social network flow inform', 36.0)],
#  [('analysi visual grand tour method cluster curv andrew data exploratori',
#    100.0)],
#  [('data visual mine icon', 16.0)],
#  [('visual segment mine explor connect data', 36.0)],
#  [('incomplet mine decis diagram function minim data specifi', 64.0)],
#  [('domain visual interact tempor data medic inform', 49.0)],
#  [('visual explor techniqu multiresolut data', 25.0)],
#  [('intrus system detect wireless antenna', 25.0)],
#  [('evalu public infrastructur key fuzzi techniqu secur polici', 64.0)],
#  [('audio lsb code hide steganographi data', 36.0)],
#  [('intrus protocol detect abus secur cryptograph comput', 49.0)],
#  [('ad re-key hoc protocol group network dsr rout perform secur commun',
#    121.0)],
#  [('evolutionari algorithm cryptographi co-design addition-chain genet comput',
#    49.0)],
#  [('fair protocol deliveri exchang certifi non-repudi secur', 49.0)],
#  [('system agent qualiti inform multi-ag', 25.0)],
#  [('digit system backup file snapshot consist forens oper checkpoint', 81.0)],
#  [('manag theori perfect algorithm one-tim key pad protect secur inform secreci data',
#    144.0)],
#  [('theori digit system multimedia code librari inform', 49.0)],
#  [('manag theori market game databas resourc inform strategi distribut',
#    81.0)],
#  [('control ded system dynam event synthesi discret', 49.0)],
#  [('life complex architectur system adapt softwar cycl', 49.0)],
#  [('brows collabor web ontolog work', 25.0)],
#  [('cognit agent formula ground languag satisfact modal commun logic', 81.0)],
#  [('rosa mine system recommend web person retriev adapt inform', 81.0)],
#  [('knowledg method consensu conflict inconsist', 25.0)],
#  [('hybrid user system method web-bas adapt consensu interfac', 64.0)],
#  [('dimension queri high databas rang spatiotempor structur data model',
#    81.0)],
#  [('parallel constraint implement time actor execut comput', 49.0)],
#  [('manag protocol rtcp multimedia scalabl commun distribut', 49.0)],
#  [('automat algorithm gener flow test softwar data genet', 64.0)],
#  [('algorithm circuit cad rout global integr', 36.0)],
#  [('structur system multimedia web-bas author applic hypermedia transclus xanalog publish',
#    100.0)],
#  [('fat cube architectur topolog network router collect interconnect commun',
#    81.0)],
#  [('formal autom softwar specif object-ori test', 36.0)],
#  [('system verifi public-key mix-net paillier privaci huffl', 49.0)],
#  [('b2c e-commerc agent technolog ontolog intellig', 36.0)],
#  [('tree uowhf function binari hash', 25.0)],
#  [('check reactiv system modular verif techniqu actor abstract model', 81.0)],
#  [('complex t-decomposit entropi measur pars comput', 36.0)],
#  [('free tree anneal skeleton geometri graph straight simul draw comput',
#    100.0)],
#  [('modular languag semant action oper structur program', 49.0)],
#  [('logic descript arithmet gener languag circuit function hardwar structur program',
#    100.0)],
#  [('coroutin hash virtual closur machin abl compil', 49.0)],
#  [('mop lua dynam reflect aspect aop', 36.0)],
#  [('manag final semant memori collect garbag', 36.0)],
#  [('formal servic web languag semant program', 36.0)],
#  [('interoper languag virtual function haskel machin net compil program',
#    81.0)],
#  [('languag bytecod virtual common runtim machin compil', 49.0)],
#  [('dynam optim just-in-tim compil', 16.0)],
#  [('dataflow function comonad law stream distribut comput', 49.0)],
#  [('analysi equat formal semant execut specif program', 49.0)],
#  [('program languag function haskel mobil comput', 36.0)],
#  [('drift tree decis concept increment data stream', 49.0)],
#  [('mine resource-awar cluster data stream comput', 36.0)],
#  [('intrus resolut detect network secur first-ord logic', 49.0)],
#  [('brows analysi mine usag web semant pattern', 49.0)],
#  [('servic trigger predict qo time qualiti seri stream model', 81.0)],
#  [('mine algorithm single-pass data stream chang', 36.0)],
#  [('drift decis learn classif increment concept rule data stream', 81.0)],
#  [('posit root equat polynomi bound', 25.0)],
#  [('order set partial supremum mathemat construct', 36.0)],
#  [('uniform revers mathemat continu construct', 25.0)],
#  [('analysi function comput', 9.0)],
#  [('cellular automaton omega halt probabl', 25.0)],
#  [('analysi ration function iter construct', 25.0)],
#  [('riesz formal topolog mathemat f-algebra space choic axiom construct',
#    81.0)],
#  [('logic filter intuitionist satur kripk ultraproduct ultrapow prime disjoint bisimul iter union model',
#    169.0)],
#  [('element posit hermitian mathemat banach state space construct algebra',
#    81.0)],
#  [('theori set algorithm sequenc binari inform random', 49.0)],
#  [('analysi theori lattic decid proof', 25.0)],
#  [('formal topolog coequalis predicativit quotient local construct', 49.0)],
#  [('theori set partial principl realiz combinatori brouwerian construct algebra',
#    81.0)],
#  [('caus determin refin construct process algebra', 36.0)],
#  [('markov chain construct', 9.0)],
#  [('regular posit topolog formal relat space real', 49.0)],
#  [('valu function compl databas axiomatis', 25.0),
#   ('depend attribut count', 9.0)],
#  [('continu construct mathemat', 9.0)],
#  [('theori mathemat hilbert space oper construct', 36.0)],
#  [('determinist attractor system languag measur omega-languag function cantor hausdorff space simpl iter fractal',
#    169.0)],
#  [('analysi ration function iter construct', 25.0)],
#  [('analysi intuitionist intermedi perhap valu real theorem', 49.0)],
#  [('order geometri conjectur sylvest construct', 25.0)],
#  [('fine fine-continu sequenc fine-comput function effect space limit weakli recurs fine-sequenti comput',
#    144.0)],
#  [('educ unit collabor languag learn object e-learn model', 64.0)],
#  [('servic system multimedia web-bas web xml semant hypermedia', 64.0)],
#  [('conceptu interact exercis learn author tool', 36.0)],
#  [('interact context awar implicit ubiquit rfid comput', 49.0)],
#  [('teach collabor learn comput simul anim program', 49.0)],
#  [('lcm campu servic web learn object virtual lom author im tool museum scorm e-learn',
#    196.0)],
#  [('diagnosi cognit environ librari learn author tool trace error model',
#    100.0)],
#  [('domot collabor learn computer-support pda mobil comput', 49.0)],
#  [('educ servic multimedia web-bas hypertext/hypermedia internet', 36.0),
#   ('comput', 1.0)],
#  [('metadata annot collabor learn object ontolog', 36.0)],
#  [('small-talk modul packag virtual rubi namespac java classbox class selector',
#    100.0)],
#  [('express modular embed coordin process algebra', 36.0)],
#  [('objectâ\xadorient formal composit object softwar specif', 49.0)],
#  [('compon code composit dynam aspect common orient net servic intermedi runtim assert autonom weav languag web manipul aspect-ori architectur program',
#    400.0)],
#  [('markov decis constraint composit reo coordin automata bisimul probabilist process',
#    100.0)],
#  [('reactiv compon system modular rebeca verif actor model', 64.0)],
#  [('interact type indic myers-brigg human-comput mbti e-learn', 49.0)],
#  [('elearn situat metadata learn', 16.0)],
#  [('user retriev learn object ontolog e-learn context-awar', 49.0)],
#  [('manag interact knowledg user design web-bas factor train usage-cent interfac pattern',
#    121.0)],
#  [('user context learn object e-learn', 25.0)],
#  [('user elearn learn adapt cscl model', 36.0)],
#  [('educ collabor game learn motiv constructiv game-bas', 49.0)],
#  [('teach personalis learn', 9.0)],
#  [('task algorithm schedul constraint graph direct preced distribut', 64.0)],
#  [('multi-dsp system schedul embed flow predict rapid perform data prototyp',
#    100.0)],
#  [('supervis fraud web-bas prevent exam assess secur', 49.0)],
#  [('manag system broker network practic learn commun', 49.0)],
#  [('organiz knowledg mental market capit practic ration retrospect trade-',
#    81.0),
#   ('constructiv intellectu commun bound model', 25.0)],
#  [('manag knowledg node commun distribut', 25.0)],
#  [('knowledg web share semant commun', 25.0)],
#  [('evolut process indigo introduct learn particip eparticip inspect improv distribut',
#    100.0)],
#  [('manag knowledg enterpris content intranet extranet practic e-learnin person technolog commun inform',
#    144.0)],
#  [('studi expert volkswagen telekom practic siemen case deutsch wiko net commun',
#    121.0)],
#  [('manag knowledg organ nebula perspect practic livingom liquid art-shta crystal commun',
#    121.0)],
#  [('visualis manag knowledg web practic semant discoveri commun', 64.0)],
#  [('knowledg trust social etiquett norm sociabl capit tacit practic explicit onlin commun',
#    144.0)],
#  [('system membran complet determin comput', 25.0)],
#  [('bond membran divis ture differenti cell comput', 49.0)],
#  [('evolut antiport system membran symport commun comput', 49.0)],
#  [('natur system entropi comput', 16.0)],
#  [('system membran maximum valu natur comput', 36.0)],
#  [('inhibitor promot univers system', 16.0)],
#  [('gate system revers fredkin conserv energy-bas logic', 49.0)],
#  [('parallel java system simul', 16.0)],
#  [('complex system membran problem bin class clip recogn pack comput', 100.0)],
#  [('membran natur distribut comput', 16.0)],
#  [('human manag knowledg competit advantag resourc integr strateg', 64.0)],
#  [('analysi knowledg audit social network flow map inventori', 64.0)],
#  [('knowledg descript skill match elicit logic', 36.0)],
#  [('disavow knowledg interact visual joint evas commun refus', 64.0)],
#  [('manag knowledg reason web case-bas semant', 36.0)],
#  [('analysi manag research knowledg develop univers process', 49.0)],
#  [('analysi manag research knowledg social distribut implement network collabor share practic localis expert appli commun strategi sustain',
#    289.0)],
#  [('knowledg metadata agreement share', 16.0)],
#  [('analysi formal semant concept relat databas lexic', 49.0)],
#  [('analysi formal graph search concept bipartit breadth', 49.0)],
#  [('mine lattic web retriev concept credo inform', 49.0)],
#  [('diagram automat layout lattic', 16.0)],
#  [('implic complex comput base', 16.0)],
#  [('analysi visual formal lattic mobil landmark vision concept local orient autonom galoi robot comput',
#    196.0)],
#  [('logic fil tableau automat check graphic method tempor buechi on-the-fli verif futur automata gil interv specif model',
#    289.0)],
#  [('abstract formal mac hine method notat sequenti commun uml process',
#    100.0)],
#  [('theori formal set reason autom heurist otter specif', 64.0)],
#  [('order formal decis sat search backtrack cnf verif partit heurist variabl bdd',
#    144.0)],
#  [('check formula implic combin sat boolean proposit static equival satisfi cec logic',
#    144.0)],
#  [('analysi model check decis diagram sat binari satisfi bmc reachabl bound bdd',
#    144.0)],
#  [('dag heurist check decis diagram state machin binari satisfi bound model',
#    121.0)],
#  [('check boolean atpg equival satisfi', 25.0)],
#  [('test object-ori softwar coverag', 16.0)],
#  [('multimedia compon system framework', 16.0)],
#  [('interact architectur service-ori servic composit web coordin connector softwar comput',
#    100.0)],
#  [('engin rewrit revers migrat rule data pattern', 49.0)],
#  [('servic portlet portal develop web component-bas applic', 49.0)],
#  [('engin agent system multi-ag methodolog softwar intellig agent-ori', 64.0)],
#  [('design process method softwar', 16.0)],
#  [('analysi manag resolut requir winwin negoti multi-criteria conflict inconsist prefer',
#    100.0)],
#  [('domain-specif evolut modular languag develop processor markup softwar approach mainten xml',
#    121.0)],
#  [('list conceptu knowledg visual annot link document digit hyperwav portal-system black librari search white futur activ repositori e-learn',
#    324.0)],
#  [('system design embed object_ori hardware/softwar processor application_specif synthesi highlevel instruct',
#    100.0)],
#  [('protocol formal method symbol bisimul noninterfer equivalence-check process algebra',
#    81.0)],
#  [('neural lempel-ziv network predict compress lossless two-stag', 49.0)],
#  [('cellular plane hyperbol automata', 16.0)],
#  [('collis root hash mod cyclic scatter primit techniqu storag prime full residu group strategi tabl',
#    225.0)],
#  [('system rewrit tissu grammar univers matrix comput', 49.0)],
#  [('semant oper', 4.0), ('picalculu', 1.0)],
#  [('function boolean decomposit equat', 16.0)],
#  [('system grid index file data multi-dimension structur spatial model',
#    81.0)],
#  [('warehous tempor relat databas algebra self-mainten data logic', 64.0)],
#  [('interschema properti sourc integr xml inform', 36.0)],
#  [('coroutin control lua gener languag structur', 36.0)],
#  [('relat coalgebra model coordin', 16.0)],
#  [('logic concurr rewrit modular languag ml semant program', 64.0)],
#  [('coordin atom concern action aspect-ori distribut program', 49.0),
#   ('handl separ', 4.0)],
#  [('combin explicit function categor substitut program', 36.0)],
#  [('script interoper languag reflect', 16.0)],
#  [('languag tactic definit middlewar distribut program', 36.0)],
#  [('function program', 4.0)],
#  [('visual design environ develop redwood tool softwar snippet drag-and-drop program',
#    100.0)],
#  [('metaprogram transform gener framework tool java refactor object-ori program',
#    81.0)],
#  [('reactiv system concurr design modular action', 36.0)],
#  [('graph refin architectur abstract', 16.0)],
#  [('architectur transform driven model graph model-integr comput', 49.0)],
#  [('protocol model-check verif time parametr', 25.0)],
#  [('model transform graph develop model-bas verif softwar comput', 64.0)],
#  [('prove refin theorem', 9.0)],
#  [('logic check system design tempor multi-object object verif model', 81.0)],
#  [('transform equat reason ultra develop non-determinist function unfold-fold heapsort specif construct program',
#    144.0)],
#  [('tempor system-level verif simul emul logic', 36.0)],
#  [('reliabl verif', 4.0)],
#  [('requir formal constraint diagram verif plc-automata real-tim specif captur',
#    81.0)],
#  [('architectur check gener code implement compil certif correct program',
#    81.0)],
#  [('alia optim dummi verif alias', 25.0)],
#  [('permut optim sgi voc translat valid verif global rule pro condit compil',
#    144.0)],
#  [('independ visual archiv interact inform sign languag retriev map computer-support commun construct',
#    144.0)],
#  [('independ visual archiv inform converg multimedia languag retriev computer-support technolog commun construct',
#    144.0)],
#  [('implic futur societ technolog wearabl pc display comput', 64.0)],
#  [('visual archiv interact multimedia dynam languag retriev map computer-support movi abstract commun inform',
#    169.0)],
#  [('hyperbol cellular plane automata tilt', 25.0)],
#  [('system interschema properti sourc integr inform semi-structur cooper',
#    64.0)],
#  [('audiovisu archiv user engin queri thesauru person search semant mpeg profil faethon',
#    144.0)],
#  [('knowledg manag mine entiti extract map semant relat topic text corpora',
#    121.0)],
#  [('knowledg manag complex theori evolutionari practic semant cognitiv heterogen communit constructiv structur distribut',
#    169.0)],
#  [('manag knowledg train e-learn scenario', 25.0)],
#  [('signal filter weak strategi process', 25.0)],
#  [('manag research knowledg architectur algorithm collabor flow measur problem-centr opencp',
#    100.0)],
#  [('manag metal knowledg system kaon ontolog industri', 49.0)],
#  [('brows carrier context search map topic structur visual bearer key post-structur process domain word knowledg assist manag navig pre-structur busi engin tool base model',
#    576.0)],
#  [('balanc manag knowledg benefit measur scorecard', 36.0)],
#  [('seci manag knowledg cynefin optim scientif gener', 49.0),
#   ('product factor km worker ashen workplac demand', 49.0)],
#  [('knowledg engin product jess ontolog rule plan xml base workflow', 100.0)],
#  [('manag knowledg social capit benchmark resourc cluster intellectu capabl',
#    81.0)],
#  [('manag knowledg prune ontolog structur comput', 36.0)],
#  [('manag knowledg system project develop pilot skill personnel compet',
#    81.0)],
#  [('knowledg capit individu explicit interpret custom integr collect intuit process',
#    100.0)],
#  [('manag knowledg represent skill ontolog matchmak', 36.0)],
#  [('repertori theori organis person measur learn role construct test', 81.0)],
#  [('human manag project skill databas resourc updat plan', 64.0)],
#  [('manag elearn personalis skill hypermedia', 25.0)],
#  [('repertori human manag knowledg theori studi develop grid approach skill techniqu case space competence-perform resourc compet',
#    256.0)],
#  [('manag knowledg transfer skill view resourc profil base compet', 81.0)],
#  [('knowledg problem environ learn skill simul assess structur solv', 81.0)],
#  [('educ manag train skill export portug', 36.0)],
#  [('manag knowledg groupwar awar expertis', 25.0)],
#  [('manag knowledg knowledge-intens organis ontolog memori group compet',
#    64.0)],
#  [('logic check system execution-bas tempor rapid monitor prototyp real-tim execut run-tim model',
#    144.0)],
#  [('domain-specif architectur transform formal model graph languag model-driven grammar model-integr specif comput',
#    144.0)],
#  [('coalgebra formal system design languag semant behavior level denot state-bas specif algebra',
#    144.0)],
#  [('protocol servic admiss interfer denial bisimul equivalence-check', 49.0)],
#  [('formal csp translat grammar specif uml model', 49.0)],
#  [('domain-specif descript embed languag hardwar', 25.0)],
#  [('semant coalgebra compon softwar', 16.0)],
#  [('formal semant action specif object-ori', 25.0)],
#  [('architectur separ adapt concern aop softwar aspect-ori applic program',
#    81.0)],
#  [('resourc mobil process-calculu distribut comput', 25.0)],
#  [('analysi constant optim code graph predic ssa-form data-flow valu propag ia',
#    121.0)],
#  [('system event-ori tupl space distribut program', 36.0)],
#  [('manag count refer memori cycl collect garbag', 49.0)],
#  [('object-ori aspect-ori program', 9.0)],
#  [('xmi meta-model xmlshema ocl xml uml', 36.0)],
#  [('asynchron invoc remot method distribut program', 36.0)],
#  [('infer type languag recurs polymorph program', 36.0)],
#  [('depend type dml match pattern', 25.0)],
#  [('parallel petri languag net fuction program', 36.0)],
#  [('manag knowledg reason web case-bas semant ontolog xml', 64.0)],
#  [('leadership cultur manag knowledg corpor', 25.0)],
#  [('manag knowledg ontolog mainten softwar', 25.0)],
#  [('manag knowledg experi base build block schema reus repositori schemata',
#    100.0)],
#  [('casebas reason retriev softwar reus', 25.0)],
#  [('diagnost knowledg check project measur km strategi integr busi cost-benefit',
#    100.0)],
#  [('cultur evalu user learn style dimens hci-', 49.0),
#   ('adapt softwar academ structur discours model', 36.0)],
#  [('manag knowledg cultur bosch decentr index', 36.0)],
#  [('manag knowledg represent retriev ontolog inform logic', 49.0)],
#  [('queri retriev ontolog refin inform', 25.0)],
#  [('plan manag knowledg risk', 16.0)],
#  [('automata fibrat iwim coordin', 16.0)],
#  [('separ oracl hierarchi function polynomial-tim class', 36.0)],
#  [('experiment user engin studi softwar interfac intellig object-ori model',
#    81.0)],
#  [('human descript cognit system perspect navig rout ellipt spatial', 81.0)],
#  [('constraint tempor granular time abstract', 25.0)],
#  [('theori reason necess tempor measur fuzzi relat approxim allen possibl interv',
#    121.0)],
#  [('transform axi medial reason recognit shape represent qualit spatial',
#    81.0)],
#  [('tableau system tempor axiomat interv logic', 36.0)],
#  [('hierarch analysi descript reason graph case-bas agronomi classif structur spatial logic',
#    121.0)],
#  [('logic reason constraint navig mobil tempor qualit integr autonom robot spatial program',
#    144.0)],
#  [('reason biolog bayesian molecular spatial qualit access', 49.0)],
#  [('rcc gi reason semant qualit data spatial', 49.0)],
#  [('protocol formal interoper wap complianc test', 36.0)],
#  [('wbt manag constructionist learn e-learn', 25.0)],
#  [('analysi model system design method state machin specif abstract comput',
#    100.0)],
#  [('complex predic time-spac implicit recurs class comput', 49.0)],
#  [('manag knowledg document agent system intellig data base inform', 81.0)],
#  [('handl compon system distribut network dinopoli transpar object aspect relat global java componentwar uniqu middlewar robust',
#    256.0)],
#  [('membran hierarchi rewrit chomski splice molecular comput', 49.0)],
#  [('analysi walsh comput', 9.0)],
#  [('cyber e-democraci speech freedom ethic internet legisl', 49.0)],
#  [('societi telecommun technolog internet mobil inform', 36.0)],
#  [('knowledg capit network map relat intellectu report', 49.0)],
#  [('informat search retriev histori legal inform', 36.0)],
#  [('situat manag knowledg absorpt organis interchang capit dynam prior learn capac intellectu capabl',
#    169.0)],
#  [('manag knowledg acquisit collabor languag natur distribut', 49.0)],
#  [('taxonomi knowledg transfer network develop recycl compani agenc sustain',
#    81.0)],
#  [('skill rdf manag ontolog', 16.0)],
#  [('manag knowledg transfer tool', 16.0)],
#  [('posit knowledg manag overload ignor agent document-explos intellig inform',
#    81.0)],
#  [('queri similarity-bas databas multi-criteria imag data oper repositori model',
#    81.0)],
#  [('knowledg manag mine map semant text topic relat corpora', 81.0)],
#  [('epistemolog manag knowledg context node distribut', 36.0)],
#  [('model user feedback queri relev retriev instanc learn memori expans base inform cooper',
#    169.0)],
#  [('manag call interact user knowledg design usage-cent interfac pattern center',
#    100.0)],
#  [('thesauru retriev gazett internet inform', 25.0)],
#  [('experi systemat learn improv process', 25.0)],
#  [('manag knowledg system work inform process', 36.0)],
#  [('knowledg portal ontolog integr inform', 25.0)],
#  [('visual metadata digit collag summar extract librari video', 64.0)],
#  [('formal method object-orient semant uml pv', 36.0)],
#  [('manag inter-domain optim system network vp atm rout qo provis hierarch',
#    121.0)],
#  [('automata languag formal lattic', 16.0)],
#  [('web learn train support mediat base commun strategi comput', 81.0)],
#  [('knowledg research web grid european technolog semant fund comput', 81.0)],
#  [('optim algorithm arithmet inclus affin function global interv bound branch',
#    100.0)],
#  [('tile plagiar string similar search token', 36.0)],
#  [('formal system power lindenmay d0l seri', 36.0)],
#  [('e-set synset wordnet id cluster', 25.0)],
#  [('island control search find rout rule', 36.0)],
#  [('analysi knowledg landscap object-bas topolog represent relat classif reific',
#    81.0)],
#  [('disjunct reason multi-ag qualit multi-dimension spatial', 36.0)],
#  [('interv time granular', 9.0)],
#  [('human np-hard hmi telerobot servic schedul team mobil job interfac machin autonom xml robot problem',
#    225.0)],
#  [('present mental dynam anim model', 25.0)],
#  [('engin system develop languag methodolog softwar hypermedia object-ori',
#    64.0)],
#  [('system trail-bas navig support trail hypermedia open', 49.0)],
#  [('architectur hypermedia structur open comput', 25.0)],
#  [('servic system multimedia web web-bas retriev semant hypermedia mpeg xml content-bas',
#    121.0)],
#  [('engin design techniqu function hypermedia program', 36.0)],
#  [('system hypertext context coher author relat function linguist model',
#    81.0)],
#  [('develop languag retriev natur softwar inform process', 49.0)],
#  [('document notat hypermedia structur xml-base', 25.0)],
#  [('employ interact e-commerc servic negoti onlin', 36.0)],
#  [('formal system coordin pattern multi-ag model', 36.0)],
#  [('complex formal decis languag synchron grammar problem comput', 64.0)],
#  [('word', 1.0)],
#  [('shannon entropi algorithm attribut index partit categor gini cluster median genet',
#    121.0)],
#  [('tree set complet product automata', 25.0)],
#  [('complex descript formal reliabl cellular languag parser finit automata ambigu pushdown softwar nondetermin',
#    169.0)],
#  [('properti invari random', 9.0)],
#  [('word dens closur primit oper base residu', 49.0)],
#  [('regular nx shuffl product languag decomposit src img', 64.0)],
#  [('formal code petri languag net', 25.0)],
#  [('synchron finit automata', 9.0)],
#  [('regular error-detect delay decid languag decod transduc channel uniqu error-correct',
#    100.0)],
#  [('disjunct word infinit ultim uniformli recurr random period', 64.0)],
#  [('plane hyperbol tile', 9.0)],
#  [('antiport membran symport univers molecular comput', 36.0)],
#  [('domain complex composit synchron automata finit function', 49.0)],
#  [('complex set entropi subword languag dens nowher', 49.0)],
#  [('determinist algorithm finit automata minim acycl construct', 49.0)],
#  [('fix power complet point iter seri semir', 49.0)],
#  [('tla reactiv formal system tool time real specif anim', 81.0)],
#  [('engin computer-aid librari softwar', 16.0)],
#  [('reusabl proof synthesi softwar program', 25.0)],
#  [('attribut gener term graph declar grammar travers program', 64.0)],
#  [('analysi check formal system verif real-tim model', 49.0)],
#  [('logic control check formal diagram develop event verif tool process model',
#    121.0)],
#  [('formal decis arithmet affniz verif augment lemma presburg specul univers integ procedur',
#    144.0)],
#  [('check system ws1 verif parameter abstract model', 49.0)],
#  [('model formal system relview relat algebra equival deriv class program',
#    100.0)],
#  [('tla diagram tempor verif refin abstract logic', 49.0)],
#  [('logic interact optim check program tempor proof verif prove techniqu theorem algebra invari specif structur correct model',
#    289.0)],
#  [('coalgebra method binari modal specif logic', 36.0)],
#  [('educ system web-bas learn train distanc teacher assess program', 81.0)],
#  [('situat environ collabor learner person learn coordin histori', 64.0)],
#  [('call assist transmiss learner languag learn co-edit voic corpu comput',
#    100.0)],
#  [('visual collabor languag represent learn bia', 36.0)],
#  [('writin call environ web-bas efl learn linguist corpu', 64.0)],
#  [('balanc parallel load high perform processor comput', 49.0)],
#  [('complex petri symmetri net comput', 25.0)],
#  [('manag knowledg environment system issu', 25.0),
#   ('poverti databas world inform', 16.0)],
#  [('minimum-weight triangul set polygon geometri skeleton combinatori point data base comput',
#    121.0)],
#  [('manag telecommun servic network ip', 25.0)],
#  [('educ scienc curriculum women breadth comput', 36.0)],
#  [('geometri design differenti surfac geometr reconstruct', 36.0)],
#  [('digit document recognit graphic librari pattern electron inform comput',
#    81.0)],
#  [('software/program transform reusabl verif synthesi softwar compil program',
#    64.0)],
#  [('educ record annot algorithm system multimedia author anim captur present',
#    100.0)],
#  [('internet secur', 4.0)],
#  [('manag knowledg search retriev databas mpeg content-bas', 49.0)],
#  [('system social multimedia behavior scienc autom inform offic', 64.0)],
#  [('societi knowledg develop european economi inform union sustain', 64.0)],
#  [('manag human knowledg superorgan organ system resourc non-explicit', 64.0)],
#  [('manag visual interact knowledg digit content human-comput librari media higher-ord inform paradigm',
#    144.0)],
#  [('manag edg environ collabor knowl virtual support work inform captur comput',
#    121.0)],
#  [('technolog standard metadata learn', 16.0)],
#  [('manag knowledg digit system librari person inform', 49.0)],
#  [('portal knowledg ontolog', 9.0)],
#  [('manag knowledg inform system', 16.0)],
#  [('manag knowledg cognit elearn learn creativ', 36.0)],
#  [('manag knowledg', 4.0)],
#  [('formal gener calculu method test-cas refin test', 49.0)],
#  [('method formal engin softwar', 16.0)],
#  [('formal method languag semant denot vdl definit oper vdm', 81.0)],
#  [('formal engin method support tool softwar vdm', 49.0)],
#  [('logic theori intuitionist vdm mathemat topo construct model', 64.0)],
#  [('engin revers semant slice denot algebra program', 49.0)],
#  [('architectur parallel high perform memori data distribut comput', 64.0)],
#  [('educ deliveri multimedia teach mix materi virtual mode univers cours comput',
#    121.0)],
#  [('system decid lindenmay equival problem', 25.0)],
#  [('cue computer-medi inform nonverb social frequenc develop durat messag ation impress social-emotion-ori commun process model',
#    225.0)],
#  [('neural network state machin abstract distribut comput', 49.0)],
#  [('descript formal sdl languag semant fdt techniqu asm state machin specif abstract',
#    144.0)],
#  [('formal gener method sequenc state machin abstract test', 64.0)],
#  [('asml parallel partial thesi synchron submachin asm state machin updat abstract',
#    121.0)],
#  [('diagram dynam compil theorem logic proof commut transit state simul data refin interact system prove cerif ment abstract correct machin forward',
#    441.0)],
#  [('falko asm-workbench state machin abstract', 25.0)],
#  [('foundat dynam languag state machin modal specif abstract logic', 81.0)],
#  [('requirements/specif cach share memori multiprocessor', 25.0)],
#  [('educ complex np-complet graph comput', 25.0)],
#  [('server hyperwav transclus inform', 16.0)],
#  [('matrix parikh map inject', 16.0)],
#  [('theori learn', 4.0)],
#  [('complex theori count ture altern machin class comput', 64.0)],
#  [('tailor groupwar cscw', 9.0)],
#  [('control decompress multimedia specul extens smt video mpeg simultan multithread',
#    100.0)],
#  [('complex rout fpga resourc hardwar reconfigur comput', 49.0)],
#  [('societi complex inform', 9.0)],
#  [('educ societi manag system inform comput', 36.0)],
#  [('chemistri electron undergradu curriculum academ structur comput', 49.0)],
#  [('educ conscious collabor embed softwar assess oper improv accredit continu life revers support reengin case work',
#    256.0),
#   ('knowledg theori manag system methodolog portfolio cycl busi engin hierarchi product oss tool model',
#    196.0)],
#  [('knowledg multi-expert visual life-long-learn system scientif languag sysem base inform construct',
#    121.0)],
#  [('concurr system x-machin channel', 16.0), ('commun process', 4.0)],
#  [('teleport visualis conceptu wide hierarchi glass context web search focu navig hypermedia world treeworld large-scal relev structur model',
#    324.0)],
#  [('manag visual knowledg environmet system data base inform', 64.0)],
#  [('gateway sql server perform cgi www java rdbm api', 81.0)],
#  [('algorithm lattic fold hp approxim protein model', 49.0)],
#  [('light requir control studi asm case refin', 49.0)],
#  [('requir formal engin verif techniqu tool softwar specif', 64.0)],
#  [('requir formal tempor object-orient real-tim specif problem logic', 64.0)],
#  [('requir formal engin system embed real-tim refin specif', 64.0)],
#  [('light control requir formal system model languag execut state-bas prototyp specif simul specification-bas',
#    169.0)],
#  [('requir specif engin pv', 16.0)],
#  [('theori learn', 4.0)],
#  [('align par product mdl sing languag compress unif natur syntax mml multipl inform',
#    169.0)],
#  [('cryptographi s-box boolean nonhomomorph function cryptanalysi', 36.0)],
#  [('analysi control architectur design perform aid multiprocessor structur',
#    64.0)],
#  [('theory-barri analysi algorithm spin synchron competit perform wait time producer_consum block lock',
#    144.0)],
#  [('superscalar architectur latenc dataflow decoupl memori multithread',
#    49.0)],
#  [('system rapid msparc real-tim prototyp multithread', 36.0)],
#  [('formal system rewrit languag regul grammar program', 49.0)],
#  [('incomplet complex time linear comput', 25.0)],
#  [('wbt manag knowledg elearn teach web base', 49.0)],
#  [('notat specif formal structur', 16.0)],
#  [('tessel hyperbol cellular plane automata', 25.0)],
#  [('constraint uncertainti comput interv logic', 25.0)],
#  [('switch horsesho system smale map henon baker', 49.0)],
#  [('system gener code constraint petri dynam behavior net inform', 81.0)],
#  [('compar protocol leader formal elect studi concurr network method standard case',
#    121.0)],
#  [('model noninterferen program properti confidenti flow intransit verif techniqu noninterfer secur specif inform ce',
#    196.0)],
#  [('formal system distribut method object-orient open specif uml pv', 81.0)],
#  [('pre formal depend post-condit heapsort invari specif agent-ori model',
#    81.0)],
#  [('complex geometri path motion plan optimis', 36.0)],
#  [('logic transform embed method function algebra program', 49.0)],
#  [('formal system method verif real-tim specif algebra', 49.0)],
#  [('analysi termin function interpret abstract program', 36.0)],
#  [('categori theori logic', 9.0)],
#  [('monoid lattic mv wajsberg boolean pseudo-wajsberg pseudo-mv residu center algebra',
#    100.0)],
#  [('concurr img process calculu graphic represent semant src machin net multiset abstract',
#    144.0)],
#  [('frequent set item closur connect support extend galoi', 64.0)],
#  [('coher behaviour equival hidden algebra', 25.0)],
#  [('pseudo-boolean optim set horn boolean function binari truth', 64.0)],
#  [('v-algebra monad mv-algebra pavelka algebra', 25.0)],
#  [('parallel type program categori semiring network mix relat enrich data abstract algebra',
#    144.0)],
#  [('kraft inequ prefix-fre set', 16.0)],
#  [('permut automorph graph hypercub group', 25.0)],
#  [('mvn n-valu lukasiewicz-moisil algebra', 16.0)],
#  [('logic substructur implic kripke-typ semant strict canon relev linear model',
#    100.0)],
#  [('graph complementar principl finit automata shift sofic', 49.0)],
#  [('logic languag boolean thought algebra', 25.0)],
#  [('system splice univers rule comput model', 36.0)],
#  [('s-order quasi-ord semir', 9.0)],
#  [('extractor function sourc random hash bit', 36.0)],
#  [('tableau transform deduct proof search autom calculi present', 64.0)],
#  [('data instanti solut structur restructur hierarch', 36.0),
#   ('set normal databas form non-', 25.0)],
#  [('logic analysi algorithm design simul average-cas', 36.0)],
#  [('permut theori revers group comput', 25.0)],
#  [('arithmet geometri precis divis exact float librari point multipl expans comput',
#    121.0)],
#  [('cryptographi scheme share secret data secur random', 49.0)],
#  [('cach network pre-fetch www wireless proxi mobil comput', 64.0)],
#  [('align reason compress unif multipl inform probabilist', 49.0)],
#  [('specif system process languag x-machin state softwar matrix commun stream test',
#    121.0)],
#  [('product languag synchronis pictur', 16.0)],
#  [('complex hyperbol theori cellular plane automata', 36.0)],
#  [('parallel automata partit decomposit time state clock', 49.0)],
#  [('tree languag dna comput', 16.0)],
#  [('transform fault failur verif toler specif model', 49.0)],
#  [('markov tree cision fault shannon net diagram petri approach binari de',
#    121.0)],
#  [('life gener uniform composit method ratio time procedur comput', 81.0)],
#  [('experiment algorithm code exact heurist constant-weight solut bounded-weight error-correct',
#    81.0)],
#  [('posit np complex ture reduct comput', 36.0)],
#  [('algorithm mount pcb assembl multi-head surfac time machin genet', 81.0)],
#  [('tableau deduct durat calculu method autom', 36.0)],
#  [('post theori align system compu ture', 36.0),
#   ('comput machin canon multipl ting paradigm', 36.0)],
#  [('arithmet semigroup embed quasilinear commut space isomorph oper interv bodi convex minkowski',
#    144.0)],
#  [('transform equat arithmet extend solut interv algebra', 49.0)],
#  [('measur uncertainti mathemat comput machin interv co-ordin model', 64.0)],
#  [('analysi evalu multimedia content applic review', 36.0)],
#  [('educ evalu experi multimedia design methodolog scienc curriculum', 64.0),
#   ('comput', 1.0)],
#  [('analysi theori reason knowledge-build collabor implic learn piagetian',
#    64.0),
#   ('condit transcript', 4.0)],
#  [('organiz evalu system design share learn memori inform', 64.0)],
#  [('educ system learn assess electron', 25.0)],
#  [('evalu round method polynomi chebyshev perturb error', 49.0)],
#  [('order complex separ hierarchi queri polynomi commut downward class comput',
#    100.0)],
#  [('multi/mix digit confer multimedia navig map video media hypermedia proceed hypertext inform publish electron',
#    196.0)],
#  [('neural network navig retriev hypertext inform', 36.0)],
#  [('p-select complex comput', 9.0)],
#  [('balanc tree ocpc workload move share work-optim memori simul mesh erew coat random thread',
#    196.0)],
#  [('nonperfect scheme secret share', 16.0)],
#  [('navig web search retriev text hypertext inform categoris', 64.0)],
#  [('visual user document retriev result rank interfac inform present', 81.0)],
#  [('script web page dynam languag cgi', 36.0)],
#  [('adapt softwar integr quadratur cubatur', 25.0)],
#  [('infer system key relat schema', 25.0)],
#  [('templat engin design revers search pattern', 36.0)],
#  [('deduct key relat databas autom schema', 36.0)],
#  [('shannon symbol text compress rank', 25.0)],
#  [('programm coprocessor rapid prototyp hardwar pc logic', 49.0)],
#  [('deref type modul borland oberon languag chill pascal object extens assign paramet pass object-ori',
#    196.0)],
#  [('concurr state machin abstract recurs distribut comput', 49.0)],
#  [('shortest path verif constrain softwar state abstract problem machin',
#    81.0)],
#  [('requir check document program code stepwis verif techniqu inspect state machin refin specif abstract model',
#    225.0)],
#  [('visual formal design modular languag montag state machin specif abstract program',
#    121.0)],
#  [('oberon languag montag refer state machin manual specif abstract program',
#    100.0)],
#  [('document code stepwis techniqu inspect state machin refin abstract program',
#    100.0)],
#  [('abstract gener verif semant back-end state machin oper compil', 81.0)],
#  [('filter gather agent-bas system reason memory-bas internet probabilist inform model',
#    100.0)],
#  [('filter knowledg manag life-cycl corpor technolog memori work inform process',
#    100.0)],
#  [('knowledg manag participatori system organis design collabor knowledge-bas argument memori',
#    100.0)],
#  [('manag knowledg studi corpor case memori', 36.0)],
#  [('groupwar design share workspac cscw workflow', 36.0)],
#  [('knowledg formal gener acquisit artifici method languag represent natur interfac intellig process',
#    144.0)],
#  [('knowledg manag system coordin mechan cscw multi-ag', 49.0)],
#  [('filter spread feedback network semant text activ relev', 64.0)],
#  [('automat system paperfold uniform sequenc tag', 36.0)],
#  [('evalu teach web-bas coursewar learn train techniqu', 49.0)],
#  [('educ d-ari overflow arithmet correct proof scienc test comput', 81.0)],
#  [('control applic discretionari cryptographi databas data secur polici object-ori access',
#    100.0)],
#  [('free placement space algorithm', 16.0)],
#  [('boolean function resili cryptolog nonlinear', 25.0)],
#  [('monstr term rewrit graph languag intermedi semant model', 64.0)],
#  [('instruction-level depend parallel schedul graph assign alloc processor',
#    64.0)],
#  [('filter algorithm process genet imag stack distribut comput', 64.0)],
#  [('theori cryptosystem code inform error-correct', 25.0)],
#  [('pram chain multithread vliw', 16.0)],
#  [('cultur research forum failur neg result fnr progress', 64.0)],
#  [('abstract protocol formal gurevich key method verif kerbero state machin secur refin specif distribut',
#    196.0)],
#  [('basic foundat formal document telecommun sdl system semant state machin execut specif abstract',
#    169.0)],
#  [('interv specif arithmet', 9.0)],
#  [('evalu type parallel algorithm queri develop methodolog text categor softwar data structur',
#    144.0)],
#  [('system rewrit term modular confluenc persist', 36.0)],
#  [('bishop dirichlet problem mathemat hilbert space construct', 49.0)],
#  [('tt-complet set chaitin wtt-complet number', 25.0)],
#  [('kraft huffman tree optimum prefix code inequ extend', 64.0)],
#  [('incomplet minim automata', 9.0)],
#  [('order decid monad well-quasi-ord', 16.0), ('logic', 1.0)],
#  [('set hierarchi graph obstruct polynomi minor', 36.0)],
#  [('variable-length code encod represent decod t-code', 36.0)],
#  [('properti invari random', 9.0)],
#  [('infinit set close sequenc map measur cantor comput', 64.0)],
#  [('logic model complet kripk intermedi jump oper comput', 64.0)],
#  [('map mathemat pointwis sequenti continu linear construct', 49.0)],
#  [('agent flow arrow belief oper modal commun inform logic', 81.0)],
#  [('hypermedia structur system model', 16.0)],
#  [('theori optim parallel queri learn equival membership dfa comput', 81.0)],
#  [('permut cryptographi s-box attack differenti box linear substitut', 64.0)],
#  [('engin document multimedia teach technolog distanc integr electron inform comput',
#    100.0)],
#  [('educ design film televis distanc instruct', 36.0)],
#  [('free design thesi linux circuit asic unix integr softwar diploma pc',
#    121.0)],
#  [('system multimedia teach develop distanc onlin media publish', 64.0)],
#  [('knowledg inform gather system agent data retriev internet broker distribut',
#    100.0)],
#  [('complex network combin boolean measur function monoton', 49.0)],
#  [('disjunct word properti represent period ration invari number normal',
#    81.0)],
#  [('triangul rotat edge-flip flip distanc oper', 36.0)],
#  [('educ cscw cai teach hyperwav web author hm-card distanc www softwar hyper-',
#    144.0),
#   ('cbt', 1.0)],
#  [('educ groupwar studi cooper classroom support scienc case work electron comput',
#    121.0)],
#  [('formal parallel system rewrit languag k-limit', 36.0)],
#  [('synchronis code string t-code decomposit recurs t-augment redund effici',
#    81.0)],
#  [('parallel program coursewar vision onlin world-wide-web comput', 49.0)],
#  [('educ literaci document evaluation/methodolog multimedia design hypertext web system prepar scienc world-wid',
#    144.0),
#   ('inform comput', 4.0)],
#  [('model system squar arithmet kinet enzym uncertainti valid verif approxim interpol comput manipul',
#    169.0),
#   ('interv algebra', 4.0)],
#  [('number system reason implic quantifi fuzzi approxim approach linguist inform',
#    100.0)],
#  [('comparison sequenc dna biolog fpga vlsi hardwar', 49.0)],
#  [('monstr term rewrit graph languag intermedi semant model', 64.0)],
#  [('system hierarchi rewrit languag regul chomski dna splice famili molecular abstract recombin genet',
#    169.0)],
#  [('effectiv set complet function pseudosimpl extension bound', 49.0)],
#  [('formal system languag grammar team', 25.0)],
#  [('gopher link system hypertext internet www hyper-', 49.0),
#   ('consist scalabl p-flood inform distribut', 25.0)],
#  [('encrypt cryptographi s-box boolean sac function propag characterist nonlinear',
#    81.0)],
#  [('visualis interact system graphic internet hypermedia inform', 49.0)],
#  [('societi cultur web aspect histori www world-wid sgml', 64.0)],
#  [('gopher system internet inform distribut', 25.0)],
#  [('algorithm graph biconnect st-number distribut', 25.0)],
#  [('system geometri elimin polynomi differenti prove decomposit mechan triangular',
#    81.0),
#   ('theorem', 1.0)],
#  [('digit teach cbt learn librari support technolog cai instruct electron',
#    100.0)],
#  [('algorithm public design high key cryptographi testabl speed multipli hardwar',
#    100.0)],
#  [('system xanadu network hyper-', 16.0),
#   ('www internet hypermedia inform', 16.0)],
#  [('equat arithmet partial float method finit differenti numer propag point differ error',
#    144.0)],
#  [('theori system arithmet ration lexicograph number continu fraction comput',
#    81.0)],
#  [('on-lin super-scal accur reliabl arithmet precis high-radix vliw credibl',
#    81.0)],
#  [('analysi arithmet manipul algebra interv error comput', 49.0)],
#  [('on-lin fraction digit set arithmet number represent interv continu redund comput',
#    121.0)],
#  [('ieee handl arithmet implement', 16.0), ('standard comput', 4.0)],
#  [('arithmet function comput elementari reduct rang', 36.0)],
#  [('grammar life artifici system', 16.0)],
#  [('multimedia queri network navig home imag store hypermedia distribut',
#    81.0)],
#  [('gif debat compuserv softwar unisi internet patent lzw', 64.0)],
#  [('concurr monstr term rewrit graph network serialis simul pi-calculu process',
#    100.0)],
#  [('balanc system cach load network perform file distribut', 64.0)],
#  [('command assist agent electron pad predict search messag exampl voic program',
#    121.0)],
#  [('cube theori tile wang aperiod mathemat automata machin sequenti discret',
#    100.0)],
#  [('automat link mainten data hypermedia model', 36.0)],
#  [('teach coursewar whiteboard distanc hypermedia electron', 36.0)],
#  [('featur agent-interact constraint distribut problem sign coordin negoti multiag strategi solv cooper',
#    144.0)],
#  [('free word formal context languag map l-system parikh problem', 81.0)],
#  [('ai parallel qsim constraint satisfact distribut', 36.0)],
#  [('control anonym access authent big secur', 36.0), ('brother', 1.0)],
#  [('complex blank-endmark chaitin string random self-delimit', 36.0)],
#  [('estim digit radix high divis approxim', 36.0)],
#  [('tree share work-optim memori simul mesh erew coat random', 81.0)],
#  [('shuffl system chomski grammar oper', 25.0)],
#  [('educ', 1.0), ('comput', 1.0)],
#  [('arithmet code lz vector text compress quantis', 49.0)],
#  [('understand affin match imag fusion registr inform spatial', 64.0)],
#  [('evolutionari optim algorithm network-on-chip map multi-object system-on-chip simul',
#    64.0)],
#  [('algorithm cryptographi s-box multi-object evolv hardwar genet optimis',
#    64.0)],
#  [('tree fault neural decis program network hardwar monitor intellig electron genet comput',
#    144.0)],
#  [('filter transconduct optim leapfrog algorithm evolutionari design method circuit search multi-object classic pattern genet amplifi oper problem electron',
#    324.0)],
#  [('evolutionari multius algorithm code divis detect access multipl genet comput',
#    100.0)],
#  [('formal reactiv system tempor altern verif automata time assert monitor run-tim specif seri logic',
#    196.0)],
#  [('arithmet revers circuit oper multipli comput', 36.0)],
#  [('hierarchi complet domat exact uncolor boolean minim color number', 81.0)],
#  [('human inform system issu pervas devic societ technolog portabl health expert process',
#    144.0)],
#  [('system environ artifici smart multiag intellig', 36.0)],
#  [('automat diagnosi micro-kernel embed sensor arrhythmia wireless real-tim cardiac telemedicin ecg',
#    121.0)],
#  [('agent devic context-awar technolog mobil telemedicin comput', 49.0)],
#  [('provis servic smart-hom web-bas behavior technolog care monitor telemedicin',
#    81.0)],
#  [('cancer record patient confidenti languag computer privaci natur health secur bioinformat process electron',
#    169.0)],
#  [('jini agent healthcar pervas home comput', 36.0)],
#  [('healthcar privaci qualiti privacy-awar ubiquit comput', 36.0)],
#  [('mosaic interact visual rfid context awar implicit ubiquit inform comput',
#    100.0)],
# ...
#    121.0)],
#  [('applic languag interfac program', 16.0)],
#  [('analysi slice function program', 16.0)],
#  [('infer overload type system close constrain open world approach polymorph',
#    100.0)],
#  [('semant action formal object-ori', 16.0)],
#  [('selecti manag knowledg algorithm servic web resourc ws qualiti', 81.0)],
#  [('semant choreographi servic', 9.0)],
#  [('manag knowledg descript compet creation represent skill e-learn logic',
#    81.0)],
#  [('programm engin design develop learn instruct compet', 49.0)],
#  [('link annot similar typed-link futur index citat', 49.0)],
#  [('gener learn function approxim attent reinforc', 36.0)],
#  [('scienc educ inform comput', 16.0)],
#  [('transform system entiti combin extract', 25.0), ('stack corpu', 4.0)],
#  [('co-evolut algorithm emerg evolv hardwar commun genet', 49.0)],
#  [('optim quadrat neighborhood search assign swarm variabl particl problem',
#    81.0)],
#  [('algorithm neural process network ph fuzzi neutral recurr genet model',
#    100.0)],
#  [('signal evolutionari neural design cellular network analog circuit process dac',
#    100.0)],
#  [('system network artifici forens secur immun comput', 49.0)],
#  [('manet autoconfigur olsr', 9.0)],
#  [('ad hoc network adapt rout cluster wireless scalabl', 64.0)],
#  [('mpr qualiti local servic network bandwidth avail multi-point flood admiss relay qo olsr ad control optim hoc interfer rout',
#    361.0)],
#  [('vote aggreg network sensor cluster data head energy-effici', 64.0)],
#  [('ad evalu balanc hoc protocol cach load network mobil rout distanc perform ad-hoc energi node on-demand vector effici',
#    324.0)],
#  [('interoper languag virtual function haskel machin net compil program',
#    81.0)],
#  [('hierarch model encrypt bilinear standard identity-bas pair', 49.0)],
#  [('deduct type calculu mathemat natur negationless construct logic', 64.0)],
#  [('geometri video databas data structur comput', 36.0)],
#  [('proxim collabor learn support mobil comput', 36.0)],
#  [('pso sigmoid polygon function centroid approxim', 36.0)],
#  [('metric riemannian similar support machin vector', 36.0)],
#  [('metadata extract learn vector support machin keyword', 49.0)],
#  [('evolutionari mine system algorithm express gene artif rule data meta-rul immun program',
#    144.0)],
#  [('independ densest graph subgraph number eigenvalu', 36.0)],
#  [('reson isoarithm perfect aromat hydrocarbon clar factor polyhex kekul match polycycl structur benzenoid',
#    169.0)],
#  [('theori categori automata rabin-scott behaviour meali final moor sequenti semiautomata',
#    100.0)],
#  [('gray code single-dist', 9.0)],
#  [('complex evolutionari ture network processor machin class', 49.0)],
#  [('steiner tree approxim ratio minimum heurist sweep-lin span', 64.0)],
#  [('hertz hsalmankhan175jek lattic mv mtl nm residu bl generalized-mv wnm algebra generalized-bl divis gener wajsberg pocrim t-norm',
#    289.0),
#   ('bck weak-bl heyt hilbert imtl', 25.0)],
#  [('theori matroid geometri pebbl rigid game hypergraph comput', 64.0)],
#  [('metric regular theori fix mine asymptot proof function nonexpans halpern point iter',
#    144.0)],
#  [('bistabl elementari kroneck set graph irreduc support match adjac total perfect product boolean fulli bipartit stabl indecompos matrix cover',
#    361.0)],
#  [('neural membran system astrocyt spike comput', 36.0)],
#  [('interact protocol type system termin regist languag agapia rv-system voic distribut program',
#    144.0)],
#  [('balanc graph sign', 9.0)],
#  [('metric modular entropi lattic', 16.0)],
#  [('graph geodes theori connect', 16.0)],
#  [('short topolog graph grid connected hamiltonian coeffici', 49.0)],
#  [('coverif co-design slice softwar hardwar program', 36.0)],
#  [('evolut petri reflect softwar net', 25.0)],
#  [('formal servic method web e-bart', 25.0)],
#  [('protocol formal network rebeca method modular verif', 49.0)],
#  [('odedialect languag ontolog translat', 16.0)],
#  [('metadata annot web extract semant ontolog inform', 49.0)],
#  [('visual web semant rank schema', 25.0)],
#  [('queri interoper web retriev semant inform', 36.0)],
#  [('manag knowledg queri languag databas ontolog mediat internet applic distribut',
#    100.0)],
#  [('life annot web nlp scienc semant ontolog cores', 64.0)],
#  [('cscw architectur groupwar asynchron notif collabor synchron simul', 64.0)],
#  [('servic system collabor web learn semant ontolog tool discoveri cscl',
#    100.0)],
#  [('situat interact collabor share learn workspac nomad work model', 81.0)],
#  [('groupwar service-ori servic col unit web labor platform ad-hoc mobil middlewar scenario',
#    144.0)],
#  [('meet upper-lay pattern middlewar electron', 25.0)],
#  [('script architectur design collabor learn integr', 36.0)],
#  [('text segment cluster', 9.0)],
#  [('digit document tool-support web semant prepar history-informat xml tag mediev',
#    100.0)],
#  [('featur recognit confus measur zone mechan matrix metaclass charact',
#    81.0)],
#  [('pattern signatur recognit verif', 16.0)],
#  [('ta da segment document recognit table-form extract handwritten', 64.0)],
#  [('engin document interfer back-to-front show-', 25.0), ('bleed', 1.0)],
#  [('light segment maximum foreground/background restor histor manuscript imag color arab likelihood k-',
#    144.0),
#   ('intens normalis', 4.0)],
#  [('engin document interfer back-to-front show bleed', 36.0)],
#  [('analysi recognit symbol discrimin condit', 25.0)],
#  [('fair protocol public exchang key cryptographi secur', 49.0)],
#  [('cryptographi secur authent', 9.0)],
#  [('exchang graph key notion secur random', 36.0), ('re-', 1.0)],
#  [('transfer oblivi privaci protect commerc electron', 36.0)],
#  [('key-shar unknown key resili agreement bellare-rogaway authent bilater model',
#    81.0)],
#  [('exchang key roam anonym authent', 25.0)],
#  [('certificateless encrypt attack standard malici kgc model', 49.0)],
#  [('fast field arithmet algorithm cryptographi koblitz finit curv cryptograph ellipt',
#    100.0)],
#  [('analysi knowledg social network collabor softwar wiki work', 64.0)],
#  [('ruler carpent algorithm fold approxim problem', 36.0)],
#  [('analysi user gener e-commun content weblog blog', 49.0)],
#  [('interact compens classif advertis model', 25.0)],
#  [('neighbor network voronoi nearest road pine continu', 49.0)],
#  [('traffic analysi user end-to-end experi measur behaviour perform qualiti internet passiv',
#    121.0)],
#  [('market design network bandwidth alloc resourc', 36.0)],
#  [('queu servic cost telric prioriti bitstream over-engin qualiti access model',
#    100.0)],
#  [('call voip delay eigenvector zrtp puzzl challenge-respons srtp comput',
#    81.0)],
#  [('digit servic multimedia ict divid web-bas e-servic broadband access',
#    81.0)],
#  [('incomplet game learn price interdomain stabil inform', 49.0)],
#  [('network bandwidth multiplex reaction cost econom contract competit price effect curv provis statist demand',
#    196.0)],
#  [('analysi reliabl network risk commun', 25.0)],
#  [('secur man-in-the-middle-attack zrtp', 9.0)],
#  [('analysi servic experi object happi qualiti ecosystem holist busi model',
#    100.0)],
#  [('traffic model network plan scenario', 25.0)],
#  [('riesz analysi topolog represent hausdorff space theorem comput', 64.0)],
#  [('analysi multi-represent flowchart multi-funct realiz abstract comput',
#    49.0)],
#  [('real elementari number class liouvil comput', 36.0),
#   ('constant grzegorczyk function euler lower', 25.0)],
#  [('hift topolog type system dynam pressur physic statist comput', 81.0)],
#  [('bloch constant algorithm comput', 16.0)],
#  [('analysi count hierarchi integr weak riemann', 36.0)],
#  [('complex rule real quadratur comput', 25.0)],
#  [('analysi probabilist measur comput', 16.0)],
#  [('higher filter conveni topolog type equilog categori qcb-space space weak limit comput',
#    144.0)],
#  [('nig lemma fan brouwer theorem', 25.0)],
#  [('na mine reason case-bas explan classif text bay pattern data', 100.0)],
#  [('engin server-sid portal develop web technolog java', 49.0)],
#  [('educ conceptu reusabl unit design interoper languag learn framework process model',
#    121.0)],
#  [('educ public scienc bia gender report statist comput', 64.0)],
#  [('formal system process auction english specif multi-ag algebra', 64.0)],
#  [('system retriev rank inform distribut', 25.0)],
#  [('agent algorithm system dynam negoti methodolog alloc wireless resourc channel simul commun strategi multi-ag',
#    196.0)],
#  [('manag trade market agent suppli softwar simul chain multi-ag electron',
#    100.0)],
#  [('ad knowledg hoc agent table-driven aodv network bit-map rout discoveri overhead reduc tabl',
#    169.0)],
#  [('metric evalu system perform multi-ag', 25.0)],
#  [('align social queri network semant propag ontolog', 49.0)],
#  [('system agent integr data prolog-lik comput', 36.0)],
#  [('market reinforc learn simul', 16.0)],
#  [('architectur engin system model-driven softwar component-bas', 36.0)],
#  [('featur gateway mine system compon embed product line decomposit hardwar softwar mainten reus model',
#    196.0)],
#  [('requir optim select softwar cot model', 36.0)],
#  [('understand knowledg engin system revers legaci reus', 49.0)],
#  [('acm architectur servic mismatch web style softwar', 49.0)],
#  [('architectur transform driven crosscut develop aspect concern softwar orient mda model',
#    121.0)],
#  [('gener develop product model-driven line tool softwar deriv program',
#    81.0)],
#  [('servic web product web-bas line applic busi process', 64.0)],
#  [('properti efremovi pre-', 9.0), ('space', 1.0)],
#  [('method lisp object common orient binari meta-program', 49.0)],
#  [('metaobject protocol gener lisp special function', 36.0)],
#  [('metaobject protocol type lisp common clim present', 49.0)],
#  [('context-ori dispatch prototype-bas ambient subject multipl intellig program',
#    64.0)],
#  [('lisp map common object-rel smalltalk', 25.0)],
#  [('reason tempor lisp relat s-languag algebra', 36.0)],
#  [('analysi visual user market stock graphic nasdaq veloc forc interfac data inform',
#    144.0)],
#  [('interact groupwar awar real-tim community-bas', 25.0)],
#  [('interact groupwar design base model', 25.0)],
#  [('groupwar model-bas plastic awar approach shared-knowledg', 36.0)],
#  [('develop groupwar model-driven cscw', 16.0)],
#  [('automat requir interact transform usabl gener code compil sketch model',
#    100.0)],
#  [('metric evalu cognit context method walkthrough usabaipo spanish-speak heurist',
#    81.0),
#   ('usabl', 1.0)],
#  [('automat program ambient smart adapt home natur intellig ubiquit comput',
#    100.0)],
#  [('task model collabor ambient context awar intellig ubiquit comput', 81.0)],
#  [('human interact evalu engin access websit usabl comput', 64.0)],
#  [('knowledg featur select represent retriev learn support classif text preprocess machin data vector inform',
#    196.0)],
#  [('reattempt truncat markovian seamless finit mobil model', 49.0)],
#  [('visual system meet extract retriev multimod inform electron', 64.0)],
#  [('programm neural network core perceptron configur fuzzi fpga ip vhdl multilay hardwar logic',
#    169.0)],
#  [('metadata annot decis scholarli network web make', 49.0), ('mash-', 1.0)],
#  [('metadata repositori share learn object build reus commun structur comput',
#    100.0)],
#  [('ethic engin web search person pagerank privaci bia inform', 81.0)],
#  [('taxonomi knowledg design collabor product web train support author semant tool base instruct e-learn model',
#    225.0)],
#  [('digit multimedia entertain search semant ontolog', 36.0)],
#  [('social content web user-gener platform media mpeg', 49.0)],
#  [('assist web extract applic inform', 25.0)],
#  [('wrapper mine system web autom data inform', 49.0)],
#  [('wrapper tree-edit web crawl distanc hidden', 36.0)],
#  [('web extract page classif cluster data', 36.0)],
#  [('extract ontolog data inform semi-structur', 25.0)],
#  [('visual inform extract block', 16.0)],
#  [('ahead featur composit verif asm', 25.0)],
#  [('metamodel engin languag model-driven asm state simul abstract machin',
#    81.0)],
#  [('formal system embed method verif real-tim state machin specif abstract',
#    100.0)],
#  [('logic model-check predic time state simul real-tim abstract machin',
#    81.0)],
#  [('diagram dynam logic electron theorem commut state simul data refin interact precondit prove weakest purs mondex abstract machin secur forward',
#    400.0)],
#  [('servic composit mediat discoveri process workflow', 36.0)],
#  [('protocol induct goal method verif threat model', 49.0)],
#  [('architectur composit modular measur adapt coordin coupl softwar reus commun',
#    100.0)],
#  [('compon program adapt softwar logic', 25.0)],
#  [('compon system mismatch composit behaviour valid adapt transit aspect-ori interfac run-tim program',
#    144.0)],
#  [('interact pattern cc adapt extend aspect-ori machin softwar state specif uml program',
#    144.0)],
#  [('techniqu web engin adapt', 16.0)],
#  [('m-interact knowledg complex system meta-synthesi open intellig m-space process',
#    81.0)],
#  [('brows assist agent method web learn increment softwar statist', 81.0)],
#  [('mine market agent pattern microstructur data surveil', 49.0)],
#  [('wpki parti non-repudi secur mobil', 25.0), ('trust agent', 4.0)],
#  [('balanc deliveri algorithm cach load content network divid scope', 81.0)],
#  [('e-busi studi agent case plan report deploy multi-ag', 64.0)],
#  [('traffic optim system citi ligh multi-ag model', 49.0)],
#  [('posit lb tree fingerprint decis method ubiquitous-campu', 49.0)],
#  [('search semanti ontolog inform meta', 25.0)],
#  [('shop graphic flow search salesman tabu travel hardwar', 64.0)],
#  [('segment layer evolut set multi-lay termin level imag curv criterion',
#    100.0)],
#  [('system network learn fuzzi classif bayesian machin genet logic', 81.0)],
#  [('steiner tree evolutionari algorithm path-relink prize collect transgenet problem',
#    81.0)],
#  [('hybrid optim algorithm schedul problem network genet bu', 64.0)],
#  [('quantum finit assign state machin problem comput', 49.0)],
#  [('optim multiobject network sensor metaheurist', 25.0)],
#  [('algorithm optim search genet', 16.0)],
#  [('featur theori optim set rough select two-step ant coloni swarm intellig particl problem',
#    169.0)],
#  [('optim evolut parallel stochast cell combinatori cluster vlsi metaheurist placement simul comput',
#    144.0)],
#  [('system emerg recommend e-learn swarm intellig multi-ag', 49.0)],
#  [('diagnost decis system error e-health individu support dss bay rate base inform intervent theorem',
#    196.0)],
#  [('interact human-comput', 4.0)],
#  [('ergonom evalu cognit interfac', 16.0)],
#  [('interact market phone usag human-comput sociolog factor computer-support breath mediat varieti determin mobil intens work cooper',
#    256.0)],
#  [('human interact user interfac cscw mobil ubiquit comput', 64.0)],
#  [('engin develop web support access tool applic process', 64.0)],
#  [('ergonom user cognit design interfac', 25.0)],
#  [('educ mine adapt support author data applic hypermedia', 64.0)],
#  [('rdf evalu metadata educ desktop ad semi-automat adapt author semant caf hypermedia',
#    144.0)],
#  [('domain system tutor author ontolog constraint-bas intellig model', 64.0)],
#  [('design graph sequenc learn translat im', 36.0)],
#  [('task schedul collabor ambient author activ space social-awar hypermedia intellig comput',
#    121.0)],
#  [('educ metadata user templat guidelin design elearn web learn object adapt semant standard activ pedagogi model',
#    256.0)],
#  [('educ cultur system cae adapt hypermedia', 36.0)],
#  [('environ game learn adapt author tool base e-learn', 64.0)],
#  [('understand analysi architectur mine document digit librari imag softwar',
#    81.0)],
#  [('evalu digit content languag format librari convers migrat xml file plan characteris preserv',
#    169.0)],
#  [('svm featur neural network classif crime scene', 49.0)],
#  [('author pattern recognit verif', 16.0)],
#  [('analysi resolut document ultra recognit hmm web retriev index text imag low',
#    144.0)],
#  [('depend document network stack structur', 25.0)],
#  [('evalu document binar imag process', 25.0)],
#  [('grid cluster imag load-balanc process', 25.0)],
#  ...]

# %% [markdown]
# ### Rake Title

# %%
rakeTitle = setRakeInPreWords(rakeTitle)
# Out:
# process-ori commun structur integr
# outcom interact small factor synchron learn onlin accept workplac determin group
# knowledg share learn weblog space
# manag knowledg architectur pre-built implement method space orient inform process model
# evalu visual transfer knowledg project map long-term applic tube
# manag knowledg activity-bas system reconcil approach workflow
# human toolkit knowledge-intens organis design network factor methodolog km technolog integr
# knowledge-intens process kmdl improv analys busi captur
# knowledg manag enterpris role solut busi process
# knowledg design work infrastructur model
# knowledg call-centr hierarchi infrastructur process model
# manag knowledg servic orient approach base process
# non-block concurr algorithm queue formal construct
# observ investig atom
# asynchron consid verifi relax atom case mechan commun correct
# compens precis transact bpel applic busi model
# understand system replic broadcast atom advantag quorum
# manifesto atom
# develop softwar atom
# first-class atom system provis
# visual mine semi-automat subgroup vikamin
# visual social recommend flow network
# orthogon high-dimension curv data
# mine system lite-weight integr data oper ubiquit gui
# visual segment mine decis interact explor connect rule data
# incomplet visual uncertain decis depend diagram manipul
# visual interact highli gravi tempor explor data inform structur
# explor multiresolut scalabl data
# intrud wireless locat physic
# evalu fuzzi techniqu level refer secur polici model
# audio distort lsb code increas steganographi reduc robust
# intrus protocol detect embed protomon prevent monitor cryptograph
# slide protocol group network window ad-hoc secur commun
# software/hardwar co-design hardwar secur cryptograph effici
# signatur rsa-bas e-good deliveri verifi encrypt certifi
# assur system combin explor lazi open sourc qualiti space inform multi-ag
# low-intrus digit disk tool checkpoint consist forens
# transfer network scheme data secur comput
# analysi gossip pirat fingerprint code trace erasur construct
# problem creation game databasesa profil inform distribut
# control ded method synthesi applic
# complex system implic develop softwar structur tendenc
# brows user collabor web extract semant bookmark interest base
# intern cognit agent ground languag relat structur problem
# hybrid queri recommend
# knowledg semant level inconsist process
# hybrid user system web adapt interfac consensus-bas
# model retriev provabl approxim comput spatiotempor effici
# time actor cost comput
# analysi evalu control protocol design scheme perform ms-rtcp real-tim scalabl
# automat algorithm gener flow test data
# estim theoret rout upper bound
# document multimedia html transclus fine-grain
# cube complex fat topolog commun collect
# formal framework autom testaf
# cryptosystem shuffl verifi variant paillier provabl secur base effici
# b2c agent marketplac virtual exploit ontolog
# domain tree algorithm uowhf finit extend binari
# check composit rebeca verif autom abstract model
# fast t-decomposit algorithm
# free tree polygon simpl insid bound draw
# definit languag construct approach
# design function match hardwar perfect program
# implement lua
# aspectlua dynam aop approach
# semant formal final
# servic web languag build interfac pew
# languag platform function compil net nonâ­strict
# script run lua clr translat bytecod
# evalu experiment technolog jit java
# signal comonad
# scheme languag specif equat
# pure languag function mobil mhaskel comput
# tree decis dynam learn data stream
# data resource-awar mine stream
# alert mine id network extract attack categor stream scenario
# mine usag web request semant preprocess stream
# trigger time qualiti condit seri stream
# mine append-onli item dynam onlin data continu stream chang
# select learn numer border increment exampl rule data stream
# posit root polynomi bound
# suprema construct
# uniform equival continu construct theorem
# spectrum oper self-adjoint comput
# algorithm cellular irreduc automata univers
# analysi ration function iter construct
# formal gelfand stone-yosida topolog represent mathemat construct theorem
# axiomat intuitionist class model
# element posit banach space state algebra firm
# sequenc random nonrandom
# permut linear rule lattic
# topolog formal coequalis quotient space
# theori set principl brouwerian construct
# construct process program
# aspect markov chain construct
# regular posit formal relat
# function tree depend count
# continu construct
# result oper construct algebra
# languag lukasiewicz hausdorff measur
# mathemat determin principl object
# perhap valu intermedi theorem
# sylvest conjectur construct approach
# fine function effect space limit sequenti recurs comput
# unit content learn activ model
# appli web person technolog e-aula lt semant gt e-learn
# conceptu descript experi learn tool
# classroom approach identif ubiquit process comput
# educ program collabor learn tool integr comput
# conceptu evolut virtual object ii chasqui
# diagnosi environ learn author activ kadd
# task asynchron system collabor learn support pda
# tele-educ research studi project case
# collabor learn object author ontolog integr
# analyz divers modul
# behavior descript compon coordin
# gener composit object algebra
# service-ori compon composit dynam assert approach autonom non-invas paradigm
# reo circuit connector probabilist model
# modular languag verif actor component-bas
# computer-human learn effect personality-awar interfac
# situat manag metadata learn model
# architectur user deliveri context materi awar approach e-learn
# system web-bas factor train intercultur
# system student discov e-learn model
# higher educ user system experi elearn learn adapt model
# knowledg unigam social game learn train skill concept univers lifelong game-bas
# classroom-bas personalis learn adapt role e-learn
# algorithm schedul partial graph constrain message-optim preced distribut
# multi-dsp accur system environ predict rapid perform prototyp base
# secur web-bas exam
# knowledg decis exchang network learn facilit make
# knowledg manag central km trade-
# organiz knowledg studi pizzarotti case reific node commun
# ontology-bas knowledg system ontoshar share practic virtual commun
# studi project indigo introduct particip case
# perspect practic technolog integr commun
# chao knowledg coproduct hierarchi net expert
# manag knowledg evolut organ perspect liquid cycl crystal
# knowledg creation share map support implicit base commun
# stepping-ston empathi trust social etiquett capit practic commun
# determin evolution-commun system
# system popul
# rule system symport/antiport
# complex note system measur probabilist
# element system maximum find
# system promoters/inhibitor
# gate system fredkin simul energy-bas
# membran java simul comput
# system item bin famili pack effici
# separ system membran activ rule
# larg knowledg enterpris croatian competit advantag sourc integr
# analysi knowledg audit systemat flow map approach integr inventori
# task individu assign approach profil semantic-bas
# knowledg visual interact joint facilit commun
# web introduct framework cbr technolog km semant
# analysi manag research knowledg transfer public develop hero case univers process
# analysi knowledg transfer social network method selakt localis expert sustain
# metadata investig share
# analysi formal concept databas lexic model
# lattic graph search concept partit breadth
# lattic retriev concept exploit credo potenti inform
# order addit diagram avoid conflict
# intract duquenne-guigu base comput
# theori visual lattic landmark galoi probabilist
# logic model check appli tool interv fbt specif on-the-fli
# check csp state consist base uml class model
# system enterpris support autom inform
# sat search static global manipul heurist minc variable-ord bdd
# signal acceler check combin relationship global equival
# approxim bdd-base improv bound sat-bas model
# function-complet sat search support heurist lookahead effici
# signal circuit-sat solver guid correl
# coupling-bas test program
# multimedia engin survey softwar
# contract composit interact servic
# softwar experi
# web introduct compon portlet
# develop system multi-ag methodolog
# process custom construct
# analysi requir negoti multi-criteria
# applic develop approach add document-ori
# expect digit librari
# system base develop embed synthesi object-ori reus oo-asip
# analysi protocol symbol approach secur
# telemetri fast neural lempel-ziv network numer compress lossless predictor data
# hyperbol tile cell space combinator
# root group hash full search primit prime
# rewrit tissu system
# word control formal
# boolean function decomposit
# grid retriev point geometr ram model
# warehous past tempor increment mainten data oper base logic
# automat x-global system flexibl variou semant level sourc
# coroutin lua
# interconnect relat compon model
# rewrit modular cml semant
# recoveri system implement aspectj coordin error object-ori distribut
# partial multi-combin church-ross categor theorem
# script lua clr luainterfac net
# method tactic remot invoc
# function total program
# environ support redwood snippet drag-and-drop program
# metaprogram environ metaj extens java
# control reactiv system modular synchron improv
# architectur transform poset graph label abstract
# environ metamodel mof-bas
# studi comparison verif case tool parametr
# platform analysi transform model
# environ proof z-specif
# check system design object increment
# interact formal support function tool deriv correct program
# tempor optim compil logic
# protocol studi statechart verif case profisaf uml
# system moby/rt verif real-tim tool specif
# check ensur implement compil
# alia optim code fortran verif
# voc methodolog valid translat optimizingcompil
# bibliographi visual archiv languag share cross-disciplinari inform
# foundat effort multimedia languag miracl computer-support repositori inform
# futur societi implic pc
# visual dynam miracl work applic inform
# regular fibonacci hyperbol type tile code rectangular plane
# handl csc interact system cyclic sourc data semi-structur structur convert
# audiovisu archiv unifi heterogen access
# automat knowledg aggreg represent compound discoveri
# knowledg interdisciplinari divers creation overview rich
# manag knowledg converg train work make e-learn scenario
# filter formul strategi process
# manag knowledg solv problem comput
# metal manag knowledg oper industri
# process-ori knowledg structur
# manag knowledg benefit award result german
# post-nonaka manag knowledg
# grid semant work optimis
# system social profit organis network capit benchmark build scb
# identif domain pruning-bas ontolog
# manag ipd putzmeist project develop pilot skill integr personnel base compet
# human knowledg capit individu bridg custom
# ontology-bas descript formal skill semant match approach
# requir organis illustr measur learn methodolog exampl kit tool
# manag develop practic person knowledge-bas skill approach
# manag elearn prerequisit appli skill structur compet
# domain studi employe dynam identifi methodolog case
# manag transfer individu transpar concept integr compet
# problem environ learn skill simul assess solv
# manag consequ european bad problemat member union
# peripher knowledg system exact share awar expertis
# manag system organis exampl memori group inform compet
# constraint combin tempor time monitor specif seri logic
# transform formal graph interpret
# defin rosetta formal coalgebra languag semant specif
# vulner servic detect flow denial method inform
# gener automat csp specif
# descript implement embed languag haskel
# compon calculu
# semant specif object-ori action
# j2me develop aspectj adapt applic
# concurr type program languag object resourc mobil distribut comput
# code constant predic propag
# event-driven reactiv tupl space luat
# lazi cyclic refer count
# aspect weav strategi
# model constraint languag object orient xml specifi xocl logic
# asynchron invoc method remot java
# infer type implement practic haskel recurs polymorph
# pattern match depend type
# parallel program made haskel simpl effici
# ontology-bas manag knowledg reason case-bas match structur perfect
# manag knowledg soft factor effect strong
# knowledg organ mainten softwar
# experi librari build pleaser block schema base
# examplet reus case-bas softwar
# knowledg manag busi effect integr top-
# starting-point defin culture-bound user system design learn adapt characterist
# robert manag knowledg note gmbh bosch oe-sal area culture-sensit
# ontology-bas semanticmin knowledg retriev
# ontology-bas librarian manag knowledg agent system role
# knowledg organiz manag risk
# model iwim automaton coordin semant multipli hierarch
# function class relativ
# experiment assist engin studi softwar
# object rout relat action vector spatial model
# tempor granular convers direct
# uncertainti tempor fuzzi reason
# detect represent symmetri object structur abstract
# tempor neighborhood proposit interv logic
# compar reason graph case-bas map
# topolog motion time integr model
# reason appli calculu spatial access
# properti region propag reason
# inoteroper protocol wireless approach applic test
# difficult introduc solut school e-learn
# analysi system design high develop method origin level asm
# complex languag polynomi time-spac implicit recurs class
# manag knowledg model power applic
# compon system gener
# membran power creation rule comput
# fine note comput
# internet democraci possibl
# societi telecommun caus mobil
# analysi visualis bibliometr capit intellectu
# domain knowledg interact mental share build role histori legal model
# understand manag knowledg organis capit ground learn intellectu process
# discoveri knowledg expert demand
# knowledg transfer network develop recycl foster sustain
# ontology-bas manag challeng goal skill opportun
# knowledg implement concept commun foster
# knowledg manag overload knowledge-attention-gap underestim inform problem
# metadata retriev databas imag content-bas effici
# mine gener map text topic
# manag knowledg block build approach node distribut
# system queri retriev instanc memori improv expans inform cooper
# manag knowledg design usage-cent softwar interfac
# knowledg thesauri retriev autom sourc gazett internet
# expect exploit softwar experi
# manag knowledg user system exchang synchron shark mobil group
# manag knowledg focus user access distribut
# knowledg visual archiv film extract video
# diagram sequenc framework semant uml pv
# optim algorithm network atm rout global flood provis bound hierarch
# heyt languag formal algebra
# bank team-ori interact co-op select european learn distanc applic strategi
# knowledg prospect programm project web grid space
# extent optim arithmet unconstrain affin global applic
# plagiar set jplag
# hd0l seri power simplif
# synset type wordnet gener semiautomat cluster
# path-find three-tier architectur
# classifi object-bas system design repres relat structur spatial
# dimens multipl agent spatial-reason
# granul interv reason
# enviro task servic schedul team indoor mobil autonom robot
# mental dynam repres exampl
# design implement develop hyperlink softwar approach object-ori base usual structur specif
# trailtrec appli framework concept trail hypermedia open
# research structur comput
# interact annot meta-data retriev xml semant mpeg
# design hypermedia engin challeng
# hypertext model compon context-sensit
# multimedia encyclopedia softwar
# hypermedia structur xml-base
# employ servic hyperwav hwoe onlin
# observ sourc agent model
# complex languag synchron context-fre comput
# word distanc addit quasi_dist
# algorithm information-theoretical-bas find partit median
# quasi-product tree automata
# complex descript resourc machin limit
# simpli differ number base normal
# word languag closur primit oper
# regular languag shuffl decomposit
# remark defin code petri net
# synchron stabil finit automata
# finite-delay decod error-correct
# word infinit hierarchi bridg
# hyperbol tile pentagon plane singl
# symport rule system power
# constant gener finit synchron automata
# larg disjunct sequenc set
# determinist fast algorithm finit automata minim acycl simpl construct
# ration addit semir
# gener disco toolset
# environ korrigan
# reusabl gener fred proof real approach correct program
# attribut gener term graph declar program
# environ verif raven analyz real-tim
# control architectur verif softwar open industri
# decis studi arithmet practic presburg extens univers case mechan procedur
# parameter protocol verif
# system sequenc relview
# reactiv system diagram design refin
# check real-tim effici correct model
# coalgebra languag ccsl specif class
# leadership schoolteach evalu system ict develop web-bas train improv in-servic
# environ collabor web-bas learn support agent-ori
# write environ efl synchron internet
# represent lear guidanc discours
# write languag platform onlin teacher
# load redistribut problem message-minim
# complex method symmetri reduct comput
# manag knowledg countri poverty-stricken crisi
# geometri easi recent question solut comput
# manag telecommun servic challeng
# educ futur scienc glimps comput
# tube wrap
# graphic librari demand futur recent solut problem
# issu compil
# teach tomorrow anim purpos
# internet secur
# multimedia retriev mpeg relev content-bas
# organ learn
# sustain knowledg job economi
# manag knowledg superorgan
# analysi knowledg visual discov
# manag knowledg environ collabor virtual
# standard metadata
# manag knowledg digit person librari
# richli knowledg soft seal-ii unstructur structur spot
# manag knowledg tour servic guid framework siemen busi
# societi knowledg adult learn inform
# effort manag knowledg success
# systemat calculu test-design approach refin base abstract
# formal engin teach techniqu thought text book softwar differ plan base
# transit vdm vdl
# develop ten histor vdmtool bootstrap year
# mac mathemat view eclect airchinnigh irish school luca construct
# solo bagatel arrang vdm
# high perform data specif distribut comput
# univers virtual
# equival dt0l problem
# computer-medi affect frequenc develop durat messag impress commun
# neural abstract machin
# formal run sdl asm definit specif compil model
# automat asm-bas sequenc criteria coverag test
# partial updat explor
# gener verif asm simul refin
# abstract compil state machin
# logic abstract state machin
# model protocol cach locat verif memori state consist specif abstract machin
# np-hard gener graph proof variant color
# transclus centuri st
# languag map codifi matrix parikh
# measur learn effici
# nondetermin determin count altern
# tailor word collabor processor
# control specul processor simultan multithread
# price fpga rout
# societi complex inform system
# invis workplac process
# chemistri undergradu curriculum integr applic electron structur comput
# system methodolog tool improv continu
# knowledg design coffein construct present
# system x-machin approach commun
# conceptu large-scal hypermedia treeworld model
# manag knowledg environment informat
# workload rdbms-www heavi perform interfac
# algorithm lattic fold implic pattern protein invari crystal
# light requir control studi case state machin abstract captur
# light requir control scr studi appli method case
# light control forest studi case approach applic
# light requir control studi develop increment case real-tim
# light-control evalu requir studi nimbu case captur
# light control system analyz pv
# function p-time identif class effici
# align product languag search framework pars compress unif natur syntax multipl inform
# kth-order s-box nonhomomorph
# algorithm dynam specul mem-slic partit thread
# switch architectur perform block multithread
# architectur schedul cach dataflow perform execut
# msparc real-tim multithread architectur
# protocol system grammar negat condit cooper
# incomplet linear time
# document implement concept activ applic
# element style techniqu specif structur
# hyperbol cellular plane automata tool
# constraint uncertainti quantifi propag approxim heterogen solv algebra
# switch system map comput nonlinear
# system dynam behavior relat net inform model
# ieee elect leader formal appli method survey
# admiss interfer nondeterminist
# statechart outlin semant uml pv
# observation-ori perspect specif formal
# algorithm problem solv motion plan
# read function program logic
# control studi verifi system method specifi case real-tim
# termin esfp ensur
# system inclus weak
# pseudo_wajsberg lattic structur algebra
# pi-calculu machin
# data galoi mine connect
# coher behaviour specif object-ori algebra
# pseudo-boolean horn quadrat function monoton
# represent monad algebra theorem pavelka
# categori semiring relat enrich mix
# kraft-chaitin set extens free-extend prefix-fre theorem
# hypercub group automorph
# iv mvn connect lukasiewicz-moisil n-valu algebra
# logic substructur canon construct model
# shift complementar space comput
# sign bool
# system simul
# note pa-ord partially-ord scienc relat comput structur semir
# extractor world real
# interaction-ori tableau transform search-ori proof calculi
# data automat restructur
# evalu algorithm formula boolean averag perform case demand-driven
# gate theoret revers aspect group logic
# divis float point applic determin expans comput
# scheme share random multi-secret
# architectur environ web survey wireless commun
# align reason introduct search compress unif overview multipl probabilist inform
# x-machin commun stream system
# distribut issu languag pictur relat process
# hyperbol cellular sat polynomi plane automata space solut
# decomposit time automata
# iter tree case splice
# transform formal system background verif fault-toler classif approach specif
# tree advanc fault model
# life laha gener comput time applic distribut model
# code bounded-weight note error-correct
# ture reduct posit power
# algorithm mount multi-head surfac machin plan
# calculu durat method decis
# align search compress unif multipl inform comput
# interv bodi convex algebra
# equat solut interv class algebra
# interv model measur uncertainti
# evalu compar multimedia product print inform review electron
# educ evalu multimedia context
# reason knowledge-build key condit assess computer-bas commun process
# educ evalu design share bridg qualit effect memori approach quantit
# system challeng www-base learn assess opportun
# evalu round chebyshev perturb simul error seri
# hierarchi queri order polynomi
# interact confer design develop video role proceed
# assist neural agent shape web link-bas hypermedia
# advic note karp-lipton set linear-nondetermin linear-
# move simul pram hash thread
# basic gener properti scheme share nonperfect secret
# context categoris
# engin select web search retriev result view effect improv
# lua flexibl web extens build applic
# hybrid adapt subdivis routin integr strategi
# key relat databas schema number
# employ structur design practic exist function tool versu pattern recov
# key relat databas schema deriv linear
# shannon symbol text compress rank recod
# programm hardwar prototyp pc
# type modul extens pointer compat refer paramet
# abstract recurs state machin
# shortest studi path constrain asm case
# life develop asm softwar cycl integr
# montag languag realist specif program
# oberon specif formal
# code product cell asm refin specif
# asm-approach compil back-end construct correct
# filter news manag framework data distribut
# technolog manag knowledg inform
# organis negoti memori construct reconstruct
# knowledg manag prospect challeng practic corpor memori industri
# environ ministeri complementari tool
# knowledg engin document sharabl product languag natur approach
# knowledg ariadn flexibl coordin support work
# filter agent text profil inform
# automat descript optim paperfold sequenc
# web-bas train aspect
# note overflow detect proof adder number complement correct logic
# control discretionari hash function databas
# free overlap place
# function highli t-resili nonlinear
# independ monstr suspend semant ii
# scheme assign perform work-greedi bound
# filter parallel algorithm design distribut implement stack
# code scheme multisecret-shar linear error-correct
# architectur mtac vliw pram simul multithread
# forum neg explicit result
# analysi formal system kerbero authent
# sdl semant state machin abstract
# gener specif bia
# parallel structur document comput
# persist confluenc
# aspect problem construct dirichlet
# reduc chaitin number strong
# code prefix optimum extend
# incomplet determinist minim automata
# order ideal note set graph obstruct monad
# order ideal obstruct lower minor parameter mani
# variable-length code encod decod format repres fixed-length t-deplet
# properti invari sequenc random
# set function grow cantor surject comput
# complet intermedi effect theorem logic
# map mathemat sequenti continu linear construct
# agent flow arrow imperfect commun inform logic
# concept famili dortmund applic hypermedia model
# optim algorithm parallel learn dfa
# difficulti box strong cryptograph substitut construct
# teach technolog distanc integr inform multimedia-bas
# educ design product tv aspect video distanc
# design asic home
# teach distanc publish media
# knowledg combin heterogen repositori inform
# function monoton ceil boolean
# disjunct number omega-word real
# edge-flip triangul distanc
# unifi late teach environ learn concept
# human cooper classroom computer-support electron
# remark partition-limit system propag etol
# serial gener t-code compress data commun
# coursewar deliv www hypertext base
# www-aid improv evalu instruct
# fit uncertainti biolog curv data interpol
# system reason approxim applic inform inexact
# comparison sequenc biolog dedic hardwar
# monstr issu fundament design
# regular power languag splice restrict rule
# complet pseudosimpl set
# system variant grammar team cooper
# architectur system referenti distribut integr scalabl inform maintain
# characterist function propag relationship cryptograph nonlinear
# network inform hyper-
# www
# internet gopher evolut
# vertic algorithm graph biconnect st-number distribut effici
# geometri method differenti prove mechan theorem
# digit teach librari learn support
# high-spe design chip path rsab crypto data test
# www comparison hyper-
# heat equat finit round-
# lcf represent ration lexicograph binari
# on-lin accur arithmet radix high credibl comput
# arithmet interv applic direct
# serial digit arithmet
# ieee formal arithmet implement correct comput
# modular reduct rang
# eco-grammar condit system tabl
# environ hypermedia home object
# internet patent softwar
# monstr pi-calculu translat
# system cach network file distribut
# assist person comput
# aperiod wang cube set
# hypermedia
# author fli
# constraint age inform agent
# territori word prime go-lik parikh
# parallel constraint exploit qualit satisfact simul
# level anonym
# string random
# estim divis high-radix approxim quotient-digit
# tree implement work-optim mesh erew
# grammar oper base shuffl
# write scientif reason broca environ computer mediat
# text compress ziv-lempel differenti
# algorithm exponenti decreas affin function distanc match
# problem network-on-chip map multi-object approach genet
# box pareto-optim hardwar substitut
# automat fault program methodolog monitor hardwar electron
# evolutionari algorithm design method circuit search multi-object pattern problem
# evolutionari multius ds/cdma algorithm detect
# metric on-lin constraint tempor finit altern time-seri automata monitor
# revers karatsuba algorithm
# hierarchi graph complet exact domat uncolor boolean exact-four-color survey minim number problem
# manag issu pervas technolog synergi util health
# assist place support monitor health age
# system arrhythmia tele-assist real-tim monitor dedic cardiac
# cammd devic mobil medic context-awar
# provis impact home behavior technolog care monitor health
# collabor research system biomed
# system tele-hom healthcar pervas multimod
# design healthcar privaci qop qualiti applic ubiquit
# visual servic confer context technolog approach rfid
# environ ambient mechan conflict intellig solv
# emilet enabl reflect framework ami
# architectur network sensor modular wireless node
# compon develop ambient aspect applic
# hybrid manag ocp architectur system contextu inform model
# manag trust servic network ad-hoc discoveri secur base
# danger monopoli engin web search connect view dot restrict
# inherit system coercion kenzo model
# architectur descript formal system languag tempor symbol transit base logic
# persian/arab captcha baffletext
# logic optim design languag yap compil program
# challeng gener program process algebra
# optim experi just-in-tim sun java compil
# detect smell bad aspectj
# slice program calcul
# design pattern languag visitor
# mobil haskel strong
# interoper object system model
# servic express web case pattern pew workflow
# defin diagram composit atom behavior uml
# type-saf queri languag object version
# larg assimil numer scale observ simul fusion sequenti inform data
# unsupervis discov interest data tabl
# secreci introduct random
# gener compromis imposs pseudorandom number
# cryptographi quantum progress comput
# formal languag boolean repres function implicitli membership test
# exponential-tim determinist algorithm domat satisfi color improv number random problem
# theori random algorithm complex
# properti term behaviour prove observ specif
# estim fingerprint algorithm verif enhanc orient ridg
# telemetri fault neural sensor compress predictor toler data
# revisit time-vari system
# domain lattic constraint scheme interv branch
# analysi constraint method sequenc biolog base
# process global bisimul equival
# verifi properti tccp real-tim program
# theori failur implement functional-log construct program
# crwl program rewrit verif logic
# introduc tutori tool itp
# xpath languag magic set
# multi-adjoint logic operational/interpret unfold program
# survey plagiar
# institut gener behavior refin hidden logic
# analysi elect leader prism variat ring anonym itai-rodeh
# join-set elimin assign static singl redund comput
# transform emerg shape web consum commun inform
# mutual queue algorithm migrat exclus
# petri relat causal live net characteris structur
# user algorithm enterpris system cluster poca distribut
# evalu creation knowledge-bas fuzzi
# web uml-bas applic data-ori model
# design implement enum-bas servic
# cach server perform proxi model
# system develop exact plant classif qualiti improv
# extens cql databas dynam
# rule-bas japlo java program
# season lymphoid method time leukaemia data childhood acut seri analys
# system crop softwar analys model
# interact architectur geo-bas client-serv portal web technolog modern
# sequenc neighborhood retriev databas imag applic process
# higher educ flexibl student internet profil base cours model
# endocrin mathemat system model
# applic wavelet construct
# topolog network wireless resourc mainten effici
# system membran graphic oper comput
# estim theori paramet approach inform distribut cauchi
# human visual phasetransition-lik inform process chang
# societi primari teacher school inform
# protocol addit time-releas kudo-mathuria examin
# synthesi optim structur workflow
# educ complex engin system it-bas technolog approach
# educ informat scienc comput logic
# independ system project medip-platform imag softwar medic process
# agent-bas system recommend negoti improv
# estim system describ relat observ paramet noisi
# knowledg set experi ontolog owl structur
# placement fault system place isol event point invari
# rule-bas system agent implement negoti autom price
# path predict framework behavior case internet data
# incomplet order partit consensu deriv cover hierarch
# depend attribut valu consensu determin interv
# user system utter speech auto dialog respons rate entrain
# system global memori space conic
# interact environ immers convers build
# human system avatar-bas real-tim proxi commun
# analysi knowledg circul convers quanta
# algorithm ae implement circuit increas perform fpga runtim
# estim architectur vari illumin motion real-tim condit robust
# self-tim design implement microprocessor fpga amcc
# set implement sequenc complementari interleav correl hardwar effici
# evalu system chip vision perform reconfigurable/programm limit
# implement dynam fpga idea
# pipelin loop data-depend sequenc
# requir formal verifi method valid specifi
# theori formal method practic becom
# floating-point verif
# check softwar model
# mainstream formal method autom enter
# verif grand challeng
# method realis formal benefit
# code softwar
# formal system represent learn configur methodolog e-learn scenario
# posit root method comparison polynomi variou bound comput
# applic digit emerg develop journal mashup paradigm
# compile-tim function polytim comput
# system payment transact internet
# cultur copyright manag e-commerc system servic digit web protect inform provid
# refin control specif access
# servic web commut atom achiev action
# manag architectur system reflect augment databas
# atom improv correct program
# webquest deadlock studi synchron framework improv process
# educ languag support author operation model
# educ pipeline-schedul purpos simul
# metadata design ontolog lo qualiti improv base instruct model
# educ separ poeml unit flexibl support concern approach model
# creat engin graduat onlin degre mexico univers
# editor handheld hme educ context model
# digit design environ collabor game learn
# cetl reusabl perspect network collabor map learn object year academ
# handheld collabor composit web foreign languag tool comput
# moodl design map learn step im
# languag cml model
# architectur propos constraint
# logic verif law condit object-ori program
# remov lalr conflict methodolog
# advic optim aspect
# languag anim visual simul
# aspectlua reus achiev re-aspectlua
# spreadsheet tabular abstract program
# architectur concurr system count cyclic lazi refer multi-processor
# count cyclic object refer perman
# extens languag api
# lazi function slice higher-ord
# overload close support coexist world definit open
# semant visitor action pattern
# manag knowledg servic select web qo base
# conceptu manag knowledg sophi choreographi framework grammar ontolog model
# manag task composit coursewar skill assign autom semantic-bas
# programm engin gener develop instruct compet
# futur link creat
# attent learn reinforc focu
# learn student distanc satisfact java cours program
# applic gener extract tagger perform improv inform
# co-evolut commun ehw approach
# hybrid optim algorithm quadrat neighborhood fuzzi assign solv swarm variabl particl problem
# neural algorithm process network chemic fuzzi base recurr genet model
# signal architectur neural implement network scheme analog circuit cell process
# system artifici forens immun base comput
# detect address duplic autoconfigur olsr
# dsr rout adapt extens sourc cluster hierarch
# manet servic rout qualiti olsr
# vca algorithm network sensor cluster voting-bas energy-effici
# ad balanc hoc protocol reactiv cach load rout energi enhanc node effici
# nonã‚â­strict languag platform function net compil
# ciphertext constant size hibe extens augment selective-id model
# deduct system pedagog proposit natur case
# metadata queri method tempor video interv access effici
# proxim explor classroom applic mobil sensemak
# digit algorithm polygon approxim curv approach swarm base particl discret
# metric svm similar improv base
# scientif learning-bas extract machin literatur keyword
# model mine express gene rule immun program
# independ spectral densest graph subgraph number
# contribut perfect graph-theoret polyhex recent match benzenoid
# transform automata behaviour equival
# gray code
# filter evolutionari network connect processor accept
# steiner analysi tree algorithm
# attempt algebra treat part
# graph spars grade matroid
# regular asymptot map nonexpans halpern iter rate
# stabl bipartit matric graph
# control system neural astrocyte-lik spike
# interact high-level regist voic structur program
# balanc system set finit applic
# metric-entropi lattic pair
# network sign reachabl connect
# graph hamilton topolog grid
# depend system graph co-design methodolog hardware/softwar verif level base
# net petri self-evolv
# implement theoret web e-bart altern sevic
# tree protocol formal check deduct modul proof integr perlman stp span
# set system implement languag declar translat odedialect ontolog
# ontology-bas content web creation framework adapt semant
# element rdf visual rank schema applic
# semant keyword discov user
# agent network search sewasi semant mediat
# ontology-bas domain mine retriev support biolog text approach inform
# asynchron servic commun collabor synchron support trade-
# educ search support semant tool ontoolcol cscl
# interact seamless collabor connect transit disconnect
# service-ori unit collabor support ad-hoc integr mobil scenario
# architectur compon meet pda pattern
# script control architectur environ collabor
# themat segment text cluster evolv
# history-sci document informat impact historian xml tool markup mediev
# handwrit recognit appli zone mechan metaclass
# classifi off-lin signatur combin verif roc-spac
# artefact remov table-form extract
# remov detail document algorithm interfer method back-to-front assess quantit
# hybrid separ method foreground/background methodolog histor manuscript arab
# remov algorithm document interfer back-to-front binar
# recognit method symbol learn progress
# fair set multi-
# nmac/hmac popular result function instanti hash
# key exchang parallel
# transfer scheme oblivi k-out-of-
# key-shar protocol unknown key attack agreement bilater
# formal roam privacy-preserv extens definit secur construct effici
# public certificateless encrypt key attack standard malici secur kgc model
# scalar parallel koblitz formul curv multipl
# knowledg organ network wiki-bas analyz improv process
# ruler algorithm fold approxim time linear problem
# success commun factor weblog
# advertis interact compens model
# queri network pine road base spatial
# estim passiv qualiti experi
# trade link market path bandwidth commun
# servic qo cost bitstream paramet access model
# zrtp enhanc puzzl
# barrier perspect develop drive broadband access ce
# optim perspect learn negoti transit price distribut
# market size bandwidth dynam game cost effect price provis
# analysi model failur network risk econom correl commun normal copula
# attack zrtp aspect man-in-the-middl secur usabl
# ecosystem commun qualiti experi
# traffic estim model aggreg behavior approxim scenario
# riesz compact represent hausdorff local space comput
# set multi-repres program close multi-funct comput
# constant famou subrecurs sever comput
# topolog pressur physic shift sofic applic statist comput
# bloch constant comput
# analysi system weak integr riemann
# weight optim bit-complex find rule integr quadratur nearli
# repres notion space probabilist comput
# filter weak space limit relationship
# nig fan hypothesi proof lemma equival uniqu direct brouwer theorem
# classifi na driven explan bay multipl
# mobidi educ portal
# conceptu design framework learn create-by-reus approach solut
# educ research public scienc bia literatur comput
# english formal agent-bas finit state auction
# system partial retriev rank relev judgement
# evalu system algorithm methodolog alloc wireless resourc simul improv commun multi-ag model
# manag agent-bas dynam suppli solut chain
# ad knowledg hoc topolog agent network bit-map discoveri mobil
# evalu system perform structur multi-ag
# transform social queri central network1 semant base
# system agent map action integr schema p2p data
# market learn futur simul reinforc
# analysi domain-specif architectur foundat framework interpret softwar model
# mine compon embed product line techniqu softwar revit
# requir compon system experi select cost autom cot base
# retriev tool legaci inform lift
# architectur servic mismatch web avoid softwar
# crossmda manag model-driven aspect approach
# annot product model-driven techniqu tool deriv base
# service-ori develop web applic process
# space efremovi condit complement
# program perspect method binari clo
# special lisp object-ori custom
# clim implement type present
# context-ori system ambient object program
# ucl-glorp common orm lisp
# theori reason implement tempor lisp tool qualit s-languag inform
# visual interact nasdaq veloc activ forc chang
# groupwar collabor support shared-workspac inform
# groupwar user ciam develop methodolog interfac
# conceptu user group-awar gener collabor scheme plastic framework explicit interfac
# domain defin task studi system space-design convers act case cscw
# requir interact transform technolog base mda captur model
# evalu cognit walkthrough test academia spanish-speak heurist websit usabl
# environ eas semi-automat smart home adapt percept
# task system develop collabor ambient intellig base model
# evalu assist design tool websit weba
# larg featur document select classif collect
# handov automat retrial user guarante seamless redial mobil
# manag knowledg meet learn activ enhanc applic inform access
# implement core perceptron configur fuzzi devic function gui ip activ multilay logic
# applic journal digit
# network learn latent object support repositori
# web search
# taxonomi design product web train support macro
# formal entertain game semant media industri
# metadata content imagesemant user-gener
# mass inform integr
# web languag autom workflow
# structure-bas web hidden crawl
# experiment studi page semant data-intensiveweb relationship structur
# resili inform extract explor
# visual segment web page extract recognis block
# studi modular product line case jbook softwar theorem
# engin languag state simul metamodel-bas abstract machin
# engin system languag time state machin real-tim abstract
# logic model-check predic time state simul abstract machin
# invari refin asm preserv
# architectur asm servic orient
# secur protocol correct
# practic adapt techniqu survey softwar
# compon system framework adapt java-bas logic
# mismatch composit adapt behaviour interfac run-tim
# safe develop dynam framework adapt softwar aspect-ori
# user rux-method web adapt multidevic interfac
# knowledg system metasynthesi intellig process
# agent learn framework increment softwar ap
# trade market agent power pattern microstructur surveil
# agent-bas system payment perspect wireless non-repudi mechan mobil pki
# optim algorithm cach load cdn rad
# workforc exchang alloc resourc pathway solut intellig problem
# traffic manag agent-bas approach
# posit lb system implement u-campu prototyp
# system agent web search semant enhanc applic base tag meta
# tabu search gpu
# segment set multi-lay method level imag
# automat induct investig altern fuzzi rule approach base
# steiner hybrid tree algorithm prize collect transgenet problem
# hybrid time-depend optim algorithm network bu
# evolutionari quantum-inspir finit synchron assign state machin
# optim network sensor layout multi-object
# algorithm gadym design problem mechan genet
# featur select problem step
# stochast evolut strategi parallel
# base recommend learner swarm intellig cours e-learn
# back decis support bay intellig medicin
# hci countri ibero-american state
# evalu ergonom cognit develop interfac
# cultur phone usag factor adopt mobil model
# aula user ciam studi design collabor case interfac applic
# develop web support applic access
# ergonom cognit discuss design move scienc interfac
# analysi log aeh improv cours
# automat ad spiral adapt author hypermedia model
# domain ontolog model
# design sequenc learn adapt author im rich cours
# task author activ space social-awar
# model gener standards-bas dynam learn adapt approach scenario
# author educ onlin cultur
# school board creat set environ game adapt elg
# archiv annot digit document architectur gener convers semant collect
# digit systemat languag object extens characteris preserv
# project stereoscop represent classif crime scene
# adverb verif author
# word resolut system ultra recognit hmm open-vocabulari language-independ base low
# depend document network layout stack structur
# techniqu evalu binar algorithm
# compar implement grid bigbatch aspect cluster
# domain task environ collabor ctml model
# featur groupwar user develop extend support interfac applic model
# user collabor model-bas support interfac creativ specif prototyping-driven
# environ interact gaze-bas virtual
# song play pictur accord display
# implement movement flow optic virtual mous rel head
# human interact cve base commun model
# user system design model-driven interfac approach inform workflow
# tune fine web site imag museum access
# evalu interact propos agent-bas system petri net
# taxonomi interact groupwar system develop integr model
# input task consequ precis two-hand spatial manipul speed applic percept model
# domain diamodl eclips framework dialog case integr model
# system appli problem sharp mathemat adapt onlin hypermedia solv
# align user model-driven interfac approach busi process
# ascii program graphic pars
# fusion shortcut monad program
# resolut gener lalr parser support conflict
# schedul high subgraph perform processor isomorph base instruct comput
# weak elimin tabl cycl
# explor concurr lua program
# aspect reentranc control
# extens implement lightweight aspectj
# advic interact type aspectj raw
# semant definit disentangl denot
# formal languag semant action uml
# featur law model algebra
# educ system design learn adapt hypermedia
# ideal maxim notion construct
# manag iqm3 matur qualiti inform model
# logic bck unitarili attempt
# switch diagnosi fault detect network-on-chip function onlin
# determin lag invest softwar
# clinic environ adapt real-world ontolog
# defin behavior or-join busi process model
# optim depend queri dynam limit access
# modal infinitari non-denumer logic
# concurr nonblock reason
# depend express proposit databas practition function weak full
# transact aries-bas state machin abstract
# design databas global minim time space updat base storag
# semistructur formal verif data pv model
# formal aggreg framework olap-oltp model
# complex ideal coincid valu characteris
# warehous design dynam state machin data abstract
# digit good superdistribut
# design secur multimedia authent
# multimedia network attack stabil heterogen adversari
# topolog impact attack threat chang
# traffic denial-of-servic detect method attack test statist base distribut
# urgent danish adopt busi model
# social recommend share platform multi sourc resourc tag provid
# script life interact knowledg collabor share learn virtual classif
# list arm project embed linux mail behaviour sourc case open model
# composit support aspect aop structur kernel
# sql queri criteria coverag structur test
# fair protocol sign negoti contract non-repudi secur
# control dynam ds role rbac session base access
# posit complex root quadrat polynomi valu linear bound
# homomorph cryptosystem advanc
# estim algorithm unit magnet measur compass inerti orient dcm base
# analysi compar complex studi methodolog ontolog integr
# support preprocess cluster data vector procedur effici
# pde-peda optim algorithm multi-object pareto-bas
# hybrid multifacet sequenc search integr discoveri pattern frame-relay pso-ann
# hybrid shop algorithm flow quantum-inspir makespan immun criterion
# expos road recognit sign imag approach differ graph-bas guidanc robust
# lexic context web fingerprint
# infer optim algorithm network gene regulatori
# prune multi-sub-swarm multilay ensembl particl swarm
# system framework scenario sdlma multi-ag model
# brows url user psycholog method person
# analysi migrat agent framework
# control gener infrastructur access e-passport mechan secur e-docu purpos
# protocol agent network sensor platform support wireless cryptograph
# analysi chess environ cipher pervas suitabl full-round secur comput
# multimedia content network tv heterogen wireless dvb/gpr protect mobil
# usf-pa studi core framework technolog secur ubiquit
# pervas vascular palm authent pattern
# ad hoc enforc highli network dynam mobil cooper
# system neural network pervas vehicl smart classif road secur base
# topolog elementari comput
# convers finite-tim preserv comput
# hyperbol system symmetr oper solut pde comput
# tietze-urysohn qcb-space effect theorem
# blowup complex topolog problem
# result measur repres
# squar unit fine-comput function integr
# metric urysohn univers space construct
# metric set circularli chainabl space comput
# np oracl relativ question sever structur
# inclus thousand ten differenti effect monkey approach solut comput
# exist base schauder effect
# innov perspect european qualiti e-learn
# educ system design web approach meta-model multi-disciplinari base
# learn object pool applic scenario
# evalu aiml-bas tq-bot tutor bot
# digit inclus environ peopl virtual special eduquito
# manag develop web learn style applic
# spiral timelin support semant
# visual tree languag syntax cours process
# assist coala program environ learn distribut comput

# %%
rakeTitle
# Out:
# ['process-ori commun structur integr',
#  'outcom interact small factor synchron learn onlin accept workplac determin group',
#  'knowledg share learn weblog space',
#  'manag knowledg architectur pre-built implement method space orient inform process model',
#  'evalu visual transfer knowledg project map long-term applic tube',
#  'manag knowledg activity-bas system reconcil approach workflow',
#  'human toolkit knowledge-intens organis design network factor methodolog km technolog integr',
#  'knowledge-intens process kmdl improv analys busi captur',
#  'knowledg manag enterpris role solut busi process',
#  'knowledg design work infrastructur model',
#  'knowledg call-centr hierarchi infrastructur process model',
#  'manag knowledg servic orient approach base process',
#  'non-block concurr algorithm queue formal construct',
#  'observ investig atom',
#  'asynchron consid verifi relax atom case mechan commun correct',
#  'compens precis transact bpel applic busi model',
#  'understand system replic broadcast atom advantag quorum',
#  'manifesto atom',
#  'develop softwar atom',
#  'first-class atom system provis',
#  'visual mine semi-automat subgroup vikamin',
#  'visual social recommend flow network',
#  'orthogon high-dimension curv data',
#  'mine system lite-weight integr data oper ubiquit gui',
#  'visual segment mine decis interact explor connect rule data',
#  'incomplet visual uncertain decis depend diagram manipul',
#  'visual interact highli gravi tempor explor data inform structur',
#  'explor multiresolut scalabl data',
#  'intrud wireless locat physic',
#  'evalu fuzzi techniqu level refer secur polici model',
#  'audio distort lsb code increas steganographi reduc robust',
#  'intrus protocol detect embed protomon prevent monitor cryptograph',
#  'slide protocol group network window ad-hoc secur commun',
#  'software/hardwar co-design hardwar secur cryptograph effici',
#  'signatur rsa-bas e-good deliveri verifi encrypt certifi',
#  'assur system combin explor lazi open sourc qualiti space inform multi-ag',
#  'low-intrus digit disk tool checkpoint consist forens',
#  'transfer network scheme data secur comput',
#  'analysi gossip pirat fingerprint code trace erasur construct',
#  'problem creation game databasesa profil inform distribut',
#  'control ded method synthesi applic',
#  'complex system implic develop softwar structur tendenc',
#  'brows user collabor web extract semant bookmark interest base',
#  'intern cognit agent ground languag relat structur problem',
#  'hybrid queri recommend',
#  'knowledg semant level inconsist process',
#  'hybrid user system web adapt interfac consensus-bas',
#  'model retriev provabl approxim comput spatiotempor effici',
#  'time actor cost comput',
#  'analysi evalu control protocol design scheme perform ms-rtcp real-tim scalabl',
#  'automat algorithm gener flow test data',
#  'estim theoret rout upper bound',
#  'document multimedia html transclus fine-grain',
#  'cube complex fat topolog commun collect',
#  'formal framework autom testaf',
#  'cryptosystem shuffl verifi variant paillier provabl secur base effici',
#  'b2c agent marketplac virtual exploit ontolog',
#  'domain tree algorithm uowhf finit extend binari',
#  'check composit rebeca verif autom abstract model',
#  'fast t-decomposit algorithm',
#  'free tree polygon simpl insid bound draw',
#  'definit languag construct approach',
#  'design function match hardwar perfect program',
#  'implement lua',
#  'aspectlua dynam aop approach',
#  'semant formal final',
#  'servic web languag build interfac pew',
#  'languag platform function compil net nonâ\xadstrict',
#  'script run lua clr translat bytecod',
#  'evalu experiment technolog jit java',
#  'signal comonad',
#  'scheme languag specif equat',
#  'pure languag function mobil mhaskel comput',
#  'tree decis dynam learn data stream',
#  'data resource-awar mine stream',
#  'alert mine id network extract attack categor stream scenario',
#  'mine usag web request semant preprocess stream',
#  'trigger time qualiti condit seri stream',
#  'mine append-onli item dynam onlin data continu stream chang',
#  'select learn numer border increment exampl rule data stream',
#  'posit root polynomi bound',
#  'suprema construct',
#  'uniform equival continu construct theorem',
#  'spectrum oper self-adjoint comput',
#  'algorithm cellular irreduc automata univers',
#  'analysi ration function iter construct',
#  'formal gelfand stone-yosida topolog represent mathemat construct theorem',
#  'axiomat intuitionist class model',
#  'element posit banach space state algebra firm',
#  'sequenc random nonrandom',
#  'permut linear rule lattic',
#  'topolog formal coequalis quotient space',
#  'theori set principl brouwerian construct',
#  'construct process program',
#  'aspect markov chain construct',
#  'regular posit formal relat',
#  'function tree depend count',
#  'continu construct',
#  'result oper construct algebra',
#  'languag lukasiewicz hausdorff measur',
#  'mathemat determin principl object',
#  'perhap valu intermedi theorem',
#  'sylvest conjectur construct approach',
#  'fine function effect space limit sequenti recurs comput',
#  'unit content learn activ model',
#  'appli web person technolog e-aula lt semant gt e-learn',
#  'conceptu descript experi learn tool',
#  'classroom approach identif ubiquit process comput',
#  'educ program collabor learn tool integr comput',
#  'conceptu evolut virtual object ii chasqui',
#  'diagnosi environ learn author activ kadd',
#  'task asynchron system collabor learn support pda',
#  'tele-educ research studi project case',
#  'collabor learn object author ontolog integr',
#  'analyz divers modul',
#  'behavior descript compon coordin',
#  'gener composit object algebra',
#  'service-ori compon composit dynam assert approach autonom non-invas paradigm',
#  'reo circuit connector probabilist model',
#  'modular languag verif actor component-bas',
#  'computer-human learn effect personality-awar interfac',
#  'situat manag metadata learn model',
#  'architectur user deliveri context materi awar approach e-learn',
#  'system web-bas factor train intercultur',
#  'system student discov e-learn model',
#  'higher educ user system experi elearn learn adapt model',
#  'knowledg unigam social game learn train skill concept univers lifelong game-bas',
#  'classroom-bas personalis learn adapt role e-learn',
#  'algorithm schedul partial graph constrain message-optim preced distribut',
#  'multi-dsp accur system environ predict rapid perform prototyp base',
#  'secur web-bas exam',
#  'knowledg decis exchang network learn facilit make',
#  'knowledg manag central km trade-',
#  'organiz knowledg studi pizzarotti case reific node commun',
#  'ontology-bas knowledg system ontoshar share practic virtual commun',
#  'studi project indigo introduct particip case',
#  'perspect practic technolog integr commun',
#  'chao knowledg coproduct hierarchi net expert',
#  'manag knowledg evolut organ perspect liquid cycl crystal',
#  'knowledg creation share map support implicit base commun',
#  'stepping-ston empathi trust social etiquett capit practic commun',
#  'determin evolution-commun system',
#  'system popul',
#  'rule system symport/antiport',
#  'complex note system measur probabilist',
#  'element system maximum find',
#  'system promoters/inhibitor',
#  'gate system fredkin simul energy-bas',
#  'membran java simul comput',
#  'system item bin famili pack effici',
#  'separ system membran activ rule',
#  'larg knowledg enterpris croatian competit advantag sourc integr',
#  'analysi knowledg audit systemat flow map approach integr inventori',
#  'task individu assign approach profil semantic-bas',
#  'knowledg visual interact joint facilit commun',
#  'web introduct framework cbr technolog km semant',
#  'analysi manag research knowledg transfer public develop hero case univers process',
#  'analysi knowledg transfer social network method selakt localis expert sustain',
#  'metadata investig share',
#  'analysi formal concept databas lexic model',
#  'lattic graph search concept partit breadth',
#  'lattic retriev concept exploit credo potenti inform',
#  'order addit diagram avoid conflict',
#  'intract duquenne-guigu base comput',
#  'theori visual lattic landmark galoi probabilist',
#  'logic model check appli tool interv fbt specif on-the-fli',
#  'check csp state consist base uml class model',
#  'system enterpris support autom inform',
#  'sat search static global manipul heurist minc variable-ord bdd',
#  'signal acceler check combin relationship global equival',
#  'approxim bdd-base improv bound sat-bas model',
#  'function-complet sat search support heurist lookahead effici',
#  'signal circuit-sat solver guid correl',
#  'coupling-bas test program',
#  'multimedia engin survey softwar',
#  'contract composit interact servic',
#  'softwar experi',
#  'web introduct compon portlet',
#  'develop system multi-ag methodolog',
#  'process custom construct',
#  'analysi requir negoti multi-criteria',
#  'applic develop approach add document-ori',
#  'expect digit librari',
#  'system base develop embed synthesi object-ori reus oo-asip',
#  'analysi protocol symbol approach secur',
#  'telemetri fast neural lempel-ziv network numer compress lossless predictor data',
#  'hyperbol tile cell space combinator',
#  'root group hash full search primit prime',
#  'rewrit tissu system',
#  'word control formal',
#  'boolean function decomposit',
#  'grid retriev point geometr ram model',
#  'warehous past tempor increment mainten data oper base logic',
#  'automat x-global system flexibl variou semant level sourc',
#  'coroutin lua',
#  'interconnect relat compon model',
#  'rewrit modular cml semant',
#  'recoveri system implement aspectj coordin error object-ori distribut',
#  'partial multi-combin church-ross categor theorem',
#  'script lua clr luainterfac net',
#  'method tactic remot invoc',
#  'function total program',
#  'environ support redwood snippet drag-and-drop program',
#  'metaprogram environ metaj extens java',
#  'control reactiv system modular synchron improv',
#  'architectur transform poset graph label abstract',
#  'environ metamodel mof-bas',
#  'studi comparison verif case tool parametr',
#  'platform analysi transform model',
#  'environ proof z-specif',
#  'check system design object increment',
#  'interact formal support function tool deriv correct program',
#  'tempor optim compil logic',
#  'protocol studi statechart verif case profisaf uml',
#  'system moby/rt verif real-tim tool specif',
#  'check ensur implement compil',
#  'alia optim code fortran verif',
#  'voc methodolog valid translat optimizingcompil',
#  'bibliographi visual archiv languag share cross-disciplinari inform',
#  'foundat effort multimedia languag miracl computer-support repositori inform',
#  'futur societi implic pc',
#  'visual dynam miracl work applic inform',
#  'regular fibonacci hyperbol type tile code rectangular plane',
#  'handl csc interact system cyclic sourc data semi-structur structur convert',
#  'audiovisu archiv unifi heterogen access',
#  'automat knowledg aggreg represent compound discoveri',
#  'knowledg interdisciplinari divers creation overview rich',
#  'manag knowledg converg train work make e-learn scenario',
#  'filter formul strategi process',
#  'manag knowledg solv problem comput',
#  'metal manag knowledg oper industri',
#  'process-ori knowledg structur',
#  'manag knowledg benefit award result german',
#  'post-nonaka manag knowledg',
#  'grid semant work optimis',
#  'system social profit organis network capit benchmark build scb',
#  'identif domain pruning-bas ontolog',
#  'manag ipd putzmeist project develop pilot skill integr personnel base compet',
#  'human knowledg capit individu bridg custom',
#  'ontology-bas descript formal skill semant match approach',
#  'requir organis illustr measur learn methodolog exampl kit tool',
#  'manag develop practic person knowledge-bas skill approach',
#  'manag elearn prerequisit appli skill structur compet',
#  'domain studi employe dynam identifi methodolog case',
#  'manag transfer individu transpar concept integr compet',
#  'problem environ learn skill simul assess solv',
#  'manag consequ european bad problemat member union',
#  'peripher knowledg system exact share awar expertis',
#  'manag system organis exampl memori group inform compet',
#  'constraint combin tempor time monitor specif seri logic',
#  'transform formal graph interpret',
#  'defin rosetta formal coalgebra languag semant specif',
#  'vulner servic detect flow denial method inform',
#  'gener automat csp specif',
#  'descript implement embed languag haskel',
#  'compon calculu',
#  'semant specif object-ori action',
#  'j2me develop aspectj adapt applic',
#  'concurr type program languag object resourc mobil distribut comput',
#  'code constant predic propag',
#  'event-driven reactiv tupl space luat',
#  'lazi cyclic refer count',
#  'aspect weav strategi',
#  'model constraint languag object orient xml specifi xocl logic',
#  'asynchron invoc method remot java',
#  'infer type implement practic haskel recurs polymorph',
#  'pattern match depend type',
#  'parallel program made haskel simpl effici',
#  'ontology-bas manag knowledg reason case-bas match structur perfect',
#  'manag knowledg soft factor effect strong',
#  'knowledg organ mainten softwar',
#  'experi librari build pleaser block schema base',
#  'examplet reus case-bas softwar',
#  'knowledg manag busi effect integr top-',
#  'starting-point defin culture-bound user system design learn adapt characterist',
#  'robert manag knowledg note gmbh bosch oe-sal area culture-sensit',
#  'ontology-bas semanticmin knowledg retriev',
#  'ontology-bas librarian manag knowledg agent system role',
#  'knowledg organiz manag risk',
#  'model iwim automaton coordin semant multipli hierarch',
#  'function class relativ',
#  'experiment assist engin studi softwar',
#  'object rout relat action vector spatial model',
#  'tempor granular convers direct',
#  'uncertainti tempor fuzzi reason',
#  'detect represent symmetri object structur abstract',
#  'tempor neighborhood proposit interv logic',
#  'compar reason graph case-bas map',
#  'topolog motion time integr model',
#  'reason appli calculu spatial access',
#  'properti region propag reason',
#  'inoteroper protocol wireless approach applic test',
#  'difficult introduc solut school e-learn',
#  'analysi system design high develop method origin level asm',
#  'complex languag polynomi time-spac implicit recurs class',
#  'manag knowledg model power applic',
#  'compon system gener',
#  'membran power creation rule comput',
#  'fine note comput',
#  'internet democraci possibl',
#  'societi telecommun caus mobil',
#  'analysi visualis bibliometr capit intellectu',
#  'domain knowledg interact mental share build role histori legal model',
#  'understand manag knowledg organis capit ground learn intellectu process',
#  'discoveri knowledg expert demand',
#  'knowledg transfer network develop recycl foster sustain',
#  'ontology-bas manag challeng goal skill opportun',
#  'knowledg implement concept commun foster',
#  'knowledg manag overload knowledge-attention-gap underestim inform problem',
#  'metadata retriev databas imag content-bas effici',
#  'mine gener map text topic',
#  'manag knowledg block build approach node distribut',
#  'system queri retriev instanc memori improv expans inform cooper',
#  'manag knowledg design usage-cent softwar interfac',
#  'knowledg thesauri retriev autom sourc gazett internet',
#  'expect exploit softwar experi',
#  'manag knowledg user system exchang synchron shark mobil group',
#  'manag knowledg focus user access distribut',
#  'knowledg visual archiv film extract video',
#  'diagram sequenc framework semant uml pv',
#  'optim algorithm network atm rout global flood provis bound hierarch',
#  'heyt languag formal algebra',
#  'bank team-ori interact co-op select european learn distanc applic strategi',
#  'knowledg prospect programm project web grid space',
#  'extent optim arithmet unconstrain affin global applic',
#  'plagiar set jplag',
#  'hd0l seri power simplif',
#  'synset type wordnet gener semiautomat cluster',
#  'path-find three-tier architectur',
#  'classifi object-bas system design repres relat structur spatial',
#  'dimens multipl agent spatial-reason',
#  'granul interv reason',
#  'enviro task servic schedul team indoor mobil autonom robot',
#  'mental dynam repres exampl',
#  'design implement develop hyperlink softwar approach object-ori base usual structur specif',
#  'trailtrec appli framework concept trail hypermedia open',
#  'research structur comput',
#  'interact annot meta-data retriev xml semant mpeg',
#  'design hypermedia engin challeng',
#  'hypertext model compon context-sensit',
#  'multimedia encyclopedia softwar',
#  'hypermedia structur xml-base',
#  'employ servic hyperwav hwoe onlin',
#  'observ sourc agent model',
#  'complex languag synchron context-fre comput',
#  'word distanc addit quasi_dist',
#  'algorithm information-theoretical-bas find partit median',
#  'quasi-product tree automata',
#  'complex descript resourc machin limit',
#  'simpli differ number base normal',
#  'word languag closur primit oper',
#  'regular languag shuffl decomposit',
#  'remark defin code petri net',
#  'synchron stabil finit automata',
#  'finite-delay decod error-correct',
#  'word infinit hierarchi bridg',
#  'hyperbol tile pentagon plane singl',
#  'symport rule system power',
#  'constant gener finit synchron automata',
#  'larg disjunct sequenc set',
#  'determinist fast algorithm finit automata minim acycl simpl construct',
#  'ration addit semir',
#  'gener disco toolset',
#  'environ korrigan',
#  'reusabl gener fred proof real approach correct program',
#  'attribut gener term graph declar program',
#  'environ verif raven analyz real-tim',
#  'control architectur verif softwar open industri',
#  'decis studi arithmet practic presburg extens univers case mechan procedur',
#  'parameter protocol verif',
#  'system sequenc relview',
#  'reactiv system diagram design refin',
#  'check real-tim effici correct model',
#  'coalgebra languag ccsl specif class',
#  'leadership schoolteach evalu system ict develop web-bas train improv in-servic',
#  'environ collabor web-bas learn support agent-ori',
#  'write environ efl synchron internet',
#  'represent lear guidanc discours',
#  'write languag platform onlin teacher',
#  'load redistribut problem message-minim',
#  'complex method symmetri reduct comput',
#  'manag knowledg countri poverty-stricken crisi',
#  'geometri easi recent question solut comput',
#  'manag telecommun servic challeng',
#  'educ futur scienc glimps comput',
#  'tube wrap',
#  'graphic librari demand futur recent solut problem',
#  'issu compil',
#  'teach tomorrow anim purpos',
#  'internet secur',
#  'multimedia retriev mpeg relev content-bas',
#  'organ learn',
#  'sustain knowledg job economi',
#  'manag knowledg superorgan',
#  'analysi knowledg visual discov',
#  'manag knowledg environ collabor virtual',
#  'standard metadata',
#  'manag knowledg digit person librari',
#  'richli knowledg soft seal-ii unstructur structur spot',
#  'manag knowledg tour servic guid framework siemen busi',
#  'societi knowledg adult learn inform',
#  'effort manag knowledg success',
#  'systemat calculu test-design approach refin base abstract',
#  'formal engin teach techniqu thought text book softwar differ plan base',
#  'transit vdm vdl',
#  'develop ten histor vdmtool bootstrap year',
#  'mac mathemat view eclect airchinnigh irish school luca construct',
#  'solo bagatel arrang vdm',
#  'high perform data specif distribut comput',
#  'univers virtual',
#  'equival dt0l problem',
#  'computer-medi affect frequenc develop durat messag impress commun',
#  'neural abstract machin',
#  'formal run sdl asm definit specif compil model',
#  'automat asm-bas sequenc criteria coverag test',
#  'partial updat explor',
#  'gener verif asm simul refin',
#  'abstract compil state machin',
#  'logic abstract state machin',
#  'model protocol cach locat verif memori state consist specif abstract machin',
#  'np-hard gener graph proof variant color',
#  'transclus centuri st',
#  'languag map codifi matrix parikh',
#  'measur learn effici',
#  'nondetermin determin count altern',
#  'tailor word collabor processor',
#  'control specul processor simultan multithread',
#  'price fpga rout',
#  'societi complex inform system',
#  'invis workplac process',
#  'chemistri undergradu curriculum integr applic electron structur comput',
#  'system methodolog tool improv continu',
#  'knowledg design coffein construct present',
#  'system x-machin approach commun',
#  'conceptu large-scal hypermedia treeworld model',
#  'manag knowledg environment informat',
#  'workload rdbms-www heavi perform interfac',
#  'algorithm lattic fold implic pattern protein invari crystal',
#  'light requir control studi case state machin abstract captur',
#  'light requir control scr studi appli method case',
#  'light control forest studi case approach applic',
#  'light requir control studi develop increment case real-tim',
#  'light-control evalu requir studi nimbu case captur',
#  'light control system analyz pv',
#  'function p-time identif class effici',
#  'align product languag search framework pars compress unif natur syntax multipl inform',
#  'kth-order s-box nonhomomorph',
#  'algorithm dynam specul mem-slic partit thread',
#  'switch architectur perform block multithread',
#  'architectur schedul cach dataflow perform execut',
#  'msparc real-tim multithread architectur',
#  'protocol system grammar negat condit cooper',
#  'incomplet linear time',
#  'document implement concept activ applic',
#  'element style techniqu specif structur',
#  'hyperbol cellular plane automata tool',
#  'constraint uncertainti quantifi propag approxim heterogen solv algebra',
#  'switch system map comput nonlinear',
#  'system dynam behavior relat net inform model',
#  'ieee elect leader formal appli method survey',
#  'admiss interfer nondeterminist',
#  'statechart outlin semant uml pv',
#  'observation-ori perspect specif formal',
#  'algorithm problem solv motion plan',
#  'read function program logic',
#  'control studi verifi system method specifi case real-tim',
#  'termin esfp ensur',
#  'system inclus weak',
#  'pseudo_wajsberg lattic structur algebra',
#  'pi-calculu machin',
#  'data galoi mine connect',
#  'coher behaviour specif object-ori algebra',
#  'pseudo-boolean horn quadrat function monoton',
#  'represent monad algebra theorem pavelka',
#  'categori semiring relat enrich mix',
#  'kraft-chaitin set extens free-extend prefix-fre theorem',
#  'hypercub group automorph',
#  'iv mvn connect lukasiewicz-moisil n-valu algebra',
#  'logic substructur canon construct model',
#  'shift complementar space comput',
#  'sign bool',
#  'system simul',
#  'note pa-ord partially-ord scienc relat comput structur semir',
#  'extractor world real',
#  'interaction-ori tableau transform search-ori proof calculi',
#  'data automat restructur',
#  'evalu algorithm formula boolean averag perform case demand-driven',
#  'gate theoret revers aspect group logic',
#  'divis float point applic determin expans comput',
#  'scheme share random multi-secret',
#  'architectur environ web survey wireless commun',
#  'align reason introduct search compress unif overview multipl probabilist inform',
#  'x-machin commun stream system',
#  'distribut issu languag pictur relat process',
#  'hyperbol cellular sat polynomi plane automata space solut',
#  'decomposit time automata',
#  'iter tree case splice',
#  'transform formal system background verif fault-toler classif approach specif',
#  'tree advanc fault model',
#  'life laha gener comput time applic distribut model',
#  'code bounded-weight note error-correct',
#  'ture reduct posit power',
#  'algorithm mount multi-head surfac machin plan',
#  'calculu durat method decis',
#  'align search compress unif multipl inform comput',
#  'interv bodi convex algebra',
#  'equat solut interv class algebra',
#  'interv model measur uncertainti',
#  'evalu compar multimedia product print inform review electron',
#  'educ evalu multimedia context',
#  'reason knowledge-build key condit assess computer-bas commun process',
#  'educ evalu design share bridg qualit effect memori approach quantit',
#  'system challeng www-base learn assess opportun',
#  'evalu round chebyshev perturb simul error seri',
#  'hierarchi queri order polynomi',
#  'interact confer design develop video role proceed',
#  'assist neural agent shape web link-bas hypermedia',
#  'advic note karp-lipton set linear-nondetermin linear-',
#  'move simul pram hash thread',
#  'basic gener properti scheme share nonperfect secret',
#  'context categoris',
#  'engin select web search retriev result view effect improv',
#  'lua flexibl web extens build applic',
#  'hybrid adapt subdivis routin integr strategi',
#  'key relat databas schema number',
#  'employ structur design practic exist function tool versu pattern recov',
#  'key relat databas schema deriv linear',
#  'shannon symbol text compress rank recod',
#  'programm hardwar prototyp pc',
#  'type modul extens pointer compat refer paramet',
#  'abstract recurs state machin',
#  'shortest studi path constrain asm case',
#  'life develop asm softwar cycl integr',
#  'montag languag realist specif program',
#  'oberon specif formal',
#  'code product cell asm refin specif',
#  'asm-approach compil back-end construct correct',
#  'filter news manag framework data distribut',
#  'technolog manag knowledg inform',
#  'organis negoti memori construct reconstruct',
#  'knowledg manag prospect challeng practic corpor memori industri',
#  'environ ministeri complementari tool',
#  'knowledg engin document sharabl product languag natur approach',
#  'knowledg ariadn flexibl coordin support work',
#  'filter agent text profil inform',
#  'automat descript optim paperfold sequenc',
#  'web-bas train aspect',
#  'note overflow detect proof adder number complement correct logic',
#  'control discretionari hash function databas',
#  'free overlap place',
#  'function highli t-resili nonlinear',
#  'independ monstr suspend semant ii',
#  'scheme assign perform work-greedi bound',
#  'filter parallel algorithm design distribut implement stack',
#  'code scheme multisecret-shar linear error-correct',
#  'architectur mtac vliw pram simul multithread',
#  'forum neg explicit result',
#  'analysi formal system kerbero authent',
#  'sdl semant state machin abstract',
#  'gener specif bia',
#  'parallel structur document comput',
#  'persist confluenc',
#  'aspect problem construct dirichlet',
#  'reduc chaitin number strong',
#  'code prefix optimum extend',
#  'incomplet determinist minim automata',
#  'order ideal note set graph obstruct monad',
#  'order ideal obstruct lower minor parameter mani',
#  'variable-length code encod decod format repres fixed-length t-deplet',
#  'properti invari sequenc random',
#  'set function grow cantor surject comput',
#  'complet intermedi effect theorem logic',
#  'map mathemat sequenti continu linear construct',
#  'agent flow arrow imperfect commun inform logic',
#  'concept famili dortmund applic hypermedia model',
#  'optim algorithm parallel learn dfa',
#  'difficulti box strong cryptograph substitut construct',
#  'teach technolog distanc integr inform multimedia-bas',
#  'educ design product tv aspect video distanc',
#  'design asic home',
#  'teach distanc publish media',
#  'knowledg combin heterogen repositori inform',
#  'function monoton ceil boolean',
#  'disjunct number omega-word real',
#  'edge-flip triangul distanc',
#  'unifi late teach environ learn concept',
#  'human cooper classroom computer-support electron',
#  'remark partition-limit system propag etol',
#  'serial gener t-code compress data commun',
#  'coursewar deliv www hypertext base',
#  'www-aid improv evalu instruct',
#  'fit uncertainti biolog curv data interpol',
#  'system reason approxim applic inform inexact',
#  'comparison sequenc biolog dedic hardwar',
#  'monstr issu fundament design',
#  'regular power languag splice restrict rule',
#  'complet pseudosimpl set',
#  'system variant grammar team cooper',
#  'architectur system referenti distribut integr scalabl inform maintain',
#  'characterist function propag relationship cryptograph nonlinear',
#  'network inform hyper-',
#  'www',
#  'internet gopher evolut',
#  'vertic algorithm graph biconnect st-number distribut effici',
#  'geometri method differenti prove mechan theorem',
#  'digit teach librari learn support',
#  'high-spe design chip path rsab crypto data test',
#  'www comparison hyper-',
#  'heat equat finit round-',
#  'lcf represent ration lexicograph binari',
#  'on-lin accur arithmet radix high credibl comput',
#  'arithmet interv applic direct',
#  'serial digit arithmet',
#  'ieee formal arithmet implement correct comput',
#  'modular reduct rang',
#  'eco-grammar condit system tabl',
#  'environ hypermedia home object',
#  'internet patent softwar',
#  'monstr pi-calculu translat',
#  'system cach network file distribut',
#  'assist person comput',
#  'aperiod wang cube set',
#  'hypermedia',
#  'author fli',
#  'constraint age inform agent',
#  'territori word prime go-lik parikh',
#  'parallel constraint exploit qualit satisfact simul',
#  'level anonym',
#  'string random',
#  'estim divis high-radix approxim quotient-digit',
#  'tree implement work-optim mesh erew',
#  'grammar oper base shuffl',
#  'write scientif reason broca environ computer mediat',
#  'text compress ziv-lempel differenti',
#  'algorithm exponenti decreas affin function distanc match',
#  'problem network-on-chip map multi-object approach genet',
#  'box pareto-optim hardwar substitut',
#  'automat fault program methodolog monitor hardwar electron',
#  'evolutionari algorithm design method circuit search multi-object pattern problem',
#  'evolutionari multius ds/cdma algorithm detect',
#  'metric on-lin constraint tempor finit altern time-seri automata monitor',
#  'revers karatsuba algorithm',
#  'hierarchi graph complet exact domat uncolor boolean exact-four-color survey minim number problem',
#  'manag issu pervas technolog synergi util health',
#  'assist place support monitor health age',
#  'system arrhythmia tele-assist real-tim monitor dedic cardiac',
#  'cammd devic mobil medic context-awar',
#  'provis impact home behavior technolog care monitor health',
#  'collabor research system biomed',
#  'system tele-hom healthcar pervas multimod',
#  'design healthcar privaci qop qualiti applic ubiquit',
#  'visual servic confer context technolog approach rfid',
#  'environ ambient mechan conflict intellig solv',
#  'emilet enabl reflect framework ami',
#  'architectur network sensor modular wireless node',
#  'compon develop ambient aspect applic',
#  'hybrid manag ocp architectur system contextu inform model',
#  'manag trust servic network ad-hoc discoveri secur base',
#  'danger monopoli engin web search connect view dot restrict',
#  'inherit system coercion kenzo model',
#  'architectur descript formal system languag tempor symbol transit base logic',
#  'persian/arab captcha baffletext',
#  'logic optim design languag yap compil program',
#  'challeng gener program process algebra',
#  'optim experi just-in-tim sun java compil',
#  'detect smell bad aspectj',
#  'slice program calcul',
#  'design pattern languag visitor',
#  'mobil haskel strong',
#  'interoper object system model',
#  'servic express web case pattern pew workflow',
#  'defin diagram composit atom behavior uml',
#  'type-saf queri languag object version',
#  'larg assimil numer scale observ simul fusion sequenti inform data',
#  'unsupervis discov interest data tabl',
#  'secreci introduct random',
#  'gener compromis imposs pseudorandom number',
#  'cryptographi quantum progress comput',
#  'formal languag boolean repres function implicitli membership test',
#  'exponential-tim determinist algorithm domat satisfi color improv number random problem',
#  'theori random algorithm complex',
#  'properti term behaviour prove observ specif',
#  'estim fingerprint algorithm verif enhanc orient ridg',
#  'telemetri fault neural sensor compress predictor toler data',
#  'revisit time-vari system',
#  'domain lattic constraint scheme interv branch',
#  'analysi constraint method sequenc biolog base',
#  'process global bisimul equival',
#  'verifi properti tccp real-tim program',
#  'theori failur implement functional-log construct program',
#  'crwl program rewrit verif logic',
#  'introduc tutori tool itp',
#  'xpath languag magic set',
#  'multi-adjoint logic operational/interpret unfold program',
#  'survey plagiar',
#  'institut gener behavior refin hidden logic',
#  'analysi elect leader prism variat ring anonym itai-rodeh',
#  'join-set elimin assign static singl redund comput',
#  'transform emerg shape web consum commun inform',
#  'mutual queue algorithm migrat exclus',
#  'petri relat causal live net characteris structur',
#  'user algorithm enterpris system cluster poca distribut',
#  'evalu creation knowledge-bas fuzzi',
#  'web uml-bas applic data-ori model',
#  'design implement enum-bas servic',
#  'cach server perform proxi model',
#  'system develop exact plant classif qualiti improv',
#  'extens cql databas dynam',
#  'rule-bas japlo java program',
#  'season lymphoid method time leukaemia data childhood acut seri analys',
#  'system crop softwar analys model',
#  'interact architectur geo-bas client-serv portal web technolog modern',
#  'sequenc neighborhood retriev databas imag applic process',
#  'higher educ flexibl student internet profil base cours model',
#  'endocrin mathemat system model',
#  'applic wavelet construct',
#  'topolog network wireless resourc mainten effici',
#  'system membran graphic oper comput',
#  'estim theori paramet approach inform distribut cauchi',
#  'human visual phasetransition-lik inform process chang',
#  'societi primari teacher school inform',
#  'protocol addit time-releas kudo-mathuria examin',
#  'synthesi optim structur workflow',
#  'educ complex engin system it-bas technolog approach',
#  'educ informat scienc comput logic',
#  'independ system project medip-platform imag softwar medic process',
#  'agent-bas system recommend negoti improv',
#  'estim system describ relat observ paramet noisi',
#  'knowledg set experi ontolog owl structur',
#  'placement fault system place isol event point invari',
#  'rule-bas system agent implement negoti autom price',
#  'path predict framework behavior case internet data',
#  'incomplet order partit consensu deriv cover hierarch',
#  'depend attribut valu consensu determin interv',
#  'user system utter speech auto dialog respons rate entrain',
#  'system global memori space conic',
#  'interact environ immers convers build',
#  'human system avatar-bas real-tim proxi commun',
#  'analysi knowledg circul convers quanta',
#  'algorithm ae implement circuit increas perform fpga runtim',
#  'estim architectur vari illumin motion real-tim condit robust',
#  'self-tim design implement microprocessor fpga amcc',
#  'set implement sequenc complementari interleav correl hardwar effici',
#  'evalu system chip vision perform reconfigurable/programm limit',
#  'implement dynam fpga idea',
#  'pipelin loop data-depend sequenc',
#  'requir formal verifi method valid specifi',
#  'theori formal method practic becom',
#  'floating-point verif',
#  'check softwar model',
#  'mainstream formal method autom enter',
#  'verif grand challeng',
#  'method realis formal benefit',
#  'code softwar',
#  'formal system represent learn configur methodolog e-learn scenario',
#  'posit root method comparison polynomi variou bound comput',
#  'applic digit emerg develop journal mashup paradigm',
#  'compile-tim function polytim comput',
#  'system payment transact internet',
#  'cultur copyright manag e-commerc system servic digit web protect inform provid',
#  'refin control specif access',
#  'servic web commut atom achiev action',
#  'manag architectur system reflect augment databas',
#  'atom improv correct program',
#  'webquest deadlock studi synchron framework improv process',
#  'educ languag support author operation model',
#  'educ pipeline-schedul purpos simul',
#  'metadata design ontolog lo qualiti improv base instruct model',
#  'educ separ poeml unit flexibl support concern approach model',
#  'creat engin graduat onlin degre mexico univers',
#  'editor handheld hme educ context model',
#  'digit design environ collabor game learn',
#  'cetl reusabl perspect network collabor map learn object year academ',
#  'handheld collabor composit web foreign languag tool comput',
#  'moodl design map learn step im',
#  'languag cml model',
#  'architectur propos constraint',
#  'logic verif law condit object-ori program',
#  'remov lalr conflict methodolog',
#  'advic optim aspect',
#  'languag anim visual simul',
#  'aspectlua reus achiev re-aspectlua',
#  'spreadsheet tabular abstract program',
#  'architectur concurr system count cyclic lazi refer multi-processor',
#  'count cyclic object refer perman',
#  'extens languag api',
#  'lazi function slice higher-ord',
#  'overload close support coexist world definit open',
#  'semant visitor action pattern',
#  'manag knowledg servic select web qo base',
#  'conceptu manag knowledg sophi choreographi framework grammar ontolog model',
#  'manag task composit coursewar skill assign autom semantic-bas',
#  'programm engin gener develop instruct compet',
#  'futur link creat',
#  'attent learn reinforc focu',
#  'learn student distanc satisfact java cours program',
#  'applic gener extract tagger perform improv inform',
#  'co-evolut commun ehw approach',
#  'hybrid optim algorithm quadrat neighborhood fuzzi assign solv swarm variabl particl problem',
#  'neural algorithm process network chemic fuzzi base recurr genet model',
#  'signal architectur neural implement network scheme analog circuit cell process',
#  'system artifici forens immun base comput',
#  'detect address duplic autoconfigur olsr',
#  'dsr rout adapt extens sourc cluster hierarch',
#  'manet servic rout qualiti olsr',
#  'vca algorithm network sensor cluster voting-bas energy-effici',
#  'ad balanc hoc protocol reactiv cach load rout energi enhanc node effici',
#  'nonã‚â\xadstrict languag platform function net compil',
#  'ciphertext constant size hibe extens augment selective-id model',
#  'deduct system pedagog proposit natur case',
#  'metadata queri method tempor video interv access effici',
#  'proxim explor classroom applic mobil sensemak',
#  'digit algorithm polygon approxim curv approach swarm base particl discret',
#  'metric svm similar improv base',
#  'scientif learning-bas extract machin literatur keyword',
#  'model mine express gene rule immun program',
#  'independ spectral densest graph subgraph number',
#  'contribut perfect graph-theoret polyhex recent match benzenoid',
#  'transform automata behaviour equival',
#  'gray code',
#  'filter evolutionari network connect processor accept',
#  'steiner analysi tree algorithm',
#  'attempt algebra treat part',
#  'graph spars grade matroid',
#  'regular asymptot map nonexpans halpern iter rate',
#  'stabl bipartit matric graph',
#  'control system neural astrocyte-lik spike',
#  'interact high-level regist voic structur program',
#  'balanc system set finit applic',
#  'metric-entropi lattic pair',
#  'network sign reachabl connect',
#  'graph hamilton topolog grid',
#  'depend system graph co-design methodolog hardware/softwar verif level base',
#  'net petri self-evolv',
#  'implement theoret web e-bart altern sevic',
#  'tree protocol formal check deduct modul proof integr perlman stp span',
#  'set system implement languag declar translat odedialect ontolog',
#  'ontology-bas content web creation framework adapt semant',
#  'element rdf visual rank schema applic',
#  'semant keyword discov user',
#  'agent network search sewasi semant mediat',
#  'ontology-bas domain mine retriev support biolog text approach inform',
#  'asynchron servic commun collabor synchron support trade-',
#  'educ search support semant tool ontoolcol cscl',
#  'interact seamless collabor connect transit disconnect',
#  'service-ori unit collabor support ad-hoc integr mobil scenario',
#  'architectur compon meet pda pattern',
#  'script control architectur environ collabor',
#  'themat segment text cluster evolv',
#  'history-sci document informat impact historian xml tool markup mediev',
#  'handwrit recognit appli zone mechan metaclass',
#  'classifi off-lin signatur combin verif roc-spac',
#  'artefact remov table-form extract',
#  'remov detail document algorithm interfer method back-to-front assess quantit',
#  'hybrid separ method foreground/background methodolog histor manuscript arab',
#  'remov algorithm document interfer back-to-front binar',
#  'recognit method symbol learn progress',
#  'fair set multi-',
#  'nmac/hmac popular result function instanti hash',
#  'key exchang parallel',
#  'transfer scheme oblivi k-out-of-',
#  'key-shar protocol unknown key attack agreement bilater',
#  'formal roam privacy-preserv extens definit secur construct effici',
#  'public certificateless encrypt key attack standard malici secur kgc model',
#  'scalar parallel koblitz formul curv multipl',
#  'knowledg organ network wiki-bas analyz improv process',
#  'ruler algorithm fold approxim time linear problem',
#  'success commun factor weblog',
#  'advertis interact compens model',
#  'queri network pine road base spatial',
#  'estim passiv qualiti experi',
#  'trade link market path bandwidth commun',
#  'servic qo cost bitstream paramet access model',
#  'zrtp enhanc puzzl',
#  'barrier perspect develop drive broadband access ce',
#  'optim perspect learn negoti transit price distribut',
#  'market size bandwidth dynam game cost effect price provis',
#  'analysi model failur network risk econom correl commun normal copula',
#  'attack zrtp aspect man-in-the-middl secur usabl',
#  'ecosystem commun qualiti experi',
#  'traffic estim model aggreg behavior approxim scenario',
#  'riesz compact represent hausdorff local space comput',
#  'set multi-repres program close multi-funct comput',
#  'constant famou subrecurs sever comput',
#  'topolog pressur physic shift sofic applic statist comput',
#  'bloch constant comput',
#  'analysi system weak integr riemann',
#  'weight optim bit-complex find rule integr quadratur nearli',
#  'repres notion space probabilist comput',
#  'filter weak space limit relationship',
#  'nig fan hypothesi proof lemma equival uniqu direct brouwer theorem',
#  'classifi na driven explan bay multipl',
#  'mobidi educ portal',
#  'conceptu design framework learn create-by-reus approach solut',
#  'educ research public scienc bia literatur comput',
#  'english formal agent-bas finit state auction',
#  'system partial retriev rank relev judgement',
#  'evalu system algorithm methodolog alloc wireless resourc simul improv commun multi-ag model',
#  'manag agent-bas dynam suppli solut chain',
#  'ad knowledg hoc topolog agent network bit-map discoveri mobil',
#  'evalu system perform structur multi-ag',
#  'transform social queri central network1 semant base',
#  'system agent map action integr schema p2p data',
#  'market learn futur simul reinforc',
#  'analysi domain-specif architectur foundat framework interpret softwar model',
#  'mine compon embed product line techniqu softwar revit',
#  'requir compon system experi select cost autom cot base',
#  'retriev tool legaci inform lift',
#  'architectur servic mismatch web avoid softwar',
#  'crossmda manag model-driven aspect approach',
#  'annot product model-driven techniqu tool deriv base',
#  'service-ori develop web applic process',
#  'space efremovi condit complement',
#  'program perspect method binari clo',
#  'special lisp object-ori custom',
#  'clim implement type present',
#  'context-ori system ambient object program',
#  'ucl-glorp common orm lisp',
#  'theori reason implement tempor lisp tool qualit s-languag inform',
#  'visual interact nasdaq veloc activ forc chang',
#  'groupwar collabor support shared-workspac inform',
#  'groupwar user ciam develop methodolog interfac',
#  'conceptu user group-awar gener collabor scheme plastic framework explicit interfac',
#  'domain defin task studi system space-design convers act case cscw',
#  'requir interact transform technolog base mda captur model',
#  'evalu cognit walkthrough test academia spanish-speak heurist websit usabl',
#  'environ eas semi-automat smart home adapt percept',
#  'task system develop collabor ambient intellig base model',
#  'evalu assist design tool websit weba',
#  'larg featur document select classif collect',
#  'handov automat retrial user guarante seamless redial mobil',
#  'manag knowledg meet learn activ enhanc applic inform access',
#  'implement core perceptron configur fuzzi devic function gui ip activ multilay logic',
#  'applic journal digit',
#  'network learn latent object support repositori',
#  'web search',
#  'taxonomi design product web train support macro',
#  'formal entertain game semant media industri',
#  'metadata content imagesemant user-gener',
#  'mass inform integr',
#  'web languag autom workflow',
#  'structure-bas web hidden crawl',
#  'experiment studi page semant data-intensiveweb relationship structur',
#  'resili inform extract explor',
#  'visual segment web page extract recognis block',
#  'studi modular product line case jbook softwar theorem',
#  'engin languag state simul metamodel-bas abstract machin',
#  'engin system languag time state machin real-tim abstract',
#  'logic model-check predic time state simul abstract machin',
#  'invari refin asm preserv',
#  'architectur asm servic orient',
#  'secur protocol correct',
#  'practic adapt techniqu survey softwar',
#  'compon system framework adapt java-bas logic',
#  'mismatch composit adapt behaviour interfac run-tim',
#  'safe develop dynam framework adapt softwar aspect-ori',
#  'user rux-method web adapt multidevic interfac',
#  'knowledg system metasynthesi intellig process',
#  'agent learn framework increment softwar ap',
#  'trade market agent power pattern microstructur surveil',
#  'agent-bas system payment perspect wireless non-repudi mechan mobil pki',
#  'optim algorithm cach load cdn rad',
#  'workforc exchang alloc resourc pathway solut intellig problem',
#  'traffic manag agent-bas approach',
#  'posit lb system implement u-campu prototyp',
#  'system agent web search semant enhanc applic base tag meta',
#  'tabu search gpu',
#  'segment set multi-lay method level imag',
#  'automat induct investig altern fuzzi rule approach base',
#  'steiner hybrid tree algorithm prize collect transgenet problem',
#  'hybrid time-depend optim algorithm network bu',
#  'evolutionari quantum-inspir finit synchron assign state machin',
#  'optim network sensor layout multi-object',
#  'algorithm gadym design problem mechan genet',
#  'featur select problem step',
#  'stochast evolut strategi parallel',
#  'base recommend learner swarm intellig cours e-learn',
#  'back decis support bay intellig medicin',
#  'hci countri ibero-american state',
#  'evalu ergonom cognit develop interfac',
#  'cultur phone usag factor adopt mobil model',
#  'aula user ciam studi design collabor case interfac applic',
#  'develop web support applic access',
#  'ergonom cognit discuss design move scienc interfac',
#  'analysi log aeh improv cours',
#  'automat ad spiral adapt author hypermedia model',
#  'domain ontolog model',
#  'design sequenc learn adapt author im rich cours',
#  'task author activ space social-awar',
#  'model gener standards-bas dynam learn adapt approach scenario',
#  'author educ onlin cultur',
#  'school board creat set environ game adapt elg',
#  'archiv annot digit document architectur gener convers semant collect',
#  'digit systemat languag object extens characteris preserv',
#  'project stereoscop represent classif crime scene',
#  'adverb verif author',
#  'word resolut system ultra recognit hmm open-vocabulari language-independ base low',
#  'depend document network layout stack structur',
#  'techniqu evalu binar algorithm',
#  'compar implement grid bigbatch aspect cluster',
#  ...]

# %% [markdown]
# ### Rake Keyword

# %%
rakeKeyword = setRakeInPreWords(rakeKeyword)
# Out:
# knowledg knowledge-intens gener wiki process-ori commun structur process cooper
# assur profession studi empir learn train computer-support qualiti workplac cooper
# experience-bas system agent pedagog arrang learn weblog micro-didact space wiki inform
# manag filter knowledg inform collabor method introduct retriev ontolog context-awar busi process model
# manag visual knowledg inform metaphor project commun storytel
# manag knowledg workflow
# manag knowledg inter-organiz network collabor busi
# manag knowledg knowledge-intens descript k-model languag process-ori busi process model
# knowledg manag research market enterpris tool softwar busi process
# manag knowledg theori busi instrument activ work infrastructur stanc process model
# manag knowledg system data base inform
# process manag knowledg servic
# prover formal concurr proof atom refin
# formal develop method atom observ refin
# asynchron relax verif atom commun process algebra
# formal compens ing method languag transact long-runn semant specif
# system isol replic broadcast atom quorum
# formal depend method languag transact atom hardwar program
# concurr develop transact atom softwar monitor ocl uml
# cach transact coher atom memori
# analysi visual mine subgroup data
# visual reput social network flow inform
# analysi visual grand tour method cluster curv andrew data exploratori
# data visual mine icon
# visual segment mine explor connect data
# incomplet mine decis diagram function minim data specifi
# domain visual interact tempor data medic inform
# visual explor techniqu multiresolut data
# intrus system detect wireless antenna
# evalu public infrastructur key fuzzi techniqu secur polici
# audio lsb code hide steganographi data
# intrus protocol detect abus secur cryptograph comput
# ad re-key hoc protocol group network dsr rout perform secur commun
# evolutionari algorithm cryptographi co-design addition-chain genet comput
# fair protocol deliveri exchang certifi non-repudi secur
# system agent qualiti inform multi-ag
# digit system backup file snapshot consist forens oper checkpoint
# manag theori perfect algorithm one-tim key pad protect secur inform secreci data
# theori digit system multimedia code librari inform
# manag theori market game databas resourc inform strategi distribut
# control ded system dynam event synthesi discret
# life complex architectur system adapt softwar cycl
# brows collabor web ontolog work
# cognit agent formula ground languag satisfact modal commun logic
# rosa mine system recommend web person retriev adapt inform
# knowledg method consensu conflict inconsist
# hybrid user system method web-bas adapt consensu interfac
# dimension queri high databas rang spatiotempor structur data model
# parallel constraint implement time actor execut comput
# manag protocol rtcp multimedia scalabl commun distribut
# automat algorithm gener flow test softwar data genet
# algorithm circuit cad rout global integr
# structur system multimedia web-bas author applic hypermedia transclus xanalog publish
# fat cube architectur topolog network router collect interconnect commun
# formal autom softwar specif object-ori test
# system verifi public-key mix-net paillier privaci huffl
# b2c e-commerc agent technolog ontolog intellig
# tree uowhf function binari hash
# check reactiv system modular verif techniqu actor abstract model
# complex t-decomposit entropi measur pars comput
# free tree anneal skeleton geometri graph straight simul draw comput
# modular languag semant action oper structur program
# logic descript arithmet gener languag circuit function hardwar structur program
# coroutin hash virtual closur machin abl compil
# mop lua dynam reflect aspect aop
# manag final semant memori collect garbag
# formal servic web languag semant program
# interoper languag virtual function haskel machin net compil program
# languag bytecod virtual common runtim machin compil
# dynam optim just-in-tim compil
# dataflow function comonad law stream distribut comput
# analysi equat formal semant execut specif program
# program languag function haskel mobil comput
# drift tree decis concept increment data stream
# mine resource-awar cluster data stream comput
# intrus resolut detect network secur first-ord logic
# brows analysi mine usag web semant pattern
# servic trigger predict qo time qualiti seri stream model
# mine algorithm single-pass data stream chang
# drift decis learn classif increment concept rule data stream
# posit root equat polynomi bound
# order set partial supremum mathemat construct
# uniform revers mathemat continu construct
# analysi function comput
# cellular automaton omega halt probabl
# analysi ration function iter construct
# riesz formal topolog mathemat f-algebra space choic axiom construct
# logic filter intuitionist satur kripk ultraproduct ultrapow prime disjoint bisimul iter union model
# element posit hermitian mathemat banach state space construct algebra
# theori set algorithm sequenc binari inform random
# analysi theori lattic decid proof
# formal topolog coequalis predicativit quotient local construct
# theori set partial principl realiz combinatori brouwerian construct algebra
# caus determin refin construct process algebra
# markov chain construct
# regular posit topolog formal relat space real
# valu function compl databas axiomatis
# continu construct mathemat
# theori mathemat hilbert space oper construct
# determinist attractor system languag measur omega-languag function cantor hausdorff space simpl iter fractal
# analysi ration function iter construct
# analysi intuitionist intermedi perhap valu real theorem
# order geometri conjectur sylvest construct
# fine fine-continu sequenc fine-comput function effect space limit weakli recurs fine-sequenti comput
# educ unit collabor languag learn object e-learn model
# servic system multimedia web-bas web xml semant hypermedia
# conceptu interact exercis learn author tool
# interact context awar implicit ubiquit rfid comput
# teach collabor learn comput simul anim program
# lcm campu servic web learn object virtual lom author im tool museum scorm e-learn
# diagnosi cognit environ librari learn author tool trace error model
# domot collabor learn computer-support pda mobil comput
# educ servic multimedia web-bas hypertext/hypermedia internet
# metadata annot collabor learn object ontolog
# small-talk modul packag virtual rubi namespac java classbox class selector
# express modular embed coordin process algebra
# objectâ­orient formal composit object softwar specif
# compon code composit dynam aspect common orient net servic intermedi runtim assert autonom weav languag web manipul aspect-ori architectur program
# markov decis constraint composit reo coordin automata bisimul probabilist process
# reactiv compon system modular rebeca verif actor model
# interact type indic myers-brigg human-comput mbti e-learn
# elearn situat metadata learn
# user retriev learn object ontolog e-learn context-awar
# manag interact knowledg user design web-bas factor train usage-cent interfac pattern
# user context learn object e-learn
# user elearn learn adapt cscl model
# educ collabor game learn motiv constructiv game-bas
# teach personalis learn
# task algorithm schedul constraint graph direct preced distribut
# multi-dsp system schedul embed flow predict rapid perform data prototyp
# supervis fraud web-bas prevent exam assess secur
# manag system broker network practic learn commun
# organiz knowledg mental market capit practic ration retrospect trade-
# manag knowledg node commun distribut
# knowledg web share semant commun
# evolut process indigo introduct learn particip eparticip inspect improv distribut
# manag knowledg enterpris content intranet extranet practic e-learnin person technolog commun inform
# studi expert volkswagen telekom practic siemen case deutsch wiko net commun
# manag knowledg organ nebula perspect practic livingom liquid art-shta crystal commun
# visualis manag knowledg web practic semant discoveri commun
# knowledg trust social etiquett norm sociabl capit tacit practic explicit onlin commun
# system membran complet determin comput
# bond membran divis ture differenti cell comput
# evolut antiport system membran symport commun comput
# natur system entropi comput
# system membran maximum valu natur comput
# inhibitor promot univers system
# gate system revers fredkin conserv energy-bas logic
# parallel java system simul
# complex system membran problem bin class clip recogn pack comput
# membran natur distribut comput
# human manag knowledg competit advantag resourc integr strateg
# analysi knowledg audit social network flow map inventori
# knowledg descript skill match elicit logic
# disavow knowledg interact visual joint evas commun refus
# manag knowledg reason web case-bas semant
# analysi manag research knowledg develop univers process
# analysi manag research knowledg social distribut implement network collabor share practic localis expert appli commun strategi sustain
# knowledg metadata agreement share
# analysi formal semant concept relat databas lexic
# analysi formal graph search concept bipartit breadth
# mine lattic web retriev concept credo inform
# diagram automat layout lattic
# implic complex comput base
# analysi visual formal lattic mobil landmark vision concept local orient autonom galoi robot comput
# logic fil tableau automat check graphic method tempor buechi on-the-fli verif futur automata gil interv specif model
# abstract formal mac hine method notat sequenti commun uml process
# theori formal set reason autom heurist otter specif
# order formal decis sat search backtrack cnf verif partit heurist variabl bdd
# check formula implic combin sat boolean proposit static equival satisfi cec logic
# analysi model check decis diagram sat binari satisfi bmc reachabl bound bdd
# dag heurist check decis diagram state machin binari satisfi bound model
# check boolean atpg equival satisfi
# test object-ori softwar coverag
# multimedia compon system framework
# interact architectur service-ori servic composit web coordin connector softwar comput
# engin rewrit revers migrat rule data pattern
# servic portlet portal develop web component-bas applic
# engin agent system multi-ag methodolog softwar intellig agent-ori
# design process method softwar
# analysi manag resolut requir winwin negoti multi-criteria conflict inconsist prefer
# domain-specif evolut modular languag develop processor markup softwar approach mainten xml
# list conceptu knowledg visual annot link document digit hyperwav portal-system black librari search white futur activ repositori e-learn
# system design embed object_ori hardware/softwar processor application_specif synthesi highlevel instruct
# protocol formal method symbol bisimul noninterfer equivalence-check process algebra
# neural lempel-ziv network predict compress lossless two-stag
# cellular plane hyperbol automata
# collis root hash mod cyclic scatter primit techniqu storag prime full residu group strategi tabl
# system rewrit tissu grammar univers matrix comput
# semant oper
# function boolean decomposit equat
# system grid index file data multi-dimension structur spatial model
# warehous tempor relat databas algebra self-mainten data logic
# interschema properti sourc integr xml inform
# coroutin control lua gener languag structur
# relat coalgebra model coordin
# logic concurr rewrit modular languag ml semant program
# coordin atom concern action aspect-ori distribut program
# combin explicit function categor substitut program
# script interoper languag reflect
# languag tactic definit middlewar distribut program
# function program
# visual design environ develop redwood tool softwar snippet drag-and-drop program
# metaprogram transform gener framework tool java refactor object-ori program
# reactiv system concurr design modular action
# graph refin architectur abstract
# architectur transform driven model graph model-integr comput
# protocol model-check verif time parametr
# model transform graph develop model-bas verif softwar comput
# prove refin theorem
# logic check system design tempor multi-object object verif model
# transform equat reason ultra develop non-determinist function unfold-fold heapsort specif construct program
# tempor system-level verif simul emul logic
# reliabl verif
# requir formal constraint diagram verif plc-automata real-tim specif captur
# architectur check gener code implement compil certif correct program
# alia optim dummi verif alias
# permut optim sgi voc translat valid verif global rule pro condit compil
# independ visual archiv interact inform sign languag retriev map computer-support commun construct
# independ visual archiv inform converg multimedia languag retriev computer-support technolog commun construct
# implic futur societ technolog wearabl pc display comput
# visual archiv interact multimedia dynam languag retriev map computer-support movi abstract commun inform
# hyperbol cellular plane automata tilt
# system interschema properti sourc integr inform semi-structur cooper
# audiovisu archiv user engin queri thesauru person search semant mpeg profil faethon
# knowledg manag mine entiti extract map semant relat topic text corpora
# knowledg manag complex theori evolutionari practic semant cognitiv heterogen communit constructiv structur distribut
# manag knowledg train e-learn scenario
# signal filter weak strategi process
# manag research knowledg architectur algorithm collabor flow measur problem-centr opencp
# manag metal knowledg system kaon ontolog industri
# brows carrier context search map topic structur visual bearer key post-structur process domain word knowledg assist manag navig pre-structur busi engin tool base model
# balanc manag knowledg benefit measur scorecard
# seci manag knowledg cynefin optim scientif gener
# knowledg engin product jess ontolog rule plan xml base workflow
# manag knowledg social capit benchmark resourc cluster intellectu capabl
# manag knowledg prune ontolog structur comput
# manag knowledg system project develop pilot skill personnel compet
# knowledg capit individu explicit interpret custom integr collect intuit process
# manag knowledg represent skill ontolog matchmak
# repertori theori organis person measur learn role construct test
# human manag project skill databas resourc updat plan
# manag elearn personalis skill hypermedia
# repertori human manag knowledg theori studi develop grid approach skill techniqu case space competence-perform resourc compet
# manag knowledg transfer skill view resourc profil base compet
# knowledg problem environ learn skill simul assess structur solv
# educ manag train skill export portug
# manag knowledg groupwar awar expertis
# manag knowledg knowledge-intens organis ontolog memori group compet
# logic check system execution-bas tempor rapid monitor prototyp real-tim execut run-tim model
# domain-specif architectur transform formal model graph languag model-driven grammar model-integr specif comput
# coalgebra formal system design languag semant behavior level denot state-bas specif algebra
# protocol servic admiss interfer denial bisimul equivalence-check
# formal csp translat grammar specif uml model
# domain-specif descript embed languag hardwar
# semant coalgebra compon softwar
# formal semant action specif object-ori
# architectur separ adapt concern aop softwar aspect-ori applic program
# resourc mobil process-calculu distribut comput
# analysi constant optim code graph predic ssa-form data-flow valu propag ia
# system event-ori tupl space distribut program
# manag count refer memori cycl collect garbag
# object-ori aspect-ori program
# xmi meta-model xmlshema ocl xml uml
# asynchron invoc remot method distribut program
# infer type languag recurs polymorph program
# depend type dml match pattern
# parallel petri languag net fuction program
# manag knowledg reason web case-bas semant ontolog xml
# leadership cultur manag knowledg corpor
# manag knowledg ontolog mainten softwar
# manag knowledg experi base build block schema reus repositori schemata
# casebas reason retriev softwar reus
# diagnost knowledg check project measur km strategi integr busi cost-benefit
# cultur evalu user learn style dimens hci-
# manag knowledg cultur bosch decentr index
# manag knowledg represent retriev ontolog inform logic
# queri retriev ontolog refin inform
# plan manag knowledg risk
# automata fibrat iwim coordin
# separ oracl hierarchi function polynomial-tim class
# experiment user engin studi softwar interfac intellig object-ori model
# human descript cognit system perspect navig rout ellipt spatial
# constraint tempor granular time abstract
# theori reason necess tempor measur fuzzi relat approxim allen possibl interv
# transform axi medial reason recognit shape represent qualit spatial
# tableau system tempor axiomat interv logic
# hierarch analysi descript reason graph case-bas agronomi classif structur spatial logic
# logic reason constraint navig mobil tempor qualit integr autonom robot spatial program
# reason biolog bayesian molecular spatial qualit access
# rcc gi reason semant qualit data spatial
# protocol formal interoper wap complianc test
# wbt manag constructionist learn e-learn
# analysi model system design method state machin specif abstract comput
# complex predic time-spac implicit recurs class comput
# manag knowledg document agent system intellig data base inform
# handl compon system distribut network dinopoli transpar object aspect relat global java componentwar uniqu middlewar robust
# membran hierarchi rewrit chomski splice molecular comput
# analysi walsh comput
# cyber e-democraci speech freedom ethic internet legisl
# societi telecommun technolog internet mobil inform
# knowledg capit network map relat intellectu report
# informat search retriev histori legal inform
# situat manag knowledg absorpt organis interchang capit dynam prior learn capac intellectu capabl
# manag knowledg acquisit collabor languag natur distribut
# taxonomi knowledg transfer network develop recycl compani agenc sustain
# skill rdf manag ontolog
# manag knowledg transfer tool
# posit knowledg manag overload ignor agent document-explos intellig inform
# queri similarity-bas databas multi-criteria imag data oper repositori model
# knowledg manag mine map semant text topic relat corpora
# epistemolog manag knowledg context node distribut
# model user feedback queri relev retriev instanc learn memori expans base inform cooper
# manag call interact user knowledg design usage-cent interfac pattern center
# thesauru retriev gazett internet inform
# experi systemat learn improv process
# manag knowledg system work inform process
# knowledg portal ontolog integr inform
# visual metadata digit collag summar extract librari video
# formal method object-orient semant uml pv
# manag inter-domain optim system network vp atm rout qo provis hierarch
# automata languag formal lattic
# web learn train support mediat base commun strategi comput
# knowledg research web grid european technolog semant fund comput
# optim algorithm arithmet inclus affin function global interv bound branch
# tile plagiar string similar search token
# formal system power lindenmay d0l seri
# e-set synset wordnet id cluster
# island control search find rout rule
# analysi knowledg landscap object-bas topolog represent relat classif reific
# disjunct reason multi-ag qualit multi-dimension spatial
# interv time granular
# human np-hard hmi telerobot servic schedul team mobil job interfac machin autonom xml robot problem
# present mental dynam anim model
# engin system develop languag methodolog softwar hypermedia object-ori
# system trail-bas navig support trail hypermedia open
# architectur hypermedia structur open comput
# servic system multimedia web web-bas retriev semant hypermedia mpeg xml content-bas
# engin design techniqu function hypermedia program
# system hypertext context coher author relat function linguist model
# develop languag retriev natur softwar inform process
# document notat hypermedia structur xml-base
# employ interact e-commerc servic negoti onlin
# formal system coordin pattern multi-ag model
# complex formal decis languag synchron grammar problem comput
# word
# shannon entropi algorithm attribut index partit categor gini cluster median genet
# tree set complet product automata
# complex descript formal reliabl cellular languag parser finit automata ambigu pushdown softwar nondetermin
# properti invari random
# word dens closur primit oper base residu
# regular nx shuffl product languag decomposit src img
# formal code petri languag net
# synchron finit automata
# regular error-detect delay decid languag decod transduc channel uniqu error-correct
# disjunct word infinit ultim uniformli recurr random period
# plane hyperbol tile
# antiport membran symport univers molecular comput
# domain complex composit synchron automata finit function
# complex set entropi subword languag dens nowher
# determinist algorithm finit automata minim acycl construct
# fix power complet point iter seri semir
# tla reactiv formal system tool time real specif anim
# engin computer-aid librari softwar
# reusabl proof synthesi softwar program
# attribut gener term graph declar grammar travers program
# analysi check formal system verif real-tim model
# logic control check formal diagram develop event verif tool process model
# formal decis arithmet affniz verif augment lemma presburg specul univers integ procedur
# check system ws1 verif parameter abstract model
# model formal system relview relat algebra equival deriv class program
# tla diagram tempor verif refin abstract logic
# logic interact optim check program tempor proof verif prove techniqu theorem algebra invari specif structur correct model
# coalgebra method binari modal specif logic
# educ system web-bas learn train distanc teacher assess program
# situat environ collabor learner person learn coordin histori
# call assist transmiss learner languag learn co-edit voic corpu comput
# visual collabor languag represent learn bia
# writin call environ web-bas efl learn linguist corpu
# balanc parallel load high perform processor comput
# complex petri symmetri net comput
# manag knowledg environment system issu
# minimum-weight triangul set polygon geometri skeleton combinatori point data base comput
# manag telecommun servic network ip
# educ scienc curriculum women breadth comput
# geometri design differenti surfac geometr reconstruct
# digit document recognit graphic librari pattern electron inform comput
# software/program transform reusabl verif synthesi softwar compil program
# educ record annot algorithm system multimedia author anim captur present
# internet secur
# manag knowledg search retriev databas mpeg content-bas
# system social multimedia behavior scienc autom inform offic
# societi knowledg develop european economi inform union sustain
# manag human knowledg superorgan organ system resourc non-explicit
# manag visual interact knowledg digit content human-comput librari media higher-ord inform paradigm
# manag edg environ collabor knowl virtual support work inform captur comput
# technolog standard metadata learn
# manag knowledg digit system librari person inform
# portal knowledg ontolog
# manag knowledg inform system
# manag knowledg cognit elearn learn creativ
# manag knowledg
# formal gener calculu method test-cas refin test
# method formal engin softwar
# formal method languag semant denot vdl definit oper vdm
# formal engin method support tool softwar vdm
# logic theori intuitionist vdm mathemat topo construct model
# engin revers semant slice denot algebra program
# architectur parallel high perform memori data distribut comput
# educ deliveri multimedia teach mix materi virtual mode univers cours comput
# system decid lindenmay equival problem
# cue computer-medi inform nonverb social frequenc develop durat messag ation impress social-emotion-ori commun process model
# neural network state machin abstract distribut comput
# descript formal sdl languag semant fdt techniqu asm state machin specif abstract
# formal gener method sequenc state machin abstract test
# asml parallel partial thesi synchron submachin asm state machin updat abstract
# diagram dynam compil theorem logic proof commut transit state simul data refin interact system prove cerif ment abstract correct machin forward
# falko asm-workbench state machin abstract
# foundat dynam languag state machin modal specif abstract logic
# requirements/specif cach share memori multiprocessor
# educ complex np-complet graph comput
# server hyperwav transclus inform
# matrix parikh map inject
# theori learn
# complex theori count ture altern machin class comput
# tailor groupwar cscw
# control decompress multimedia specul extens smt video mpeg simultan multithread
# complex rout fpga resourc hardwar reconfigur comput
# societi complex inform
# educ societi manag system inform comput
# chemistri electron undergradu curriculum academ structur comput
# educ conscious collabor embed softwar assess oper improv accredit continu life revers support reengin case work
# knowledg multi-expert visual life-long-learn system scientif languag sysem base inform construct
# concurr system x-machin channel
# teleport visualis conceptu wide hierarchi glass context web search focu navig hypermedia world treeworld large-scal relev structur model
# manag visual knowledg environmet system data base inform
# gateway sql server perform cgi www java rdbm api
# algorithm lattic fold hp approxim protein model
# light requir control studi asm case refin
# requir formal engin verif techniqu tool softwar specif
# requir formal tempor object-orient real-tim specif problem logic
# requir formal engin system embed real-tim refin specif
# light control requir formal system model languag execut state-bas prototyp specif simul specification-bas
# requir specif engin pv
# theori learn
# align par product mdl sing languag compress unif natur syntax mml multipl inform
# cryptographi s-box boolean nonhomomorph function cryptanalysi
# analysi control architectur design perform aid multiprocessor structur
# theory-barri analysi algorithm spin synchron competit perform wait time producer_consum block lock
# superscalar architectur latenc dataflow decoupl memori multithread
# system rapid msparc real-tim prototyp multithread
# formal system rewrit languag regul grammar program
# incomplet complex time linear comput
# wbt manag knowledg elearn teach web base
# notat specif formal structur
# tessel hyperbol cellular plane automata
# constraint uncertainti comput interv logic
# switch horsesho system smale map henon baker
# system gener code constraint petri dynam behavior net inform
# compar protocol leader formal elect studi concurr network method standard case
# model noninterferen program properti confidenti flow intransit verif techniqu noninterfer secur specif inform ce
# formal system distribut method object-orient open specif uml pv
# pre formal depend post-condit heapsort invari specif agent-ori model
# complex geometri path motion plan optimis
# logic transform embed method function algebra program
# formal system method verif real-tim specif algebra
# analysi termin function interpret abstract program
# categori theori logic
# monoid lattic mv wajsberg boolean pseudo-wajsberg pseudo-mv residu center algebra
# concurr img process calculu graphic represent semant src machin net multiset abstract
# frequent set item closur connect support extend galoi
# coher behaviour equival hidden algebra
# pseudo-boolean optim set horn boolean function binari truth
# v-algebra monad mv-algebra pavelka algebra
# parallel type program categori semiring network mix relat enrich data abstract algebra
# kraft inequ prefix-fre set
# permut automorph graph hypercub group
# mvn n-valu lukasiewicz-moisil algebra
# logic substructur implic kripke-typ semant strict canon relev linear model
# graph complementar principl finit automata shift sofic
# logic languag boolean thought algebra
# system splice univers rule comput model
# s-order quasi-ord semir
# extractor function sourc random hash bit
# tableau transform deduct proof search autom calculi present
# data instanti solut structur restructur hierarch
# logic analysi algorithm design simul average-cas
# permut theori revers group comput
# arithmet geometri precis divis exact float librari point multipl expans comput
# cryptographi scheme share secret data secur random
# cach network pre-fetch www wireless proxi mobil comput
# align reason compress unif multipl inform probabilist
# specif system process languag x-machin state softwar matrix commun stream test
# product languag synchronis pictur
# complex hyperbol theori cellular plane automata
# parallel automata partit decomposit time state clock
# tree languag dna comput
# transform fault failur verif toler specif model
# markov tree cision fault shannon net diagram petri approach binari de
# life gener uniform composit method ratio time procedur comput
# experiment algorithm code exact heurist constant-weight solut bounded-weight error-correct
# posit np complex ture reduct comput
# algorithm mount pcb assembl multi-head surfac time machin genet
# tableau deduct durat calculu method autom
# post theori align system compu ture
# arithmet semigroup embed quasilinear commut space isomorph oper interv bodi convex minkowski
# transform equat arithmet extend solut interv algebra
# measur uncertainti mathemat comput machin interv co-ordin model
# analysi evalu multimedia content applic review
# educ evalu experi multimedia design methodolog scienc curriculum
# analysi theori reason knowledge-build collabor implic learn piagetian
# organiz evalu system design share learn memori inform
# educ system learn assess electron
# evalu round method polynomi chebyshev perturb error
# order complex separ hierarchi queri polynomi commut downward class comput
# multi/mix digit confer multimedia navig map video media hypermedia proceed hypertext inform publish electron
# neural network navig retriev hypertext inform
# p-select complex comput
# balanc tree ocpc workload move share work-optim memori simul mesh erew coat random thread
# nonperfect scheme secret share
# navig web search retriev text hypertext inform categoris
# visual user document retriev result rank interfac inform present
# script web page dynam languag cgi
# adapt softwar integr quadratur cubatur
# infer system key relat schema
# templat engin design revers search pattern
# deduct key relat databas autom schema
# shannon symbol text compress rank
# programm coprocessor rapid prototyp hardwar pc logic
# deref type modul borland oberon languag chill pascal object extens assign paramet pass object-ori
# concurr state machin abstract recurs distribut comput
# shortest path verif constrain softwar state abstract problem machin
# requir check document program code stepwis verif techniqu inspect state machin refin specif abstract model
# visual formal design modular languag montag state machin specif abstract program
# oberon languag montag refer state machin manual specif abstract program
# document code stepwis techniqu inspect state machin refin abstract program
# abstract gener verif semant back-end state machin oper compil
# filter gather agent-bas system reason memory-bas internet probabilist inform model
# filter knowledg manag life-cycl corpor technolog memori work inform process
# knowledg manag participatori system organis design collabor knowledge-bas argument memori
# manag knowledg studi corpor case memori
# groupwar design share workspac cscw workflow
# knowledg formal gener acquisit artifici method languag represent natur interfac intellig process
# knowledg manag system coordin mechan cscw multi-ag
# filter spread feedback network semant text activ relev
# automat system paperfold uniform sequenc tag
# evalu teach web-bas coursewar learn train techniqu
# educ d-ari overflow arithmet correct proof scienc test comput
# control applic discretionari cryptographi databas data secur polici object-ori access
# free placement space algorithm
# boolean function resili cryptolog nonlinear
# monstr term rewrit graph languag intermedi semant model
# instruction-level depend parallel schedul graph assign alloc processor
# filter algorithm process genet imag stack distribut comput
# theori cryptosystem code inform error-correct
# pram chain multithread vliw
# cultur research forum failur neg result fnr progress
# abstract protocol formal gurevich key method verif kerbero state machin secur refin specif distribut
# basic foundat formal document telecommun sdl system semant state machin execut specif abstract
# interv specif arithmet
# evalu type parallel algorithm queri develop methodolog text categor softwar data structur
# system rewrit term modular confluenc persist
# bishop dirichlet problem mathemat hilbert space construct
# tt-complet set chaitin wtt-complet number
# kraft huffman tree optimum prefix code inequ extend
# incomplet minim automata
# order decid monad well-quasi-ord
# set hierarchi graph obstruct polynomi minor
# variable-length code encod represent decod t-code
# properti invari random
# infinit set close sequenc map measur cantor comput
# logic model complet kripk intermedi jump oper comput
# map mathemat pointwis sequenti continu linear construct
# agent flow arrow belief oper modal commun inform logic
# hypermedia structur system model
# theori optim parallel queri learn equival membership dfa comput
# permut cryptographi s-box attack differenti box linear substitut
# engin document multimedia teach technolog distanc integr electron inform comput
# educ design film televis distanc instruct
# free design thesi linux circuit asic unix integr softwar diploma pc
# system multimedia teach develop distanc onlin media publish
# knowledg inform gather system agent data retriev internet broker distribut
# complex network combin boolean measur function monoton
# disjunct word properti represent period ration invari number normal
# triangul rotat edge-flip flip distanc oper
# educ cscw cai teach hyperwav web author hm-card distanc www softwar hyper-
# educ groupwar studi cooper classroom support scienc case work electron comput
# formal parallel system rewrit languag k-limit
# synchronis code string t-code decomposit recurs t-augment redund effici
# parallel program coursewar vision onlin world-wide-web comput
# educ literaci document evaluation/methodolog multimedia design hypertext web system prepar scienc world-wid
# model system squar arithmet kinet enzym uncertainti valid verif approxim interpol comput manipul
# number system reason implic quantifi fuzzi approxim approach linguist inform
# comparison sequenc dna biolog fpga vlsi hardwar
# monstr term rewrit graph languag intermedi semant model
# system hierarchi rewrit languag regul chomski dna splice famili molecular abstract recombin genet
# effectiv set complet function pseudosimpl extension bound
# formal system languag grammar team
# gopher link system hypertext internet www hyper-
# encrypt cryptographi s-box boolean sac function propag characterist nonlinear
# visualis interact system graphic internet hypermedia inform
# societi cultur web aspect histori www world-wid sgml
# gopher system internet inform distribut
# algorithm graph biconnect st-number distribut
# system geometri elimin polynomi differenti prove decomposit mechan triangular
# digit teach cbt learn librari support technolog cai instruct electron
# algorithm public design high key cryptographi testabl speed multipli hardwar
# system xanadu network hyper-
# equat arithmet partial float method finit differenti numer propag point differ error
# theori system arithmet ration lexicograph number continu fraction comput
# on-lin super-scal accur reliabl arithmet precis high-radix vliw credibl
# analysi arithmet manipul algebra interv error comput
# on-lin fraction digit set arithmet number represent interv continu redund comput
# ieee handl arithmet implement
# arithmet function comput elementari reduct rang
# grammar life artifici system
# multimedia queri network navig home imag store hypermedia distribut
# gif debat compuserv softwar unisi internet patent lzw
# concurr monstr term rewrit graph network serialis simul pi-calculu process
# balanc system cach load network perform file distribut
# command assist agent electron pad predict search messag exampl voic program
# cube theori tile wang aperiod mathemat automata machin sequenti discret
# automat link mainten data hypermedia model
# teach coursewar whiteboard distanc hypermedia electron
# featur agent-interact constraint distribut problem sign coordin negoti multiag strategi solv cooper
# free word formal context languag map l-system parikh problem
# ai parallel qsim constraint satisfact distribut
# control anonym access authent big secur
# complex blank-endmark chaitin string random self-delimit
# estim digit radix high divis approxim
# tree share work-optim memori simul mesh erew coat random
# shuffl system chomski grammar oper
# educ
# arithmet code lz vector text compress quantis
# understand affin match imag fusion registr inform spatial
# evolutionari optim algorithm network-on-chip map multi-object system-on-chip simul
# algorithm cryptographi s-box multi-object evolv hardwar genet optimis
# tree fault neural decis program network hardwar monitor intellig electron genet comput
# filter transconduct optim leapfrog algorithm evolutionari design method circuit search multi-object classic pattern genet amplifi oper problem electron
# evolutionari multius algorithm code divis detect access multipl genet comput
# formal reactiv system tempor altern verif automata time assert monitor run-tim specif seri logic
# arithmet revers circuit oper multipli comput
# hierarchi complet domat exact uncolor boolean minim color number
# human inform system issu pervas devic societ technolog portabl health expert process
# system environ artifici smart multiag intellig
# automat diagnosi micro-kernel embed sensor arrhythmia wireless real-tim cardiac telemedicin ecg
# agent devic context-awar technolog mobil telemedicin comput
# provis servic smart-hom web-bas behavior technolog care monitor telemedicin
# cancer record patient confidenti languag computer privaci natur health secur bioinformat process electron
# jini agent healthcar pervas home comput
# healthcar privaci qualiti privacy-awar ubiquit comput
# mosaic interact visual rfid context awar implicit ubiquit inform comput
# ambienc environ context privaci awar intellig
# ambient pervas smart space intellig middlewar comput
# architectur design network sensor modular wireless node hardwar
# compon ambient pervas aspect intellig middlewar comput
# hybrid architectur decis merg web semant rule inform context-awar
# trust protocol servic network ad-hoc discoveri secur
# mine engin social issu web search retriev inform
# inherit symbol coercion comput specif algebra
# formal type compon graphic softwar logic mix descript tempor transit notat data specif system languag glue abstract architectur engin symbol base
# human recognit ture captcha charact comput persian public text internet baffletext arab secur
# dynam optim just-in-tim compil
# coalgebra coinduct process algebra
# dynam optim just-in-tim compil
# develop languag aspectj aspect softwar orient refactor
# analysi slice function program
# free invoc context method sequenc languag grammar aspect visitor essenti pattern
# program function haskel strong mobil comput
# interoper object virtual machin model
# servic languag web workflow pattern program
# semant uml automata nonsequenti
# manag type system queri languag semant databas oper object-ori
# filter scienc simul fusion particl data
# instanc rule interesting pattern data
# cryptographi secur random
# mersenn gener method pseudorandom simul twister carlo number mont random
# cryptographi quantum comput
# bdd complex formal decis algorithm diagram properti program languag sublinear boolean function bp binari branch random test comput
# exponential-tim determinist algorithm exact random comput
# algorithm complex random class
# term context behaviour observ specif cover
# estim filter fingerprint gabor enhanc orient
# neural network compress predictor toler error data
# system ing dna molecular splic comput
# optim constraint propag interv solv branch
# handl rna constraint secondari predict format gene grammar concept rule protein structur
# compar concurr process equival preorder semant readi simul trace bisimul refus
# logic model check concurr constraint tempor time paradigm
# narrow failur negat functional-log construct program
# logic rewrit maud verif function program
# equat induct semant prove theorem itp data membership structur logic
# logic xpath set languag magic program
# logic transform fuzzi unfold program
# cheat ipr plagiar detect similar
# institut congruenc leibniz behavior relat equival refin hidden logic
# elect check leader formal algorithm model network verif anonym probabilist distribut comput
# ssa optim compil
# self-organis system social emerg collabor network share web-bas build blog file wiki podcast applic commun work inform
# mutual complex section queue algorithm distribut network messag migrat exclus critic comput
# analysi deadlock-fre petri live siphon net structur
# balanc user system enterpris load cluster profil distribut
# evalu proxim datalog knowledge-bas fuzzi strategi
# mvc xslt design web xmi pattern techniqu data applic xml uml model
# domain dn system servic telephon enum-bas client procedur number
# queue cach network server perform proxi model
# thermovis potato plant breed dimens classif imag improv qualif fractal
# data-flow queri databas languag
# prolog japlo java
# season analysi lymphoid method decomposit time leukaemia childhood acut seri
# estim educ method crop model
# geo-bas servic market portal web-bas map java ajax xml
# segment retriev databas imag process
# higher educ featur driven virtual classroom conflict definit cours construct model
# chao equat graphic differenti endocrin nonlinear
# signal haar-lik system multiresolut imag wavelet process
# ad control hoc topolog algorithm network distribut
# parallel membran system graphic interfac oper comput
# estim discrimin inaccuraci paramet inform distribut cauchi
# visual neural network artifici phase associ transit memori abil inform process
# societi literaci digit teacher school inform compet
# protocol formal time-releas cryptographi kudo-mathuria verif time cryptograph capsul
# p-graph network synthesi workflow
# higher educ system engin product integr inform
# scienc educ logic comput
# analysi visual volum surfac render virtual imag surgeri multimod medic process
# hybrid agent-bas system petri recommend negoti net thread
# knowledg system represent estimatio relat input-output paramet identif
# knowledg formal acquisit network method artifici represent semant information_systems_appl intellig
# diagnosi fault k-distinguish system p-invari event place-transit d-partit point net discret test
# rule-bas system represent transact multiag commerc electron
# manag knowledg mine end-to-end-perform network predict grid behavior perform internet data
# incomplet order method partit consensu cover hierarch
# theori depend system agent attribut consensu conflict distribut
# utter speech interfac rate entrain
# manag visual knowledg skg content globe inform sustain
# convers panorama network locomot
# gener realiti virtual avatar-bas motion commun captur
# convers acquisit quantiz knowledg
# throughput pipelin control latenc regist ae dynam loop fpga total time unrol iter reconfigur
# system optic robust flow devic illumin fpga real-tim imag reconfigur process
# protocol asynchron self-tim microprocessor phase virtex fpga ii
# set implement ultrason fpga-bas sequenc complementari techniqu compress correl effici
# architectur algorithm implement imag system-on-a-programmable-chip hardwar process
# partial cryptographi dynam fpga idea reconfigur
# pipelin scheme loop fpga hardwar compil
# requir formal scr method toolset
# b-method method formal
# hardwar method formal verif
# method check formal model
# method formal
# grand formal challeng method verif
# correct method formal construct
# method formal engin softwar
# formal system represent learn configur e-learn scenario
# posit root isol real upper bound
# mashup web visualis
# templat polytim function static comput
# e-commerc formal system payment cryptographi verif secur
# manag copyright metadata user system e-commerc servic licens digit web interfac integr protect applic inform usabl watermark
# control system event refin access
# control concurr servic web transact atom commut distribut
# databas reflect perform
# memori handl transact
# technolog educ e-learn webquest
# unit design graphic learn ld author im notat
# list educ collis pipelin insert latenc schedul delay diagram state simul forbidden reserv vector tabl
# design learn object ontolog qualiti instruct
# educ separ flexibl languag concern model
# educ graduat webct onlin degre
# handheld devic simul authoring-tool model
# design collabor game learn cscl model
# human evaluation/methodolog network factor commun
# interact ute collabor pervas learn synchron comp mobil comput
# moodl design map learn im integr
# requir languag non-funct specif program
# constrai architectur model-driven nt softwar reus program
# program refactor law condit logic
# pars lalr methodolog conflict
# advic optim aspect-ori weav compil program
# demonstr visual program
# lua reusabl dynam aspect heterogen aop
# spreadsheet call-by-ne structur abstract program
# manag concurr count refer memori collect garbag
# manag tenur count graph cyclic object refer memori perman collect garbag
# applic languag interfac program
# analysi slice function program
# infer overload type system close constrain open world approach polymorph
# semant action formal object-ori
# selecti manag knowledg algorithm servic web resourc ws qualiti
# semant choreographi servic
# manag knowledg descript compet creation represent skill e-learn logic
# programm engin design develop learn instruct compet
# link annot similar typed-link futur index citat
# gener learn function approxim attent reinforc
# scienc educ inform comput
# transform system entiti combin extract
# co-evolut algorithm emerg evolv hardwar commun genet
# optim quadrat neighborhood search assign swarm variabl particl problem
# algorithm neural process network ph fuzzi neutral recurr genet model
# signal evolutionari neural design cellular network analog circuit process dac
# system network artifici forens secur immun comput
# manet autoconfigur olsr
# ad hoc network adapt rout cluster wireless scalabl
# mpr qualiti local servic network bandwidth avail multi-point flood admiss relay qo olsr ad control optim hoc interfer rout
# vote aggreg network sensor cluster data head energy-effici
# ad evalu balanc hoc protocol cach load network mobil rout distanc perform ad-hoc energi node on-demand vector effici
# interoper languag virtual function haskel machin net compil program
# hierarch model encrypt bilinear standard identity-bas pair
# deduct type calculu mathemat natur negationless construct logic
# geometri video databas data structur comput
# proxim collabor learn support mobil comput
# pso sigmoid polygon function centroid approxim
# metric riemannian similar support machin vector
# metadata extract learn vector support machin keyword
# evolutionari mine system algorithm express gene artif rule data meta-rul immun program
# independ densest graph subgraph number eigenvalu
# reson isoarithm perfect aromat hydrocarbon clar factor polyhex kekul match polycycl structur benzenoid
# theori categori automata rabin-scott behaviour meali final moor sequenti semiautomata
# gray code single-dist
# complex evolutionari ture network processor machin class
# steiner tree approxim ratio minimum heurist sweep-lin span
# hertz hsalmankhan175jek lattic mv mtl nm residu bl generalized-mv wnm algebra generalized-bl divis gener wajsberg pocrim t-norm
# theori matroid geometri pebbl rigid game hypergraph comput
# metric regular theori fix mine asymptot proof function nonexpans halpern point iter
# bistabl elementari kroneck set graph irreduc support match adjac total perfect product boolean fulli bipartit stabl indecompos matrix cover
# neural membran system astrocyt spike comput
# interact protocol type system termin regist languag agapia rv-system voic distribut program
# balanc graph sign
# metric modular entropi lattic
# graph geodes theori connect
# short topolog graph grid connected hamiltonian coeffici
# coverif co-design slice softwar hardwar program
# evolut petri reflect softwar net
# formal servic method web e-bart
# protocol formal network rebeca method modular verif
# odedialect languag ontolog translat
# metadata annot web extract semant ontolog inform
# visual web semant rank schema
# queri interoper web retriev semant inform
# manag knowledg queri languag databas ontolog mediat internet applic distribut
# life annot web nlp scienc semant ontolog cores
# cscw architectur groupwar asynchron notif collabor synchron simul
# servic system collabor web learn semant ontolog tool discoveri cscl
# situat interact collabor share learn workspac nomad work model
# groupwar service-ori servic col unit web labor platform ad-hoc mobil middlewar scenario
# meet upper-lay pattern middlewar electron
# script architectur design collabor learn integr
# text segment cluster
# digit document tool-support web semant prepar history-informat xml tag mediev
# featur recognit confus measur zone mechan matrix metaclass charact
# pattern signatur recognit verif
# ta da segment document recognit table-form extract handwritten
# engin document interfer back-to-front show-
# light segment maximum foreground/background restor histor manuscript imag color arab likelihood k-
# engin document interfer back-to-front show bleed
# analysi recognit symbol discrimin condit
# fair protocol public exchang key cryptographi secur
# cryptographi secur authent
# exchang graph key notion secur random
# transfer oblivi privaci protect commerc electron
# key-shar unknown key resili agreement bellare-rogaway authent bilater model
# exchang key roam anonym authent
# certificateless encrypt attack standard malici kgc model
# fast field arithmet algorithm cryptographi koblitz finit curv cryptograph ellipt
# analysi knowledg social network collabor softwar wiki work
# ruler carpent algorithm fold approxim problem
# analysi user gener e-commun content weblog blog
# interact compens classif advertis model
# neighbor network voronoi nearest road pine continu
# traffic analysi user end-to-end experi measur behaviour perform qualiti internet passiv
# market design network bandwidth alloc resourc
# queu servic cost telric prioriti bitstream over-engin qualiti access model
# call voip delay eigenvector zrtp puzzl challenge-respons srtp comput
# digit servic multimedia ict divid web-bas e-servic broadband access
# incomplet game learn price interdomain stabil inform
# network bandwidth multiplex reaction cost econom contract competit price effect curv provis statist demand
# analysi reliabl network risk commun
# secur man-in-the-middle-attack zrtp
# analysi servic experi object happi qualiti ecosystem holist busi model
# traffic model network plan scenario
# riesz analysi topolog represent hausdorff space theorem comput
# analysi multi-represent flowchart multi-funct realiz abstract comput
# real elementari number class liouvil comput
# hift topolog type system dynam pressur physic statist comput
# bloch constant algorithm comput
# analysi count hierarchi integr weak riemann
# complex rule real quadratur comput
# analysi probabilist measur comput
# higher filter conveni topolog type equilog categori qcb-space space weak limit comput
# nig lemma fan brouwer theorem
# na mine reason case-bas explan classif text bay pattern data
# engin server-sid portal develop web technolog java
# educ conceptu reusabl unit design interoper languag learn framework process model
# educ public scienc bia gender report statist comput
# formal system process auction english specif multi-ag algebra
# system retriev rank inform distribut
# agent algorithm system dynam negoti methodolog alloc wireless resourc channel simul commun strategi multi-ag
# manag trade market agent suppli softwar simul chain multi-ag electron
# ad knowledg hoc agent table-driven aodv network bit-map rout discoveri overhead reduc tabl
# metric evalu system perform multi-ag
# align social queri network semant propag ontolog
# system agent integr data prolog-lik comput
# market reinforc learn simul
# architectur engin system model-driven softwar component-bas
# featur gateway mine system compon embed product line decomposit hardwar softwar mainten reus model
# requir optim select softwar cot model
# understand knowledg engin system revers legaci reus
# acm architectur servic mismatch web style softwar
# architectur transform driven crosscut develop aspect concern softwar orient mda model
# gener develop product model-driven line tool softwar deriv program
# servic web product web-bas line applic busi process
# properti efremovi pre-
# method lisp object common orient binari meta-program
# metaobject protocol gener lisp special function
# metaobject protocol type lisp common clim present
# context-ori dispatch prototype-bas ambient subject multipl intellig program
# lisp map common object-rel smalltalk
# reason tempor lisp relat s-languag algebra
# analysi visual user market stock graphic nasdaq veloc forc interfac data inform
# interact groupwar awar real-tim community-bas
# interact groupwar design base model
# groupwar model-bas plastic awar approach shared-knowledg
# develop groupwar model-driven cscw
# automat requir interact transform usabl gener code compil sketch model
# metric evalu cognit context method walkthrough usabaipo spanish-speak heurist
# automat program ambient smart adapt home natur intellig ubiquit comput
# task model collabor ambient context awar intellig ubiquit comput
# human interact evalu engin access websit usabl comput
# knowledg featur select represent retriev learn support classif text preprocess machin data vector inform
# reattempt truncat markovian seamless finit mobil model
# visual system meet extract retriev multimod inform electron
# programm neural network core perceptron configur fuzzi fpga ip vhdl multilay hardwar logic
# metadata annot decis scholarli network web make
# metadata repositori share learn object build reus commun structur comput
# ethic engin web search person pagerank privaci bia inform
# taxonomi knowledg design collabor product web train support author semant tool base instruct e-learn model
# digit multimedia entertain search semant ontolog
# social content web user-gener platform media mpeg
# assist web extract applic inform
# wrapper mine system web autom data inform
# wrapper tree-edit web crawl distanc hidden
# web extract page classif cluster data
# extract ontolog data inform semi-structur
# visual inform extract block
# ahead featur composit verif asm
# metamodel engin languag model-driven asm state simul abstract machin
# formal system embed method verif real-tim state machin specif abstract
# logic model-check predic time state simul real-tim abstract machin
# diagram dynam logic electron theorem commut state simul data refin interact precondit prove weakest purs mondex abstract machin secur forward
# servic composit mediat discoveri process workflow
# protocol induct goal method verif threat model
# architectur composit modular measur adapt coordin coupl softwar reus commun
# compon program adapt softwar logic
# compon system mismatch composit behaviour valid adapt transit aspect-ori interfac run-tim program
# interact pattern cc adapt extend aspect-ori machin softwar state specif uml program
# techniqu web engin adapt
# m-interact knowledg complex system meta-synthesi open intellig m-space process
# brows assist agent method web learn increment softwar statist
# mine market agent pattern microstructur data surveil
# wpki parti non-repudi secur mobil
# balanc deliveri algorithm cach load content network divid scope
# e-busi studi agent case plan report deploy multi-ag
# traffic optim system citi ligh multi-ag model
# posit lb tree fingerprint decis method ubiquitous-campu
# search semanti ontolog inform meta
# shop graphic flow search salesman tabu travel hardwar
# segment layer evolut set multi-lay termin level imag curv criterion
# system network learn fuzzi classif bayesian machin genet logic
# steiner tree evolutionari algorithm path-relink prize collect transgenet problem
# hybrid optim algorithm schedul problem network genet bu
# quantum finit assign state machin problem comput
# optim multiobject network sensor metaheurist
# algorithm optim search genet
# featur theori optim set rough select two-step ant coloni swarm intellig particl problem
# optim evolut parallel stochast cell combinatori cluster vlsi metaheurist placement simul comput
# system emerg recommend e-learn swarm intellig multi-ag
# diagnost decis system error e-health individu support dss bay rate base inform intervent theorem
# interact human-comput
# ergonom evalu cognit interfac
# interact market phone usag human-comput sociolog factor computer-support breath mediat varieti determin mobil intens work cooper
# human interact user interfac cscw mobil ubiquit comput
# engin develop web support access tool applic process
# ergonom user cognit design interfac
# educ mine adapt support author data applic hypermedia
# rdf evalu metadata educ desktop ad semi-automat adapt author semant caf hypermedia
# domain system tutor author ontolog constraint-bas intellig model
# design graph sequenc learn translat im
# task schedul collabor ambient author activ space social-awar hypermedia intellig comput
# educ metadata user templat guidelin design elearn web learn object adapt semant standard activ pedagogi model
# educ cultur system cae adapt hypermedia
# environ game learn adapt author tool base e-learn
# understand analysi architectur mine document digit librari imag softwar
# evalu digit content languag format librari convers migrat xml file plan characteris preserv
# svm featur neural network classif crime scene
# author pattern recognit verif
# analysi resolut document ultra recognit hmm web retriev index text imag low
# depend document network stack structur
# evalu document binar imag process
# grid cluster imag load-balanc process
# domain task environ collabor model
# groupwar user awar interfac group
# user design model-bas develop interfac prototyp specif
# input interact environ human-comput game virtual devic video eye track
# user ambient interfac intellig inform indirect
# human interact optic flow virtual mous comput
# interact realiti collabor human-comput environ virtual
# user system collabor flow develop model-driven interfac approach userinterfac inform workflow
# visit guidelin virtual access museum usabl cooper
# evalu interact ei user agent ui architectur system human-comput softwar interfac inform electron
# taxonomi interact propos groupwar develop model-bas computer-human methodolog
# interact user realiti virtual interfac bi-manu
# domain user design eclips model-bas framework dialog interfac model
# interact environ learn adapt user-comput thought heurist teaching/learn hypermedia strategi
# engin design model-driven user-cent busi process model
# pars haskel edit presentation-ori
# program monad function effect shortcut fusion comput
# automat remov lalr methodolog pars compress conflict tabl
# schedul subgraph isomorph d-vliw instruct
# refer weak collect tabl garbag
# concurr lua luaproc messag non-preempt preemptiv pass multithread
# languag aspect reentranc aspect-ori pointcut program
# implement extens spectj aspect-ori program
# type system semant aspect-ori oper program
# modular languag semant denot aspect-ori definit program
# unifi formal languag semant action model
# featur product line softwar algebra refactor law model
# system design learn adapt ld author im rule tool hypermedia
# maxim ideal construct
# manag matur qualiti data inform model
# bck weak-bl heyt hilbert imtl hertz r0 lattic mv mtl nm jek residu bl generalized-mv wnm algebra generalized-bl divis wajsberg pocrim generalized-wajsberg t-norm
# switch diagnosi fault network-on-chip function onlin test model
# develop lag invest softwar
# clinic knowledg formal represent ontolog
# bpmn problem standard or-join busi process
# optim depend inclus queri function limit access
# logic uniform cut-rul infinitari canon modal substitut model
# lock-fre algorithm concurr linearis share atom verif relat nonblock memori simul reduct
# depend relat databas proposit function weak complex-valu axiomatis logic
# control concurr recoveri transact databas state machin abstract process
# depend design relat databas univers form normal
# semistructur ora-ss verif autom data pv model
# frame cube aggreg oltp-olap olap function oper specif
# complex ideal coincid valu restructur
# on-lin warehous process state machin data abstract refin analyt
# copyright trust good digit content superdistribut protect comput
# set design principl authent content-bas watermark
# theori queue multimedia network attack stabil adversari commun
# share attack peersim file applic chang
# network monitor protect secur statist comput
# heterarchi social web wikinom media
# manag metadata knowledg digit recommend collabor share web classif resourc tag
# life knowledg collabor share virtual muve onlin world
# system social collabor network project embed web-bas virtual open sourc work commun inform
# composit aspect aop aspect-ori reflex structur kernel program
# sql criteria coverag databas test adequaci
# protocol properti exchang confidenti sign negoti contract intellectu secur
# control privileg role rbac ansi
# posit root isol vincent real upper bound theorem
# encrypt homomorph cryptosystem probabl
# estim quaternion represent euler orient dcm
# import similar concept ontolog identity-bas integr conflict
# neighbor elimin share nois support cluster nearest vector
# estim offspr optim evolut algorithm pareto gener scheme multi-object differenti distribut
# model mine multifacet sequenc mode computation-ori concern definit pattern frame-relay comput
# hybrid shop gate algorithm schedul rotat quantum flow immun
# theori recognit detect graph sign hdr
# knowledg minutia mine wordnet golden web semant ontolog discoveri
# algorithm network gene bayesian genet
# classifi optim multi-lay prune swarm ensembl particl model
# interact system languag multi-ag scenario
# brows user engin search person re-rank
# evalu system agent perform propag mobil multi-ag
# control rfid document e-docu secur pervas technolog mechan e-passport infrastructur electron access comput
# protocol agent cryptographi network sensor smartcard wireless
# permut data-depend chess cipher attack related-key differenti block oper cryptanalysi
# identif manag fingerprint user digit drm multimedia tv gpr video scrambl match secur mobil dvb-
# surveil framework privaci secur intellig access
# near-infrar signatur vascular thin authent pattern multimod biometr
# ad hoc network selfish mobil cooperation-enforc
# transform neural recognit process network vehicl classif imag wavelet normal
# analysi topolog comput
# slide domain analysi theori finite-tim function constant-tim block comput
# metric hyperbol system norm scheme pencil approxim finite-dimension space differ stabil matrix pde comput
# analysi topolog qcb-space space comput
# theori equat type differenti blowup
# analysi admiss represent measur normal devic physic distribut comput
# fine-comput function integr oper fubini theorem
# metric urysohn mathemat univers space construct
# metric continuum set properti circularli chainabl effect space recurs cover comput
# oracl halt relativ p-np machin bss problem
# analysi semicomput equat ordinari inclus differenti lipschitz condit comput
# analysi computat schauder function basi
# territori innov vision qualiti stakehold e-learn
# educ design develop web model-driven multi-disciplinari
# collabor learn object repositori e-learn
# moodl alic tq-bot system bdi clarolin tutor aiml intellig chatterbot
# environ person virtual disabl access
# applic web-bas style learn
# moodl visual spiral timelin e-learn
# educ visual tree syntax softwar
# system tutor learn intellig program

# %%
rakeKeyword
# Out:
# ['knowledg knowledge-intens gener wiki process-ori commun structur process cooper',
#  'assur profession studi empir learn train computer-support qualiti workplac cooper',
#  'experience-bas system agent pedagog arrang learn weblog micro-didact space wiki inform',
#  'manag filter knowledg inform collabor method introduct retriev ontolog context-awar busi process model',
#  'manag visual knowledg inform metaphor project commun storytel',
#  'manag knowledg workflow',
#  'manag knowledg inter-organiz network collabor busi',
#  'manag knowledg knowledge-intens descript k-model languag process-ori busi process model',
#  'knowledg manag research market enterpris tool softwar busi process',
#  'manag knowledg theori busi instrument activ work infrastructur stanc process model',
#  'manag knowledg system data base inform',
#  'process manag knowledg servic',
#  'prover formal concurr proof atom refin',
#  'formal develop method atom observ refin',
#  'asynchron relax verif atom commun process algebra',
#  'formal compens ing method languag transact long-runn semant specif',
#  'system isol replic broadcast atom quorum',
#  'formal depend method languag transact atom hardwar program',
#  'concurr develop transact atom softwar monitor ocl uml',
#  'cach transact coher atom memori',
#  'analysi visual mine subgroup data',
#  'visual reput social network flow inform',
#  'analysi visual grand tour method cluster curv andrew data exploratori',
#  'data visual mine icon',
#  'visual segment mine explor connect data',
#  'incomplet mine decis diagram function minim data specifi',
#  'domain visual interact tempor data medic inform',
#  'visual explor techniqu multiresolut data',
#  'intrus system detect wireless antenna',
#  'evalu public infrastructur key fuzzi techniqu secur polici',
#  'audio lsb code hide steganographi data',
#  'intrus protocol detect abus secur cryptograph comput',
#  'ad re-key hoc protocol group network dsr rout perform secur commun',
#  'evolutionari algorithm cryptographi co-design addition-chain genet comput',
#  'fair protocol deliveri exchang certifi non-repudi secur',
#  'system agent qualiti inform multi-ag',
#  'digit system backup file snapshot consist forens oper checkpoint',
#  'manag theori perfect algorithm one-tim key pad protect secur inform secreci data',
#  'theori digit system multimedia code librari inform',
#  'manag theori market game databas resourc inform strategi distribut',
#  'control ded system dynam event synthesi discret',
#  'life complex architectur system adapt softwar cycl',
#  'brows collabor web ontolog work',
#  'cognit agent formula ground languag satisfact modal commun logic',
#  'rosa mine system recommend web person retriev adapt inform',
#  'knowledg method consensu conflict inconsist',
#  'hybrid user system method web-bas adapt consensu interfac',
#  'dimension queri high databas rang spatiotempor structur data model',
#  'parallel constraint implement time actor execut comput',
#  'manag protocol rtcp multimedia scalabl commun distribut',
#  'automat algorithm gener flow test softwar data genet',
#  'algorithm circuit cad rout global integr',
#  'structur system multimedia web-bas author applic hypermedia transclus xanalog publish',
#  'fat cube architectur topolog network router collect interconnect commun',
#  'formal autom softwar specif object-ori test',
#  'system verifi public-key mix-net paillier privaci huffl',
#  'b2c e-commerc agent technolog ontolog intellig',
#  'tree uowhf function binari hash',
#  'check reactiv system modular verif techniqu actor abstract model',
#  'complex t-decomposit entropi measur pars comput',
#  'free tree anneal skeleton geometri graph straight simul draw comput',
#  'modular languag semant action oper structur program',
#  'logic descript arithmet gener languag circuit function hardwar structur program',
#  'coroutin hash virtual closur machin abl compil',
#  'mop lua dynam reflect aspect aop',
#  'manag final semant memori collect garbag',
#  'formal servic web languag semant program',
#  'interoper languag virtual function haskel machin net compil program',
#  'languag bytecod virtual common runtim machin compil',
#  'dynam optim just-in-tim compil',
#  'dataflow function comonad law stream distribut comput',
#  'analysi equat formal semant execut specif program',
#  'program languag function haskel mobil comput',
#  'drift tree decis concept increment data stream',
#  'mine resource-awar cluster data stream comput',
#  'intrus resolut detect network secur first-ord logic',
#  'brows analysi mine usag web semant pattern',
#  'servic trigger predict qo time qualiti seri stream model',
#  'mine algorithm single-pass data stream chang',
#  'drift decis learn classif increment concept rule data stream',
#  'posit root equat polynomi bound',
#  'order set partial supremum mathemat construct',
#  'uniform revers mathemat continu construct',
#  'analysi function comput',
#  'cellular automaton omega halt probabl',
#  'analysi ration function iter construct',
#  'riesz formal topolog mathemat f-algebra space choic axiom construct',
#  'logic filter intuitionist satur kripk ultraproduct ultrapow prime disjoint bisimul iter union model',
#  'element posit hermitian mathemat banach state space construct algebra',
#  'theori set algorithm sequenc binari inform random',
#  'analysi theori lattic decid proof',
#  'formal topolog coequalis predicativit quotient local construct',
#  'theori set partial principl realiz combinatori brouwerian construct algebra',
#  'caus determin refin construct process algebra',
#  'markov chain construct',
#  'regular posit topolog formal relat space real',
#  'valu function compl databas axiomatis',
#  'continu construct mathemat',
#  'theori mathemat hilbert space oper construct',
#  'determinist attractor system languag measur omega-languag function cantor hausdorff space simpl iter fractal',
#  'analysi ration function iter construct',
#  'analysi intuitionist intermedi perhap valu real theorem',
#  'order geometri conjectur sylvest construct',
#  'fine fine-continu sequenc fine-comput function effect space limit weakli recurs fine-sequenti comput',
#  'educ unit collabor languag learn object e-learn model',
#  'servic system multimedia web-bas web xml semant hypermedia',
#  'conceptu interact exercis learn author tool',
#  'interact context awar implicit ubiquit rfid comput',
#  'teach collabor learn comput simul anim program',
#  'lcm campu servic web learn object virtual lom author im tool museum scorm e-learn',
#  'diagnosi cognit environ librari learn author tool trace error model',
#  'domot collabor learn computer-support pda mobil comput',
#  'educ servic multimedia web-bas hypertext/hypermedia internet',
#  'metadata annot collabor learn object ontolog',
#  'small-talk modul packag virtual rubi namespac java classbox class selector',
#  'express modular embed coordin process algebra',
#  'objectâ\xadorient formal composit object softwar specif',
#  'compon code composit dynam aspect common orient net servic intermedi runtim assert autonom weav languag web manipul aspect-ori architectur program',
#  'markov decis constraint composit reo coordin automata bisimul probabilist process',
#  'reactiv compon system modular rebeca verif actor model',
#  'interact type indic myers-brigg human-comput mbti e-learn',
#  'elearn situat metadata learn',
#  'user retriev learn object ontolog e-learn context-awar',
#  'manag interact knowledg user design web-bas factor train usage-cent interfac pattern',
#  'user context learn object e-learn',
#  'user elearn learn adapt cscl model',
#  'educ collabor game learn motiv constructiv game-bas',
#  'teach personalis learn',
#  'task algorithm schedul constraint graph direct preced distribut',
#  'multi-dsp system schedul embed flow predict rapid perform data prototyp',
#  'supervis fraud web-bas prevent exam assess secur',
#  'manag system broker network practic learn commun',
#  'organiz knowledg mental market capit practic ration retrospect trade-',
#  'manag knowledg node commun distribut',
#  'knowledg web share semant commun',
#  'evolut process indigo introduct learn particip eparticip inspect improv distribut',
#  'manag knowledg enterpris content intranet extranet practic e-learnin person technolog commun inform',
#  'studi expert volkswagen telekom practic siemen case deutsch wiko net commun',
#  'manag knowledg organ nebula perspect practic livingom liquid art-shta crystal commun',
#  'visualis manag knowledg web practic semant discoveri commun',
#  'knowledg trust social etiquett norm sociabl capit tacit practic explicit onlin commun',
#  'system membran complet determin comput',
#  'bond membran divis ture differenti cell comput',
#  'evolut antiport system membran symport commun comput',
#  'natur system entropi comput',
#  'system membran maximum valu natur comput',
#  'inhibitor promot univers system',
#  'gate system revers fredkin conserv energy-bas logic',
#  'parallel java system simul',
#  'complex system membran problem bin class clip recogn pack comput',
#  'membran natur distribut comput',
#  'human manag knowledg competit advantag resourc integr strateg',
#  'analysi knowledg audit social network flow map inventori',
#  'knowledg descript skill match elicit logic',
#  'disavow knowledg interact visual joint evas commun refus',
#  'manag knowledg reason web case-bas semant',
#  'analysi manag research knowledg develop univers process',
#  'analysi manag research knowledg social distribut implement network collabor share practic localis expert appli commun strategi sustain',
#  'knowledg metadata agreement share',
#  'analysi formal semant concept relat databas lexic',
#  'analysi formal graph search concept bipartit breadth',
#  'mine lattic web retriev concept credo inform',
#  'diagram automat layout lattic',
#  'implic complex comput base',
#  'analysi visual formal lattic mobil landmark vision concept local orient autonom galoi robot comput',
#  'logic fil tableau automat check graphic method tempor buechi on-the-fli verif futur automata gil interv specif model',
#  'abstract formal mac hine method notat sequenti commun uml process',
#  'theori formal set reason autom heurist otter specif',
#  'order formal decis sat search backtrack cnf verif partit heurist variabl bdd',
#  'check formula implic combin sat boolean proposit static equival satisfi cec logic',
#  'analysi model check decis diagram sat binari satisfi bmc reachabl bound bdd',
#  'dag heurist check decis diagram state machin binari satisfi bound model',
#  'check boolean atpg equival satisfi',
#  'test object-ori softwar coverag',
#  'multimedia compon system framework',
#  'interact architectur service-ori servic composit web coordin connector softwar comput',
#  'engin rewrit revers migrat rule data pattern',
#  'servic portlet portal develop web component-bas applic',
#  'engin agent system multi-ag methodolog softwar intellig agent-ori',
#  'design process method softwar',
#  'analysi manag resolut requir winwin negoti multi-criteria conflict inconsist prefer',
#  'domain-specif evolut modular languag develop processor markup softwar approach mainten xml',
#  'list conceptu knowledg visual annot link document digit hyperwav portal-system black librari search white futur activ repositori e-learn',
#  'system design embed object_ori hardware/softwar processor application_specif synthesi highlevel instruct',
#  'protocol formal method symbol bisimul noninterfer equivalence-check process algebra',
#  'neural lempel-ziv network predict compress lossless two-stag',
#  'cellular plane hyperbol automata',
#  'collis root hash mod cyclic scatter primit techniqu storag prime full residu group strategi tabl',
#  'system rewrit tissu grammar univers matrix comput',
#  'semant oper',
#  'function boolean decomposit equat',
#  'system grid index file data multi-dimension structur spatial model',
#  'warehous tempor relat databas algebra self-mainten data logic',
#  'interschema properti sourc integr xml inform',
#  'coroutin control lua gener languag structur',
#  'relat coalgebra model coordin',
#  'logic concurr rewrit modular languag ml semant program',
#  'coordin atom concern action aspect-ori distribut program',
#  'combin explicit function categor substitut program',
#  'script interoper languag reflect',
#  'languag tactic definit middlewar distribut program',
#  'function program',
#  'visual design environ develop redwood tool softwar snippet drag-and-drop program',
#  'metaprogram transform gener framework tool java refactor object-ori program',
#  'reactiv system concurr design modular action',
#  'graph refin architectur abstract',
#  'architectur transform driven model graph model-integr comput',
#  'protocol model-check verif time parametr',
#  'model transform graph develop model-bas verif softwar comput',
#  'prove refin theorem',
#  'logic check system design tempor multi-object object verif model',
#  'transform equat reason ultra develop non-determinist function unfold-fold heapsort specif construct program',
#  'tempor system-level verif simul emul logic',
#  'reliabl verif',
#  'requir formal constraint diagram verif plc-automata real-tim specif captur',
#  'architectur check gener code implement compil certif correct program',
#  'alia optim dummi verif alias',
#  'permut optim sgi voc translat valid verif global rule pro condit compil',
#  'independ visual archiv interact inform sign languag retriev map computer-support commun construct',
#  'independ visual archiv inform converg multimedia languag retriev computer-support technolog commun construct',
#  'implic futur societ technolog wearabl pc display comput',
#  'visual archiv interact multimedia dynam languag retriev map computer-support movi abstract commun inform',
#  'hyperbol cellular plane automata tilt',
#  'system interschema properti sourc integr inform semi-structur cooper',
#  'audiovisu archiv user engin queri thesauru person search semant mpeg profil faethon',
#  'knowledg manag mine entiti extract map semant relat topic text corpora',
#  'knowledg manag complex theori evolutionari practic semant cognitiv heterogen communit constructiv structur distribut',
#  'manag knowledg train e-learn scenario',
#  'signal filter weak strategi process',
#  'manag research knowledg architectur algorithm collabor flow measur problem-centr opencp',
#  'manag metal knowledg system kaon ontolog industri',
#  'brows carrier context search map topic structur visual bearer key post-structur process domain word knowledg assist manag navig pre-structur busi engin tool base model',
#  'balanc manag knowledg benefit measur scorecard',
#  'seci manag knowledg cynefin optim scientif gener',
#  'knowledg engin product jess ontolog rule plan xml base workflow',
#  'manag knowledg social capit benchmark resourc cluster intellectu capabl',
#  'manag knowledg prune ontolog structur comput',
#  'manag knowledg system project develop pilot skill personnel compet',
#  'knowledg capit individu explicit interpret custom integr collect intuit process',
#  'manag knowledg represent skill ontolog matchmak',
#  'repertori theori organis person measur learn role construct test',
#  'human manag project skill databas resourc updat plan',
#  'manag elearn personalis skill hypermedia',
#  'repertori human manag knowledg theori studi develop grid approach skill techniqu case space competence-perform resourc compet',
#  'manag knowledg transfer skill view resourc profil base compet',
#  'knowledg problem environ learn skill simul assess structur solv',
#  'educ manag train skill export portug',
#  'manag knowledg groupwar awar expertis',
#  'manag knowledg knowledge-intens organis ontolog memori group compet',
#  'logic check system execution-bas tempor rapid monitor prototyp real-tim execut run-tim model',
#  'domain-specif architectur transform formal model graph languag model-driven grammar model-integr specif comput',
#  'coalgebra formal system design languag semant behavior level denot state-bas specif algebra',
#  'protocol servic admiss interfer denial bisimul equivalence-check',
#  'formal csp translat grammar specif uml model',
#  'domain-specif descript embed languag hardwar',
#  'semant coalgebra compon softwar',
#  'formal semant action specif object-ori',
#  'architectur separ adapt concern aop softwar aspect-ori applic program',
#  'resourc mobil process-calculu distribut comput',
#  'analysi constant optim code graph predic ssa-form data-flow valu propag ia',
#  'system event-ori tupl space distribut program',
#  'manag count refer memori cycl collect garbag',
#  'object-ori aspect-ori program',
#  'xmi meta-model xmlshema ocl xml uml',
#  'asynchron invoc remot method distribut program',
#  'infer type languag recurs polymorph program',
#  'depend type dml match pattern',
#  'parallel petri languag net fuction program',
#  'manag knowledg reason web case-bas semant ontolog xml',
#  'leadership cultur manag knowledg corpor',
#  'manag knowledg ontolog mainten softwar',
#  'manag knowledg experi base build block schema reus repositori schemata',
#  'casebas reason retriev softwar reus',
#  'diagnost knowledg check project measur km strategi integr busi cost-benefit',
#  'cultur evalu user learn style dimens hci-',
#  'manag knowledg cultur bosch decentr index',
#  'manag knowledg represent retriev ontolog inform logic',
#  'queri retriev ontolog refin inform',
#  'plan manag knowledg risk',
#  'automata fibrat iwim coordin',
#  'separ oracl hierarchi function polynomial-tim class',
#  'experiment user engin studi softwar interfac intellig object-ori model',
#  'human descript cognit system perspect navig rout ellipt spatial',
#  'constraint tempor granular time abstract',
#  'theori reason necess tempor measur fuzzi relat approxim allen possibl interv',
#  'transform axi medial reason recognit shape represent qualit spatial',
#  'tableau system tempor axiomat interv logic',
#  'hierarch analysi descript reason graph case-bas agronomi classif structur spatial logic',
#  'logic reason constraint navig mobil tempor qualit integr autonom robot spatial program',
#  'reason biolog bayesian molecular spatial qualit access',
#  'rcc gi reason semant qualit data spatial',
#  'protocol formal interoper wap complianc test',
#  'wbt manag constructionist learn e-learn',
#  'analysi model system design method state machin specif abstract comput',
#  'complex predic time-spac implicit recurs class comput',
#  'manag knowledg document agent system intellig data base inform',
#  'handl compon system distribut network dinopoli transpar object aspect relat global java componentwar uniqu middlewar robust',
#  'membran hierarchi rewrit chomski splice molecular comput',
#  'analysi walsh comput',
#  'cyber e-democraci speech freedom ethic internet legisl',
#  'societi telecommun technolog internet mobil inform',
#  'knowledg capit network map relat intellectu report',
#  'informat search retriev histori legal inform',
#  'situat manag knowledg absorpt organis interchang capit dynam prior learn capac intellectu capabl',
#  'manag knowledg acquisit collabor languag natur distribut',
#  'taxonomi knowledg transfer network develop recycl compani agenc sustain',
#  'skill rdf manag ontolog',
#  'manag knowledg transfer tool',
#  'posit knowledg manag overload ignor agent document-explos intellig inform',
#  'queri similarity-bas databas multi-criteria imag data oper repositori model',
#  'knowledg manag mine map semant text topic relat corpora',
#  'epistemolog manag knowledg context node distribut',
#  'model user feedback queri relev retriev instanc learn memori expans base inform cooper',
#  'manag call interact user knowledg design usage-cent interfac pattern center',
#  'thesauru retriev gazett internet inform',
#  'experi systemat learn improv process',
#  'manag knowledg system work inform process',
#  'knowledg portal ontolog integr inform',
#  'visual metadata digit collag summar extract librari video',
#  'formal method object-orient semant uml pv',
#  'manag inter-domain optim system network vp atm rout qo provis hierarch',
#  'automata languag formal lattic',
#  'web learn train support mediat base commun strategi comput',
#  'knowledg research web grid european technolog semant fund comput',
#  'optim algorithm arithmet inclus affin function global interv bound branch',
#  'tile plagiar string similar search token',
#  'formal system power lindenmay d0l seri',
#  'e-set synset wordnet id cluster',
#  'island control search find rout rule',
#  'analysi knowledg landscap object-bas topolog represent relat classif reific',
#  'disjunct reason multi-ag qualit multi-dimension spatial',
#  'interv time granular',
#  'human np-hard hmi telerobot servic schedul team mobil job interfac machin autonom xml robot problem',
#  'present mental dynam anim model',
#  'engin system develop languag methodolog softwar hypermedia object-ori',
#  'system trail-bas navig support trail hypermedia open',
#  'architectur hypermedia structur open comput',
#  'servic system multimedia web web-bas retriev semant hypermedia mpeg xml content-bas',
#  'engin design techniqu function hypermedia program',
#  'system hypertext context coher author relat function linguist model',
#  'develop languag retriev natur softwar inform process',
#  'document notat hypermedia structur xml-base',
#  'employ interact e-commerc servic negoti onlin',
#  'formal system coordin pattern multi-ag model',
#  'complex formal decis languag synchron grammar problem comput',
#  'word',
#  'shannon entropi algorithm attribut index partit categor gini cluster median genet',
#  'tree set complet product automata',
#  'complex descript formal reliabl cellular languag parser finit automata ambigu pushdown softwar nondetermin',
#  'properti invari random',
#  'word dens closur primit oper base residu',
#  'regular nx shuffl product languag decomposit src img',
#  'formal code petri languag net',
#  'synchron finit automata',
#  'regular error-detect delay decid languag decod transduc channel uniqu error-correct',
#  'disjunct word infinit ultim uniformli recurr random period',
#  'plane hyperbol tile',
#  'antiport membran symport univers molecular comput',
#  'domain complex composit synchron automata finit function',
#  'complex set entropi subword languag dens nowher',
#  'determinist algorithm finit automata minim acycl construct',
#  'fix power complet point iter seri semir',
#  'tla reactiv formal system tool time real specif anim',
#  'engin computer-aid librari softwar',
#  'reusabl proof synthesi softwar program',
#  'attribut gener term graph declar grammar travers program',
#  'analysi check formal system verif real-tim model',
#  'logic control check formal diagram develop event verif tool process model',
#  'formal decis arithmet affniz verif augment lemma presburg specul univers integ procedur',
#  'check system ws1 verif parameter abstract model',
#  'model formal system relview relat algebra equival deriv class program',
#  'tla diagram tempor verif refin abstract logic',
#  'logic interact optim check program tempor proof verif prove techniqu theorem algebra invari specif structur correct model',
#  'coalgebra method binari modal specif logic',
#  'educ system web-bas learn train distanc teacher assess program',
#  'situat environ collabor learner person learn coordin histori',
#  'call assist transmiss learner languag learn co-edit voic corpu comput',
#  'visual collabor languag represent learn bia',
#  'writin call environ web-bas efl learn linguist corpu',
#  'balanc parallel load high perform processor comput',
#  'complex petri symmetri net comput',
#  'manag knowledg environment system issu',
#  'minimum-weight triangul set polygon geometri skeleton combinatori point data base comput',
#  'manag telecommun servic network ip',
#  'educ scienc curriculum women breadth comput',
#  'geometri design differenti surfac geometr reconstruct',
#  'digit document recognit graphic librari pattern electron inform comput',
#  'software/program transform reusabl verif synthesi softwar compil program',
#  'educ record annot algorithm system multimedia author anim captur present',
#  'internet secur',
#  'manag knowledg search retriev databas mpeg content-bas',
#  'system social multimedia behavior scienc autom inform offic',
#  'societi knowledg develop european economi inform union sustain',
#  'manag human knowledg superorgan organ system resourc non-explicit',
#  'manag visual interact knowledg digit content human-comput librari media higher-ord inform paradigm',
#  'manag edg environ collabor knowl virtual support work inform captur comput',
#  'technolog standard metadata learn',
#  'manag knowledg digit system librari person inform',
#  'portal knowledg ontolog',
#  'manag knowledg inform system',
#  'manag knowledg cognit elearn learn creativ',
#  'manag knowledg',
#  'formal gener calculu method test-cas refin test',
#  'method formal engin softwar',
#  'formal method languag semant denot vdl definit oper vdm',
#  'formal engin method support tool softwar vdm',
#  'logic theori intuitionist vdm mathemat topo construct model',
#  'engin revers semant slice denot algebra program',
#  'architectur parallel high perform memori data distribut comput',
#  'educ deliveri multimedia teach mix materi virtual mode univers cours comput',
#  'system decid lindenmay equival problem',
#  'cue computer-medi inform nonverb social frequenc develop durat messag ation impress social-emotion-ori commun process model',
#  'neural network state machin abstract distribut comput',
#  'descript formal sdl languag semant fdt techniqu asm state machin specif abstract',
#  'formal gener method sequenc state machin abstract test',
#  'asml parallel partial thesi synchron submachin asm state machin updat abstract',
#  'diagram dynam compil theorem logic proof commut transit state simul data refin interact system prove cerif ment abstract correct machin forward',
#  'falko asm-workbench state machin abstract',
#  'foundat dynam languag state machin modal specif abstract logic',
#  'requirements/specif cach share memori multiprocessor',
#  'educ complex np-complet graph comput',
#  'server hyperwav transclus inform',
#  'matrix parikh map inject',
#  'theori learn',
#  'complex theori count ture altern machin class comput',
#  'tailor groupwar cscw',
#  'control decompress multimedia specul extens smt video mpeg simultan multithread',
#  'complex rout fpga resourc hardwar reconfigur comput',
#  'societi complex inform',
#  'educ societi manag system inform comput',
#  'chemistri electron undergradu curriculum academ structur comput',
#  'educ conscious collabor embed softwar assess oper improv accredit continu life revers support reengin case work',
#  'knowledg multi-expert visual life-long-learn system scientif languag sysem base inform construct',
#  'concurr system x-machin channel',
#  'teleport visualis conceptu wide hierarchi glass context web search focu navig hypermedia world treeworld large-scal relev structur model',
#  'manag visual knowledg environmet system data base inform',
#  'gateway sql server perform cgi www java rdbm api',
#  'algorithm lattic fold hp approxim protein model',
#  'light requir control studi asm case refin',
#  'requir formal engin verif techniqu tool softwar specif',
#  'requir formal tempor object-orient real-tim specif problem logic',
#  'requir formal engin system embed real-tim refin specif',
#  'light control requir formal system model languag execut state-bas prototyp specif simul specification-bas',
#  'requir specif engin pv',
#  'theori learn',
#  'align par product mdl sing languag compress unif natur syntax mml multipl inform',
#  'cryptographi s-box boolean nonhomomorph function cryptanalysi',
#  'analysi control architectur design perform aid multiprocessor structur',
#  'theory-barri analysi algorithm spin synchron competit perform wait time producer_consum block lock',
#  'superscalar architectur latenc dataflow decoupl memori multithread',
#  'system rapid msparc real-tim prototyp multithread',
#  'formal system rewrit languag regul grammar program',
#  'incomplet complex time linear comput',
#  'wbt manag knowledg elearn teach web base',
#  'notat specif formal structur',
#  'tessel hyperbol cellular plane automata',
#  'constraint uncertainti comput interv logic',
#  'switch horsesho system smale map henon baker',
#  'system gener code constraint petri dynam behavior net inform',
#  'compar protocol leader formal elect studi concurr network method standard case',
#  'model noninterferen program properti confidenti flow intransit verif techniqu noninterfer secur specif inform ce',
#  'formal system distribut method object-orient open specif uml pv',
#  'pre formal depend post-condit heapsort invari specif agent-ori model',
#  'complex geometri path motion plan optimis',
#  'logic transform embed method function algebra program',
#  'formal system method verif real-tim specif algebra',
#  'analysi termin function interpret abstract program',
#  'categori theori logic',
#  'monoid lattic mv wajsberg boolean pseudo-wajsberg pseudo-mv residu center algebra',
#  'concurr img process calculu graphic represent semant src machin net multiset abstract',
#  'frequent set item closur connect support extend galoi',
#  'coher behaviour equival hidden algebra',
#  'pseudo-boolean optim set horn boolean function binari truth',
#  'v-algebra monad mv-algebra pavelka algebra',
#  'parallel type program categori semiring network mix relat enrich data abstract algebra',
#  'kraft inequ prefix-fre set',
#  'permut automorph graph hypercub group',
#  'mvn n-valu lukasiewicz-moisil algebra',
#  'logic substructur implic kripke-typ semant strict canon relev linear model',
#  'graph complementar principl finit automata shift sofic',
#  'logic languag boolean thought algebra',
#  'system splice univers rule comput model',
#  's-order quasi-ord semir',
#  'extractor function sourc random hash bit',
#  'tableau transform deduct proof search autom calculi present',
#  'data instanti solut structur restructur hierarch',
#  'logic analysi algorithm design simul average-cas',
#  'permut theori revers group comput',
#  'arithmet geometri precis divis exact float librari point multipl expans comput',
#  'cryptographi scheme share secret data secur random',
#  'cach network pre-fetch www wireless proxi mobil comput',
#  'align reason compress unif multipl inform probabilist',
#  'specif system process languag x-machin state softwar matrix commun stream test',
#  'product languag synchronis pictur',
#  'complex hyperbol theori cellular plane automata',
#  'parallel automata partit decomposit time state clock',
#  'tree languag dna comput',
#  'transform fault failur verif toler specif model',
#  'markov tree cision fault shannon net diagram petri approach binari de',
#  'life gener uniform composit method ratio time procedur comput',
#  'experiment algorithm code exact heurist constant-weight solut bounded-weight error-correct',
#  'posit np complex ture reduct comput',
#  'algorithm mount pcb assembl multi-head surfac time machin genet',
#  'tableau deduct durat calculu method autom',
#  'post theori align system compu ture',
#  'arithmet semigroup embed quasilinear commut space isomorph oper interv bodi convex minkowski',
#  'transform equat arithmet extend solut interv algebra',
#  'measur uncertainti mathemat comput machin interv co-ordin model',
#  'analysi evalu multimedia content applic review',
#  'educ evalu experi multimedia design methodolog scienc curriculum',
#  'analysi theori reason knowledge-build collabor implic learn piagetian',
#  'organiz evalu system design share learn memori inform',
#  'educ system learn assess electron',
#  'evalu round method polynomi chebyshev perturb error',
#  'order complex separ hierarchi queri polynomi commut downward class comput',
#  'multi/mix digit confer multimedia navig map video media hypermedia proceed hypertext inform publish electron',
#  'neural network navig retriev hypertext inform',
#  'p-select complex comput',
#  'balanc tree ocpc workload move share work-optim memori simul mesh erew coat random thread',
#  'nonperfect scheme secret share',
#  'navig web search retriev text hypertext inform categoris',
#  'visual user document retriev result rank interfac inform present',
#  'script web page dynam languag cgi',
#  'adapt softwar integr quadratur cubatur',
#  'infer system key relat schema',
#  'templat engin design revers search pattern',
#  'deduct key relat databas autom schema',
#  'shannon symbol text compress rank',
#  'programm coprocessor rapid prototyp hardwar pc logic',
#  'deref type modul borland oberon languag chill pascal object extens assign paramet pass object-ori',
#  'concurr state machin abstract recurs distribut comput',
#  'shortest path verif constrain softwar state abstract problem machin',
#  'requir check document program code stepwis verif techniqu inspect state machin refin specif abstract model',
#  'visual formal design modular languag montag state machin specif abstract program',
#  'oberon languag montag refer state machin manual specif abstract program',
#  'document code stepwis techniqu inspect state machin refin abstract program',
#  'abstract gener verif semant back-end state machin oper compil',
#  'filter gather agent-bas system reason memory-bas internet probabilist inform model',
#  'filter knowledg manag life-cycl corpor technolog memori work inform process',
#  'knowledg manag participatori system organis design collabor knowledge-bas argument memori',
#  'manag knowledg studi corpor case memori',
#  'groupwar design share workspac cscw workflow',
#  'knowledg formal gener acquisit artifici method languag represent natur interfac intellig process',
#  'knowledg manag system coordin mechan cscw multi-ag',
#  'filter spread feedback network semant text activ relev',
#  'automat system paperfold uniform sequenc tag',
#  'evalu teach web-bas coursewar learn train techniqu',
#  'educ d-ari overflow arithmet correct proof scienc test comput',
#  'control applic discretionari cryptographi databas data secur polici object-ori access',
#  'free placement space algorithm',
#  'boolean function resili cryptolog nonlinear',
#  'monstr term rewrit graph languag intermedi semant model',
#  'instruction-level depend parallel schedul graph assign alloc processor',
#  'filter algorithm process genet imag stack distribut comput',
#  'theori cryptosystem code inform error-correct',
#  'pram chain multithread vliw',
#  'cultur research forum failur neg result fnr progress',
#  'abstract protocol formal gurevich key method verif kerbero state machin secur refin specif distribut',
#  'basic foundat formal document telecommun sdl system semant state machin execut specif abstract',
#  'interv specif arithmet',
#  'evalu type parallel algorithm queri develop methodolog text categor softwar data structur',
#  'system rewrit term modular confluenc persist',
#  'bishop dirichlet problem mathemat hilbert space construct',
#  'tt-complet set chaitin wtt-complet number',
#  'kraft huffman tree optimum prefix code inequ extend',
#  'incomplet minim automata',
#  'order decid monad well-quasi-ord',
#  'set hierarchi graph obstruct polynomi minor',
#  'variable-length code encod represent decod t-code',
#  'properti invari random',
#  'infinit set close sequenc map measur cantor comput',
#  'logic model complet kripk intermedi jump oper comput',
#  'map mathemat pointwis sequenti continu linear construct',
#  'agent flow arrow belief oper modal commun inform logic',
#  'hypermedia structur system model',
#  'theori optim parallel queri learn equival membership dfa comput',
#  'permut cryptographi s-box attack differenti box linear substitut',
#  'engin document multimedia teach technolog distanc integr electron inform comput',
#  'educ design film televis distanc instruct',
#  'free design thesi linux circuit asic unix integr softwar diploma pc',
#  'system multimedia teach develop distanc onlin media publish',
#  'knowledg inform gather system agent data retriev internet broker distribut',
#  'complex network combin boolean measur function monoton',
#  'disjunct word properti represent period ration invari number normal',
#  'triangul rotat edge-flip flip distanc oper',
#  'educ cscw cai teach hyperwav web author hm-card distanc www softwar hyper-',
#  'educ groupwar studi cooper classroom support scienc case work electron comput',
#  'formal parallel system rewrit languag k-limit',
#  'synchronis code string t-code decomposit recurs t-augment redund effici',
#  'parallel program coursewar vision onlin world-wide-web comput',
#  'educ literaci document evaluation/methodolog multimedia design hypertext web system prepar scienc world-wid',
#  'model system squar arithmet kinet enzym uncertainti valid verif approxim interpol comput manipul',
#  'number system reason implic quantifi fuzzi approxim approach linguist inform',
#  'comparison sequenc dna biolog fpga vlsi hardwar',
#  'monstr term rewrit graph languag intermedi semant model',
#  'system hierarchi rewrit languag regul chomski dna splice famili molecular abstract recombin genet',
#  'effectiv set complet function pseudosimpl extension bound',
#  'formal system languag grammar team',
#  'gopher link system hypertext internet www hyper-',
#  'encrypt cryptographi s-box boolean sac function propag characterist nonlinear',
#  'visualis interact system graphic internet hypermedia inform',
#  'societi cultur web aspect histori www world-wid sgml',
#  'gopher system internet inform distribut',
#  'algorithm graph biconnect st-number distribut',
#  'system geometri elimin polynomi differenti prove decomposit mechan triangular',
#  'digit teach cbt learn librari support technolog cai instruct electron',
#  'algorithm public design high key cryptographi testabl speed multipli hardwar',
#  'system xanadu network hyper-',
#  'equat arithmet partial float method finit differenti numer propag point differ error',
#  'theori system arithmet ration lexicograph number continu fraction comput',
#  'on-lin super-scal accur reliabl arithmet precis high-radix vliw credibl',
#  'analysi arithmet manipul algebra interv error comput',
#  'on-lin fraction digit set arithmet number represent interv continu redund comput',
#  'ieee handl arithmet implement',
#  'arithmet function comput elementari reduct rang',
#  'grammar life artifici system',
#  'multimedia queri network navig home imag store hypermedia distribut',
#  'gif debat compuserv softwar unisi internet patent lzw',
#  'concurr monstr term rewrit graph network serialis simul pi-calculu process',
#  'balanc system cach load network perform file distribut',
#  'command assist agent electron pad predict search messag exampl voic program',
#  'cube theori tile wang aperiod mathemat automata machin sequenti discret',
#  'automat link mainten data hypermedia model',
#  'teach coursewar whiteboard distanc hypermedia electron',
#  'featur agent-interact constraint distribut problem sign coordin negoti multiag strategi solv cooper',
#  'free word formal context languag map l-system parikh problem',
#  'ai parallel qsim constraint satisfact distribut',
#  'control anonym access authent big secur',
#  'complex blank-endmark chaitin string random self-delimit',
#  'estim digit radix high divis approxim',
#  'tree share work-optim memori simul mesh erew coat random',
#  'shuffl system chomski grammar oper',
#  'educ',
#  'arithmet code lz vector text compress quantis',
#  'understand affin match imag fusion registr inform spatial',
#  'evolutionari optim algorithm network-on-chip map multi-object system-on-chip simul',
#  'algorithm cryptographi s-box multi-object evolv hardwar genet optimis',
#  'tree fault neural decis program network hardwar monitor intellig electron genet comput',
#  'filter transconduct optim leapfrog algorithm evolutionari design method circuit search multi-object classic pattern genet amplifi oper problem electron',
#  'evolutionari multius algorithm code divis detect access multipl genet comput',
#  'formal reactiv system tempor altern verif automata time assert monitor run-tim specif seri logic',
#  'arithmet revers circuit oper multipli comput',
#  'hierarchi complet domat exact uncolor boolean minim color number',
#  'human inform system issu pervas devic societ technolog portabl health expert process',
#  'system environ artifici smart multiag intellig',
#  'automat diagnosi micro-kernel embed sensor arrhythmia wireless real-tim cardiac telemedicin ecg',
#  'agent devic context-awar technolog mobil telemedicin comput',
#  'provis servic smart-hom web-bas behavior technolog care monitor telemedicin',
#  'cancer record patient confidenti languag computer privaci natur health secur bioinformat process electron',
#  'jini agent healthcar pervas home comput',
#  'healthcar privaci qualiti privacy-awar ubiquit comput',
#  'mosaic interact visual rfid context awar implicit ubiquit inform comput',
#  'ambienc environ context privaci awar intellig',
#  'ambient pervas smart space intellig middlewar comput',
#  'architectur design network sensor modular wireless node hardwar',
#  'compon ambient pervas aspect intellig middlewar comput',
#  'hybrid architectur decis merg web semant rule inform context-awar',
#  'trust protocol servic network ad-hoc discoveri secur',
#  'mine engin social issu web search retriev inform',
#  'inherit symbol coercion comput specif algebra',
#  'formal type compon graphic softwar logic mix descript tempor transit notat data specif system languag glue abstract architectur engin symbol base',
#  'human recognit ture captcha charact comput persian public text internet baffletext arab secur',
#  'dynam optim just-in-tim compil',
#  'coalgebra coinduct process algebra',
#  'dynam optim just-in-tim compil',
#  'develop languag aspectj aspect softwar orient refactor',
#  'analysi slice function program',
#  'free invoc context method sequenc languag grammar aspect visitor essenti pattern',
#  'program function haskel strong mobil comput',
#  'interoper object virtual machin model',
#  'servic languag web workflow pattern program',
#  'semant uml automata nonsequenti',
#  'manag type system queri languag semant databas oper object-ori',
#  'filter scienc simul fusion particl data',
#  'instanc rule interesting pattern data',
#  'cryptographi secur random',
#  'mersenn gener method pseudorandom simul twister carlo number mont random',
#  'cryptographi quantum comput',
#  'bdd complex formal decis algorithm diagram properti program languag sublinear boolean function bp binari branch random test comput',
#  'exponential-tim determinist algorithm exact random comput',
#  'algorithm complex random class',
#  'term context behaviour observ specif cover',
#  'estim filter fingerprint gabor enhanc orient',
#  'neural network compress predictor toler error data',
#  'system ing dna molecular splic comput',
#  'optim constraint propag interv solv branch',
#  'handl rna constraint secondari predict format gene grammar concept rule protein structur',
#  'compar concurr process equival preorder semant readi simul trace bisimul refus',
#  'logic model check concurr constraint tempor time paradigm',
#  'narrow failur negat functional-log construct program',
#  'logic rewrit maud verif function program',
#  'equat induct semant prove theorem itp data membership structur logic',
#  'logic xpath set languag magic program',
#  'logic transform fuzzi unfold program',
#  'cheat ipr plagiar detect similar',
#  'institut congruenc leibniz behavior relat equival refin hidden logic',
#  'elect check leader formal algorithm model network verif anonym probabilist distribut comput',
#  'ssa optim compil',
#  'self-organis system social emerg collabor network share web-bas build blog file wiki podcast applic commun work inform',
#  'mutual complex section queue algorithm distribut network messag migrat exclus critic comput',
#  'analysi deadlock-fre petri live siphon net structur',
#  'balanc user system enterpris load cluster profil distribut',
#  'evalu proxim datalog knowledge-bas fuzzi strategi',
#  'mvc xslt design web xmi pattern techniqu data applic xml uml model',
#  'domain dn system servic telephon enum-bas client procedur number',
#  'queue cach network server perform proxi model',
#  'thermovis potato plant breed dimens classif imag improv qualif fractal',
#  'data-flow queri databas languag',
#  'prolog japlo java',
#  'season analysi lymphoid method decomposit time leukaemia childhood acut seri',
#  'estim educ method crop model',
#  'geo-bas servic market portal web-bas map java ajax xml',
#  'segment retriev databas imag process',
#  'higher educ featur driven virtual classroom conflict definit cours construct model',
#  'chao equat graphic differenti endocrin nonlinear',
#  'signal haar-lik system multiresolut imag wavelet process',
#  'ad control hoc topolog algorithm network distribut',
#  'parallel membran system graphic interfac oper comput',
#  'estim discrimin inaccuraci paramet inform distribut cauchi',
#  'visual neural network artifici phase associ transit memori abil inform process',
#  'societi literaci digit teacher school inform compet',
#  'protocol formal time-releas cryptographi kudo-mathuria verif time cryptograph capsul',
#  'p-graph network synthesi workflow',
#  'higher educ system engin product integr inform',
#  'scienc educ logic comput',
#  'analysi visual volum surfac render virtual imag surgeri multimod medic process',
#  'hybrid agent-bas system petri recommend negoti net thread',
#  'knowledg system represent estimatio relat input-output paramet identif',
#  'knowledg formal acquisit network method artifici represent semant information_systems_appl intellig',
#  'diagnosi fault k-distinguish system p-invari event place-transit d-partit point net discret test',
#  'rule-bas system represent transact multiag commerc electron',
#  'manag knowledg mine end-to-end-perform network predict grid behavior perform internet data',
#  'incomplet order method partit consensu cover hierarch',
#  'theori depend system agent attribut consensu conflict distribut',
#  'utter speech interfac rate entrain',
#  'manag visual knowledg skg content globe inform sustain',
#  'convers panorama network locomot',
#  'gener realiti virtual avatar-bas motion commun captur',
#  'convers acquisit quantiz knowledg',
#  'throughput pipelin control latenc regist ae dynam loop fpga total time unrol iter reconfigur',
#  'system optic robust flow devic illumin fpga real-tim imag reconfigur process',
#  'protocol asynchron self-tim microprocessor phase virtex fpga ii',
#  'set implement ultrason fpga-bas sequenc complementari techniqu compress correl effici',
#  'architectur algorithm implement imag system-on-a-programmable-chip hardwar process',
#  'partial cryptographi dynam fpga idea reconfigur',
#  'pipelin scheme loop fpga hardwar compil',
#  'requir formal scr method toolset',
#  'b-method method formal',
#  'hardwar method formal verif',
#  'method check formal model',
#  'method formal',
#  'grand formal challeng method verif',
#  'correct method formal construct',
#  'method formal engin softwar',
#  'formal system represent learn configur e-learn scenario',
#  'posit root isol real upper bound',
#  'mashup web visualis',
#  'templat polytim function static comput',
#  'e-commerc formal system payment cryptographi verif secur',
#  'manag copyright metadata user system e-commerc servic licens digit web interfac integr protect applic inform usabl watermark',
#  'control system event refin access',
#  'control concurr servic web transact atom commut distribut',
#  'databas reflect perform',
#  'memori handl transact',
#  'technolog educ e-learn webquest',
#  'unit design graphic learn ld author im notat',
#  'list educ collis pipelin insert latenc schedul delay diagram state simul forbidden reserv vector tabl',
#  'design learn object ontolog qualiti instruct',
#  'educ separ flexibl languag concern model',
#  'educ graduat webct onlin degre',
#  'handheld devic simul authoring-tool model',
#  'design collabor game learn cscl model',
#  'human evaluation/methodolog network factor commun',
#  'interact ute collabor pervas learn synchron comp mobil comput',
#  'moodl design map learn im integr',
#  'requir languag non-funct specif program',
#  'constrai architectur model-driven nt softwar reus program',
#  'program refactor law condit logic',
#  'pars lalr methodolog conflict',
#  'advic optim aspect-ori weav compil program',
#  'demonstr visual program',
#  'lua reusabl dynam aspect heterogen aop',
#  'spreadsheet call-by-ne structur abstract program',
#  'manag concurr count refer memori collect garbag',
#  'manag tenur count graph cyclic object refer memori perman collect garbag',
#  'applic languag interfac program',
#  'analysi slice function program',
#  'infer overload type system close constrain open world approach polymorph',
#  'semant action formal object-ori',
#  'selecti manag knowledg algorithm servic web resourc ws qualiti',
#  'semant choreographi servic',
#  'manag knowledg descript compet creation represent skill e-learn logic',
#  'programm engin design develop learn instruct compet',
#  'link annot similar typed-link futur index citat',
#  'gener learn function approxim attent reinforc',
#  'scienc educ inform comput',
#  'transform system entiti combin extract',
#  'co-evolut algorithm emerg evolv hardwar commun genet',
#  'optim quadrat neighborhood search assign swarm variabl particl problem',
#  'algorithm neural process network ph fuzzi neutral recurr genet model',
#  'signal evolutionari neural design cellular network analog circuit process dac',
#  'system network artifici forens secur immun comput',
#  'manet autoconfigur olsr',
#  'ad hoc network adapt rout cluster wireless scalabl',
#  'mpr qualiti local servic network bandwidth avail multi-point flood admiss relay qo olsr ad control optim hoc interfer rout',
#  'vote aggreg network sensor cluster data head energy-effici',
#  'ad evalu balanc hoc protocol cach load network mobil rout distanc perform ad-hoc energi node on-demand vector effici',
#  'interoper languag virtual function haskel machin net compil program',
#  'hierarch model encrypt bilinear standard identity-bas pair',
#  'deduct type calculu mathemat natur negationless construct logic',
#  'geometri video databas data structur comput',
#  'proxim collabor learn support mobil comput',
#  'pso sigmoid polygon function centroid approxim',
#  'metric riemannian similar support machin vector',
#  'metadata extract learn vector support machin keyword',
#  'evolutionari mine system algorithm express gene artif rule data meta-rul immun program',
#  'independ densest graph subgraph number eigenvalu',
#  'reson isoarithm perfect aromat hydrocarbon clar factor polyhex kekul match polycycl structur benzenoid',
#  'theori categori automata rabin-scott behaviour meali final moor sequenti semiautomata',
#  'gray code single-dist',
#  'complex evolutionari ture network processor machin class',
#  'steiner tree approxim ratio minimum heurist sweep-lin span',
#  'hertz hsalmankhan175jek lattic mv mtl nm residu bl generalized-mv wnm algebra generalized-bl divis gener wajsberg pocrim t-norm',
#  'theori matroid geometri pebbl rigid game hypergraph comput',
#  'metric regular theori fix mine asymptot proof function nonexpans halpern point iter',
#  'bistabl elementari kroneck set graph irreduc support match adjac total perfect product boolean fulli bipartit stabl indecompos matrix cover',
#  'neural membran system astrocyt spike comput',
#  'interact protocol type system termin regist languag agapia rv-system voic distribut program',
#  'balanc graph sign',
#  'metric modular entropi lattic',
#  'graph geodes theori connect',
#  'short topolog graph grid connected hamiltonian coeffici',
#  'coverif co-design slice softwar hardwar program',
#  'evolut petri reflect softwar net',
#  'formal servic method web e-bart',
#  'protocol formal network rebeca method modular verif',
#  'odedialect languag ontolog translat',
#  'metadata annot web extract semant ontolog inform',
#  'visual web semant rank schema',
#  'queri interoper web retriev semant inform',
#  'manag knowledg queri languag databas ontolog mediat internet applic distribut',
#  'life annot web nlp scienc semant ontolog cores',
#  'cscw architectur groupwar asynchron notif collabor synchron simul',
#  'servic system collabor web learn semant ontolog tool discoveri cscl',
#  'situat interact collabor share learn workspac nomad work model',
#  'groupwar service-ori servic col unit web labor platform ad-hoc mobil middlewar scenario',
#  'meet upper-lay pattern middlewar electron',
#  'script architectur design collabor learn integr',
#  'text segment cluster',
#  'digit document tool-support web semant prepar history-informat xml tag mediev',
#  'featur recognit confus measur zone mechan matrix metaclass charact',
#  'pattern signatur recognit verif',
#  'ta da segment document recognit table-form extract handwritten',
#  'engin document interfer back-to-front show-',
#  'light segment maximum foreground/background restor histor manuscript imag color arab likelihood k-',
#  'engin document interfer back-to-front show bleed',
#  'analysi recognit symbol discrimin condit',
#  'fair protocol public exchang key cryptographi secur',
#  'cryptographi secur authent',
#  'exchang graph key notion secur random',
#  'transfer oblivi privaci protect commerc electron',
#  'key-shar unknown key resili agreement bellare-rogaway authent bilater model',
#  'exchang key roam anonym authent',
#  'certificateless encrypt attack standard malici kgc model',
#  'fast field arithmet algorithm cryptographi koblitz finit curv cryptograph ellipt',
#  'analysi knowledg social network collabor softwar wiki work',
#  'ruler carpent algorithm fold approxim problem',
#  'analysi user gener e-commun content weblog blog',
#  'interact compens classif advertis model',
#  'neighbor network voronoi nearest road pine continu',
#  'traffic analysi user end-to-end experi measur behaviour perform qualiti internet passiv',
#  'market design network bandwidth alloc resourc',
#  'queu servic cost telric prioriti bitstream over-engin qualiti access model',
#  'call voip delay eigenvector zrtp puzzl challenge-respons srtp comput',
#  'digit servic multimedia ict divid web-bas e-servic broadband access',
#  'incomplet game learn price interdomain stabil inform',
#  'network bandwidth multiplex reaction cost econom contract competit price effect curv provis statist demand',
#  'analysi reliabl network risk commun',
#  'secur man-in-the-middle-attack zrtp',
#  'analysi servic experi object happi qualiti ecosystem holist busi model',
#  'traffic model network plan scenario',
#  'riesz analysi topolog represent hausdorff space theorem comput',
#  'analysi multi-represent flowchart multi-funct realiz abstract comput',
#  'real elementari number class liouvil comput',
#  'hift topolog type system dynam pressur physic statist comput',
#  'bloch constant algorithm comput',
#  'analysi count hierarchi integr weak riemann',
#  'complex rule real quadratur comput',
#  'analysi probabilist measur comput',
#  'higher filter conveni topolog type equilog categori qcb-space space weak limit comput',
#  'nig lemma fan brouwer theorem',
#  'na mine reason case-bas explan classif text bay pattern data',
#  'engin server-sid portal develop web technolog java',
#  'educ conceptu reusabl unit design interoper languag learn framework process model',
#  'educ public scienc bia gender report statist comput',
#  'formal system process auction english specif multi-ag algebra',
#  'system retriev rank inform distribut',
#  'agent algorithm system dynam negoti methodolog alloc wireless resourc channel simul commun strategi multi-ag',
#  'manag trade market agent suppli softwar simul chain multi-ag electron',
#  'ad knowledg hoc agent table-driven aodv network bit-map rout discoveri overhead reduc tabl',
#  'metric evalu system perform multi-ag',
#  'align social queri network semant propag ontolog',
#  'system agent integr data prolog-lik comput',
#  'market reinforc learn simul',
#  'architectur engin system model-driven softwar component-bas',
#  'featur gateway mine system compon embed product line decomposit hardwar softwar mainten reus model',
#  'requir optim select softwar cot model',
#  'understand knowledg engin system revers legaci reus',
#  'acm architectur servic mismatch web style softwar',
#  'architectur transform driven crosscut develop aspect concern softwar orient mda model',
#  'gener develop product model-driven line tool softwar deriv program',
#  'servic web product web-bas line applic busi process',
#  'properti efremovi pre-',
#  'method lisp object common orient binari meta-program',
#  'metaobject protocol gener lisp special function',
#  'metaobject protocol type lisp common clim present',
#  'context-ori dispatch prototype-bas ambient subject multipl intellig program',
#  'lisp map common object-rel smalltalk',
#  'reason tempor lisp relat s-languag algebra',
#  'analysi visual user market stock graphic nasdaq veloc forc interfac data inform',
#  'interact groupwar awar real-tim community-bas',
#  'interact groupwar design base model',
#  'groupwar model-bas plastic awar approach shared-knowledg',
#  'develop groupwar model-driven cscw',
#  'automat requir interact transform usabl gener code compil sketch model',
#  'metric evalu cognit context method walkthrough usabaipo spanish-speak heurist',
#  'automat program ambient smart adapt home natur intellig ubiquit comput',
#  'task model collabor ambient context awar intellig ubiquit comput',
#  'human interact evalu engin access websit usabl comput',
#  'knowledg featur select represent retriev learn support classif text preprocess machin data vector inform',
#  'reattempt truncat markovian seamless finit mobil model',
#  'visual system meet extract retriev multimod inform electron',
#  'programm neural network core perceptron configur fuzzi fpga ip vhdl multilay hardwar logic',
#  'metadata annot decis scholarli network web make',
#  'metadata repositori share learn object build reus commun structur comput',
#  'ethic engin web search person pagerank privaci bia inform',
#  'taxonomi knowledg design collabor product web train support author semant tool base instruct e-learn model',
#  'digit multimedia entertain search semant ontolog',
#  'social content web user-gener platform media mpeg',
#  'assist web extract applic inform',
#  'wrapper mine system web autom data inform',
#  'wrapper tree-edit web crawl distanc hidden',
#  'web extract page classif cluster data',
#  'extract ontolog data inform semi-structur',
#  'visual inform extract block',
#  'ahead featur composit verif asm',
#  'metamodel engin languag model-driven asm state simul abstract machin',
#  'formal system embed method verif real-tim state machin specif abstract',
#  'logic model-check predic time state simul real-tim abstract machin',
#  'diagram dynam logic electron theorem commut state simul data refin interact precondit prove weakest purs mondex abstract machin secur forward',
#  'servic composit mediat discoveri process workflow',
#  'protocol induct goal method verif threat model',
#  'architectur composit modular measur adapt coordin coupl softwar reus commun',
#  'compon program adapt softwar logic',
#  'compon system mismatch composit behaviour valid adapt transit aspect-ori interfac run-tim program',
#  'interact pattern cc adapt extend aspect-ori machin softwar state specif uml program',
#  'techniqu web engin adapt',
#  'm-interact knowledg complex system meta-synthesi open intellig m-space process',
#  'brows assist agent method web learn increment softwar statist',
#  'mine market agent pattern microstructur data surveil',
#  'wpki parti non-repudi secur mobil',
#  'balanc deliveri algorithm cach load content network divid scope',
#  'e-busi studi agent case plan report deploy multi-ag',
#  'traffic optim system citi ligh multi-ag model',
#  'posit lb tree fingerprint decis method ubiquitous-campu',
#  'search semanti ontolog inform meta',
#  'shop graphic flow search salesman tabu travel hardwar',
#  'segment layer evolut set multi-lay termin level imag curv criterion',
#  'system network learn fuzzi classif bayesian machin genet logic',
#  'steiner tree evolutionari algorithm path-relink prize collect transgenet problem',
#  'hybrid optim algorithm schedul problem network genet bu',
#  'quantum finit assign state machin problem comput',
#  'optim multiobject network sensor metaheurist',
#  'algorithm optim search genet',
#  'featur theori optim set rough select two-step ant coloni swarm intellig particl problem',
#  'optim evolut parallel stochast cell combinatori cluster vlsi metaheurist placement simul comput',
#  'system emerg recommend e-learn swarm intellig multi-ag',
#  'diagnost decis system error e-health individu support dss bay rate base inform intervent theorem',
#  'interact human-comput',
#  'ergonom evalu cognit interfac',
#  'interact market phone usag human-comput sociolog factor computer-support breath mediat varieti determin mobil intens work cooper',
#  'human interact user interfac cscw mobil ubiquit comput',
#  'engin develop web support access tool applic process',
#  'ergonom user cognit design interfac',
#  'educ mine adapt support author data applic hypermedia',
#  'rdf evalu metadata educ desktop ad semi-automat adapt author semant caf hypermedia',
#  'domain system tutor author ontolog constraint-bas intellig model',
#  'design graph sequenc learn translat im',
#  'task schedul collabor ambient author activ space social-awar hypermedia intellig comput',
#  'educ metadata user templat guidelin design elearn web learn object adapt semant standard activ pedagogi model',
#  'educ cultur system cae adapt hypermedia',
#  'environ game learn adapt author tool base e-learn',
#  'understand analysi architectur mine document digit librari imag softwar',
#  'evalu digit content languag format librari convers migrat xml file plan characteris preserv',
#  'svm featur neural network classif crime scene',
#  'author pattern recognit verif',
#  'analysi resolut document ultra recognit hmm web retriev index text imag low',
#  'depend document network stack structur',
#  'evalu document binar imag process',
#  'grid cluster imag load-balanc process',
#  ...]

# %% [markdown]
# ## Search word repeated in the Title and Keyword

# %%
# import difflib

# %%
# def findSimilarOrIntersecting(lista1, lista2):
#     palabras_similares = []
    
#     for palabra1 in lista1:
#         for palabra2 in lista2:
#             s = difflib.SequenceMatcher(None, palabra1, palabra2)
#             if s.ratio() > 0.8:  # Puedes ajustar el umbral según tus necesidades
#                 palabras_similares.append(palabra1)
#                 break  # Rompe el bucle interno una vez que se encuentra una palabra similar
    
#     return palabras_similares

# def searchRepeatedWord(rakeTitle,rakeKeyword):

#     similarityList = []
#     for i in range(len(rakeTitle)):
#         list1 = rakeTitle[i].split()
#         list2 = rakeKeyword[i].split()
#         similarity = findSimilarOrIntersecting(list1, list2)
#         similarityList.append(similarity)
#     return similarityList

# %%
# similarityList = searchRepeatedWord(rakeTitle,rakeKeyword)

# %%
# for i in range(len(rakeTitle)):
#     print("words title: ",rakeTitle[i], "\nwords keyword: ", rakeKeyword[i], "\nwords repeated: ", similarityList[i])
# Out:
# words title:  integration community structure
# words keyword:  generation community cooperative knowledge wiki structure process
# words repeated:  ['community', 'structure']
# words title:  outcome synchronously interaction small learning workplace determining factor online acceptance group
# words keyword:  cooperative learning workplace training assurance study empirical professional quality
# words repeated:  ['learning', 'workplace']
# words title:  information weblogs sharing learning knowledge space
# words keyword:  information system agent learning weblog pedagogical space wiki arrangement
# words repeated:  ['information', 'weblogs', 'learning', 'space']
# words title:  management oriented implementing method modelling knowledge space architecture information process
# words keyword:  filtering collaborative management business method introduction modelling knowledge ontology information process retrieval
# words repeated:  ['management', 'method', 'modelling', 'knowledge', 'information', 'process']
# words title:  visualization transfer project map evaluation knowledge application tube
# words keyword:  communication visualization visual storytelling management metaphor project knowledge information
# words repeated:  ['visualization', 'project', 'knowledge']
# words title:  management system knowledge reconciling approach workflow
# words keyword:  knowledge management workflow
# words repeated:  ['management', 'knowledge', 'workflow']
# words title:  human toolkit technological design methodology network factor integrate km organisational
# words keyword:  networked collaborative management business network knowledge
# words repeated:  ['network']
# words title:  analysing business capturing kmdl improving process
# words keyword:  management business knowledge modeling description language process
# words repeated:  ['business', 'process']
# words title:  management solution business knowledge role enterprise process
# words keyword:  research market management business knowledge software tool enterprise process
# words repeated:  ['management', 'business', 'knowledge', 'enterprise', 'process']
# words title:  design knowledge modeling work infrastructure
# words keyword:  activity management business stance instrument knowledge theory modeling work infrastructure process
# words repeated:  ['knowledge', 'modeling', 'work', 'infrastructure']
# words title:  hierarchy knowledge infrastructure process model
# words keyword:  management system knowledge data base information
# words repeated:  ['knowledge']
# words title:  based management oriented knowledge approach service process
# words keyword:  service management knowledge process
# words repeated:  ['management', 'knowledge', 'service', 'process']
# words title:  queue algorithm formal construction concurrent
# words keyword:  refinement prover formal atomicity proof concurrency
# words repeated:  ['formal', 'concurrent']
# words title:  investigating atomicity observability
# words keyword:  observability refinement formal atomicity method development
# words repeated:  ['atomicity', 'observability']
# words title:  communication atomicity relaxing case mechanism verifying correctness asynchronous
# words keyword:  communication atomicity verification relaxation algebra process asynchronous
# words repeated:  ['communication', 'atomicity', 'asynchronous']
# words title:  compensating business modelling bpel precise transaction application
# words keyword:  formal ing semantics compensation specification method transaction language
# words repeated:  ['compensating', 'transaction']
# words title:  system replication broadcast understanding advantage quorum atomic
# words keyword:  system replication broadcast quorum atomic isolation
# words repeated:  ['system', 'replication', 'broadcast', 'quorum', 'atomic']
# words title:  manifesto atomic
# words keyword:  programming formal atomicity hardware method dependability transaction language
# words repeated:  []
# words title:  software development atomicity
# words keyword:  atomicity software development transaction monitor ocl uml concurrency
# words repeated:  ['software', 'development', 'atomicity']
# words title:  atomicity system provision
# words keyword:  atomicity coherence transactional cache memory
# words repeated:  ['atomicity']
# words title:  visual vikamine subgroup mining
# words keyword:  visualization analysis subgroup mining data
# words repeated:  ['subgroup', 'mining']
# words title:  visualizing social network flow recommendation
# words keyword:  visualizing reputation social network flow information
# words repeated:  ['visualizing', 'social', 'network', 'flow']
# words title:  orthogonal data visualization curve
# words keyword:  visual grand curve tour analysis method clustering andrew data exploratory
# words repeated:  ['data', 'curve']
# words title:  system operating mining ubiquitous data integrating gui
# words keyword:  data visualization mining icon
# words repeated:  ['mining', 'data']
# words title:  exploration visual decision segment mining connecting rule interactive data
# words keyword:  exploration visual segment mining connecting data
# words repeated:  ['exploration', 'visual', 'segment', 'mining', 'connecting', 'data']
# words title:  visualization decision uncertain diagram manipulation dependency incomplete
# words keyword:  decision incompletely diagram mining minimization function
# words repeated:  ['decision', 'diagram', 'incomplete']
# words title:  highly visualization temporal gravi interactive data structured information explore
# words keyword:  domain visualization temporal medical interactive data information
# words repeated:  ['visualization', 'temporal', 'interactive', 'data', 'information']
# words title:  large exploration visual scalable set data multiresolution
# words keyword:  exploration visualization visual technique data multiresolution
# words repeated:  ['exploration', 'visual', 'data', 'multiresolution']
# words title:  physically wireless locating intruder
# words keyword:  intrusion system wireless antenna detection
# words repeated:  ['wireless']
# words title:  reference security evaluation level policy fuzzy technique model
# words keyword:  public key security evaluation policy fuzzy technique infrastructure
# words repeated:  ['security', 'evaluation', 'policy', 'fuzzy', 'technique']
# words title:  audio robustness lsb reduced increasing steganography coding distortion
# words keyword:  audio lsb steganography coding data hiding
# words repeated:  ['audio', 'lsb', 'steganography', 'coding']
# words title:  protocol intrusion cryptographic embedded protomon monitor detection prevention
# words keyword:  protocol intrusion cryptographic security computer detection abuse
# words repeated:  ['protocol', 'intrusion', 'cryptographic', 'detection']
# words title:  communication protocol network sliding window secure group
# words keyword:  ad routing hoc protocol performance communication network dsr secure group
# words repeated:  ['communication', 'protocol', 'network', 'secure', 'group']
# words title:  cryptographic efficient secure hardware
# words keyword:  algorithm genetic computation cryptography evolutionary
# words repeated:  ['cryptographic']
# words title:  certified signature encryption verifiable delivery recoverable
# words keyword:  certified fair protocol exchange security delivery
# words repeated:  ['certified', 'delivery']
# words title:  exploration system combination source assurance space lazy information quality open
# words keyword:  system agent information quality
# words repeated:  ['system', 'information', 'quality']
# words title:  disk digital tool forensics checkpointing consistent
# words keyword:  consistency system backup operating digital file snapshot forensics checkpointing
# words repeated:  ['digital', 'forensics', 'checkpointing', 'consistent']
# words title:  secured transfer network scheme computer data
# words keyword:  management algorithm key security pad secrecy protection theory data information perfect
# words repeated:  ['data']
# words title:  gossip analysis construction code erasure fingerprinting pirate tracing
# words keyword:  system multimedia digital coding theory library information
# words repeated:  []
# words title:  profile creation game distributed information databasesas problem
# words keyword:  database market manager game strategy distributed theory information resource
# words repeated:  ['game', 'distributed', 'information', 'databasesas']
# words title:  control ded method synthesis application
# words keyword:  control ded system event dynamic synthesis discrete
# words repeated:  ['control', 'ded', 'synthesis']
# words title:  complex system implication structural software development tendency
# words keyword:  life complex adaptable system cycle software architecture
# words repeated:  ['complex', 'system', 'software']
# words title:  based user collaborative web bookmark browsing extraction interest semantic
# words keyword:  collaborative web browsing ontology work
# words repeated:  ['collaborative', 'web', 'browsing']
# words title:  cognitive grounding internal agent relation structure language problem
# words keyword:  cognitive communication grounding agent formula satisfaction language modal logic
# words repeated:  ['cognitive', 'grounding', 'agent', 'language']
# words title:  hybrid method query searching recommendation rankfeed
# words keyword:  rosa adaptive system web mining recommendation information personalization retrieval
# words repeated:  ['recommendation']
# words title:  inconsistency knowledge level processing semantic
# words keyword:  consensus method knowledge conflict inconsistent
# words repeated:  ['inconsistency', 'knowledge']
# words title:  hybrid user system adaptation web interface
# words keyword:  hybrid consensus user system adaptation method interface
# words repeated:  ['hybrid', 'user', 'system', 'adaptation', 'interface']
# words title:  approximate computational model efficient spatiotemporal provably retrieval
# words keyword:  database high dimensionality query structure spatiotemporal modeling range data
# words repeated:  ['spatiotemporal']
# words title:  time computation actor cost
# words keyword:  parallel constraint execution computation time actor implementation
# words repeated:  ['time', 'computation', 'actor']
# words title:  performance protocol scalable control analysis design scheme evaluation
# words keyword:  communication protocol rtcp management multimedia scalability distributed
# words repeated:  ['protocol']
# words title:  generation testing algorithm genetic flow automatic data test
# words keyword:  generation testing algorithm genetic flow software automatic data test
# words repeated:  ['generation', 'testing', 'algorithm', 'genetic', 'flow', 'automatic', 'data', 'test']
# words title:  routing estimation theoretical upper bound
# words keyword:  routing algorithm circuit cad global integrated
# words repeated:  ['routing']
# words title:  document multimedia transclusions html
# words keyword:  authoring xanalogical system multimedia transclusions application structure hypermedia publishing
# words repeated:  ['multimedia', 'transclusions']
# words title:  communication cube fat complexity collective topology
# words keyword:  interconnection fat cube communication network router collective architecture topology
# words repeated:  ['communication', 'cube', 'fat', 'collective', 'topology']
# words title:  class test testing automation formal specification framework testaf
# words keyword:  testing formal automated specification software
# words repeated:  ['testing', 'formal', 'specification']
# words title:  based cryptosystem efficient variant verifiable paillier secure provably shuffle
# words keyword:  privacy system verifiable paillier huffles
# words repeated:  ['verifiable', 'paillier', 'shuffle']
# words title:  b2c agent virtual exploiting ontology marketplace
# words keyword:  b2c agent ontology technology intelligent
# words repeated:  ['b2c', 'agent', 'ontology']
# words title:  domain tree algorithm uowhf extenders binary finite
# words keyword:  tree uowhf binary function hash
# words repeated:  ['tree', 'uowhf', 'binary']
# words title:  compositional rebeca automated verification abstraction checking model
# words keyword:  system modular verification reactive abstraction checking actor technique model
# words repeated:  ['verification', 'abstraction', 'checking', 'model']
# words title:  fast algorithm
# words keyword:  entropy complexity computable parsing measure
# words repeated:  []
# words title:  free simple tree polygon bounded inside draw
# words keyword:  free computational tree geometry skeleton graph straight annealing simulated drawing
# words repeated:  ['free', 'tree']
# words title:  language constructive definition approach
# words keyword:  programming semantics modularity structural action operational language
# words repeated:  ['language']
# words title:  programming design match functional hardware perfect
# words keyword:  programming generation hardware circuit structure description functional arithmetic language logic
# words repeated:  ['programming', 'functional', 'hardware']
# words title:  lua implementation
# words keyword:  coroutines closure virtual machine ables compiler hash
# words repeated:  []
# words title:  aspectlua dynamic aop approach
# words keyword:  mop lua reflection aspect dynamic aop
# words repeated:  ['dynamic', 'aop']
# words title:  finalizers semantics formal
# words keyword:  collection management garbage semantics finalization memory
# words repeated:  ['semantics']
# words title:  building web language service interface pew
# words keyword:  programming formal web semantics service language
# words repeated:  ['web', 'language', 'service']
# words title:  net compiling platform functional language
# words keyword:  programming net functional virtual haskell interoperability language machine compiler
# words repeated:  ['net', 'functional', 'language']
# words title:  bytecode script lua clr translation running
# words keyword:  bytecodes virtual runtime common language machine compiler
# words repeated:  ['bytecode']
# words title:  evaluation experimental jit java technology
# words keyword:  optimization dynamic compilation compiler
# words repeated:  []
# words title:  signal comonads
# words keyword:  dataflow computation comonads function law stream distributive
# words repeated:  ['comonads']
# words title:  language equational scheme specification
# words keyword:  formal analysis semantics equational specification executable program
# words repeated:  ['equational', 'specification']
# words title:  computation mhaskell functional language mobile purely
# words keyword:  programming computation haskell functional language mobile
# words repeated:  ['computation', 'mhaskell', 'functional', 'language', 'mobile']
# words title:  tree decision learning dynamic data stream
# words keyword:  drift decision tree incremental concept data stream
# words repeated:  ['tree', 'decision', 'data', 'stream']
# words title:  data mining stream
# words keyword:  computing mining clustering data stream
# words repeated:  ['data', 'mining', 'stream']
# words title:  categorization alert id network attack mining extraction stream scenario
# words keyword:  resolution intrusion security network detection logic
# words repeated:  ['network']
# words title:  web request mining preprocessing semantic usage stream
# words keyword:  analysis web mining browsing pattern usage semantic
# words repeated:  ['web', 'mining', 'semantic', 'usage']
# words title:  evaluating trigger requirement condition streaming time series quality
# words keyword:  prediction trigger qos streaming time series service quality model
# words repeated:  ['trigger', 'streaming', 'time', 'series', 'quality']
# words title:  item mining online dynamic continuous data stream change
# words keyword:  algorithm mining data stream change
# words repeated:  ['mining', 'data', 'stream', 'change']
# words title:  learning incremental border selection rule data stream numerical
# words keyword:  drift decision classification learning incremental concept rule data stream
# words repeated:  ['learning', 'incremental', 'rule', 'data', 'stream']
# words title:  root polynomial positive bound
# words keyword:  root polynomial positive equation bound
# words repeated:  ['root', 'polynomial', 'positive', 'bound']
# words title:  suprema constructive
# words keyword:  set supremum constructive mathematics ordered partially
# words repeated:  ['constructive']
# words title:  uniform constructive equivalent continuity theorem
# words keyword:  uniform constructive mathematics reverse continuity
# words repeated:  ['uniform', 'constructive', 'continuity']
# words title:  spectrum computability operator
# words keyword:  computable functional analysis
# words repeated:  []
# words title:  algorithmic cellular automaton universe irreducibility
# words keyword:  cellular automaton omega probability halting
# words repeated:  ['cellular', 'automaton']
# words title:  rational analysis constructive function iterated
# words keyword:  rational analysis constructive function iteration
# words repeated:  ['rational', 'analysis', 'constructive', 'function']
# words title:  formal gelfand constructive mathematics representation topology theorem
# words keyword:  riesz formal constructive mathematics space axiom choice topology
# words repeated:  ['formal', 'constructive', 'mathematics', 'topology']
# words title:  axiomatic intuitionistic class model
# words keyword:  logic ultrapower filter kripke ultraproduct prime disjoint saturated iterated bisimulation intuitionistic union model
# words repeated:  ['intuitionistic', 'model']
# words title:  element positive banach state space firmness algebra
# words keyword:  element hermitian constructive mathematics banach positive state space algebra
# words repeated:  ['element', 'positive', 'banach', 'state', 'space', 'algebra']
# words title:  sequence random
# words keyword:  randomness set algorithmic binary theory sequence information random
# words repeated:  ['sequence', 'random']
# words title:  permutability linear lattice rule
# words keyword:  analysis proof decidability theory lattice
# words repeated:  ['lattice']
# words title:  formal quotient space coequalisers topology
# words keyword:  locale formal constructive predicativit quotient coequalisers topology
# words repeated:  ['formal', 'quotient', 'coequalisers', 'topology']
# words title:  principle set constructive theory brouwerian
# words keyword:  principle set partial constructive realizability combinatory theory brouwerian algebra
# words repeated:  ['principle', 'set', 'constructive', 'theory', 'brouwerian']
# words title:  constructing process program
# words keyword:  constructive determinism process algebra
# words repeated:  ['constructing', 'process']
# words title:  aspect markov chain constructive
# words keyword:  markov chain constructive
# words repeated:  ['markov', 'chain', 'constructive']
# words title:  regular formal relation meaning positivity space
# words keyword:  regular formal relation positivity space real topology
# words repeated:  ['regular', 'formal', 'relation', 'positivity', 'space']
# words title:  functional dependency tree counting
# words keyword:  counting
# words repeated:  ['counting']
# words title:  continuity constructively
# words keyword:  continuity constructive mathematics
# words repeated:  ['continuity', 'constructively']
# words title:  result constructive operator algebra
# words keyword:  constructive operator mathematics hilbert theory space
# words repeated:  ['constructive', 'operator']
# words title:  language lukasiewicz hausdorff measure
# words keyword:  simple attractor system function deterministic cantor hausdorff space language iterated fractal measure
# words repeated:  ['language', 'hausdorff', 'measure']
# words title:  determine principle mathematical object
# words keyword:  rational analysis constructive function iteration
# words repeated:  []
# words title:  intermediate theorem
# words keyword:  analysis
# words repeated:  []
# words title:  constructive conjecture sylvester approach
# words keyword:  geometry constructive ordered sylvester conjecture
# words repeated:  ['constructive', 'conjecture', 'sylvester']
# words title:  fine computability effective function limiting sequential space recursion
# words keyword:  weakly fine computability effective function limiting space recursion sequence
# words repeated:  ['fine', 'computability', 'effective', 'function', 'limiting', 'space', 'recursion']
# words title:  activity unit content learning modelling
# words keyword:  collaborative unit learning modelling object educational language
# words repeated:  ['unit', 'learning', 'modelling']
# words title:  web lt semantic gt technology personalization applied
# words keyword:  system multimedia web xml service hypermedia semantic
# words repeated:  ['web', 'semantic']
# words title:  experience reinforcement learning conceptual tool description
# words keyword:  learning conceptual interactive tool authoring exercise
# words repeated:  ['learning', 'conceptual', 'tool']
# words title:  computing ubiquitous classroom approach process identification
# words keyword:  aware interaction computing context ubiquitous implicit rfid
# words repeated:  ['computing', 'ubiquitous']
# words title:  programming collaborative learning computer educational tool integrating
# words keyword:  programming animation collaborative learning simulation computer teaching program
# words repeated:  ['programming', 'collaborative', 'learning', 'computer']
# words title:  evolution virtual object conceptualization ii chasqui
# words keyword:  lcm learning web ims object virtual lom tool museum service scorm authoring campus
# words repeated:  ['virtual', 'object']
# words title:  activity authoring environment learning diagnosis kadd
# words keyword:  cognitive environment learning diagnosis tool library tracing error authoring model
# words repeated:  ['authoring', 'environment', 'learning', 'diagnosis']
# words title:  asynchronous task collaborative system learning support pda
# words keyword:  collaborative computing learning domotics pda mobile
# words repeated:  ['collaborative', 'learning', 'pda']
# words title:  research project study case
# words keyword:  multimedia computer internet service education
# words repeated:  []
# words title:  collaborative learning object ontology integrating authoring
# words keyword:  metadata collaborative annotation learning object ontology
# words repeated:  ['collaborative', 'learning', 'object', 'ontology']
# words title:  analyzing diversity module
# words keyword:  virtual module package classboxes java selector ruby namespaces class
# words repeated:  ['module']
# words title:  behavioral coordinating description component
# words keyword:  coordination modular expressiveness embedding process algebra
# words repeated:  ['coordinating']
# words title:  object generation composition algebra
# words keyword:  formal composition specification object software
# words repeated:  ['object', 'composition']
# words title:  assertive autonomous composition approach dynamic component paradigm
# words keyword:  autonomous code manipulation aspect intermediate dynamic common service net language runtime architecture assertive programming oriented web composition component weaving
# words repeated:  ['assertive', 'autonomous', 'composition', 'dynamic', 'component']
# words title:  probabilistic reo circuit connector model
# words keyword:  markov decision probabilistic constraint coordination reo composition automaton bisimulation process
# words repeated:  ['probabilistic', 'reo']
# words title:  modular verification actor language
# words keyword:  system modular rebeca verification reactive actor component model
# words repeated:  ['modular', 'verification', 'actor']
# words title:  learning effect interface
# words keyword:  type interaction indicator mbti
# words repeated:  []
# words title:  metadata management situated learning model
# words keyword:  learning metadata elearning situated
# words repeated:  ['metadata', 'situated', 'learning']
# words title:  user aware context approach delivery material architecture
# words keyword:  user learning object ontology retrieval
# words repeated:  ['user']
# words title:  system training factor intercultural
# words keyword:  user management design interaction training knowledge factor pattern interface
# words repeated:  ['training', 'factor']
# words title:  system student discovering model
# words keyword:  user context learning object
# words repeated:  []
# words title:  higher adaptive model user system learning elearning education experience
# words keyword:  adaptive user learning elearning modeling cscl model
# words repeated:  ['adaptive', 'model', 'user', 'learning', 'elearning']
# words title:  social learning training knowledge game unigame concept skill university lifelong
# words keyword:  motivation collaborative learning game education constructivism
# words repeated:  ['learning', 'game']
# words title:  personalisation adaptation learning role
# words keyword:  learning teaching personalisation
# words repeated:  ['personalisation', 'learning']
# words title:  constrained algorithm graph partial scheduling distributed precedence
# words keyword:  directed task algorithm constraint graph scheduling distributed precedence
# words repeated:  ['constrained', 'algorithm', 'graph', 'scheduling', 'distributed', 'precedence']
# words title:  based environment performance system prediction rapid prototyping accurate
# words keyword:  performance system embedded prediction flow rapid scheduling prototyping data
# words repeated:  ['performance', 'system', 'prediction', 'rapid', 'prototyping']
# words title:  securing exam
# words keyword:  assessment fraud security exam supervision prevention
# words repeated:  ['exam']
# words title:  decision exchange making network learning knowledge facilitating
# words keyword:  community management system network learning practice broker
# words repeated:  ['network', 'learning']
# words title:  versus distribution knowledge km centralization managing
# words keyword:  organizational mental market community retrospective capital rationality bounded knowledge practice intellectual constructivism model
# words repeated:  ['knowledge']
# words title:  organizational community reification knowledge pizzarotti case study node
# words keyword:  community management knowledge distributed node
# words repeated:  ['community', 'knowledge', 'node']
# words title:  ontoshare community sharing system knowledge virtual practice
# words keyword:  community sharing web knowledge semantic
# words repeated:  ['community', 'sharing', 'knowledge']
# words title:  process participative project indigo introduction study case
# words keyword:  participative evolution learning indigo introduction improvement distributed inspection process
# words repeated:  ['process', 'participative', 'indigo', 'introduction']
# words title:  community practice integrated technology perspective
# words keyword:  community management content intranet extranet knowledge practice enterprise technology information personalization
# words repeated:  ['community', 'practice', 'technology']
# words title:  hierarchy chaos coproduction knowledge net expert
# words keyword:  siemens community volkswagen telekom practice deutsche case study wiko net expert
# words repeated:  ['net', 'expert']
# words title:  evolution management organic knowledge cycle liquidization perspective crystallization
# words keyword:  crystallizer community management nebula organic knowledge livingom practice liquidization perspective crystallization
# words repeated:  ['management', 'organic', 'knowledge', 'liquidization', 'perspective', 'crystallization']
# words title:  supporting based community sharing mapping creation knowledge implicit
# words keyword:  community management discovery web knowledge practice visualisation semantic
# words repeated:  ['community', 'knowledge']
# words title:  trust community etiquette social practice empathy capital
# words keyword:  trust community etiquette social norm tacit knowledge sociability explicit practice online capital
# words repeated:  ['trust', 'community', 'etiquette', 'social', 'practice', 'capital']
# words title:  determinism system
# words keyword:  computational system computing membrane completeness determinism
# words repeated:  ['determinism', 'system']
# words title:  population system
# words keyword:  computability differentiation computing membrane division cell turing bonding
# words repeated:  []
# words title:  rule system
# words keyword:  communication antiport evolution system computing membrane symport
# words repeated:  ['system']
# words title:  note system probabilistic complexity measure
# words keyword:  natural computing entropy system
# words repeated:  ['system']
# words title:  element finding system maximum
# words keyword:  system computing membrane maximum natural
# words repeated:  ['system', 'maximum']
# words title:  system
# words keyword:  universality inhibitor system promoter
# words repeated:  ['system']
# words title:  gate system fredkin simulating
# words keyword:  reversibility gate system fredkin conservative logic
# words repeated:  ['gate', 'system', 'fredkin']
# words title:  computing membrane simulator java
# words keyword:  simulation java system parallelism
# words repeated:  ['simulator', 'java']
# words title:  system family efficient item bin packing
# words keyword:  recognizer system complexity problem computing membrane bin packing clip class
# words repeated:  ['system', 'bin', 'packing']
# words title:  system separation membrane rule active
# words keyword:  natural computing membrane distributed
# words repeated:  ['membrane']
# words title:  large competitive croatian integration source knowledge advantage enterprise
# words keyword:  human competitive management integration knowledge advantage strategic resource
# words repeated:  ['competitive', 'integration', 'source', 'knowledge', 'advantage']
# words title:  audit mapping analysis integration flow knowledge systematic approach inventory
# words keyword:  audit analysis social network flow map knowledge inventory
# words repeated:  ['audit', 'analysis', 'flow', 'knowledge', 'inventory']
# words title:  task profile approach assignment individual
# words keyword:  knowledge skill elicitation description matching logic
# words repeated:  []
# words title:  communication visualization joint knowledge interactive facilitating
# words keyword:  communication visualization interaction joint knowledge evasion refusal disavowal
# words repeated:  ['communication', 'visualization', 'joint', 'knowledge', 'interactive']
# words title:  web introduction framework cbr successful km technology semantic
# words keyword:  management reasoning web knowledge semantic
# words repeated:  ['web', 'semantic']
# words title:  research management public analysis knowledge development hero case university transference process
# words keyword:  research management analysis knowledge development university process
# words repeated:  ['research', 'management', 'analysis', 'knowledge', 'development', 'university', 'process']
# words title:  transfer sustainable social analysis network method selakt knowledge localisation expert
# words keyword:  research sharing management community social analysis network collaboration knowledge strategy sustainability practice distributed implementation localisation expert applied
# words repeated:  ['social', 'analysis', 'network', 'knowledge', 'localisation', 'expert']
# words title:  investigation metadata thinking sharing
# words keyword:  metadata agreement knowledge sharing
# words repeated:  ['metadata', 'sharing']
# words title:  database formal analysis lexical modelling concept
# words keyword:  database formal relation analysis lexical concept semantic
# words repeated:  ['database', 'formal', 'analysis', 'lexical', 'concept']
# words title:  graph search partition concept breadth lattice
# words keyword:  formal analysis bipartite graph search concept breadth
# words repeated:  ['graph', 'search', 'concept', 'breadth']
# words title:  information concept exploiting potential credo lattice retrieval
# words keyword:  information web mining concept credo lattice retrieval
# words repeated:  ['information', 'concept', 'credo', 'lattice', 'retrieval']
# words title:  additive order diagram avoidance conflict
# words keyword:  diagram automatic layout lattice
# words repeated:  ['diagram']
# words title:  computing base intractability
# words keyword:  base implication computational complexity
# words repeated:  ['base']
# words title:  visual probabilistic landmark theory galois lattice
# words keyword:  mobile autonomous visual formal analysis localization landmark computer vision concept robotics galois lattice orientation
# words repeated:  ['visual', 'landmark', 'galois', 'lattice']
# words title:  interval logic model specification fbt checking tool applying
# words keyword:  interval fil graphical tableau logic temporal future method buechi specification automaton verification automatic checking gil model
# words repeated:  ['interval', 'logic', 'model', 'specification', 'checking']
# words title:  based consistency csp checking state uml class model
# words keyword:  formal mac hine method communicating sequential abstract notation uml process
# words repeated:  ['uml']
# words title:  system automated support enterprise information
# words keyword:  formal set reasoning heuristic automated specification theory otter
# words repeated:  ['automated']
# words title:  mince heuristic manipulation sat search static global bdd
# words keyword:  ordering partitioning decision formal heuristic sat search bdds backtrack cnf variable verification
# words repeated:  ['heuristic', 'sat', 'search', 'bdd']
# words title:  combinational relationship signal equivalence accelerate structural global checking
# words keyword:  equivalence formula sat boolean implication static checking propositional satisfiability combinational cec logic
# words repeated:  ['combinational', 'equivalence', 'checking']
# words title:  approximate bounded checking improving traversal model
# words keyword:  decision reachability analysis diagram bounded sat bdds binary checking satisfiability bmc model
# words repeated:  ['bounded', 'checking', 'model']
# words title:  heuristic efficient sat search support lookahead
# words keyword:  dag decision diagram heuristic bounded binary checking state satisfiability machine model
# words repeated:  ['heuristic']
# words title:  signal solver correlation guided
# words keyword:  equivalence boolean checking atpg satisfiability
# words repeated:  []
# words title:  testing program
# words keyword:  software coverage testing
# words repeated:  ['testing']
# words title:  multimedia software survey engineering
# words keyword:  multimedia framework system component
# words repeated:  ['multimedia']
# words title:  service composition interaction contract
# words keyword:  interaction computing coordination composition web architectural connector software architecture service
# words repeated:  ['service', 'composition', 'interaction']
# words title:  experience software dynamic
# words keyword:  rewriting engineering reverse migration rule data pattern
# words repeated:  []
# words title:  portlets web introduction component
# words keyword:  portlets portal web development application service
# words repeated:  ['portlets', 'web']
# words title:  developing methodology system
# words keyword:  agent system methodology engineering software intelligent
# words repeated:  ['methodology', 'system']
# words title:  construction customization process
# words keyword:  design software method process
# words repeated:  ['process']
# words title:  preference negotiation analysis requirement
# words keyword:  resolution negotiation inconsistency management analysis winwin requirement preference conflict
# words repeated:  ['preference', 'negotiation', 'analysis', 'requirement']
# words title:  development application approach add
# words keyword:  evolution modular software development processor markup approach language xml maintenance
# words repeated:  ['development', 'approach']
# words title:  library expect digital
# words keyword:  list repository search conceptual library document black white active visualization future annotation knowledge digital hyperwave link searching
# words repeated:  ['library', 'digital']
# words title:  reuse based system embedded development synthesis
# words keyword:  system design embedded object_oriented application_specific processor synthesis highlevel instruction
# words repeated:  ['system', 'embedded', 'synthesis']
# words title:  protocol analysis security approach symbolic
# words keyword:  protocol formal method noninterference bisimulation symbolic process algebra
# words repeated:  ['protocol', 'symbolic']
# words title:  predictor data telemetry fast neural network compression numeric lossless
# words keyword:  neural prediction network compression lossless
# words repeated:  ['predictor', 'neural', 'network', 'compression', 'lossless']
# words title:  hyperbolic tiling cell space combinatoric
# words keyword:  cellular hyperbolic plane automaton
# words repeated:  ['hyperbolic']
# words title:  full hash table root group search primitive prime residue
# words keyword:  table root mod full cyclic scatter primitive storage collision strategy prime residue technique group hash
# words repeated:  ['full', 'hash', 'table', 'root', 'group', 'primitive', 'prime', 'residue']
# words title:  rewriting system tissue
# words keyword:  computational system rewriting grammar tissue universality matrix
# words repeated:  ['rewriting', 'system', 'tissue']
# words title:  word control formal model
# words keyword:  operational semantics
# words repeated:  []
# words title:  decomposition boolean function equation
# words keyword:  function decomposition boolean equation
# words repeated:  ['decomposition', 'boolean', 'function', 'equation']
# words title:  retrieval grid point ram geometric model
# words keyword:  indexing system grid file structure data spatial model
# words repeated:  ['grid', 'model']
# words title:  maintenance based temporal past incremental warehouse operator data logic
# words keyword:  database temporal warehouse relational algebra data logic
# words repeated:  ['temporal', 'warehouse', 'data', 'logic']
# words title:  system integration source flexibility automatic level xml semantic
# words keyword:  interschema integration source xml information property
# words repeated:  ['integration', 'source', 'xml']
# words title:  coroutines lua
# words keyword:  control coroutines lua generator structure language
# words repeated:  ['coroutines', 'lua']
# words title:  interconnection model relational component
# words keyword:  coordination coalgebra relation model
# words repeated:  ['model', 'relational']
# words title:  rewriting modular semantics cml
# words keyword:  programming rewriting semantics modularity ml concurrent language logic
# words repeated:  ['rewriting', 'modular', 'semantics']
# words title:  recovery system implementing aspectj coordinated distributed error
# words keyword:  programming handling separation exception concern coordinated distributed action atomic
# words repeated:  ['coordinated', 'distributed']
# words title:  partial theorem categorical
# words keyword:  programming substitution combinators explicit functional categorical
# words repeated:  ['categorical']
# words title:  luainterface lua clr net scripting
# words keyword:  language reflection scripting interoperability
# words repeated:  ['scripting']
# words title:  invocation remote method tactic
# words keyword:  middleware programming tactic distributed language definition
# words repeated:  ['tactic']
# words title:  programming total functional
# words keyword:  programming functional
# words repeated:  ['programming', 'functional']
# words title:  programming environment support redwood snippet
# words keyword:  programming visual environment design software development redwood tool snippet
# words repeated:  ['programming', 'environment', 'redwood', 'snippet']
# words title:  environment metaprogramming metaj java extensible
# words keyword:  programming transformation framework refactoring tool java generative program
# words repeated:  ['metaprogramming', 'java']
# words title:  control synchronization system modularity reactive improve
# words keyword:  system design modular reactive action concurrency
# words repeated:  ['system', 'modularity', 'reactive']
# words title:  poset graph transformation architectural abstraction labelled
# words keyword:  graph refinement abstraction architecture
# words repeated:  ['graph', 'architectural', 'abstraction']
# words title:  environment metamodeling
# words keyword:  driven computing graph transformation architecture model
# words repeated:  []
# words title:  comparison verification parametric case tool study
# words keyword:  protocol timed verification parametric
# words repeated:  ['verification', 'parametric']
# words title:  analysis transformation platform modeling model
# words keyword:  graph transformation computation verification software development model
# words repeated:  ['transformation', 'model']
# words title:  proof environment
# words keyword:  refinement proving theorem
# words repeated:  []
# words title:  system incrementally design object checking
# words keyword:  model temporal system design modelling object verification checking logic
# words repeated:  ['system', 'design', 'object', 'checking']
# words title:  derivation formally support interactive tool functional correct program
# words keyword:  programming ultra reasoning constructive equational transformation specification development heapsort functional program
# words repeated:  ['functional', 'program']
# words title:  compilation optimized temporal logic
# words keyword:  temporal simulation verification logic
# words repeated:  ['temporal', 'logic']
# words title:  profisafe protocol verification case study uml statecharts
# words keyword:  reliability verification
# words repeated:  ['verification']
# words title:  system specification verification tool
# words keyword:  formal capture constraint diagram requirement specification verification
# words repeated:  ['specification', 'verification']
# words title:  ensure correctness implementation compiler program checking
# words keyword:  generation program code checking generator architecture correctness implementation compiler certificate
# words repeated:  ['correctness', 'implementation', 'compiler', 'program', 'checking']
# words title:  code fortran optimization verification alias
# words keyword:  aliasing dummy optimization verification alias
# words repeated:  ['optimization', 'verification', 'alias']
# words title:  validation translation methodology voc optimizingcompilers
# words keyword:  sgi validation translation voc optimizing optimization condition verification global rule pro permutation compiler
# words repeated:  ['validation', 'translation', 'voc']
# words title:  visual sharing archiving language bibliography information
# words keyword:  communication independent visual sign map archiving interactive language constructed information retrieval
# words repeated:  ['visual', 'archiving', 'language', 'information']
# words title:  repository multimedia effort foundation miracle language information
# words keyword:  constructed communication independent visual multimedia converging archiving language technology information retrieval
# words repeated:  ['multimedia', 'language', 'information']
# words title:  future pc society implication
# words keyword:  future societal computer implication pc technology display wearable
# words repeated:  ['future', 'pc', 'implication']
# words title:  visual working dynamic application miracle information
# words keyword:  communication visual multimedia movie map archiving dynamic interactive language information abstract retrieval
# words repeated:  ['visual', 'dynamic', 'information']
# words title:  regular fibonacci hyperbolic type rectangular plane tiling coding
# words keyword:  hyperbolic cellular plane automaton tiltings
# words repeated:  ['hyperbolic', 'plane', 'tiling']
# words title:  cyclical csc handling system interaction source converter structure data structured
# words keyword:  system cooperative interschema integration source information property
# words repeated:  ['system', 'interaction', 'source']
# words title:  archive heterogeneous unified audiovisual access
# words keyword:  user archive profile engine search query semantic thesaurus mpeg audiovisual faethon personalization
# words repeated:  ['archive', 'audiovisual']
# words title:  discovery aggregation knowledge compound automatic representation
# words keyword:  corpus management relation entity knowledge mining map text topic extraction named semantic
# words repeated:  ['knowledge']
# words title:  interdisciplinary creation diversity richness knowledge overview
# words keyword:  management complexity structuration knowledge practice cognitivism distributed theory communites heterogeneity evolutionary semantic constructivism
# words repeated:  ['knowledge']
# words title:  management training knowledge converging work make scenario
# words keyword:  management training knowledge scenario
# words repeated:  ['management', 'training', 'knowledge', 'scenario']
# words title:  strategy filter formulation process
# words keyword:  signal filter strategy weak process
# words repeated:  ['strategy', 'filter', 'process']
# words title:  computational management knowledge solving problem
# words keyword:  research collaborative management algorithmic flow knowledge measurement opencps architecture
# words repeated:  ['management', 'knowledge']
# words title:  metal industry knowledge operation managing
# words keyword:  metal industry management system knowledge kaon ontology
# words repeated:  ['metal', 'industry', 'knowledge']
# words title:  structuring knowledge
# words keyword:  carrier context search map navigator topic structure bearer key browsing process domain word visualization based engine knowledge assistant modeling management business tool base
# words repeated:  ['knowledge']
# words title:  manager benefit management award knowledge result german
# words keyword:  benefit management knowledge measurement balanced scorecard
# words repeated:  ['benefit', 'management', 'knowledge']
# words title:  knowledge management
# words keyword:  workplace knowledge optimization factor km worker ashen demand
# words repeated:  ['knowledge']
# words title:  grid knowledge optimisation work semantic design putting
# words keyword:  planning production jess knowledge engineering rule ontology xml base workflow
# words repeated:  ['knowledge']
# words title:  capital organisation system scbs social building network profiting benchmarking
# words keyword:  capital capability management social resource knowledge intellectual cluster benchmarking
# words repeated:  ['capital', 'social', 'benchmarking']
# words title:  domain ontology identification
# words keyword:  management pruning computing knowledge structural ontology
# words repeated:  ['ontology']
# words title:  ipd management project pilot skill development competence integrated personnel base putzmeister
# words keyword:  management system project pilot knowledge skill development competence personnel
# words repeated:  ['management', 'project', 'pilot', 'skill', 'development', 'competence', 'personnel']
# words title:  human individual customer knowledge bridge capital
# words keyword:  customer integration knowledge explicit intuition collective individual process capital
# words repeated:  ['individual', 'customer', 'knowledge', 'capital']
# words title:  formal skill match description approach semantic
# words keyword:  management matchmaking knowledge skill representation ontology
# words repeated:  ['skill']
# words title:  illustrative learning requirement measurement methodological organisational kit tool
# words keyword:  repertory learning measurement role organisational theory personal construct test
# words repeated:  ['learning', 'measurement', 'organisational']
# words title:  management practical skill development approach personal
# ...
# words repeated:  ['lua', 'concurrent']
# words title:  aspect reentrancy controlling
# words keyword:  programming reentrancy aspect language pointcut
# words repeated:  ['aspect', 'reentrancy']
# words title:  extensible lightweight aspectj implementation
# words keyword:  programming spectj implementation extensible
# words repeated:  ['extensible', 'aspectj', 'implementation']
# words title:  type interaction aspectj raw advice
# words keyword:  programming type system semantics operational
# words repeated:  ['type']
# words title:  denotational semantics disentangling definition
# words keyword:  denotational programming semantics modularity language definition
# words repeated:  ['denotational', 'semantics', 'definition']
# words title:  formal semantics action language uml
# words keyword:  formal semantics unified action modeling language
# words repeated:  ['formal', 'semantics', 'action', 'language']
# words title:  algebraic feature law model
# words keyword:  law product line refactoring software algebraic feature model
# words repeated:  ['algebraic', 'feature', 'law', 'model']
# words title:  adaptive system design learning educational hypermedia
# words keyword:  adaptive system design learning ims ld rule tool hypermedia authoring
# words repeated:  ['adaptive', 'system', 'design', 'learning', 'hypermedia']
# words title:  ideal constructive notion maximality
# words keyword:  maximal constructive ideal
# words repeated:  ['ideal', 'constructive', 'maximality']
# words title:  iqm3 management maturity information quality model
# words keyword:  management maturity data information quality model
# words repeated:  ['management', 'maturity', 'information', 'quality', 'model']
# words title:  logic bck attempt algebra unitarily treat part
# words keyword:  bck divisible hilbert imtl hertz mv nm residuated bl algebra wajsberg heyting pocrim lattice
# words repeated:  ['bck', 'algebra']
# words title:  switch fault diagnosis online functional detection
# words keyword:  switch testing fault diagnosis online functional model
# words repeated:  ['switch', 'fault', 'diagnosis', 'online', 'functional']
# words title:  investment software determining lag
# words keyword:  investment software development lag
# words repeated:  ['investment', 'software', 'lag']
# words title:  environment clinical ontology adapting
# words keyword:  formal clinical knowledge representation ontology
# words repeated:  ['clinical', 'ontology']
# words title:  business defining behavior process model
# words keyword:  bpmn problem business standard process
# words repeated:  ['business', 'process']
# words title:  optimization query limitation dynamic dependency access
# words keyword:  optimization query limitation functional dependency inclusion access
# words repeated:  ['optimization', 'query', 'limitation', 'dependency', 'access']
# words title:  infinitary modal logic
# words keyword:  logic infinitary substitution uniform canonical modal model
# words repeated:  ['infinitary', 'modal', 'logic']
# words title:  nonblocking concurrency reasoning
# words keyword:  linearisability atomicity relation algorithm nonblocking simulation verification shared memory concurrency reduction
# words repeated:  ['nonblocking', 'concurrency']
# words title:  database full expressiveness propositional practitioner weak functional dependency
# words keyword:  database propositional axiomatisation relational weak functional dependency logic
# words repeated:  ['database', 'propositional', 'weak', 'functional', 'dependency']
# words title:  state machine processing abstract model transaction
# words keyword:  database control recovery transaction state machine processing concurrency abstract
# words repeated:  ['state', 'machine', 'processing', 'abstract', 'transaction']
# words title:  database based design update storage minimization global time space
# words keyword:  database universal relation design form dependency normal
# words repeated:  ['database', 'design']
# words title:  formal pvs verification data semistructured model
# words keyword:  pvs automated verification modeling data semistructured
# words repeated:  ['pvs', 'verification', 'data', 'semistructured']
# words title:  formal aggregation framework model
# words keyword:  frame cube aggregation operator specification olap function
# words repeated:  ['aggregation']
# words title:  complex ideal characterisation coincidence
# words keyword:  complex ideal
# words repeated:  ['complex', 'ideal']
# words title:  design warehouse dynamic state data machine abstract
# words keyword:  refinement analytical warehouse state data machine processing abstract
# words repeated:  ['warehouse', 'state', 'data', 'machine', 'abstract']
# words title:  superdistribution digital good
# words keyword:  superdistribution copyright good computing content protection trusted digital
# words repeated:  ['superdistribution', 'digital', 'good']
# words title:  design multimedia secure authentication
# words keyword:  principle authentication set design watermarking
# words repeated:  ['design', 'authentication']
# words title:  adversarial multimedia heterogeneous network attack stability
# words keyword:  communication adversarial multimedia network attack theory queueing stability
# words repeated:  ['adversarial', 'multimedia', 'network', 'attack', 'stability']
# words title:  impact attack threat topology change
# words keyword:  sharing change attack peersim file application topology
# words repeated:  ['attack', 'topology', 'change']
# words title:  traffic based method attack distributed detection statistical test
# words keyword:  computing security network protection monitoring statistical
# words repeated:  ['statistical']
# words title:  business web adoption urgent newspaper danish model
# words keyword:  model social business web medium
# words repeated:  ['business', 'web', 'model']
# words title:  sharing social source providing platform multi recommendation tag resource
# words keyword:  recommender metadata collaborative management classification sharing web knowledge tagging digital resource
# words repeated:  ['sharing', 'source', 'resource']
# words title:  group script life collaborative sharing classification interaction learning knowledge virtual
# words keyword:  life sharing collaboration knowledge virtual muve online world
# words repeated:  ['life', 'collaborative', 'sharing', 'knowledge', 'virtual']
# words title:  list arm embedded project modelling source linux behaviour mailing case open
# words keyword:  community collaborative system social embedded network project source virtual work information open
# words repeated:  ['embedded', 'project', 'source', 'open']
# words title:  supporting composition structural aspect aop kernel
# words keyword:  programming composition aspect structural aop reflex kernel
# words repeated:  ['composition', 'structural', 'aspect', 'aop', 'kernel']
# words title:  sql coverage testing query structural criterion
# words keyword:  database testing coverage sql criterion adequacy test
# words repeated:  ['sql', 'coverage', 'testing', 'criterion']
# words title:  fair negotiation protocol contract secure signing
# words keyword:  protocol exchange contract signing intellectual secure confidentiality property
# words repeated:  ['protocol', 'contract', 'secure', 'signing']
# words title:  based control role rbac dynamic session access
# words keyword:  access
# words repeated:  ['access']
# words title:  root quadratic complexity polynomial positive linear bound
# words keyword:  root isolation vincent positive real upper bound theorem
# words repeated:  ['root', 'positive', 'bound']
# words title:  cryptosystems advance homomorphic
# words keyword:  probability encryption homomorphic cryptosystems
# words repeated:  ['cryptosystems', 'homomorphic']
# words title:  based estimation algorithm unit magnetic measurement compass dcm orientation inertial
# words keyword:  estimation orientation representation euler quaternion dcm
# words repeated:  ['estimation', 'dcm', 'orientation']
# words title:  complexity comparative analysis integration methodology ontology study
# words keyword:  importance similarity integration concept ontology conflict
# words repeated:  ['integration', 'ontology']
# words title:  efficient preprocessing support clustering data vector procedure
# words keyword:  neighbor noise support shared clustering nearest elimination vector
# words repeated:  ['support', 'clustering', 'vector']
# words title:  algorithm optimization
# words keyword:  generation estimation distribution algorithm pareto evolution offspring scheme optimization differential
# words repeated:  ['algorithm', 'optimization']
# words title:  hybrid discovery search multifaceted pattern integrative sequence
# words keyword:  computational mining mode concern multifaceted pattern sequence definition model
# words repeated:  ['multifaceted', 'pattern', 'sequence']
# words title:  hybrid shop algorithm flow immune makespan criterion
# words keyword:  hybrid shop gate rotation algorithm quantum flow scheduling immune
# words repeated:  ['hybrid', 'shop', 'algorithm', 'flow', 'immune']
# words title:  road differently exposed sign guidance image recognition approach robust
# words keyword:  graph sign hdr recognition theory detection
# words repeated:  ['sign', 'recognition']
# words title:  lexical context web fingerprinting
# words keyword:  minutia wordnet golden discovery web mining knowledge ontology semantic
# words repeated:  ['web']
# words title:  regulatory algorithm genetic network optimization inference gene bayesian
# words keyword:  algorithm genetic network gene bayesian
# words repeated:  ['algorithm', 'genetic', 'network', 'gene', 'bayesian']
# words title:  multilayer pruning particle optimization swarm ensemble
# words keyword:  classifier pruning particle optimization swarm ensemble model
# words repeated:  ['pruning', 'particle', 'optimization', 'swarm', 'ensemble']
# words title:  system framework sdlmas modeling scenario
# words keyword:  system interaction language scenario
# words repeated:  ['system', 'scenario']
# words title:  url user psychological method browsing personalized characteristic
# words keyword:  user engine search browsing personalization
# words repeated:  ['user', 'browsing']
# words title:  migration framework agent analysis
# words keyword:  propagation performance system agent evaluation mobile
# words repeated:  ['agent']
# words title:  control purpose security general mechanism infrastructure access
# words keyword:  control rfid document computing security technology electronic mechanism infrastructure access pervasive
# words repeated:  ['control', 'security', 'mechanism', 'infrastructure', 'access']
# words title:  protocol agent cryptographic network sensor platform support wireless
# words keyword:  protocol agent network sensor smartcard wireless cryptography
# words repeated:  ['protocol', 'agent', 'cryptographic', 'network', 'sensor', 'wireless']
# words title:  environment analysis chess computing security cipher suitable pervasive
# words keyword:  chess cipher attack operation cryptanalysis block permutation differential
# words repeated:  ['chess', 'cipher']
# words title:  protecting multimedia content network heterogeneous tv wireless mobile
# words keyword:  mobile fingerprint scrambling management drm user multimedia distribution tv gprs video digital secure matching identification
# words repeated:  ['multimedia', 'tv', 'mobile']
# words title:  security core framework ubiquitous study technology
# words keyword:  control privacy security framework surveillance intelligent access
# words repeated:  ['security', 'framework']
# words title:  authentication analysis vein vascular palm pattern pervasive
# words keyword:  authentication signature multimodal vascular thinning pattern biometric
# words repeated:  ['authentication', 'vascular', 'pattern']
# words title:  highly cooperation enforcement ad hoc network dynamic mobile
# words keyword:  ad selfishness hoc network mobile
# words repeated:  ['ad', 'hoc', 'network', 'mobile']
# words title:  vehicle based neural system classification network security smart road pervasive
# words keyword:  vehicle transform neural classification network image recognition wavelet normalization processing
# words repeated:  ['vehicle', 'neural', 'classification', 'network']
# words title:  computable elementary topology
# words keyword:  topology computable computability analysis
# words repeated:  ['computable', 'topology']
# words title:  conversion computability preserving
# words keyword:  domain analysis computable sliding function theory block
# words repeated:  []
# words title:  hyperbolic solution system symmetric computing operator pde
# words keyword:  metric hyperbolic computability system approximation norm scheme pencil space matrix pde stability difference
# words repeated:  ['hyperbolic', 'system', 'pde']
# words title:  effective theorem
# words keyword:  analysis computable topological space
# words repeated:  []
# words title:  blowup topological problem complexity
# words keyword:  type blowup theory equation differential
# words repeated:  ['blowup']
# words title:  result representing measurement
# words keyword:  admissible distribution analysis computable device computation measurement representation normal physical
# words repeated:  ['representing', 'measurement']
# words title:  unit square function integral
# words keyword:  operator function integral fubini theorem
# words repeated:  ['function', 'integral']
# words title:  metric urysohn universal constructive space
# words keyword:  metric urysohn universal constructive mathematics space
# words repeated:  ['metric', 'urysohn', 'universal', 'constructive', 'space']
# words title:  metric chainable circularly set computable space
# words keyword:  metric continuum chainable recursive set circularly computable covering effective space property
# words repeated:  ['metric', 'chainable', 'circularly', 'set', 'computable', 'space']
# words title:  np oracle structure question relativizations
# words keyword:  bs oracle halting machine relativizations problem
# words repeated:  ['oracle', 'relativizations']
# words title:  computability solution thousand ten effective monkey approach differential inclusion
# words keyword:  analysis computable condition semicomputability lipschitz equation ordinary differential inclusion
# words repeated:  ['computability', 'differential', 'inclusion']
# words title:  base schauder existence effective
# words keyword:  analysis basis computatable schauder functional
# words repeated:  ['schauder']
# words title:  european perspective innovation quality
# words keyword:  territory vision innovation quality stakeholder
# words repeated:  ['innovation', 'quality']
# words title:  based system design web educational approach
# words keyword:  design web educational development
# words repeated:  ['design', 'web', 'educational']
# words title:  learning object pool application scenario
# words keyword:  repository collaborative learning object
# words repeated:  ['learning', 'object']
# words title:  tutor bot evaluator
# words keyword:  tutoring system alice chatterbots bdi aiml claroline moodle intelligent
# words repeated:  []
# words title:  environment people virtual educational special digital eduquito inclusion
# words keyword:  environment person virtual disability accessibility
# words repeated:  ['environment', 'virtual']
# words title:  management learning web style development application
# words keyword:  application learning style
# words repeated:  ['learning', 'style', 'application']
# words title:  spiral timeline support semantic
# words keyword:  visualization spiral timeline moodle
# words repeated:  ['spiral', 'timeline']
# words title:  syntax language processing visualization tree
# words keyword:  visualization tree educational software syntax
# words repeated:  ['syntax', 'visualization', 'tree']
# words title:  environment coala learning computer distributed assisted program
# words keyword:  programming system learning tutoring intelligent
# words repeated:  ['learning']

# %% [markdown]
# ## Removing Repeated Word

# %%
# def removeWordFromString(titleArr, keywordArr, interceptArr):
    
#     auxArr = titleArr.copy()
#     titleArrClean = []
#     for item1, item2 in zip(auxArr, interceptArr):
        
#         item1 = item1.split()

#         for wordRep in item2:
#             idx = item1.index(wordRep)
#             deleted_word = item1.pop(idx)
        
#         r = ' '.join(item1)
#         titleArrClean.append(r)

#     return titleArrClean
        
#     # return result_string

# %%
# titleArrClean = removeWordFromString(rakeTitle,rakeKeyword,similarityList)

# %%
# len(titleArrClean)
# Out:
# 1102

# %%
# for i in range(len(titleArrClean)):
#     print("words title: ",titleArrClean[i], "\nwords keyword: ", rakeKeyword[i], "\nwords repeated: ", similarityList[i])
# Out:
# words title:  integration
# words keyword:  generation community cooperative knowledge wiki structure process
# words repeated:  ['community', 'structure']
# words title:  outcome synchronously interaction small determining factor online acceptance group
# words keyword:  cooperative learning workplace training assurance study empirical professional quality
# words repeated:  ['learning', 'workplace']
# words title:  sharing knowledge
# words keyword:  information system agent learning weblog pedagogical space wiki arrangement
# words repeated:  ['information', 'weblogs', 'learning', 'space']
# words title:  oriented implementing space architecture
# words keyword:  filtering collaborative management business method introduction modelling knowledge ontology information process retrieval
# words repeated:  ['management', 'method', 'modelling', 'knowledge', 'information', 'process']
# words title:  transfer map evaluation application tube
# words keyword:  communication visualization visual storytelling management metaphor project knowledge information
# words repeated:  ['visualization', 'project', 'knowledge']
# words title:  system reconciling approach
# words keyword:  knowledge management workflow
# words repeated:  ['management', 'knowledge', 'workflow']
# words title:  human toolkit technological design methodology factor integrate km organisational
# words keyword:  networked collaborative management business network knowledge
# words repeated:  ['network']
# words title:  analysing capturing kmdl improving
# words keyword:  management business knowledge modeling description language process
# words repeated:  ['business', 'process']
# words title:  solution role
# words keyword:  research market management business knowledge software tool enterprise process
# words repeated:  ['management', 'business', 'knowledge', 'enterprise', 'process']
# words title:  design
# words keyword:  activity management business stance instrument knowledge theory modeling work infrastructure process
# words repeated:  ['knowledge', 'modeling', 'work', 'infrastructure']
# words title:  hierarchy infrastructure process model
# words keyword:  management system knowledge data base information
# words repeated:  ['knowledge']
# words title:  based oriented approach
# words keyword:  service management knowledge process
# words repeated:  ['management', 'knowledge', 'service', 'process']
# words title:  queue algorithm construction
# words keyword:  refinement prover formal atomicity proof concurrency
# words repeated:  ['formal', 'concurrent']
# words title:  investigating
# words keyword:  observability refinement formal atomicity method development
# words repeated:  ['atomicity', 'observability']
# words title:  relaxing case mechanism verifying correctness
# words keyword:  communication atomicity verification relaxation algebra process asynchronous
# words repeated:  ['communication', 'atomicity', 'asynchronous']
# words title:  business modelling bpel precise application
# words keyword:  formal ing semantics compensation specification method transaction language
# words repeated:  ['compensating', 'transaction']
# words title:  understanding advantage
# words keyword:  system replication broadcast quorum atomic isolation
# words repeated:  ['system', 'replication', 'broadcast', 'quorum', 'atomic']
# words title:  manifesto atomic
# words keyword:  programming formal atomicity hardware method dependability transaction language
# words repeated:  []
# words title:
# words keyword:  atomicity software development transaction monitor ocl uml concurrency
# words repeated:  ['software', 'development', 'atomicity']
# words title:  system provision
# words keyword:  atomicity coherence transactional cache memory
# words repeated:  ['atomicity']
# words title:  visual vikamine
# words keyword:  visualization analysis subgroup mining data
# words repeated:  ['subgroup', 'mining']
# words title:  recommendation
# words keyword:  visualizing reputation social network flow information
# words repeated:  ['visualizing', 'social', 'network', 'flow']
# words title:  orthogonal visualization
# words keyword:  visual grand curve tour analysis method clustering andrew data exploratory
# words repeated:  ['data', 'curve']
# words title:  system operating ubiquitous integrating gui
# words keyword:  data visualization mining icon
# words repeated:  ['mining', 'data']
# words title:  decision rule interactive
# words keyword:  exploration visual segment mining connecting data
# words repeated:  ['exploration', 'visual', 'segment', 'mining', 'connecting', 'data']
# words title:  visualization uncertain manipulation dependency
# words keyword:  decision incompletely diagram mining minimization function
# words repeated:  ['decision', 'diagram', 'incomplete']
# words title:  highly gravi structured explore
# words keyword:  domain visualization temporal medical interactive data information
# words repeated:  ['visualization', 'temporal', 'interactive', 'data', 'information']
# words title:  large scalable set
# words keyword:  exploration visualization visual technique data multiresolution
# words repeated:  ['exploration', 'visual', 'data', 'multiresolution']
# words title:  physically locating intruder
# words keyword:  intrusion system wireless antenna detection
# words repeated:  ['wireless']
# words title:  reference level model
# words keyword:  public key security evaluation policy fuzzy technique infrastructure
# words repeated:  ['security', 'evaluation', 'policy', 'fuzzy', 'technique']
# words title:  robustness reduced increasing distortion
# words keyword:  audio lsb steganography coding data hiding
# words repeated:  ['audio', 'lsb', 'steganography', 'coding']
# words title:  embedded protomon monitor prevention
# words keyword:  protocol intrusion cryptographic security computer detection abuse
# words repeated:  ['protocol', 'intrusion', 'cryptographic', 'detection']
# words title:  sliding window
# words keyword:  ad routing hoc protocol performance communication network dsr secure group
# words repeated:  ['communication', 'protocol', 'network', 'secure', 'group']
# words title:  efficient secure hardware
# words keyword:  algorithm genetic computation cryptography evolutionary
# words repeated:  ['cryptographic']
# words title:  signature encryption verifiable recoverable
# words keyword:  certified fair protocol exchange security delivery
# words repeated:  ['certified', 'delivery']
# words title:  exploration combination source assurance space lazy open
# words keyword:  system agent information quality
# words repeated:  ['system', 'information', 'quality']
# words title:  disk tool
# words keyword:  consistency system backup operating digital file snapshot forensics checkpointing
# words repeated:  ['digital', 'forensics', 'checkpointing', 'consistent']
# words title:  secured transfer network scheme computer
# words keyword:  management algorithm key security pad secrecy protection theory data information perfect
# words repeated:  ['data']
# words title:  gossip analysis construction code erasure fingerprinting pirate tracing
# words keyword:  system multimedia digital coding theory library information
# words repeated:  []
# words title:  profile creation problem
# words keyword:  database market manager game strategy distributed theory information resource
# words repeated:  ['game', 'distributed', 'information', 'databasesas']
# words title:  method application
# words keyword:  control ded system event dynamic synthesis discrete
# words repeated:  ['control', 'ded', 'synthesis']
# words title:  implication structural development tendency
# words keyword:  life complex adaptable system cycle software architecture
# words repeated:  ['complex', 'system', 'software']
# words title:  based user bookmark extraction interest semantic
# words keyword:  collaborative web browsing ontology work
# words repeated:  ['collaborative', 'web', 'browsing']
# words title:  internal relation structure problem
# words keyword:  cognitive communication grounding agent formula satisfaction language modal logic
# words repeated:  ['cognitive', 'grounding', 'agent', 'language']
# words title:  hybrid method query searching rankfeed
# words keyword:  rosa adaptive system web mining recommendation information personalization retrieval
# words repeated:  ['recommendation']
# words title:  level processing semantic
# words keyword:  consensus method knowledge conflict inconsistent
# words repeated:  ['inconsistency', 'knowledge']
# words title:  web
# words keyword:  hybrid consensus user system adaptation method interface
# words repeated:  ['hybrid', 'user', 'system', 'adaptation', 'interface']
# words title:  approximate computational model efficient provably retrieval
# words keyword:  database high dimensionality query structure spatiotemporal modeling range data
# words repeated:  ['spatiotemporal']
# words title:  cost
# words keyword:  parallel constraint execution computation time actor implementation
# words repeated:  ['time', 'computation', 'actor']
# words title:  performance scalable control analysis design scheme evaluation
# words keyword:  communication protocol rtcp management multimedia scalability distributed
# words repeated:  ['protocol']
# words title:
# words keyword:  generation testing algorithm genetic flow software automatic data test
# words repeated:  ['generation', 'testing', 'algorithm', 'genetic', 'flow', 'automatic', 'data', 'test']
# words title:  estimation theoretical upper bound
# words keyword:  routing algorithm circuit cad global integrated
# words repeated:  ['routing']
# words title:  document html
# words keyword:  authoring xanalogical system multimedia transclusions application structure hypermedia publishing
# words repeated:  ['multimedia', 'transclusions']
# words title:  complexity
# words keyword:  interconnection fat cube communication network router collective architecture topology
# words repeated:  ['communication', 'cube', 'fat', 'collective', 'topology']
# words title:  class test automation framework testaf
# words keyword:  testing formal automated specification software
# words repeated:  ['testing', 'formal', 'specification']
# words title:  based cryptosystem efficient variant secure provably
# words keyword:  privacy system verifiable paillier huffles
# words repeated:  ['verifiable', 'paillier', 'shuffle']
# words title:  virtual exploiting marketplace
# words keyword:  b2c agent ontology technology intelligent
# words repeated:  ['b2c', 'agent', 'ontology']
# words title:  domain algorithm extenders finite
# words keyword:  tree uowhf binary function hash
# words repeated:  ['tree', 'uowhf', 'binary']
# words title:  compositional rebeca automated
# words keyword:  system modular verification reactive abstraction checking actor technique model
# words repeated:  ['verification', 'abstraction', 'checking', 'model']
# words title:  fast algorithm
# words keyword:  entropy complexity computable parsing measure
# words repeated:  []
# words title:  simple polygon bounded inside draw
# words keyword:  free computational tree geometry skeleton graph straight annealing simulated drawing
# words repeated:  ['free', 'tree']
# words title:  constructive definition approach
# words keyword:  programming semantics modularity structural action operational language
# words repeated:  ['language']
# words title:  design match perfect
# words keyword:  programming generation hardware circuit structure description functional arithmetic language logic
# words repeated:  ['programming', 'functional', 'hardware']
# words title:  lua implementation
# words keyword:  coroutines closure virtual machine ables compiler hash
# words repeated:  []
# words title:  aspectlua approach
# words keyword:  mop lua reflection aspect dynamic aop
# words repeated:  ['dynamic', 'aop']
# words title:  finalizers formal
# words keyword:  collection management garbage semantics finalization memory
# words repeated:  ['semantics']
# words title:  building interface pew
# words keyword:  programming formal web semantics service language
# words repeated:  ['web', 'language', 'service']
# words title:  compiling platform
# words keyword:  programming net functional virtual haskell interoperability language machine compiler
# words repeated:  ['net', 'functional', 'language']
# words title:  script lua clr translation running
# words keyword:  bytecodes virtual runtime common language machine compiler
# words repeated:  ['bytecode']
# words title:  evaluation experimental jit java technology
# words keyword:  optimization dynamic compilation compiler
# words repeated:  []
# words title:  signal
# words keyword:  dataflow computation comonads function law stream distributive
# words repeated:  ['comonads']
# words title:  language scheme
# words keyword:  formal analysis semantics equational specification executable program
# words repeated:  ['equational', 'specification']
# words title:  purely
# words keyword:  programming computation haskell functional language mobile
# words repeated:  ['computation', 'mhaskell', 'functional', 'language', 'mobile']
# words title:  learning dynamic
# words keyword:  drift decision tree incremental concept data stream
# words repeated:  ['tree', 'decision', 'data', 'stream']
# words title:
# words keyword:  computing mining clustering data stream
# words repeated:  ['data', 'mining', 'stream']
# words title:  categorization alert id attack mining extraction stream scenario
# words keyword:  resolution intrusion security network detection logic
# words repeated:  ['network']
# words title:  request preprocessing stream
# words keyword:  analysis web mining browsing pattern usage semantic
# words repeated:  ['web', 'mining', 'semantic', 'usage']
# words title:  evaluating requirement condition
# words keyword:  prediction trigger qos streaming time series service quality model
# words repeated:  ['trigger', 'streaming', 'time', 'series', 'quality']
# words title:  item online dynamic continuous
# words keyword:  algorithm mining data stream change
# words repeated:  ['mining', 'data', 'stream', 'change']
# words title:  border selection numerical
# words keyword:  drift decision classification learning incremental concept rule data stream
# words repeated:  ['learning', 'incremental', 'rule', 'data', 'stream']
# words title:
# words keyword:  root polynomial positive equation bound
# words repeated:  ['root', 'polynomial', 'positive', 'bound']
# words title:  suprema
# words keyword:  set supremum constructive mathematics ordered partially
# words repeated:  ['constructive']
# words title:  equivalent theorem
# words keyword:  uniform constructive mathematics reverse continuity
# words repeated:  ['uniform', 'constructive', 'continuity']
# words title:  spectrum computability operator
# words keyword:  computable functional analysis
# words repeated:  []
# words title:  algorithmic universe irreducibility
# words keyword:  cellular automaton omega probability halting
# words repeated:  ['cellular', 'automaton']
# words title:  iterated
# words keyword:  rational analysis constructive function iteration
# words repeated:  ['rational', 'analysis', 'constructive', 'function']
# words title:  gelfand representation theorem
# words keyword:  riesz formal constructive mathematics space axiom choice topology
# words repeated:  ['formal', 'constructive', 'mathematics', 'topology']
# words title:  axiomatic class
# words keyword:  logic ultrapower filter kripke ultraproduct prime disjoint saturated iterated bisimulation intuitionistic union model
# words repeated:  ['intuitionistic', 'model']
# words title:  firmness
# words keyword:  element hermitian constructive mathematics banach positive state space algebra
# words repeated:  ['element', 'positive', 'banach', 'state', 'space', 'algebra']
# words title:
# words keyword:  randomness set algorithmic binary theory sequence information random
# words repeated:  ['sequence', 'random']
# words title:  permutability linear rule
# words keyword:  analysis proof decidability theory lattice
# words repeated:  ['lattice']
# words title:  space
# words keyword:  locale formal constructive predicativit quotient coequalisers topology
# words repeated:  ['formal', 'quotient', 'coequalisers', 'topology']
# words title:
# words keyword:  principle set partial constructive realizability combinatory theory brouwerian algebra
# words repeated:  ['principle', 'set', 'constructive', 'theory', 'brouwerian']
# words title:  program
# words keyword:  constructive determinism process algebra
# words repeated:  ['constructing', 'process']
# words title:  aspect
# words keyword:  markov chain constructive
# words repeated:  ['markov', 'chain', 'constructive']
# words title:  meaning
# words keyword:  regular formal relation positivity space real topology
# words repeated:  ['regular', 'formal', 'relation', 'positivity', 'space']
# words title:  functional dependency tree
# words keyword:  counting
# words repeated:  ['counting']
# words title:
# words keyword:  continuity constructive mathematics
# words repeated:  ['continuity', 'constructively']
# words title:  result algebra
# words keyword:  constructive operator mathematics hilbert theory space
# words repeated:  ['constructive', 'operator']
# words title:  lukasiewicz
# words keyword:  simple attractor system function deterministic cantor hausdorff space language iterated fractal measure
# words repeated:  ['language', 'hausdorff', 'measure']
# words title:  determine principle mathematical object
# words keyword:  rational analysis constructive function iteration
# words repeated:  []
# words title:  intermediate theorem
# words keyword:  analysis
# words repeated:  []
# words title:  approach
# words keyword:  geometry constructive ordered sylvester conjecture
# words repeated:  ['constructive', 'conjecture', 'sylvester']
# words title:  sequential
# words keyword:  weakly fine computability effective function limiting space recursion sequence
# words repeated:  ['fine', 'computability', 'effective', 'function', 'limiting', 'space', 'recursion']
# words title:  activity content
# words keyword:  collaborative unit learning modelling object educational language
# words repeated:  ['unit', 'learning', 'modelling']
# words title:  lt gt technology personalization applied
# words keyword:  system multimedia web xml service hypermedia semantic
# words repeated:  ['web', 'semantic']
# words title:  experience reinforcement description
# words keyword:  learning conceptual interactive tool authoring exercise
# words repeated:  ['learning', 'conceptual', 'tool']
# words title:  classroom approach process identification
# words keyword:  aware interaction computing context ubiquitous implicit rfid
# words repeated:  ['computing', 'ubiquitous']
# words title:  educational tool integrating
# words keyword:  programming animation collaborative learning simulation computer teaching program
# words repeated:  ['programming', 'collaborative', 'learning', 'computer']
# words title:  evolution conceptualization ii chasqui
# words keyword:  lcm learning web ims object virtual lom tool museum service scorm authoring campus
# words repeated:  ['virtual', 'object']
# words title:  activity kadd
# words keyword:  cognitive environment learning diagnosis tool library tracing error authoring model
# words repeated:  ['authoring', 'environment', 'learning', 'diagnosis']
# words title:  asynchronous task system support
# words keyword:  collaborative computing learning domotics pda mobile
# words repeated:  ['collaborative', 'learning', 'pda']
# words title:  research project study case
# words keyword:  multimedia computer internet service education
# words repeated:  []
# words title:  integrating authoring
# words keyword:  metadata collaborative annotation learning object ontology
# words repeated:  ['collaborative', 'learning', 'object', 'ontology']
# words title:  analyzing diversity
# words keyword:  virtual module package classboxes java selector ruby namespaces class
# words repeated:  ['module']
# words title:  behavioral description component
# words keyword:  coordination modular expressiveness embedding process algebra
# words repeated:  ['coordinating']
# words title:  generation algebra
# words keyword:  formal composition specification object software
# words repeated:  ['object', 'composition']
# words title:  approach paradigm
# words keyword:  autonomous code manipulation aspect intermediate dynamic common service net language runtime architecture assertive programming oriented web composition component weaving
# words repeated:  ['assertive', 'autonomous', 'composition', 'dynamic', 'component']
# words title:  circuit connector model
# words keyword:  markov decision probabilistic constraint coordination reo composition automaton bisimulation process
# words repeated:  ['probabilistic', 'reo']
# words title:  language
# words keyword:  system modular rebeca verification reactive actor component model
# words repeated:  ['modular', 'verification', 'actor']
# words title:  learning effect interface
# words keyword:  type interaction indicator mbti
# words repeated:  []
# words title:  management model
# words keyword:  learning metadata elearning situated
# words repeated:  ['metadata', 'situated', 'learning']
# words title:  aware context approach delivery material architecture
# words keyword:  user learning object ontology retrieval
# words repeated:  ['user']
# words title:  system intercultural
# words keyword:  user management design interaction training knowledge factor pattern interface
# words repeated:  ['training', 'factor']
# words title:  system student discovering model
# words keyword:  user context learning object
# words repeated:  []
# words title:  higher system education experience
# words keyword:  adaptive user learning elearning modeling cscl model
# words repeated:  ['adaptive', 'model', 'user', 'learning', 'elearning']
# words title:  social training knowledge unigame concept skill university lifelong
# words keyword:  motivation collaborative learning game education constructivism
# words repeated:  ['learning', 'game']
# words title:  adaptation role
# words keyword:  learning teaching personalisation
# words repeated:  ['personalisation', 'learning']
# words title:  partial
# words keyword:  directed task algorithm constraint graph scheduling distributed precedence
# words repeated:  ['constrained', 'algorithm', 'graph', 'scheduling', 'distributed', 'precedence']
# words title:  based environment accurate
# words keyword:  performance system embedded prediction flow rapid scheduling prototyping data
# words repeated:  ['performance', 'system', 'prediction', 'rapid', 'prototyping']
# words title:  securing
# words keyword:  assessment fraud security exam supervision prevention
# words repeated:  ['exam']
# words title:  decision exchange making knowledge facilitating
# words keyword:  community management system network learning practice broker
# words repeated:  ['network', 'learning']
# words title:  versus distribution km centralization managing
# words keyword:  organizational mental market community retrospective capital rationality bounded knowledge practice intellectual constructivism model
# words repeated:  ['knowledge']
# words title:  organizational reification pizzarotti case study
# words keyword:  community management knowledge distributed node
# words repeated:  ['community', 'knowledge', 'node']
# words title:  ontoshare system virtual practice
# words keyword:  community sharing web knowledge semantic
# words repeated:  ['community', 'sharing', 'knowledge']
# words title:  project study case
# words keyword:  participative evolution learning indigo introduction improvement distributed inspection process
# words repeated:  ['process', 'participative', 'indigo', 'introduction']
# words title:  integrated perspective
# words keyword:  community management content intranet extranet knowledge practice enterprise technology information personalization
# words repeated:  ['community', 'practice', 'technology']
# words title:  hierarchy chaos coproduction knowledge
# words keyword:  siemens community volkswagen telekom practice deutsche case study wiko net expert
# words repeated:  ['net', 'expert']
# words title:  evolution cycle
# words keyword:  crystallizer community management nebula organic knowledge livingom practice liquidization perspective crystallization
# words repeated:  ['management', 'organic', 'knowledge', 'liquidization', 'perspective', 'crystallization']
# words title:  supporting based sharing mapping creation implicit
# words keyword:  community management discovery web knowledge practice visualisation semantic
# words repeated:  ['community', 'knowledge']
# words title:  empathy
# words keyword:  trust community etiquette social norm tacit knowledge sociability explicit practice online capital
# words repeated:  ['trust', 'community', 'etiquette', 'social', 'practice', 'capital']
# words title:
# words keyword:  computational system computing membrane completeness determinism
# words repeated:  ['determinism', 'system']
# words title:  population system
# words keyword:  computability differentiation computing membrane division cell turing bonding
# words repeated:  []
# words title:  rule
# words keyword:  communication antiport evolution system computing membrane symport
# words repeated:  ['system']
# words title:  note probabilistic complexity measure
# words keyword:  natural computing entropy system
# words repeated:  ['system']
# words title:  element finding
# words keyword:  system computing membrane maximum natural
# words repeated:  ['system', 'maximum']
# words title:
# words keyword:  universality inhibitor system promoter
# words repeated:  ['system']
# words title:  simulating
# words keyword:  reversibility gate system fredkin conservative logic
# words repeated:  ['gate', 'system', 'fredkin']
# words title:  computing membrane
# words keyword:  simulation java system parallelism
# words repeated:  ['simulator', 'java']
# words title:  family efficient item
# words keyword:  recognizer system complexity problem computing membrane bin packing clip class
# words repeated:  ['system', 'bin', 'packing']
# words title:  system separation rule active
# words keyword:  natural computing membrane distributed
# words repeated:  ['membrane']
# words title:  large croatian enterprise
# words keyword:  human competitive management integration knowledge advantage strategic resource
# words repeated:  ['competitive', 'integration', 'source', 'knowledge', 'advantage']
# words title:  mapping integration systematic approach
# words keyword:  audit analysis social network flow map knowledge inventory
# words repeated:  ['audit', 'analysis', 'flow', 'knowledge', 'inventory']
# words title:  task profile approach assignment individual
# words keyword:  knowledge skill elicitation description matching logic
# words repeated:  []
# words title:  facilitating
# words keyword:  communication visualization interaction joint knowledge evasion refusal disavowal
# words repeated:  ['communication', 'visualization', 'joint', 'knowledge', 'interactive']
# words title:  introduction framework cbr successful km technology
# words keyword:  management reasoning web knowledge semantic
# words repeated:  ['web', 'semantic']
# words title:  public hero case transference
# words keyword:  research management analysis knowledge development university process
# words repeated:  ['research', 'management', 'analysis', 'knowledge', 'development', 'university', 'process']
# words title:  transfer sustainable method selakt
# words keyword:  research sharing management community social analysis network collaboration knowledge strategy sustainability practice distributed implementation localisation expert applied
# words repeated:  ['social', 'analysis', 'network', 'knowledge', 'localisation', 'expert']
# words title:  investigation thinking
# words keyword:  metadata agreement knowledge sharing
# words repeated:  ['metadata', 'sharing']
# words title:  modelling
# words keyword:  database formal relation analysis lexical concept semantic
# words repeated:  ['database', 'formal', 'analysis', 'lexical', 'concept']
# words title:  partition lattice
# words keyword:  formal analysis bipartite graph search concept breadth
# words repeated:  ['graph', 'search', 'concept', 'breadth']
# words title:  exploiting potential
# words keyword:  information web mining concept credo lattice retrieval
# words repeated:  ['information', 'concept', 'credo', 'lattice', 'retrieval']
# words title:  additive order avoidance conflict
# words keyword:  diagram automatic layout lattice
# words repeated:  ['diagram']
# words title:  computing intractability
# words keyword:  base implication computational complexity
# words repeated:  ['base']
# words title:  probabilistic theory
# words keyword:  mobile autonomous visual formal analysis localization landmark computer vision concept robotics galois lattice orientation
# words repeated:  ['visual', 'landmark', 'galois', 'lattice']
# words title:  fbt tool applying
# words keyword:  interval fil graphical tableau logic temporal future method buechi specification automaton verification automatic checking gil model
# words repeated:  ['interval', 'logic', 'model', 'specification', 'checking']
# words title:  based consistency csp checking state class model
# words keyword:  formal mac hine method communicating sequential abstract notation uml process
# words repeated:  ['uml']
# words title:  system support enterprise information
# words keyword:  formal set reasoning heuristic automated specification theory otter
# words repeated:  ['automated']
# words title:  mince manipulation static global
# words keyword:  ordering partitioning decision formal heuristic sat search bdds backtrack cnf variable verification
# words repeated:  ['heuristic', 'sat', 'search', 'bdd']
# words title:  relationship signal accelerate structural global
# words keyword:  equivalence formula sat boolean implication static checking propositional satisfiability combinational cec logic
# words repeated:  ['combinational', 'equivalence', 'checking']
# words title:  approximate improving traversal
# words keyword:  decision reachability analysis diagram bounded sat bdds binary checking satisfiability bmc model
# words repeated:  ['bounded', 'checking', 'model']
# words title:  efficient sat search support lookahead
# words keyword:  dag decision diagram heuristic bounded binary checking state satisfiability machine model
# words repeated:  ['heuristic']
# words title:  signal solver correlation guided
# words keyword:  equivalence boolean checking atpg satisfiability
# words repeated:  []
# words title:  program
# words keyword:  software coverage testing
# words repeated:  ['testing']
# words title:  software survey engineering
# words keyword:  multimedia framework system component
# words repeated:  ['multimedia']
# words title:  contract
# words keyword:  interaction computing coordination composition web architectural connector software architecture service
# words repeated:  ['service', 'composition', 'interaction']
# words title:  experience software dynamic
# words keyword:  rewriting engineering reverse migration rule data pattern
# words repeated:  []
# words title:  introduction component
# words keyword:  portlets portal web development application service
# words repeated:  ['portlets', 'web']
# words title:  developing
# words keyword:  agent system methodology engineering software intelligent
# words repeated:  ['methodology', 'system']
# words title:  construction customization
# words keyword:  design software method process
# words repeated:  ['process']
# words title:
# words keyword:  resolution negotiation inconsistency management analysis winwin requirement preference conflict
# words repeated:  ['preference', 'negotiation', 'analysis', 'requirement']
# words title:  application add
# words keyword:  evolution modular software development processor markup approach language xml maintenance
# words repeated:  ['development', 'approach']
# words title:  expect
# words keyword:  list repository search conceptual library document black white active visualization future annotation knowledge digital hyperwave link searching
# words repeated:  ['library', 'digital']
# words title:  reuse based development
# words keyword:  system design embedded object_oriented application_specific processor synthesis highlevel instruction
# words repeated:  ['system', 'embedded', 'synthesis']
# words title:  analysis security approach
# words keyword:  protocol formal method noninterference bisimulation symbolic process algebra
# words repeated:  ['protocol', 'symbolic']
# words title:  data telemetry fast numeric
# words keyword:  neural prediction network compression lossless
# words repeated:  ['predictor', 'neural', 'network', 'compression', 'lossless']
# words title:  tiling cell space combinatoric
# words keyword:  cellular hyperbolic plane automaton
# words repeated:  ['hyperbolic']
# words title:  search
# words keyword:  table root mod full cyclic scatter primitive storage collision strategy prime residue technique group hash
# words repeated:  ['full', 'hash', 'table', 'root', 'group', 'primitive', 'prime', 'residue']
# words title:
# words keyword:  computational system rewriting grammar tissue universality matrix
# words repeated:  ['rewriting', 'system', 'tissue']
# words title:  word control formal model
# words keyword:  operational semantics
# words repeated:  []
# words title:
# words keyword:  function decomposition boolean equation
# words repeated:  ['decomposition', 'boolean', 'function', 'equation']
# words title:  retrieval point ram geometric
# words keyword:  indexing system grid file structure data spatial model
# words repeated:  ['grid', 'model']
# words title:  maintenance based past incremental operator
# words keyword:  database temporal warehouse relational algebra data logic
# words repeated:  ['temporal', 'warehouse', 'data', 'logic']
# words title:  system flexibility automatic level semantic
# words keyword:  interschema integration source xml information property
# words repeated:  ['integration', 'source', 'xml']
# words title:
# words keyword:  control coroutines lua generator structure language
# words repeated:  ['coroutines', 'lua']
# words title:  interconnection component
# words keyword:  coordination coalgebra relation model
# words repeated:  ['model', 'relational']
# words title:  cml
# words keyword:  programming rewriting semantics modularity ml concurrent language logic
# words repeated:  ['rewriting', 'modular', 'semantics']
# words title:  recovery system implementing aspectj error
# words keyword:  programming handling separation exception concern coordinated distributed action atomic
# words repeated:  ['coordinated', 'distributed']
# words title:  partial theorem
# words keyword:  programming substitution combinators explicit functional categorical
# words repeated:  ['categorical']
# words title:  luainterface lua clr net
# words keyword:  language reflection scripting interoperability
# words repeated:  ['scripting']
# words title:  invocation remote method
# words keyword:  middleware programming tactic distributed language definition
# words repeated:  ['tactic']
# words title:  total
# words keyword:  programming functional
# words repeated:  ['programming', 'functional']
# words title:  support
# words keyword:  programming visual environment design software development redwood tool snippet
# words repeated:  ['programming', 'environment', 'redwood', 'snippet']
# words title:  environment metaj extensible
# words keyword:  programming transformation framework refactoring tool java generative program
# words repeated:  ['metaprogramming', 'java']
# words title:  control synchronization improve
# words keyword:  system design modular reactive action concurrency
# words repeated:  ['system', 'modularity', 'reactive']
# words title:  poset transformation labelled
# words keyword:  graph refinement abstraction architecture
# words repeated:  ['graph', 'architectural', 'abstraction']
# words title:  environment metamodeling
# words keyword:  driven computing graph transformation architecture model
# words repeated:  []
# words title:  comparison case tool study
# words keyword:  protocol timed verification parametric
# words repeated:  ['verification', 'parametric']
# words title:  analysis platform modeling
# words keyword:  graph transformation computation verification software development model
# words repeated:  ['transformation', 'model']
# words title:  proof environment
# words keyword:  refinement proving theorem
# words repeated:  []
# words title:  incrementally
# words keyword:  model temporal system design modelling object verification checking logic
# words repeated:  ['system', 'design', 'object', 'checking']
# words title:  derivation formally support interactive tool correct
# words keyword:  programming ultra reasoning constructive equational transformation specification development heapsort functional program
# words repeated:  ['functional', 'program']
# words title:  compilation optimized
# words keyword:  temporal simulation verification logic
# words repeated:  ['temporal', 'logic']
# words title:  profisafe protocol case study uml statecharts
# words keyword:  reliability verification
# words repeated:  ['verification']
# words title:  system tool
# words keyword:  formal capture constraint diagram requirement specification verification
# words repeated:  ['specification', 'verification']
# words title:  ensure
# words keyword:  generation program code checking generator architecture correctness implementation compiler certificate
# words repeated:  ['correctness', 'implementation', 'compiler', 'program', 'checking']
# words title:  code fortran
# words keyword:  aliasing dummy optimization verification alias
# words repeated:  ['optimization', 'verification', 'alias']
# words title:  methodology optimizingcompilers
# words keyword:  sgi validation translation voc optimizing optimization condition verification global rule pro permutation compiler
# words repeated:  ['validation', 'translation', 'voc']
# words title:  sharing bibliography
# words keyword:  communication independent visual sign map archiving interactive language constructed information retrieval
# words repeated:  ['visual', 'archiving', 'language', 'information']
# words title:  repository effort foundation miracle
# words keyword:  constructed communication independent visual multimedia converging archiving language technology information retrieval
# words repeated:  ['multimedia', 'language', 'information']
# words title:  society
# words keyword:  future societal computer implication pc technology display wearable
# words repeated:  ['future', 'pc', 'implication']
# words title:  working application miracle
# words keyword:  communication visual multimedia movie map archiving dynamic interactive language information abstract retrieval
# words repeated:  ['visual', 'dynamic', 'information']
# words title:  regular fibonacci type rectangular coding
# words keyword:  hyperbolic cellular plane automaton tiltings
# words repeated:  ['hyperbolic', 'plane', 'tiling']
# words title:  cyclical csc handling converter structure data structured
# words keyword:  system cooperative interschema integration source information property
# words repeated:  ['system', 'interaction', 'source']
# words title:  heterogeneous unified access
# words keyword:  user archive profile engine search query semantic thesaurus mpeg audiovisual faethon personalization
# words repeated:  ['archive', 'audiovisual']
# words title:  discovery aggregation compound automatic representation
# words keyword:  corpus management relation entity knowledge mining map text topic extraction named semantic
# words repeated:  ['knowledge']
# words title:  interdisciplinary creation diversity richness overview
# words keyword:  management complexity structuration knowledge practice cognitivism distributed theory communites heterogeneity evolutionary semantic constructivism
# words repeated:  ['knowledge']
# words title:  converging work make
# words keyword:  management training knowledge scenario
# words repeated:  ['management', 'training', 'knowledge', 'scenario']
# words title:  formulation
# words keyword:  signal filter strategy weak process
# words repeated:  ['strategy', 'filter', 'process']
# words title:  computational solving problem
# words keyword:  research collaborative management algorithmic flow knowledge measurement opencps architecture
# words repeated:  ['management', 'knowledge']
# words title:  operation managing
# words keyword:  metal industry management system knowledge kaon ontology
# words repeated:  ['metal', 'industry', 'knowledge']
# words title:  structuring
# words keyword:  carrier context search map navigator topic structure bearer key browsing process domain word visualization based engine knowledge assistant modeling management business tool base
# words repeated:  ['knowledge']
# words title:  manager award result german
# words keyword:  benefit management knowledge measurement balanced scorecard
# words repeated:  ['benefit', 'management', 'knowledge']
# words title:  management
# words keyword:  workplace knowledge optimization factor km worker ashen demand
# words repeated:  ['knowledge']
# words title:  grid optimisation work semantic design putting
# words keyword:  planning production jess knowledge engineering rule ontology xml base workflow
# words repeated:  ['knowledge']
# words title:  organisation system scbs building network profiting
# words keyword:  capital capability management social resource knowledge intellectual cluster benchmarking
# words repeated:  ['capital', 'social', 'benchmarking']
# words title:  domain identification
# words keyword:  management pruning computing knowledge structural ontology
# words repeated:  ['ontology']
# words title:  ipd integrated base putzmeister
# words keyword:  management system project pilot knowledge skill development competence personnel
# words repeated:  ['management', 'project', 'pilot', 'skill', 'development', 'competence', 'personnel']
# words title:  human bridge
# words keyword:  customer integration knowledge explicit intuition collective individual process capital
# words repeated:  ['individual', 'customer', 'knowledge', 'capital']
# words title:  formal match description approach semantic
# words keyword:  management matchmaking knowledge skill representation ontology
# words repeated:  ['skill']
# words title:  illustrative requirement methodological kit tool
# words keyword:  repertory learning measurement role organisational theory personal construct test
# words repeated:  ['learning', 'measurement', 'organisational']
# words title:  practical development approach personal
# words keyword:  database human management planning updating project skill resource
# words repeated:  ['management', 'skill']
# words title:  prerequisite competence structure applying
# words keyword:  management elearning skill hypermedia personalised
# words repeated:  ['management', 'elearning', 'skill']
# words title:  domain consideration methodological dynamic identifying work employee
# words keyword:  human repertory management competency grid knowledge skill development theory space approach case study technique resource
# words repeated:  ['competency', 'case', 'study']
# words title:  concept integrative individual transparency
# words keyword:  profiling based transfer management knowledge skill view competence resource
# words repeated:  ['transfer', 'management', 'competency', 'competence']
# words title:
# words keyword:  environment assessment learning knowledge skill solving structure simulated problem
# words repeated:  ['environment', 'assessment', 'learning', 'skill', 'solving', 'simulated', 'problem']
# words title:  problematic european consequence bad member union
# words keyword:  portugal management training skill export education
# words repeated:  ['management']
# words title:  peripheral sharing system exact
# words keyword:  management groupware knowledge expertise awareness
# words repeated:  ['knowledge', 'expertise', 'awareness']
# words title:  information system
# words keyword:  organisation management knowledge competence ontology organisational memory group
# words repeated:  ['management', 'competency', 'organisational', 'memory', 'group']
# words title:  combined constraint specification time series
# words keyword:  logic temporal system execution rapid prototyping checking monitoring model
# words repeated:  ['temporal', 'monitoring', 'logic']
# words title:  interpreter model
# words keyword:  formal graph computing transformation specification grammar modeling architecture language
# words repeated:  ['formal', 'graph', 'transformation', 'specification']
# words title:  rosetta defining
# words keyword:  coalgebra formal system design algebraic semantics specification behavior level denotational language
# words repeated:  ['formal', 'semantics', 'specification', 'language', 'coalgebraic']
# words title:  detect flow method vulnerability information
# words keyword:  admissible protocol denial service bisimulation interference
# words repeated:  ['denial', 'service']
# words title:  automatically generated
# words keyword:  formal translator csp specification grammar uml model
# words repeated:  ['csp', 'specification']
# words title:  implementation haskell
# words keyword:  hardware embedded description language
# words repeated:  ['hardware', 'embedded', 'description', 'language']
# words title:  calculus
# words keyword:  semantics software coalgebra component
# words repeated:  ['software', 'component']
# words title:
# words keyword:  formal semantics specification action
# words repeated:  ['semantics', 'specification', 'action']
# words title:  adaptive j2me developing aspectj
# words keyword:  programming separation software concern aop application architecture adaptability
# words repeated:  ['application']
# words title:  programming computation object concurrent typed language
# words keyword:  computing distributed mobile resource
# words repeated:  ['distributed', 'mobile', 'resource']
# words title:  code predicated
# words keyword:  constant propagation
# words repeated:  ['constant', 'propagation']
# words title:  luats reactive
# words keyword:  programming system distributed space tuple
# words repeated:  ['space', 'tuple']
# words title:  lazy cyclic
# words keyword:  reference collection management counting garbage cycle memory
# words repeated:  ['reference', 'counting']
# words title:  aspect weaving strategy
# words keyword:  programming
# words repeated:  []
# words title:  oriented constraint logical object language model
# words keyword:  xmi xmlshema ocl xml uml
# words repeated:  ['xml', 'xocl']
# words title:  java
# words keyword:  programming method distributed invocation remote asynchronous
# words repeated:  ['method', 'invocation', 'remote', 'asynchronous']
# words title:  practical implementation haskell
# words keyword:  programming polymorphic type inference recursion language
# words repeated:  ['polymorphic', 'type', 'inference', 'recursion']
# words title:
# words keyword:  dependent type dml pattern matching
# words repeated:  ['typed', 'pattern', 'dependently', 'matching']
# words title:  simple efficient made haskell
# words keyword:  programming parallelism petri fuctional net language
# words repeated:  ['programming', 'parallel']
# words title:  structural match perfect
# words keyword:  management reasoning web knowledge ontology xml semantic
# words repeated:  ['management', 'reasoning', 'knowledge']
# words title:  soft factor effect strong
# words keyword:  leadership management corporate knowledge culture
# words repeated:  ['management', 'knowledge']
# words title:  organizing
# words keyword:  management knowledge software ontology maintenance
# words repeated:  ['knowledge', 'software', 'maintenance']
# words title:  pleaser library
# words keyword:  repository reuse management building knowledge block schema base experience
# words repeated:  ['building', 'block', 'schema', 'base', 'experience']
# words title:  examplets
# words keyword:  reuse reasoning casebased software retrieval
# words repeated:  ['software', 'reuse']
# words title:  management effective start
# words keyword:  check project integration business knowledge strategy measurement km diagnostics
# words repeated:  ['business', 'integration', 'knowledge', 'strategy']
# words title:  adaptive system design defining characteristic
# words keyword:  dimension user academic discourse cultural learning evaluation style software adaptivity modeling structure
# ...
# words title:  proposal petri net
# words keyword:  ei user ui interaction informer agent system evaluation software electronic interactive architecture interface
# words repeated:  ['system', 'informer', 'evaluation', 'electronic', 'interactive']
# words title:  system model
# words keyword:  proposal groupware interaction methodological development taxonomy
# words repeated:  ['groupware', 'development', 'interactive', 'taxonomy', 'integrating']
# words title:  input task perception precision manipulation modelling consequence application speed spatial
# words keyword:  user reality interaction virtual interface
# words repeated:  []
# words title:  diamodl case integrating
# words keyword:  domain user design framework eclipse dialog modeling interface
# words repeated:  ['domain', 'framework', 'eclipse', 'dialog', 'modeling']
# words title:  system sharp mathematical online solving applied problem
# words keyword:  adaptive environment interaction heuristic learning strategy thought hypermedia
# words repeated:  ['adaptive', 'hypermedia']
# words title:  align user approach interface
# words keyword:  design business engineering modeling process
# words repeated:  ['business', 'process']
# words title:  graphical ascii presentation program
# words keyword:  haskell editing parsing
# words repeated:  ['parsing']
# words title:  program
# words keyword:  programming computational monad effect shortcut fusion functional
# words repeated:  ['fusion', 'monadic', 'shortcut']
# words title:  resolution supporting parser generator
# words keyword:  removal table lalr methodology compression automatic parsing conflict
# words repeated:  ['lalr', 'conflict']
# words title:  based performance high computer processor
# words keyword:  isomorphism subgraph scheduling instruction
# words repeated:  ['isomorphism', 'subgraph', 'scheduling', 'instruction']
# words title:  cycle eliminating
# words keyword:  reference table collection garbage weak
# words repeated:  ['table', 'weak']
# words title:  programming exploring
# words keyword:  lua multithreading luaproc message passing concurrency preemptive
# words repeated:  ['lua', 'concurrent']
# words title:  controlling
# words keyword:  programming reentrancy aspect language pointcut
# words repeated:  ['aspect', 'reentrancy']
# words title:  lightweight
# words keyword:  programming spectj implementation extensible
# words repeated:  ['extensible', 'aspectj', 'implementation']
# words title:  interaction aspectj raw advice
# words keyword:  programming type system semantics operational
# words repeated:  ['type']
# words title:  disentangling
# words keyword:  denotational programming semantics modularity language definition
# words repeated:  ['denotational', 'semantics', 'definition']
# words title:  uml
# words keyword:  formal semantics unified action modeling language
# words repeated:  ['formal', 'semantics', 'action', 'language']
# words title:
# words keyword:  law product line refactoring software algebraic feature model
# words repeated:  ['algebraic', 'feature', 'law', 'model']
# words title:  educational
# words keyword:  adaptive system design learning ims ld rule tool hypermedia authoring
# words repeated:  ['adaptive', 'system', 'design', 'learning', 'hypermedia']
# words title:  notion
# words keyword:  maximal constructive ideal
# words repeated:  ['ideal', 'constructive', 'maximality']
# words title:  iqm3
# words keyword:  management maturity data information quality model
# words repeated:  ['management', 'maturity', 'information', 'quality', 'model']
# words title:  logic attempt unitarily treat part
# words keyword:  bck divisible hilbert imtl hertz mv nm residuated bl algebra wajsberg heyting pocrim lattice
# words repeated:  ['bck', 'algebra']
# words title:  detection
# words keyword:  switch testing fault diagnosis online functional model
# words repeated:  ['switch', 'fault', 'diagnosis', 'online', 'functional']
# words title:  determining
# words keyword:  investment software development lag
# words repeated:  ['investment', 'software', 'lag']
# words title:  environment adapting
# words keyword:  formal clinical knowledge representation ontology
# words repeated:  ['clinical', 'ontology']
# words title:  defining behavior model
# words keyword:  bpmn problem business standard process
# words repeated:  ['business', 'process']
# words title:  dynamic
# words keyword:  optimization query limitation functional dependency inclusion access
# words repeated:  ['optimization', 'query', 'limitation', 'dependency', 'access']
# words title:
# words keyword:  logic infinitary substitution uniform canonical modal model
# words repeated:  ['infinitary', 'modal', 'logic']
# words title:  reasoning
# words keyword:  linearisability atomicity relation algorithm nonblocking simulation verification shared memory concurrency reduction
# words repeated:  ['nonblocking', 'concurrency']
# words title:  full expressiveness practitioner
# words keyword:  database propositional axiomatisation relational weak functional dependency logic
# words repeated:  ['database', 'propositional', 'weak', 'functional', 'dependency']
# words title:  model
# words keyword:  database control recovery transaction state machine processing concurrency abstract
# words repeated:  ['state', 'machine', 'processing', 'abstract', 'transaction']
# words title:  based update storage minimization global time space
# words keyword:  database universal relation design form dependency normal
# words repeated:  ['database', 'design']
# words title:  formal model
# words keyword:  pvs automated verification modeling data semistructured
# words repeated:  ['pvs', 'verification', 'data', 'semistructured']
# words title:  formal framework model
# words keyword:  frame cube aggregation operator specification olap function
# words repeated:  ['aggregation']
# words title:  characterisation coincidence
# words keyword:  complex ideal
# words repeated:  ['complex', 'ideal']
# words title:  design dynamic
# words keyword:  refinement analytical warehouse state data machine processing abstract
# words repeated:  ['warehouse', 'state', 'data', 'machine', 'abstract']
# words title:
# words keyword:  superdistribution copyright good computing content protection trusted digital
# words repeated:  ['superdistribution', 'digital', 'good']
# words title:  multimedia secure
# words keyword:  principle authentication set design watermarking
# words repeated:  ['design', 'authentication']
# words title:  heterogeneous
# words keyword:  communication adversarial multimedia network attack theory queueing stability
# words repeated:  ['adversarial', 'multimedia', 'network', 'attack', 'stability']
# words title:  impact threat
# words keyword:  sharing change attack peersim file application topology
# words repeated:  ['attack', 'topology', 'change']
# words title:  traffic based method attack distributed detection test
# words keyword:  computing security network protection monitoring statistical
# words repeated:  ['statistical']
# words title:  adoption urgent newspaper danish
# words keyword:  model social business web medium
# words repeated:  ['business', 'web', 'model']
# words title:  social providing platform multi recommendation tag
# words keyword:  recommender metadata collaborative management classification sharing web knowledge tagging digital resource
# words repeated:  ['sharing', 'source', 'resource']
# words title:  group script classification interaction learning
# words keyword:  life sharing collaboration knowledge virtual muve online world
# words repeated:  ['life', 'collaborative', 'sharing', 'knowledge', 'virtual']
# words title:  list arm modelling linux behaviour mailing case
# words keyword:  community collaborative system social embedded network project source virtual work information open
# words repeated:  ['embedded', 'project', 'source', 'open']
# words title:  supporting
# words keyword:  programming composition aspect structural aop reflex kernel
# words repeated:  ['composition', 'structural', 'aspect', 'aop', 'kernel']
# words title:  query structural
# words keyword:  database testing coverage sql criterion adequacy test
# words repeated:  ['sql', 'coverage', 'testing', 'criterion']
# words title:  fair negotiation
# words keyword:  protocol exchange contract signing intellectual secure confidentiality property
# words repeated:  ['protocol', 'contract', 'secure', 'signing']
# words title:  based control role rbac dynamic session
# words keyword:  access
# words repeated:  ['access']
# words title:  quadratic complexity polynomial linear
# words keyword:  root isolation vincent positive real upper bound theorem
# words repeated:  ['root', 'positive', 'bound']
# words title:  advance
# words keyword:  probability encryption homomorphic cryptosystems
# words repeated:  ['cryptosystems', 'homomorphic']
# words title:  based algorithm unit magnetic measurement compass inertial
# words keyword:  estimation orientation representation euler quaternion dcm
# words repeated:  ['estimation', 'dcm', 'orientation']
# words title:  complexity comparative analysis methodology study
# words keyword:  importance similarity integration concept ontology conflict
# words repeated:  ['integration', 'ontology']
# words title:  efficient preprocessing data procedure
# words keyword:  neighbor noise support shared clustering nearest elimination vector
# words repeated:  ['support', 'clustering', 'vector']
# words title:
# words keyword:  generation estimation distribution algorithm pareto evolution offspring scheme optimization differential
# words repeated:  ['algorithm', 'optimization']
# words title:  hybrid discovery search integrative
# words keyword:  computational mining mode concern multifaceted pattern sequence definition model
# words repeated:  ['multifaceted', 'pattern', 'sequence']
# words title:  makespan criterion
# words keyword:  hybrid shop gate rotation algorithm quantum flow scheduling immune
# words repeated:  ['hybrid', 'shop', 'algorithm', 'flow', 'immune']
# words title:  road differently exposed guidance image approach robust
# words keyword:  graph sign hdr recognition theory detection
# words repeated:  ['sign', 'recognition']
# words title:  lexical context fingerprinting
# words keyword:  minutia wordnet golden discovery web mining knowledge ontology semantic
# words repeated:  ['web']
# words title:  regulatory optimization inference
# words keyword:  algorithm genetic network gene bayesian
# words repeated:  ['algorithm', 'genetic', 'network', 'gene', 'bayesian']
# words title:  multilayer
# words keyword:  classifier pruning particle optimization swarm ensemble model
# words repeated:  ['pruning', 'particle', 'optimization', 'swarm', 'ensemble']
# words title:  framework sdlmas modeling
# words keyword:  system interaction language scenario
# words repeated:  ['system', 'scenario']
# words title:  url psychological method personalized characteristic
# words keyword:  user engine search browsing personalization
# words repeated:  ['user', 'browsing']
# words title:  migration framework analysis
# words keyword:  propagation performance system agent evaluation mobile
# words repeated:  ['agent']
# words title:  purpose general
# words keyword:  control rfid document computing security technology electronic mechanism infrastructure access pervasive
# words repeated:  ['control', 'security', 'mechanism', 'infrastructure', 'access']
# words title:  platform support
# words keyword:  protocol agent network sensor smartcard wireless cryptography
# words repeated:  ['protocol', 'agent', 'cryptographic', 'network', 'sensor', 'wireless']
# words title:  environment analysis computing security suitable pervasive
# words keyword:  chess cipher attack operation cryptanalysis block permutation differential
# words repeated:  ['chess', 'cipher']
# words title:  protecting content network heterogeneous wireless
# words keyword:  mobile fingerprint scrambling management drm user multimedia distribution tv gprs video digital secure matching identification
# words repeated:  ['multimedia', 'tv', 'mobile']
# words title:  core ubiquitous study technology
# words keyword:  control privacy security framework surveillance intelligent access
# words repeated:  ['security', 'framework']
# words title:  analysis vein palm pervasive
# words keyword:  authentication signature multimodal vascular thinning pattern biometric
# words repeated:  ['authentication', 'vascular', 'pattern']
# words title:  highly cooperation enforcement dynamic
# words keyword:  ad selfishness hoc network mobile
# words repeated:  ['ad', 'hoc', 'network', 'mobile']
# words title:  based system security smart road pervasive
# words keyword:  vehicle transform neural classification network image recognition wavelet normalization processing
# words repeated:  ['vehicle', 'neural', 'classification', 'network']
# words title:  elementary
# words keyword:  topology computable computability analysis
# words repeated:  ['computable', 'topology']
# words title:  conversion computability preserving
# words keyword:  domain analysis computable sliding function theory block
# words repeated:  []
# words title:  solution symmetric computing operator
# words keyword:  metric hyperbolic computability system approximation norm scheme pencil space matrix pde stability difference
# words repeated:  ['hyperbolic', 'system', 'pde']
# words title:  effective theorem
# words keyword:  analysis computable topological space
# words repeated:  []
# words title:  topological problem complexity
# words keyword:  type blowup theory equation differential
# words repeated:  ['blowup']
# words title:  result
# words keyword:  admissible distribution analysis computable device computation measurement representation normal physical
# words repeated:  ['representing', 'measurement']
# words title:  unit square
# words keyword:  operator function integral fubini theorem
# words repeated:  ['function', 'integral']
# words title:
# words keyword:  metric urysohn universal constructive mathematics space
# words repeated:  ['metric', 'urysohn', 'universal', 'constructive', 'space']
# words title:
# words keyword:  metric continuum chainable recursive set circularly computable covering effective space property
# words repeated:  ['metric', 'chainable', 'circularly', 'set', 'computable', 'space']
# words title:  np structure question
# words keyword:  bs oracle halting machine relativizations problem
# words repeated:  ['oracle', 'relativizations']
# words title:  solution thousand ten effective monkey approach
# words keyword:  analysis computable condition semicomputability lipschitz equation ordinary differential inclusion
# words repeated:  ['computability', 'differential', 'inclusion']
# words title:  base existence effective
# words keyword:  analysis basis computatable schauder functional
# words repeated:  ['schauder']
# words title:  european perspective
# words keyword:  territory vision innovation quality stakeholder
# words repeated:  ['innovation', 'quality']
# words title:  based system approach
# words keyword:  design web educational development
# words repeated:  ['design', 'web', 'educational']
# words title:  pool application scenario
# words keyword:  repository collaborative learning object
# words repeated:  ['learning', 'object']
# words title:  tutor bot evaluator
# words keyword:  tutoring system alice chatterbots bdi aiml claroline moodle intelligent
# words repeated:  []
# words title:  people educational special digital eduquito inclusion
# words keyword:  environment person virtual disability accessibility
# words repeated:  ['environment', 'virtual']
# words title:  management web development
# words keyword:  application learning style
# words repeated:  ['learning', 'style', 'application']
# words title:  support semantic
# words keyword:  visualization spiral timeline moodle
# words repeated:  ['spiral', 'timeline']
# words title:  language processing
# words keyword:  visualization tree educational software syntax
# words repeated:  ['syntax', 'visualization', 'tree']
# words title:  environment coala computer distributed assisted program
# words keyword:  programming system learning tutoring intelligent
# words repeated:  ['learning']

# %% [markdown]
# ## Split of Words

# %%
# ff = 0
# for i in range(len(titleArrClean)):
#     if len(titleArrClean[i]) == 0:
#         listK = rakeKeyword[i].split()
#         half_length = len(listK) // 2
#         first_half = listK[:half_length]
#         second_half = listK[half_length:]
#         first_half = ' '.join(first_half)
#         second_half = ' '.join(second_half)

#         titleArrClean[i] = first_half
#         rakeKeyword[i] = second_half
#         print(ff)
#         print(listK)
#         print(first_half)
#         print(second_half)
#         ff+=1
# Out:
# 0
# ['atomicity', 'software', 'development', 'transaction', 'monitor', 'ocl', 'uml', 'concurrency']
# atomicity software development transaction
# monitor ocl uml concurrency
# 1
# ['generation', 'testing', 'algorithm', 'genetic', 'flow', 'software', 'automatic', 'data', 'test']
# generation testing algorithm genetic
# flow software automatic data test
# 2
# ['computing', 'mining', 'clustering', 'data', 'stream']
# computing mining
# clustering data stream
# 3
# ['root', 'polynomial', 'positive', 'equation', 'bound']
# root polynomial
# positive equation bound
# 4
# ['randomness', 'set', 'algorithmic', 'binary', 'theory', 'sequence', 'information', 'random']
# randomness set algorithmic binary
# theory sequence information random
# 5
# ['principle', 'set', 'partial', 'constructive', 'realizability', 'combinatory', 'theory', 'brouwerian', 'algebra']
# principle set partial constructive
# realizability combinatory theory brouwerian algebra
# 6
# ['continuity', 'constructive', 'mathematics']
# continuity
# constructive mathematics
# 7
# ['computational', 'system', 'computing', 'membrane', 'completeness', 'determinism']
# computational system computing
# membrane completeness determinism
# 8
# ['universality', 'inhibitor', 'system', 'promoter']
# universality inhibitor
# system promoter
# 9
# ['resolution', 'negotiation', 'inconsistency', 'management', 'analysis', 'winwin', 'requirement', 'preference', 'conflict']
# resolution negotiation inconsistency management
# analysis winwin requirement preference conflict
# 10
# ['computational', 'system', 'rewriting', 'grammar', 'tissue', 'universality', 'matrix']
# computational system rewriting
# grammar tissue universality matrix
# 11
# ['function', 'decomposition', 'boolean', 'equation']
# function decomposition
# boolean equation
# 12
# ['control', 'coroutines', 'lua', 'generator', 'structure', 'language']
# control coroutines lua
# generator structure language
# 13
# ['environment', 'assessment', 'learning', 'knowledge', 'skill', 'solving', 'structure', 'simulated', 'problem']
# environment assessment learning knowledge
# skill solving structure simulated problem
# 14
# ['formal', 'semantics', 'specification', 'action']
# formal semantics
# specification action
# 15
# ['dependent', 'type', 'dml', 'pattern', 'matching']
# dependent type
# dml pattern matching
# 16
# ['computational', 'decision', 'formal', 'complexity', 'synchronized', 'grammar', 'language', 'problem']
# computational decision formal complexity
# synchronized grammar language problem
# 17
# ['tree', 'set', 'product', 'automaton', 'complete']
# tree set
# product automaton complete
# 18
# ['regular', 'nx', 'decomposition', 'product', 'src', 'language', 'shuffle', 'img']
# regular nx decomposition product
# src language shuffle img
# 19
# ['regular', 'transducer', 'delay', 'decodability', 'decoding', 'decidability', 'channel', 'language', 'unique']
# regular transducer delay decodability
# decoding decidability channel language unique
# 20
# ['human', 'superorganisms', 'management', 'system', 'knowledge', 'organization', 'resource']
# human superorganisms management
# system knowledge organization resource
# 21
# ['neural', 'network', 'computation', 'distributed', 'state', 'machine', 'abstract']
# neural network computation
# distributed state machine abstract
# 22
# ['logic', 'specification', 'dynamic', 'state', 'foundation', 'language', 'machine', 'abstract', 'modal']
# logic specification dynamic state
# foundation language machine abstract modal
# 23
# ['collaborative', 'system', 'embedded', 'methodology', 'knowledge', 'operation', 'portfolio', 'continuous', 'management', 'business', 'improvement', 'reverse', 'tool', 'os', 'education', 'model']
# collaborative system embedded methodology knowledge operation portfolio continuous
# management business improvement reverse tool os education model
# 24
# ['hierarchy', 'focus', 'model', 'wide', 'glass', 'context', 'web', 'teleportation', 'search', 'visualisation', 'navigation', 'conceptual', 'world', 'structuring', 'hypermedia', 'treeworld', 'relevance']
# hierarchy focus model wide glass context web teleportation
# search visualisation navigation conceptual world structuring hypermedia treeworld relevance
# 25
# ['visualization', 'management', 'system', 'environmetal', 'knowledge', 'data', 'base', 'information']
# visualization management system environmetal
# knowledge data base information
# 26
# ['nonhomomorphicity', 'boolean', 'function', 'cryptanalysis', 'cryptography']
# nonhomomorphicity boolean
# function cryptanalysis cryptography
# 27
# ['computational', 'complexity', 'time', 'linear', 'incompleteness']
# computational complexity
# time linear incompleteness
# 28
# ['graphical', 'img', 'process', 'semantics', 'calculus', 'representation', 'src', 'concurrent', 'net', 'machine', 'multiset', 'abstract']
# graphical img process semantics calculus representation
# src concurrent net machine multiset abstract
# 29
# ['category', 'parallel', 'semiringal', 'type', 'network', 'enriched', 'relation', 'mixed', 'program', 'data', 'abstract', 'algebra']
# category parallel semiringal type network enriched
# relation mixed program data abstract algebra
# 30
# ['graph', 'hypercube', 'permutation', 'automorphism', 'group']
# graph hypercube
# permutation automorphism group
# 31
# ['tableau', 'transformation', 'automated', 'proof', 'presentation', 'search', 'calculus', 'deduction']
# tableau transformation automated proof
# presentation search calculus deduction
# 32
# ['randomness', 'sharing', 'security', 'scheme', 'secret', 'data', 'cryptography']
# randomness sharing security
# scheme secret data cryptography
# 33
# ['testing', 'system', 'communicating', 'specification', 'software', 'state', 'language', 'matrix', 'processing', 'stream']
# testing system communicating specification software
# state language matrix processing stream
# 34
# ['parallel', 'decomposition', 'automaton', 'timed', 'partition', 'state', 'clock']
# parallel decomposition automaton
# timed partition state clock
# 35
# ['hierarchy', 'commutative', 'order', 'separation', 'complexity', 'computation', 'polynomial', 'query', 'ordered', 'downward', 'class']
# hierarchy commutative order separation complexity
# computation polynomial query ordered downward class
# 36
# ['programmable', 'rapid', 'prototyping', 'hardware', 'pc', 'coprocessor', 'logic']
# programmable rapid prototyping
# hardware pc coprocessor logic
# 37
# ['knowledg', 'filtering', 'information', 'management', 'corporate', 'knowledge', 'memory', 'technology', 'work', 'process']
# knowledg filtering information management corporate
# knowledge memory technology work process
# 38
# ['basic', 'formal', 'system', 'documentation', 'sdl', 'specification', 'telecommunication', 'semantic', 'executable', 'foundation', 'state', 'machine', 'abstract']
# basic formal system documentation sdl specification
# telecommunication semantic executable foundation state machine abstract
# 39
# ['system', 'persistency', 'term', 'rewriting', 'modularity', 'confluence']
# system persistency term
# rewriting modularity confluence
# 40
# ['kraft', 'huffman', 'tree', 'optimum', 'prefix', 'code', 'extendible', 'inequality']
# kraft huffman tree optimum
# prefix code extendible inequality
# 41
# ['mapping', 'constructive', 'mathematics', 'pointwise', 'sequential', 'continuity', 'linear']
# mapping constructive mathematics
# pointwise sequential continuity linear
# 42
# ['distance', 'document', 'multimedia', 'computer', 'engineering', 'electronic', 'integrated', 'technology', 'information', 'teaching']
# distance document multimedia computer engineering
# electronic integrated technology information teaching
# 43
# ['distance', 'system', 'multimedia', 'medium', 'development', 'online', 'publishing', 'teaching']
# distance system multimedia medium
# development online publishing teaching
# 44
# ['distance', 'rotation', 'triangulation', 'flip', 'operation']
# distance rotation
# triangulation flip operation
# 45
# ['set', 'bounded', 'effectivization', 'completeness', 'function', 'extensionally', 'pseudosimple']
# set bounded effectivization
# completeness function extensionally pseudosimple
# 46
# ['history', 'cultural', 'web', 'society', 'aspect', 'www', 'sgml']
# history cultural web
# society aspect www sgml
# 47
# ['learning', 'cbt', 'support', 'digital', 'electronic', 'instructional', 'cai', 'technology', 'library', 'teaching']
# learning cbt support digital electronic
# instructional cai technology library teaching
# 48
# ['gif', 'unisys', 'debate', 'patent', 'software', 'internet', 'compuserve', 'lzw']
# gif unisys debate patent
# software internet compuserve lzw
# 49
# ['complexity', 'chaitin', 'string', 'random']
# complexity chaitin
# string random
# 50
# ['filter', 'leapfrog', 'algorithm', 'electronics', 'design', 'genetic', 'method', 'circuit', 'optimization', 'classical', 'search', 'amplifier', 'operational', 'evolutionary', 'pattern', 'transconductance', 'problem']
# filter leapfrog algorithm electronics design genetic method circuit
# optimization classical search amplifier operational evolutionary pattern transconductance problem
# 51
# ['algorithm', 'genetic', 'code', 'computation', 'division', 'multiple', 'multiuser', 'detection', 'evolutionary', 'access']
# algorithm genetic code computation division
# multiple multiuser detection evolutionary access
# 52
# ['design', 'network', 'sensor', 'modular', 'node', 'wireless', 'architecture', 'hardware']
# design network sensor modular
# node wireless architecture hardware
# 53
# ['formal', 'temporal', 'type', 'software', 'mixed', 'language', 'logic', 'engineering', 'data', 'transition', 'graphical', 'based', 'system', 'architectural', 'glue', 'notation', 'abstract', 'specification', 'description', 'component', 'symbolic']
# formal temporal type software mixed language logic engineering data transition
# graphical based system architectural glue notation abstract specification description component symbolic
# 54
# ['human', 'security', 'automated', 'captcha', 'optical', 'turing', 'persian', 'public', 'text', 'recognition', 'arabic', 'internet', 'character', 'baffletext', 'completely']
# human security automated captcha optical turing persian
# public text recognition arabic internet character baffletext completely
# 55
# ['mobility', 'programming', 'computation', 'strong', 'functional', 'haskell', 'mobile']
# mobility programming computation
# strong functional haskell mobile
# 56
# ['programming', 'xpath', 'set', 'magic', 'language', 'logic']
# programming xpath set
# magic language logic
# 57
# ['programming', 'program', 'transformation', 'fuzzy', 'unfolding', 'logic']
# programming program transformation
# fuzzy unfolding logic
# 58
# ['mutual', 'exclusion', 'section', 'queue', 'algorithm', 'complexity', 'network', 'computer', 'critical', 'migration', 'distributed', 'message']
# mutual exclusion section queue algorithm complexity
# network computer critical migration distributed message
# 59
# ['mvc', 'xslt', 'design', 'web', 'xmi', 'xml', 'application', 'modeling', 'data', 'pattern', 'technique', 'uml', 'model']
# mvc xslt design web xmi xml
# application modeling data pattern technique uml model
# 60
# ['graphical', 'parallel', 'system', 'computing', 'membrane', 'operating', 'interface']
# graphical parallel system
# computing membrane operating interface
# 61
# ['hardware', 'method', 'formal', 'verification']
# hardware method
# formal verification
# 62
# ['grand', 'formal', 'method', 'verification', 'challenge']
# grand formal
# method verification challenge
# 63
# ['computable', 'computation', 'function', 'static', 'template', 'polytime']
# computable computation function
# static template polytime
# 64
# ['reference', 'permanent', 'collection', 'management', 'counting', 'graph', 'cyclic', 'garbage', 'tenured', 'object', 'memory']
# reference permanent collection management counting
# graph cyclic garbage tenured object memory
# 65
# ['gray', 'code']
# gray
# code
# 66
# ['stable', 'fully', 'kronecker', 'set', 'graph', 'irreducible', 'support', 'indecomposable', 'bipartite', 'total', 'adjacency', 'matching', 'perfect', 'product', 'boolean', 'elementary', 'matrix', 'cover']
# stable fully kronecker set graph irreducible support indecomposable bipartite
# total adjacency matching perfect product boolean elementary matrix cover
# 67
# ['evolution', 'petri', 'reflection', 'software', 'net']
# evolution petri
# reflection software net
# 68
# ['classification', 'compensation', 'advertising', 'interactive', 'model']
# classification compensation
# advertising interactive model
# 69
# ['wrapper', 'distance', 'web', 'crawling', 'hidden']
# wrapper distance
# web crawling hidden
# 70
# ['simulation', 'timed', 'predicate', 'state', 'machine', 'abstract', 'logic']
# simulation timed predicate
# state machine abstract logic
# 71
# ['behavioural', 'programming', 'validation', 'system', 'mismatch', 'adaptation', 'composition', 'component', 'interface', 'transition']
# behavioural programming validation system mismatch
# adaptation composition component interface transition
# 72
# ['hybrid', 'bus', 'algorithm', 'genetic', 'network', 'optimization', 'scheduling', 'problem']
# hybrid bus algorithm genetic
# network optimization scheduling problem
# 73
# ['domain', 'system', 'ontology', 'modeling', 'tutoring', 'intelligent', 'authoring', 'model']
# domain system ontology modeling
# tutoring intelligent authoring model
# 74
# ['task', 'computing', 'collaboration', 'ambient', 'scheduling', 'intelligence', 'space', 'hypermedia', 'authoring', 'active']
# task computing collaboration ambient scheduling
# intelligence space hypermedia authoring active
# 75
# ['input', 'environment', 'interaction', 'device', 'game', 'virtual', 'video', 'eye', 'tracking']
# input environment interaction device
# game virtual video eye tracking
# 76
# ['law', 'product', 'line', 'refactoring', 'software', 'algebraic', 'feature', 'model']
# law product line refactoring
# software algebraic feature model
# 77
# ['logic', 'infinitary', 'substitution', 'uniform', 'canonical', 'modal', 'model']
# logic infinitary substitution
# uniform canonical modal model
# 78
# ['superdistribution', 'copyright', 'good', 'computing', 'content', 'protection', 'trusted', 'digital']
# superdistribution copyright good computing
# content protection trusted digital
# 79
# ['generation', 'estimation', 'distribution', 'algorithm', 'pareto', 'evolution', 'offspring', 'scheme', 'optimization', 'differential']
# generation estimation distribution algorithm pareto
# evolution offspring scheme optimization differential
# 80
# ['metric', 'urysohn', 'universal', 'constructive', 'mathematics', 'space']
# metric urysohn universal
# constructive mathematics space
# 81
# ['metric', 'continuum', 'chainable', 'recursive', 'set', 'circularly', 'computable', 'covering', 'effective', 'space', 'property']
# metric continuum chainable recursive set
# circularly computable covering effective space property

# %% [markdown]
# ## Joining Title and Keywords

# %%
def joinTitleKeyword(titleArr, keywordArr):
    joinArr = []
    for item1, item2 in zip(titleArr, keywordArr):
        joinArr.append(item1+" "+ item2)
    return joinArr

# %%
# joinArr = joinTitleKeyword(titleArrClean, rakeKeyword)
joinArr = joinTitleKeyword(rakeTitle, rakeKeyword)

# %%
# for i in range(len(titleArrClean)):
#     print("words title: ",titleArrClean[i], "\nwords keyword: ", rakeKeyword[i], "\nwords joined: ", joinArr[i])

for i in range(len(rakeTitle)):
    print("words title: ",rakeTitle[i], "\nwords keyword: ", rakeKeyword[i], "\nwords joined: ", joinArr[i])
# Out:
# words title:  process-ori commun structur integr
# words keyword:  knowledg knowledge-intens gener wiki process-ori commun structur process cooper
# words joined:  process-ori commun structur integr knowledg knowledge-intens gener wiki process-ori commun structur process cooper
# words title:  outcom interact small factor synchron learn onlin accept workplac determin group
# words keyword:  assur profession studi empir learn train computer-support qualiti workplac cooper
# words joined:  outcom interact small factor synchron learn onlin accept workplac determin group assur profession studi empir learn train computer-support qualiti workplac cooper
# words title:  knowledg share learn weblog space
# words keyword:  experience-bas system agent pedagog arrang learn weblog micro-didact space wiki inform
# words joined:  knowledg share learn weblog space experience-bas system agent pedagog arrang learn weblog micro-didact space wiki inform
# words title:  manag knowledg architectur pre-built implement method space orient inform process model
# words keyword:  manag filter knowledg inform collabor method introduct retriev ontolog context-awar busi process model
# words joined:  manag knowledg architectur pre-built implement method space orient inform process model manag filter knowledg inform collabor method introduct retriev ontolog context-awar busi process model
# words title:  evalu visual transfer knowledg project map long-term applic tube
# words keyword:  manag visual knowledg inform metaphor project commun storytel
# words joined:  evalu visual transfer knowledg project map long-term applic tube manag visual knowledg inform metaphor project commun storytel
# words title:  manag knowledg activity-bas system reconcil approach workflow
# words keyword:  manag knowledg workflow
# words joined:  manag knowledg activity-bas system reconcil approach workflow manag knowledg workflow
# words title:  human toolkit knowledge-intens organis design network factor methodolog km technolog integr
# words keyword:  manag knowledg inter-organiz network collabor busi
# words joined:  human toolkit knowledge-intens organis design network factor methodolog km technolog integr manag knowledg inter-organiz network collabor busi
# words title:  knowledge-intens process kmdl improv analys busi captur
# words keyword:  manag knowledg knowledge-intens descript k-model languag process-ori busi process model
# words joined:  knowledge-intens process kmdl improv analys busi captur manag knowledg knowledge-intens descript k-model languag process-ori busi process model
# words title:  knowledg manag enterpris role solut busi process
# words keyword:  knowledg manag research market enterpris tool softwar busi process
# words joined:  knowledg manag enterpris role solut busi process knowledg manag research market enterpris tool softwar busi process
# words title:  knowledg design work infrastructur model
# words keyword:  manag knowledg theori busi instrument activ work infrastructur stanc process model
# words joined:  knowledg design work infrastructur model manag knowledg theori busi instrument activ work infrastructur stanc process model
# words title:  knowledg call-centr hierarchi infrastructur process model
# words keyword:  manag knowledg system data base inform
# words joined:  knowledg call-centr hierarchi infrastructur process model manag knowledg system data base inform
# words title:  manag knowledg servic orient approach base process
# words keyword:  process manag knowledg servic
# words joined:  manag knowledg servic orient approach base process process manag knowledg servic
# words title:  non-block concurr algorithm queue formal construct
# words keyword:  prover formal concurr proof atom refin
# words joined:  non-block concurr algorithm queue formal construct prover formal concurr proof atom refin
# words title:  observ investig atom
# words keyword:  formal develop method atom observ refin
# words joined:  observ investig atom formal develop method atom observ refin
# words title:  asynchron consid verifi relax atom case mechan commun correct
# words keyword:  asynchron relax verif atom commun process algebra
# words joined:  asynchron consid verifi relax atom case mechan commun correct asynchron relax verif atom commun process algebra
# words title:  compens precis transact bpel applic busi model
# words keyword:  formal compens ing method languag transact long-runn semant specif
# words joined:  compens precis transact bpel applic busi model formal compens ing method languag transact long-runn semant specif
# words title:  understand system replic broadcast atom advantag quorum
# words keyword:  system isol replic broadcast atom quorum
# words joined:  understand system replic broadcast atom advantag quorum system isol replic broadcast atom quorum
# words title:  manifesto atom
# words keyword:  formal depend method languag transact atom hardwar program
# words joined:  manifesto atom formal depend method languag transact atom hardwar program
# words title:  develop softwar atom
# words keyword:  concurr develop transact atom softwar monitor ocl uml
# words joined:  develop softwar atom concurr develop transact atom softwar monitor ocl uml
# words title:  first-class atom system provis
# words keyword:  cach transact coher atom memori
# words joined:  first-class atom system provis cach transact coher atom memori
# words title:  visual mine semi-automat subgroup vikamin
# words keyword:  analysi visual mine subgroup data
# words joined:  visual mine semi-automat subgroup vikamin analysi visual mine subgroup data
# words title:  visual social recommend flow network
# words keyword:  visual reput social network flow inform
# words joined:  visual social recommend flow network visual reput social network flow inform
# words title:  orthogon high-dimension curv data
# words keyword:  analysi visual grand tour method cluster curv andrew data exploratori
# words joined:  orthogon high-dimension curv data analysi visual grand tour method cluster curv andrew data exploratori
# words title:  mine system lite-weight integr data oper ubiquit gui
# words keyword:  data visual mine icon
# words joined:  mine system lite-weight integr data oper ubiquit gui data visual mine icon
# words title:  visual segment mine decis interact explor connect rule data
# words keyword:  visual segment mine explor connect data
# words joined:  visual segment mine decis interact explor connect rule data visual segment mine explor connect data
# words title:  incomplet visual uncertain decis depend diagram manipul
# words keyword:  incomplet mine decis diagram function minim data specifi
# words joined:  incomplet visual uncertain decis depend diagram manipul incomplet mine decis diagram function minim data specifi
# words title:  visual interact highli gravi tempor explor data inform structur
# words keyword:  domain visual interact tempor data medic inform
# words joined:  visual interact highli gravi tempor explor data inform structur domain visual interact tempor data medic inform
# words title:  explor multiresolut scalabl data
# words keyword:  visual explor techniqu multiresolut data
# words joined:  explor multiresolut scalabl data visual explor techniqu multiresolut data
# words title:  intrud wireless locat physic
# words keyword:  intrus system detect wireless antenna
# words joined:  intrud wireless locat physic intrus system detect wireless antenna
# words title:  evalu fuzzi techniqu level refer secur polici model
# words keyword:  evalu public infrastructur key fuzzi techniqu secur polici
# words joined:  evalu fuzzi techniqu level refer secur polici model evalu public infrastructur key fuzzi techniqu secur polici
# words title:  audio distort lsb code increas steganographi reduc robust
# words keyword:  audio lsb code hide steganographi data
# words joined:  audio distort lsb code increas steganographi reduc robust audio lsb code hide steganographi data
# words title:  intrus protocol detect embed protomon prevent monitor cryptograph
# words keyword:  intrus protocol detect abus secur cryptograph comput
# words joined:  intrus protocol detect embed protomon prevent monitor cryptograph intrus protocol detect abus secur cryptograph comput
# words title:  slide protocol group network window ad-hoc secur commun
# words keyword:  ad re-key hoc protocol group network dsr rout perform secur commun
# words joined:  slide protocol group network window ad-hoc secur commun ad re-key hoc protocol group network dsr rout perform secur commun
# words title:  software/hardwar co-design hardwar secur cryptograph effici
# words keyword:  evolutionari algorithm cryptographi co-design addition-chain genet comput
# words joined:  software/hardwar co-design hardwar secur cryptograph effici evolutionari algorithm cryptographi co-design addition-chain genet comput
# words title:  signatur rsa-bas e-good deliveri verifi encrypt certifi
# words keyword:  fair protocol deliveri exchang certifi non-repudi secur
# words joined:  signatur rsa-bas e-good deliveri verifi encrypt certifi fair protocol deliveri exchang certifi non-repudi secur
# words title:  assur system combin explor lazi open sourc qualiti space inform multi-ag
# words keyword:  system agent qualiti inform multi-ag
# words joined:  assur system combin explor lazi open sourc qualiti space inform multi-ag system agent qualiti inform multi-ag
# words title:  low-intrus digit disk tool checkpoint consist forens
# words keyword:  digit system backup file snapshot consist forens oper checkpoint
# words joined:  low-intrus digit disk tool checkpoint consist forens digit system backup file snapshot consist forens oper checkpoint
# words title:  transfer network scheme data secur comput
# words keyword:  manag theori perfect algorithm one-tim key pad protect secur inform secreci data
# words joined:  transfer network scheme data secur comput manag theori perfect algorithm one-tim key pad protect secur inform secreci data
# words title:  analysi gossip pirat fingerprint code trace erasur construct
# words keyword:  theori digit system multimedia code librari inform
# words joined:  analysi gossip pirat fingerprint code trace erasur construct theori digit system multimedia code librari inform
# words title:  problem creation game databasesa profil inform distribut
# words keyword:  manag theori market game databas resourc inform strategi distribut
# words joined:  problem creation game databasesa profil inform distribut manag theori market game databas resourc inform strategi distribut
# words title:  control ded method synthesi applic
# words keyword:  control ded system dynam event synthesi discret
# words joined:  control ded method synthesi applic control ded system dynam event synthesi discret
# words title:  complex system implic develop softwar structur tendenc
# words keyword:  life complex architectur system adapt softwar cycl
# words joined:  complex system implic develop softwar structur tendenc life complex architectur system adapt softwar cycl
# words title:  brows user collabor web extract semant bookmark interest base
# words keyword:  brows collabor web ontolog work
# words joined:  brows user collabor web extract semant bookmark interest base brows collabor web ontolog work
# words title:  intern cognit agent ground languag relat structur problem
# words keyword:  cognit agent formula ground languag satisfact modal commun logic
# words joined:  intern cognit agent ground languag relat structur problem cognit agent formula ground languag satisfact modal commun logic
# words title:  hybrid queri recommend
# words keyword:  rosa mine system recommend web person retriev adapt inform
# words joined:  hybrid queri recommend rosa mine system recommend web person retriev adapt inform
# words title:  knowledg semant level inconsist process
# words keyword:  knowledg method consensu conflict inconsist
# words joined:  knowledg semant level inconsist process knowledg method consensu conflict inconsist
# words title:  hybrid user system web adapt interfac consensus-bas
# words keyword:  hybrid user system method web-bas adapt consensu interfac
# words joined:  hybrid user system web adapt interfac consensus-bas hybrid user system method web-bas adapt consensu interfac
# words title:  model retriev provabl approxim comput spatiotempor effici
# words keyword:  dimension queri high databas rang spatiotempor structur data model
# words joined:  model retriev provabl approxim comput spatiotempor effici dimension queri high databas rang spatiotempor structur data model
# words title:  time actor cost comput
# words keyword:  parallel constraint implement time actor execut comput
# words joined:  time actor cost comput parallel constraint implement time actor execut comput
# words title:  analysi evalu control protocol design scheme perform ms-rtcp real-tim scalabl
# words keyword:  manag protocol rtcp multimedia scalabl commun distribut
# words joined:  analysi evalu control protocol design scheme perform ms-rtcp real-tim scalabl manag protocol rtcp multimedia scalabl commun distribut
# words title:  automat algorithm gener flow test data
# words keyword:  automat algorithm gener flow test softwar data genet
# words joined:  automat algorithm gener flow test data automat algorithm gener flow test softwar data genet
# words title:  estim theoret rout upper bound
# words keyword:  algorithm circuit cad rout global integr
# words joined:  estim theoret rout upper bound algorithm circuit cad rout global integr
# words title:  document multimedia html transclus fine-grain
# words keyword:  structur system multimedia web-bas author applic hypermedia transclus xanalog publish
# words joined:  document multimedia html transclus fine-grain structur system multimedia web-bas author applic hypermedia transclus xanalog publish
# words title:  cube complex fat topolog commun collect
# words keyword:  fat cube architectur topolog network router collect interconnect commun
# words joined:  cube complex fat topolog commun collect fat cube architectur topolog network router collect interconnect commun
# words title:  formal framework autom testaf
# words keyword:  formal autom softwar specif object-ori test
# words joined:  formal framework autom testaf formal autom softwar specif object-ori test
# words title:  cryptosystem shuffl verifi variant paillier provabl secur base effici
# words keyword:  system verifi public-key mix-net paillier privaci huffl
# words joined:  cryptosystem shuffl verifi variant paillier provabl secur base effici system verifi public-key mix-net paillier privaci huffl
# words title:  b2c agent marketplac virtual exploit ontolog
# words keyword:  b2c e-commerc agent technolog ontolog intellig
# words joined:  b2c agent marketplac virtual exploit ontolog b2c e-commerc agent technolog ontolog intellig
# words title:  domain tree algorithm uowhf finit extend binari
# words keyword:  tree uowhf function binari hash
# words joined:  domain tree algorithm uowhf finit extend binari tree uowhf function binari hash
# words title:  check composit rebeca verif autom abstract model
# words keyword:  check reactiv system modular verif techniqu actor abstract model
# words joined:  check composit rebeca verif autom abstract model check reactiv system modular verif techniqu actor abstract model
# words title:  fast t-decomposit algorithm
# words keyword:  complex t-decomposit entropi measur pars comput
# words joined:  fast t-decomposit algorithm complex t-decomposit entropi measur pars comput
# words title:  free tree polygon simpl insid bound draw
# words keyword:  free tree anneal skeleton geometri graph straight simul draw comput
# words joined:  free tree polygon simpl insid bound draw free tree anneal skeleton geometri graph straight simul draw comput
# words title:  definit languag construct approach
# words keyword:  modular languag semant action oper structur program
# words joined:  definit languag construct approach modular languag semant action oper structur program
# words title:  design function match hardwar perfect program
# words keyword:  logic descript arithmet gener languag circuit function hardwar structur program
# words joined:  design function match hardwar perfect program logic descript arithmet gener languag circuit function hardwar structur program
# words title:  implement lua
# words keyword:  coroutin hash virtual closur machin abl compil
# words joined:  implement lua coroutin hash virtual closur machin abl compil
# words title:  aspectlua dynam aop approach
# words keyword:  mop lua dynam reflect aspect aop
# words joined:  aspectlua dynam aop approach mop lua dynam reflect aspect aop
# words title:  semant formal final
# words keyword:  manag final semant memori collect garbag
# words joined:  semant formal final manag final semant memori collect garbag
# words title:  servic web languag build interfac pew
# words keyword:  formal servic web languag semant program
# words joined:  servic web languag build interfac pew formal servic web languag semant program
# words title:  languag platform function compil net nonâ­strict
# words keyword:  interoper languag virtual function haskel machin net compil program
# words joined:  languag platform function compil net nonâ­strict interoper languag virtual function haskel machin net compil program
# words title:  script run lua clr translat bytecod
# words keyword:  languag bytecod virtual common runtim machin compil
# words joined:  script run lua clr translat bytecod languag bytecod virtual common runtim machin compil
# words title:  evalu experiment technolog jit java
# words keyword:  dynam optim just-in-tim compil
# words joined:  evalu experiment technolog jit java dynam optim just-in-tim compil
# words title:  signal comonad
# words keyword:  dataflow function comonad law stream distribut comput
# words joined:  signal comonad dataflow function comonad law stream distribut comput
# words title:  scheme languag specif equat
# words keyword:  analysi equat formal semant execut specif program
# words joined:  scheme languag specif equat analysi equat formal semant execut specif program
# words title:  pure languag function mobil mhaskel comput
# words keyword:  program languag function haskel mobil comput
# words joined:  pure languag function mobil mhaskel comput program languag function haskel mobil comput
# words title:  tree decis dynam learn data stream
# words keyword:  drift tree decis concept increment data stream
# words joined:  tree decis dynam learn data stream drift tree decis concept increment data stream
# words title:  data resource-awar mine stream
# words keyword:  mine resource-awar cluster data stream comput
# words joined:  data resource-awar mine stream mine resource-awar cluster data stream comput
# words title:  alert mine id network extract attack categor stream scenario
# words keyword:  intrus resolut detect network secur first-ord logic
# words joined:  alert mine id network extract attack categor stream scenario intrus resolut detect network secur first-ord logic
# words title:  mine usag web request semant preprocess stream
# words keyword:  brows analysi mine usag web semant pattern
# words joined:  mine usag web request semant preprocess stream brows analysi mine usag web semant pattern
# words title:  trigger time qualiti condit seri stream
# words keyword:  servic trigger predict qo time qualiti seri stream model
# words joined:  trigger time qualiti condit seri stream servic trigger predict qo time qualiti seri stream model
# words title:  mine append-onli item dynam onlin data continu stream chang
# words keyword:  mine algorithm single-pass data stream chang
# words joined:  mine append-onli item dynam onlin data continu stream chang mine algorithm single-pass data stream chang
# words title:  select learn numer border increment exampl rule data stream
# words keyword:  drift decis learn classif increment concept rule data stream
# words joined:  select learn numer border increment exampl rule data stream drift decis learn classif increment concept rule data stream
# words title:  posit root polynomi bound
# words keyword:  posit root equat polynomi bound
# words joined:  posit root polynomi bound posit root equat polynomi bound
# words title:  suprema construct
# words keyword:  order set partial supremum mathemat construct
# words joined:  suprema construct order set partial supremum mathemat construct
# words title:  uniform equival continu construct theorem
# words keyword:  uniform revers mathemat continu construct
# words joined:  uniform equival continu construct theorem uniform revers mathemat continu construct
# words title:  spectrum oper self-adjoint comput
# words keyword:  analysi function comput
# words joined:  spectrum oper self-adjoint comput analysi function comput
# words title:  algorithm cellular irreduc automata univers
# words keyword:  cellular automaton omega halt probabl
# words joined:  algorithm cellular irreduc automata univers cellular automaton omega halt probabl
# words title:  analysi ration function iter construct
# words keyword:  analysi ration function iter construct
# words joined:  analysi ration function iter construct analysi ration function iter construct
# words title:  formal gelfand stone-yosida topolog represent mathemat construct theorem
# words keyword:  riesz formal topolog mathemat f-algebra space choic axiom construct
# words joined:  formal gelfand stone-yosida topolog represent mathemat construct theorem riesz formal topolog mathemat f-algebra space choic axiom construct
# words title:  axiomat intuitionist class model
# words keyword:  logic filter intuitionist satur kripk ultraproduct ultrapow prime disjoint bisimul iter union model
# words joined:  axiomat intuitionist class model logic filter intuitionist satur kripk ultraproduct ultrapow prime disjoint bisimul iter union model
# words title:  element posit banach space state algebra firm
# words keyword:  element posit hermitian mathemat banach state space construct algebra
# words joined:  element posit banach space state algebra firm element posit hermitian mathemat banach state space construct algebra
# words title:  sequenc random nonrandom
# words keyword:  theori set algorithm sequenc binari inform random
# words joined:  sequenc random nonrandom theori set algorithm sequenc binari inform random
# words title:  permut linear rule lattic
# words keyword:  analysi theori lattic decid proof
# words joined:  permut linear rule lattic analysi theori lattic decid proof
# words title:  topolog formal coequalis quotient space
# words keyword:  formal topolog coequalis predicativit quotient local construct
# words joined:  topolog formal coequalis quotient space formal topolog coequalis predicativit quotient local construct
# words title:  theori set principl brouwerian construct
# words keyword:  theori set partial principl realiz combinatori brouwerian construct algebra
# words joined:  theori set principl brouwerian construct theori set partial principl realiz combinatori brouwerian construct algebra
# words title:  construct process program
# words keyword:  caus determin refin construct process algebra
# words joined:  construct process program caus determin refin construct process algebra
# words title:  aspect markov chain construct
# words keyword:  markov chain construct
# words joined:  aspect markov chain construct markov chain construct
# words title:  regular posit formal relat
# words keyword:  regular posit topolog formal relat space real
# words joined:  regular posit formal relat regular posit topolog formal relat space real
# words title:  function tree depend count
# words keyword:  valu function compl databas axiomatis
# words joined:  function tree depend count valu function compl databas axiomatis
# words title:  continu construct
# words keyword:  continu construct mathemat
# words joined:  continu construct continu construct mathemat
# words title:  result oper construct algebra
# words keyword:  theori mathemat hilbert space oper construct
# words joined:  result oper construct algebra theori mathemat hilbert space oper construct
# words title:  languag lukasiewicz hausdorff measur
# words keyword:  determinist attractor system languag measur omega-languag function cantor hausdorff space simpl iter fractal
# words joined:  languag lukasiewicz hausdorff measur determinist attractor system languag measur omega-languag function cantor hausdorff space simpl iter fractal
# words title:  mathemat determin principl object
# words keyword:  analysi ration function iter construct
# words joined:  mathemat determin principl object analysi ration function iter construct
# words title:  perhap valu intermedi theorem
# words keyword:  analysi intuitionist intermedi perhap valu real theorem
# words joined:  perhap valu intermedi theorem analysi intuitionist intermedi perhap valu real theorem
# words title:  sylvest conjectur construct approach
# words keyword:  order geometri conjectur sylvest construct
# words joined:  sylvest conjectur construct approach order geometri conjectur sylvest construct
# words title:  fine function effect space limit sequenti recurs comput
# words keyword:  fine fine-continu sequenc fine-comput function effect space limit weakli recurs fine-sequenti comput
# words joined:  fine function effect space limit sequenti recurs comput fine fine-continu sequenc fine-comput function effect space limit weakli recurs fine-sequenti comput
# words title:  unit content learn activ model
# words keyword:  educ unit collabor languag learn object e-learn model
# words joined:  unit content learn activ model educ unit collabor languag learn object e-learn model
# words title:  appli web person technolog e-aula lt semant gt e-learn
# words keyword:  servic system multimedia web-bas web xml semant hypermedia
# words joined:  appli web person technolog e-aula lt semant gt e-learn servic system multimedia web-bas web xml semant hypermedia
# words title:  conceptu descript experi learn tool
# words keyword:  conceptu interact exercis learn author tool
# words joined:  conceptu descript experi learn tool conceptu interact exercis learn author tool
# words title:  classroom approach identif ubiquit process comput
# words keyword:  interact context awar implicit ubiquit rfid comput
# words joined:  classroom approach identif ubiquit process comput interact context awar implicit ubiquit rfid comput
# words title:  educ program collabor learn tool integr comput
# words keyword:  teach collabor learn comput simul anim program
# words joined:  educ program collabor learn tool integr comput teach collabor learn comput simul anim program
# words title:  conceptu evolut virtual object ii chasqui
# words keyword:  lcm campu servic web learn object virtual lom author im tool museum scorm e-learn
# words joined:  conceptu evolut virtual object ii chasqui lcm campu servic web learn object virtual lom author im tool museum scorm e-learn
# words title:  diagnosi environ learn author activ kadd
# words keyword:  diagnosi cognit environ librari learn author tool trace error model
# words joined:  diagnosi environ learn author activ kadd diagnosi cognit environ librari learn author tool trace error model
# words title:  task asynchron system collabor learn support pda
# words keyword:  domot collabor learn computer-support pda mobil comput
# words joined:  task asynchron system collabor learn support pda domot collabor learn computer-support pda mobil comput
# words title:  tele-educ research studi project case
# words keyword:  educ servic multimedia web-bas hypertext/hypermedia internet
# words joined:  tele-educ research studi project case educ servic multimedia web-bas hypertext/hypermedia internet
# words title:  collabor learn object author ontolog integr
# words keyword:  metadata annot collabor learn object ontolog
# words joined:  collabor learn object author ontolog integr metadata annot collabor learn object ontolog
# words title:  analyz divers modul
# words keyword:  small-talk modul packag virtual rubi namespac java classbox class selector
# words joined:  analyz divers modul small-talk modul packag virtual rubi namespac java classbox class selector
# words title:  behavior descript compon coordin
# words keyword:  express modular embed coordin process algebra
# words joined:  behavior descript compon coordin express modular embed coordin process algebra
# words title:  gener composit object algebra
# words keyword:  objectâ­orient formal composit object softwar specif
# words joined:  gener composit object algebra objectâ­orient formal composit object softwar specif
# words title:  service-ori compon composit dynam assert approach autonom non-invas paradigm
# words keyword:  compon code composit dynam aspect common orient net servic intermedi runtim assert autonom weav languag web manipul aspect-ori architectur program
# words joined:  service-ori compon composit dynam assert approach autonom non-invas paradigm compon code composit dynam aspect common orient net servic intermedi runtim assert autonom weav languag web manipul aspect-ori architectur program
# words title:  reo circuit connector probabilist model
# words keyword:  markov decis constraint composit reo coordin automata bisimul probabilist process
# words joined:  reo circuit connector probabilist model markov decis constraint composit reo coordin automata bisimul probabilist process
# words title:  modular languag verif actor component-bas
# words keyword:  reactiv compon system modular rebeca verif actor model
# words joined:  modular languag verif actor component-bas reactiv compon system modular rebeca verif actor model
# words title:  computer-human learn effect personality-awar interfac
# words keyword:  interact type indic myers-brigg human-comput mbti e-learn
# words joined:  computer-human learn effect personality-awar interfac interact type indic myers-brigg human-comput mbti e-learn
# words title:  situat manag metadata learn model
# words keyword:  elearn situat metadata learn
# words joined:  situat manag metadata learn model elearn situat metadata learn
# words title:  architectur user deliveri context materi awar approach e-learn
# words keyword:  user retriev learn object ontolog e-learn context-awar
# words joined:  architectur user deliveri context materi awar approach e-learn user retriev learn object ontolog e-learn context-awar
# words title:  system web-bas factor train intercultur
# words keyword:  manag interact knowledg user design web-bas factor train usage-cent interfac pattern
# words joined:  system web-bas factor train intercultur manag interact knowledg user design web-bas factor train usage-cent interfac pattern
# words title:  system student discov e-learn model
# words keyword:  user context learn object e-learn
# words joined:  system student discov e-learn model user context learn object e-learn
# words title:  higher educ user system experi elearn learn adapt model
# words keyword:  user elearn learn adapt cscl model
# words joined:  higher educ user system experi elearn learn adapt model user elearn learn adapt cscl model
# words title:  knowledg unigam social game learn train skill concept univers lifelong game-bas
# words keyword:  educ collabor game learn motiv constructiv game-bas
# words joined:  knowledg unigam social game learn train skill concept univers lifelong game-bas educ collabor game learn motiv constructiv game-bas
# words title:  classroom-bas personalis learn adapt role e-learn
# words keyword:  teach personalis learn
# words joined:  classroom-bas personalis learn adapt role e-learn teach personalis learn
# words title:  algorithm schedul partial graph constrain message-optim preced distribut
# words keyword:  task algorithm schedul constraint graph direct preced distribut
# words joined:  algorithm schedul partial graph constrain message-optim preced distribut task algorithm schedul constraint graph direct preced distribut
# words title:  multi-dsp accur system environ predict rapid perform prototyp base
# words keyword:  multi-dsp system schedul embed flow predict rapid perform data prototyp
# words joined:  multi-dsp accur system environ predict rapid perform prototyp base multi-dsp system schedul embed flow predict rapid perform data prototyp
# words title:  secur web-bas exam
# words keyword:  supervis fraud web-bas prevent exam assess secur
# words joined:  secur web-bas exam supervis fraud web-bas prevent exam assess secur
# words title:  knowledg decis exchang network learn facilit make
# words keyword:  manag system broker network practic learn commun
# words joined:  knowledg decis exchang network learn facilit make manag system broker network practic learn commun
# words title:  knowledg manag central km trade-
# words keyword:  organiz knowledg mental market capit practic ration retrospect trade-
# words joined:  knowledg manag central km trade- organiz knowledg mental market capit practic ration retrospect trade-
# words title:  organiz knowledg studi pizzarotti case reific node commun
# words keyword:  manag knowledg node commun distribut
# words joined:  organiz knowledg studi pizzarotti case reific node commun manag knowledg node commun distribut
# words title:  ontology-bas knowledg system ontoshar share practic virtual commun
# words keyword:  knowledg web share semant commun
# words joined:  ontology-bas knowledg system ontoshar share practic virtual commun knowledg web share semant commun
# words title:  studi project indigo introduct particip case
# words keyword:  evolut process indigo introduct learn particip eparticip inspect improv distribut
# words joined:  studi project indigo introduct particip case evolut process indigo introduct learn particip eparticip inspect improv distribut
# words title:  perspect practic technolog integr commun
# words keyword:  manag knowledg enterpris content intranet extranet practic e-learnin person technolog commun inform
# words joined:  perspect practic technolog integr commun manag knowledg enterpris content intranet extranet practic e-learnin person technolog commun inform
# words title:  chao knowledg coproduct hierarchi net expert
# words keyword:  studi expert volkswagen telekom practic siemen case deutsch wiko net commun
# words joined:  chao knowledg coproduct hierarchi net expert studi expert volkswagen telekom practic siemen case deutsch wiko net commun
# words title:  manag knowledg evolut organ perspect liquid cycl crystal
# words keyword:  manag knowledg organ nebula perspect practic livingom liquid art-shta crystal commun
# words joined:  manag knowledg evolut organ perspect liquid cycl crystal manag knowledg organ nebula perspect practic livingom liquid art-shta crystal commun
# words title:  knowledg creation share map support implicit base commun
# words keyword:  visualis manag knowledg web practic semant discoveri commun
# words joined:  knowledg creation share map support implicit base commun visualis manag knowledg web practic semant discoveri commun
# words title:  stepping-ston empathi trust social etiquett capit practic commun
# words keyword:  knowledg trust social etiquett norm sociabl capit tacit practic explicit onlin commun
# words joined:  stepping-ston empathi trust social etiquett capit practic commun knowledg trust social etiquett norm sociabl capit tacit practic explicit onlin commun
# words title:  determin evolution-commun system
# words keyword:  system membran complet determin comput
# words joined:  determin evolution-commun system system membran complet determin comput
# words title:  system popul
# words keyword:  bond membran divis ture differenti cell comput
# words joined:  system popul bond membran divis ture differenti cell comput
# words title:  rule system symport/antiport
# words keyword:  evolut antiport system membran symport commun comput
# words joined:  rule system symport/antiport evolut antiport system membran symport commun comput
# words title:  complex note system measur probabilist
# words keyword:  natur system entropi comput
# words joined:  complex note system measur probabilist natur system entropi comput
# words title:  element system maximum find
# words keyword:  system membran maximum valu natur comput
# words joined:  element system maximum find system membran maximum valu natur comput
# words title:  system promoters/inhibitor
# words keyword:  inhibitor promot univers system
# words joined:  system promoters/inhibitor inhibitor promot univers system
# words title:  gate system fredkin simul energy-bas
# words keyword:  gate system revers fredkin conserv energy-bas logic
# words joined:  gate system fredkin simul energy-bas gate system revers fredkin conserv energy-bas logic
# words title:  membran java simul comput
# words keyword:  parallel java system simul
# words joined:  membran java simul comput parallel java system simul
# words title:  system item bin famili pack effici
# words keyword:  complex system membran problem bin class clip recogn pack comput
# words joined:  system item bin famili pack effici complex system membran problem bin class clip recogn pack comput
# words title:  separ system membran activ rule
# words keyword:  membran natur distribut comput
# words joined:  separ system membran activ rule membran natur distribut comput
# words title:  larg knowledg enterpris croatian competit advantag sourc integr
# words keyword:  human manag knowledg competit advantag resourc integr strateg
# words joined:  larg knowledg enterpris croatian competit advantag sourc integr human manag knowledg competit advantag resourc integr strateg
# words title:  analysi knowledg audit systemat flow map approach integr inventori
# words keyword:  analysi knowledg audit social network flow map inventori
# words joined:  analysi knowledg audit systemat flow map approach integr inventori analysi knowledg audit social network flow map inventori
# words title:  task individu assign approach profil semantic-bas
# words keyword:  knowledg descript skill match elicit logic
# words joined:  task individu assign approach profil semantic-bas knowledg descript skill match elicit logic
# words title:  knowledg visual interact joint facilit commun
# words keyword:  disavow knowledg interact visual joint evas commun refus
# words joined:  knowledg visual interact joint facilit commun disavow knowledg interact visual joint evas commun refus
# words title:  web introduct framework cbr technolog km semant
# words keyword:  manag knowledg reason web case-bas semant
# words joined:  web introduct framework cbr technolog km semant manag knowledg reason web case-bas semant
# words title:  analysi manag research knowledg transfer public develop hero case univers process
# words keyword:  analysi manag research knowledg develop univers process
# words joined:  analysi manag research knowledg transfer public develop hero case univers process analysi manag research knowledg develop univers process
# words title:  analysi knowledg transfer social network method selakt localis expert sustain
# words keyword:  analysi manag research knowledg social distribut implement network collabor share practic localis expert appli commun strategi sustain
# words joined:  analysi knowledg transfer social network method selakt localis expert sustain analysi manag research knowledg social distribut implement network collabor share practic localis expert appli commun strategi sustain
# words title:  metadata investig share
# words keyword:  knowledg metadata agreement share
# words joined:  metadata investig share knowledg metadata agreement share
# words title:  analysi formal concept databas lexic model
# words keyword:  analysi formal semant concept relat databas lexic
# words joined:  analysi formal concept databas lexic model analysi formal semant concept relat databas lexic
# words title:  lattic graph search concept partit breadth
# words keyword:  analysi formal graph search concept bipartit breadth
# words joined:  lattic graph search concept partit breadth analysi formal graph search concept bipartit breadth
# words title:  lattic retriev concept exploit credo potenti inform
# words keyword:  mine lattic web retriev concept credo inform
# words joined:  lattic retriev concept exploit credo potenti inform mine lattic web retriev concept credo inform
# words title:  order addit diagram avoid conflict
# words keyword:  diagram automat layout lattic
# words joined:  order addit diagram avoid conflict diagram automat layout lattic
# words title:  intract duquenne-guigu base comput
# words keyword:  implic complex comput base
# words joined:  intract duquenne-guigu base comput implic complex comput base
# words title:  theori visual lattic landmark galoi probabilist
# words keyword:  analysi visual formal lattic mobil landmark vision concept local orient autonom galoi robot comput
# words joined:  theori visual lattic landmark galoi probabilist analysi visual formal lattic mobil landmark vision concept local orient autonom galoi robot comput
# words title:  logic model check appli tool interv fbt specif on-the-fli
# words keyword:  logic fil tableau automat check graphic method tempor buechi on-the-fli verif futur automata gil interv specif model
# words joined:  logic model check appli tool interv fbt specif on-the-fli logic fil tableau automat check graphic method tempor buechi on-the-fli verif futur automata gil interv specif model
# words title:  check csp state consist base uml class model
# words keyword:  abstract formal mac hine method notat sequenti commun uml process
# words joined:  check csp state consist base uml class model abstract formal mac hine method notat sequenti commun uml process
# words title:  system enterpris support autom inform
# words keyword:  theori formal set reason autom heurist otter specif
# words joined:  system enterpris support autom inform theori formal set reason autom heurist otter specif
# words title:  sat search static global manipul heurist minc variable-ord bdd
# words keyword:  order formal decis sat search backtrack cnf verif partit heurist variabl bdd
# words joined:  sat search static global manipul heurist minc variable-ord bdd order formal decis sat search backtrack cnf verif partit heurist variabl bdd
# words title:  signal acceler check combin relationship global equival
# words keyword:  check formula implic combin sat boolean proposit static equival satisfi cec logic
# words joined:  signal acceler check combin relationship global equival check formula implic combin sat boolean proposit static equival satisfi cec logic
# words title:  approxim bdd-base improv bound sat-bas model
# words keyword:  analysi model check decis diagram sat binari satisfi bmc reachabl bound bdd
# words joined:  approxim bdd-base improv bound sat-bas model analysi model check decis diagram sat binari satisfi bmc reachabl bound bdd
# words title:  function-complet sat search support heurist lookahead effici
# words keyword:  dag heurist check decis diagram state machin binari satisfi bound model
# words joined:  function-complet sat search support heurist lookahead effici dag heurist check decis diagram state machin binari satisfi bound model
# words title:  signal circuit-sat solver guid correl
# words keyword:  check boolean atpg equival satisfi
# words joined:  signal circuit-sat solver guid correl check boolean atpg equival satisfi
# words title:  coupling-bas test program
# words keyword:  test object-ori softwar coverag
# words joined:  coupling-bas test program test object-ori softwar coverag
# words title:  multimedia engin survey softwar
# words keyword:  multimedia compon system framework
# words joined:  multimedia engin survey softwar multimedia compon system framework
# words title:  contract composit interact servic
# words keyword:  interact architectur service-ori servic composit web coordin connector softwar comput
# words joined:  contract composit interact servic interact architectur service-ori servic composit web coordin connector softwar comput
# words title:  softwar experi
# words keyword:  engin rewrit revers migrat rule data pattern
# words joined:  softwar experi engin rewrit revers migrat rule data pattern
# words title:  web introduct compon portlet
# words keyword:  servic portlet portal develop web component-bas applic
# words joined:  web introduct compon portlet servic portlet portal develop web component-bas applic
# words title:  develop system multi-ag methodolog
# words keyword:  engin agent system multi-ag methodolog softwar intellig agent-ori
# words joined:  develop system multi-ag methodolog engin agent system multi-ag methodolog softwar intellig agent-ori
# words title:  process custom construct
# words keyword:  design process method softwar
# words joined:  process custom construct design process method softwar
# words title:  analysi requir negoti multi-criteria
# words keyword:  analysi manag resolut requir winwin negoti multi-criteria conflict inconsist prefer
# words joined:  analysi requir negoti multi-criteria analysi manag resolut requir winwin negoti multi-criteria conflict inconsist prefer
# words title:  applic develop approach add document-ori
# words keyword:  domain-specif evolut modular languag develop processor markup softwar approach mainten xml
# words joined:  applic develop approach add document-ori domain-specif evolut modular languag develop processor markup softwar approach mainten xml
# words title:  expect digit librari
# words keyword:  list conceptu knowledg visual annot link document digit hyperwav portal-system black librari search white futur activ repositori e-learn
# words joined:  expect digit librari list conceptu knowledg visual annot link document digit hyperwav portal-system black librari search white futur activ repositori e-learn
# words title:  system base develop embed synthesi object-ori reus oo-asip
# words keyword:  system design embed object_ori hardware/softwar processor application_specif synthesi highlevel instruct
# words joined:  system base develop embed synthesi object-ori reus oo-asip system design embed object_ori hardware/softwar processor application_specif synthesi highlevel instruct
# words title:  analysi protocol symbol approach secur
# words keyword:  protocol formal method symbol bisimul noninterfer equivalence-check process algebra
# words joined:  analysi protocol symbol approach secur protocol formal method symbol bisimul noninterfer equivalence-check process algebra
# words title:  telemetri fast neural lempel-ziv network numer compress lossless predictor data
# words keyword:  neural lempel-ziv network predict compress lossless two-stag
# words joined:  telemetri fast neural lempel-ziv network numer compress lossless predictor data neural lempel-ziv network predict compress lossless two-stag
# words title:  hyperbol tile cell space combinator
# words keyword:  cellular plane hyperbol automata
# words joined:  hyperbol tile cell space combinator cellular plane hyperbol automata
# words title:  root group hash full search primit prime
# words keyword:  collis root hash mod cyclic scatter primit techniqu storag prime full residu group strategi tabl
# words joined:  root group hash full search primit prime collis root hash mod cyclic scatter primit techniqu storag prime full residu group strategi tabl
# words title:  rewrit tissu system
# words keyword:  system rewrit tissu grammar univers matrix comput
# words joined:  rewrit tissu system system rewrit tissu grammar univers matrix comput
# words title:  word control formal
# words keyword:  semant oper
# words joined:  word control formal semant oper
# words title:  boolean function decomposit
# words keyword:  function boolean decomposit equat
# words joined:  boolean function decomposit function boolean decomposit equat
# words title:  grid retriev point geometr ram model
# words keyword:  system grid index file data multi-dimension structur spatial model
# words joined:  grid retriev point geometr ram model system grid index file data multi-dimension structur spatial model
# words title:  warehous past tempor increment mainten data oper base logic
# words keyword:  warehous tempor relat databas algebra self-mainten data logic
# words joined:  warehous past tempor increment mainten data oper base logic warehous tempor relat databas algebra self-mainten data logic
# words title:  automat x-global system flexibl variou semant level sourc
# words keyword:  interschema properti sourc integr xml inform
# ...
# words keyword:  control concurr recoveri transact databas state machin abstract process
# words joined:  transact aries-bas state machin abstract control concurr recoveri transact databas state machin abstract process
# words title:  design databas global minim time space updat base storag
# words keyword:  depend design relat databas univers form normal
# words joined:  design databas global minim time space updat base storag depend design relat databas univers form normal
# words title:  semistructur formal verif data pv model
# words keyword:  semistructur ora-ss verif autom data pv model
# words joined:  semistructur formal verif data pv model semistructur ora-ss verif autom data pv model
# words title:  formal aggreg framework olap-oltp model
# words keyword:  frame cube aggreg oltp-olap olap function oper specif
# words joined:  formal aggreg framework olap-oltp model frame cube aggreg oltp-olap olap function oper specif
# words title:  complex ideal coincid valu characteris
# words keyword:  complex ideal coincid valu restructur
# words joined:  complex ideal coincid valu characteris complex ideal coincid valu restructur
# words title:  warehous design dynam state machin data abstract
# words keyword:  on-lin warehous process state machin data abstract refin analyt
# words joined:  warehous design dynam state machin data abstract on-lin warehous process state machin data abstract refin analyt
# words title:  digit good superdistribut
# words keyword:  copyright trust good digit content superdistribut protect comput
# words joined:  digit good superdistribut copyright trust good digit content superdistribut protect comput
# words title:  design secur multimedia authent
# words keyword:  set design principl authent content-bas watermark
# words joined:  design secur multimedia authent set design principl authent content-bas watermark
# words title:  multimedia network attack stabil heterogen adversari
# words keyword:  theori queue multimedia network attack stabil adversari commun
# words joined:  multimedia network attack stabil heterogen adversari theori queue multimedia network attack stabil adversari commun
# words title:  topolog impact attack threat chang
# words keyword:  share attack peersim file applic chang
# words joined:  topolog impact attack threat chang share attack peersim file applic chang
# words title:  traffic denial-of-servic detect method attack test statist base distribut
# words keyword:  network monitor protect secur statist comput
# words joined:  traffic denial-of-servic detect method attack test statist base distribut network monitor protect secur statist comput
# words title:  urgent danish adopt busi model
# words keyword:  heterarchi social web wikinom media
# words joined:  urgent danish adopt busi model heterarchi social web wikinom media
# words title:  social recommend share platform multi sourc resourc tag provid
# words keyword:  manag metadata knowledg digit recommend collabor share web classif resourc tag
# words joined:  social recommend share platform multi sourc resourc tag provid manag metadata knowledg digit recommend collabor share web classif resourc tag
# words title:  script life interact knowledg collabor share learn virtual classif
# words keyword:  life knowledg collabor share virtual muve onlin world
# words joined:  script life interact knowledg collabor share learn virtual classif life knowledg collabor share virtual muve onlin world
# words title:  list arm project embed linux mail behaviour sourc case open model
# words keyword:  system social collabor network project embed web-bas virtual open sourc work commun inform
# words joined:  list arm project embed linux mail behaviour sourc case open model system social collabor network project embed web-bas virtual open sourc work commun inform
# words title:  composit support aspect aop structur kernel
# words keyword:  composit aspect aop aspect-ori reflex structur kernel program
# words joined:  composit support aspect aop structur kernel composit aspect aop aspect-ori reflex structur kernel program
# words title:  sql queri criteria coverag structur test
# words keyword:  sql criteria coverag databas test adequaci
# words joined:  sql queri criteria coverag structur test sql criteria coverag databas test adequaci
# words title:  fair protocol sign negoti contract non-repudi secur
# words keyword:  protocol properti exchang confidenti sign negoti contract intellectu secur
# words joined:  fair protocol sign negoti contract non-repudi secur protocol properti exchang confidenti sign negoti contract intellectu secur
# words title:  control dynam ds role rbac session base access
# words keyword:  control privileg role rbac ansi
# words joined:  control dynam ds role rbac session base access control privileg role rbac ansi
# words title:  posit complex root quadrat polynomi valu linear bound
# words keyword:  posit root isol vincent real upper bound theorem
# words joined:  posit complex root quadrat polynomi valu linear bound posit root isol vincent real upper bound theorem
# words title:  homomorph cryptosystem advanc
# words keyword:  encrypt homomorph cryptosystem probabl
# words joined:  homomorph cryptosystem advanc encrypt homomorph cryptosystem probabl
# words title:  estim algorithm unit magnet measur compass inerti orient dcm base
# words keyword:  estim quaternion represent euler orient dcm
# words joined:  estim algorithm unit magnet measur compass inerti orient dcm base estim quaternion represent euler orient dcm
# words title:  analysi compar complex studi methodolog ontolog integr
# words keyword:  import similar concept ontolog identity-bas integr conflict
# words joined:  analysi compar complex studi methodolog ontolog integr import similar concept ontolog identity-bas integr conflict
# words title:  support preprocess cluster data vector procedur effici
# words keyword:  neighbor elimin share nois support cluster nearest vector
# words joined:  support preprocess cluster data vector procedur effici neighbor elimin share nois support cluster nearest vector
# words title:  pde-peda optim algorithm multi-object pareto-bas
# words keyword:  estim offspr optim evolut algorithm pareto gener scheme multi-object differenti distribut
# words joined:  pde-peda optim algorithm multi-object pareto-bas estim offspr optim evolut algorithm pareto gener scheme multi-object differenti distribut
# words title:  hybrid multifacet sequenc search integr discoveri pattern frame-relay pso-ann
# words keyword:  model mine multifacet sequenc mode computation-ori concern definit pattern frame-relay comput
# words joined:  hybrid multifacet sequenc search integr discoveri pattern frame-relay pso-ann model mine multifacet sequenc mode computation-ori concern definit pattern frame-relay comput
# words title:  hybrid shop algorithm flow quantum-inspir makespan immun criterion
# words keyword:  hybrid shop gate algorithm schedul rotat quantum flow immun
# words joined:  hybrid shop algorithm flow quantum-inspir makespan immun criterion hybrid shop gate algorithm schedul rotat quantum flow immun
# words title:  expos road recognit sign imag approach differ graph-bas guidanc robust
# words keyword:  theori recognit detect graph sign hdr
# words joined:  expos road recognit sign imag approach differ graph-bas guidanc robust theori recognit detect graph sign hdr
# words title:  lexic context web fingerprint
# words keyword:  knowledg minutia mine wordnet golden web semant ontolog discoveri
# words joined:  lexic context web fingerprint knowledg minutia mine wordnet golden web semant ontolog discoveri
# words title:  infer optim algorithm network gene regulatori
# words keyword:  algorithm network gene bayesian genet
# words joined:  infer optim algorithm network gene regulatori algorithm network gene bayesian genet
# words title:  prune multi-sub-swarm multilay ensembl particl swarm
# words keyword:  classifi optim multi-lay prune swarm ensembl particl model
# words joined:  prune multi-sub-swarm multilay ensembl particl swarm classifi optim multi-lay prune swarm ensembl particl model
# words title:  system framework scenario sdlma multi-ag model
# words keyword:  interact system languag multi-ag scenario
# words joined:  system framework scenario sdlma multi-ag model interact system languag multi-ag scenario
# words title:  brows url user psycholog method person
# words keyword:  brows user engin search person re-rank
# words joined:  brows url user psycholog method person brows user engin search person re-rank
# words title:  analysi migrat agent framework
# words keyword:  evalu system agent perform propag mobil multi-ag
# words joined:  analysi migrat agent framework evalu system agent perform propag mobil multi-ag
# words title:  control gener infrastructur access e-passport mechan secur e-docu purpos
# words keyword:  control rfid document e-docu secur pervas technolog mechan e-passport infrastructur electron access comput
# words joined:  control gener infrastructur access e-passport mechan secur e-docu purpos control rfid document e-docu secur pervas technolog mechan e-passport infrastructur electron access comput
# words title:  protocol agent network sensor platform support wireless cryptograph
# words keyword:  protocol agent cryptographi network sensor smartcard wireless
# words joined:  protocol agent network sensor platform support wireless cryptograph protocol agent cryptographi network sensor smartcard wireless
# words title:  analysi chess environ cipher pervas suitabl full-round secur comput
# words keyword:  permut data-depend chess cipher attack related-key differenti block oper cryptanalysi
# words joined:  analysi chess environ cipher pervas suitabl full-round secur comput permut data-depend chess cipher attack related-key differenti block oper cryptanalysi
# words title:  multimedia content network tv heterogen wireless dvb/gpr protect mobil
# words keyword:  identif manag fingerprint user digit drm multimedia tv gpr video scrambl match secur mobil dvb-
# words joined:  multimedia content network tv heterogen wireless dvb/gpr protect mobil identif manag fingerprint user digit drm multimedia tv gpr video scrambl match secur mobil dvb-
# words title:  usf-pa studi core framework technolog secur ubiquit
# words keyword:  surveil framework privaci secur intellig access
# words joined:  usf-pa studi core framework technolog secur ubiquit surveil framework privaci secur intellig access
# words title:  pervas vascular palm authent pattern
# words keyword:  near-infrar signatur vascular thin authent pattern multimod biometr
# words joined:  pervas vascular palm authent pattern near-infrar signatur vascular thin authent pattern multimod biometr
# words title:  ad hoc enforc highli network dynam mobil cooper
# words keyword:  ad hoc network selfish mobil cooperation-enforc
# words joined:  ad hoc enforc highli network dynam mobil cooper ad hoc network selfish mobil cooperation-enforc
# words title:  system neural network pervas vehicl smart classif road secur base
# words keyword:  transform neural recognit process network vehicl classif imag wavelet normal
# words joined:  system neural network pervas vehicl smart classif road secur base transform neural recognit process network vehicl classif imag wavelet normal
# words title:  topolog elementari comput
# words keyword:  analysi topolog comput
# words joined:  topolog elementari comput analysi topolog comput
# words title:  convers finite-tim preserv comput
# words keyword:  slide domain analysi theori finite-tim function constant-tim block comput
# words joined:  convers finite-tim preserv comput slide domain analysi theori finite-tim function constant-tim block comput
# words title:  hyperbol system symmetr oper solut pde comput
# words keyword:  metric hyperbol system norm scheme pencil approxim finite-dimension space differ stabil matrix pde comput
# words joined:  hyperbol system symmetr oper solut pde comput metric hyperbol system norm scheme pencil approxim finite-dimension space differ stabil matrix pde comput
# words title:  tietze-urysohn qcb-space effect theorem
# words keyword:  analysi topolog qcb-space space comput
# words joined:  tietze-urysohn qcb-space effect theorem analysi topolog qcb-space space comput
# words title:  blowup complex topolog problem
# words keyword:  theori equat type differenti blowup
# words joined:  blowup complex topolog problem theori equat type differenti blowup
# words title:  result measur repres
# words keyword:  analysi admiss represent measur normal devic physic distribut comput
# words joined:  result measur repres analysi admiss represent measur normal devic physic distribut comput
# words title:  squar unit fine-comput function integr
# words keyword:  fine-comput function integr oper fubini theorem
# words joined:  squar unit fine-comput function integr fine-comput function integr oper fubini theorem
# words title:  metric urysohn univers space construct
# words keyword:  metric urysohn mathemat univers space construct
# words joined:  metric urysohn univers space construct metric urysohn mathemat univers space construct
# words title:  metric set circularli chainabl space comput
# words keyword:  metric continuum set properti circularli chainabl effect space recurs cover comput
# words joined:  metric set circularli chainabl space comput metric continuum set properti circularli chainabl effect space recurs cover comput
# words title:  np oracl relativ question sever structur
# words keyword:  oracl halt relativ p-np machin bss problem
# words joined:  np oracl relativ question sever structur oracl halt relativ p-np machin bss problem
# words title:  inclus thousand ten differenti effect monkey approach solut comput
# words keyword:  analysi semicomput equat ordinari inclus differenti lipschitz condit comput
# words joined:  inclus thousand ten differenti effect monkey approach solut comput analysi semicomput equat ordinari inclus differenti lipschitz condit comput
# words title:  exist base schauder effect
# words keyword:  analysi computat schauder function basi
# words joined:  exist base schauder effect analysi computat schauder function basi
# words title:  innov perspect european qualiti e-learn
# words keyword:  territori innov vision qualiti stakehold e-learn
# words joined:  innov perspect european qualiti e-learn territori innov vision qualiti stakehold e-learn
# words title:  educ system design web approach meta-model multi-disciplinari base
# words keyword:  educ design develop web model-driven multi-disciplinari
# words joined:  educ system design web approach meta-model multi-disciplinari base educ design develop web model-driven multi-disciplinari
# words title:  learn object pool applic scenario
# words keyword:  collabor learn object repositori e-learn
# words joined:  learn object pool applic scenario collabor learn object repositori e-learn
# words title:  evalu aiml-bas tq-bot tutor bot
# words keyword:  moodl alic tq-bot system bdi clarolin tutor aiml intellig chatterbot
# words joined:  evalu aiml-bas tq-bot tutor bot moodl alic tq-bot system bdi clarolin tutor aiml intellig chatterbot
# words title:  digit inclus environ peopl virtual special eduquito
# words keyword:  environ person virtual disabl access
# words joined:  digit inclus environ peopl virtual special eduquito environ person virtual disabl access
# words title:  manag develop web learn style applic
# words keyword:  applic web-bas style learn
# words joined:  manag develop web learn style applic applic web-bas style learn
# words title:  spiral timelin support semant
# words keyword:  moodl visual spiral timelin e-learn
# words joined:  spiral timelin support semant moodl visual spiral timelin e-learn
# words title:  visual tree languag syntax cours process
# words keyword:  educ visual tree syntax softwar
# words joined:  visual tree languag syntax cours process educ visual tree syntax softwar
# words title:  assist coala program environ learn distribut comput
# words keyword:  system tutor learn intellig program
# words joined:  assist coala program environ learn distribut comput system tutor learn intellig program

# %%
df_data = pd.DataFrame() 

columns_to_copy = ['ID','Title','Keywords','FirstLevel']

# Copy the specified columns from df1 to df2
for column in columns_to_copy:
    df_data[column] = df_grouped[column].copy()

# %%
df_data
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords             FirstLevel
# 0     cooperative knowledge generation,knowledge  co...                  ['H']
# 1     professional training,workplace learning,compu...              ['H' 'J']
# 2     Experience-based Information System,wiki,weblo...  ['A' 'D' 'H' 'J' 'K']
# 3     modelling method,introduction method,context-a...          ['H' 'I' 'J']
# 4     knowledge visualization,information  visualiza...                  ['H']
# ...                                                 ...                    ...
# 1097  virtual environment,accessibility,persons with...                  ['K']
# 1098              learning styles,Web-based application                  ['K']
# 1099    visualization,e-learning,timeline,spiral,Moodle              ['L' 'M']
# 1100    syntax trees,visualization,educational software              ['D' 'K']
# 1101   learning programming,intelligent tutoring system          ['D' 'I' 'L']
#
# [1102 rows x 4 columns]

# %%
# df_data['Processed_Title'] = titleArrClean
# df_data['Processed_Keyword'] = rakeKeyword
# df_data['Processed_T_K'] = joinArr

df_data['Processed_Title'] = rakeTitle
df_data['Processed_Keyword'] = rakeKeyword
df_data['Processed_T_K'] = joinArr

# %%
df_data
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords  \
# 0     cooperative knowledge generation,knowledge  co...
# 1     professional training,workplace learning,compu...
# 2     Experience-based Information System,wiki,weblo...
# 3     modelling method,introduction method,context-a...
# 4     knowledge visualization,information  visualiza...
# ...                                                 ...
# 1097  virtual environment,accessibility,persons with...
# 1098              learning styles,Web-based application
# 1099    visualization,e-learning,timeline,spiral,Moodle
# 1100    syntax trees,visualization,educational software
# 1101   learning programming,intelligent tutoring system
#
#                  FirstLevel  \
# 0                     ['H']
# 1                 ['H' 'J']
# 2     ['A' 'D' 'H' 'J' 'K']
# 3             ['H' 'I' 'J']
# 4                     ['H']
# ...                     ...
# 1097                  ['K']
# 1098                  ['K']
# 1099              ['L' 'M']
# 1100              ['D' 'K']
# 1101          ['D' 'I' 'L']
#
#                                         Processed_Title  \
# 0                    process-ori commun structur integr
# 1     outcom interact small factor synchron learn on...
# 2                     knowledg share learn weblog space
# 3     manag knowledg architectur pre-built implement...
# 4     evalu visual transfer knowledg project map lon...
# ...                                                 ...
# 1097  digit inclus environ peopl virtual special edu...
# 1098               manag develop web learn style applic
# 1099                      spiral timelin support semant
# 1100           visual tree languag syntax cours process
# 1101  assist coala program environ learn distribut c...
#
#                                       Processed_Keyword  \
# 0     knowledg knowledge-intens gener wiki process-o...
# 1     assur profession studi empir learn train compu...
# 2     experience-bas system agent pedagog arrang lea...
# 3     manag filter knowledg inform collabor method i...
# 4     manag visual knowledg inform metaphor project ...
# ...                                                 ...
# 1097               environ person virtual disabl access
# 1098                         applic web-bas style learn
# 1099                moodl visual spiral timelin e-learn
# 1100                    educ visual tree syntax softwar
# 1101                system tutor learn intellig program
#
#                                           Processed_T_K
# 0     process-ori commun structur integr knowledg kn...
# 1     outcom interact small factor synchron learn on...
# 2     knowledg share learn weblog space experience-b...
# 3     manag knowledg architectur pre-built implement...
# 4     evalu visual transfer knowledg project map lon...
# ...                                                 ...
# 1097  digit inclus environ peopl virtual special edu...
# 1098  manag develop web learn style applic applic we...
# 1099  spiral timelin support semant moodl visual spi...
# 1100  visual tree languag syntax cours process educ ...
# 1101  assist coala program environ learn distribut c...
#
# [1102 rows x 7 columns]

# %% [markdown]
# # Load in CSV

# %%
import os

# %%
output = os.path.join("data/dataClean/", "df_Processed_Data.csv")
df_data.to_csv(output, index=False)

# %%
df_Processed_Data = pd.read_csv('data/dataClean/df_Processed_Data.csv')
df_Processed_Data
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords  \
# 0     cooperative knowledge generation,knowledge  co...
# 1     professional training,workplace learning,compu...
# 2     Experience-based Information System,wiki,weblo...
# 3     modelling method,introduction method,context-a...
# 4     knowledge visualization,information  visualiza...
# ...                                                 ...
# 1097  virtual environment,accessibility,persons with...
# 1098              learning styles,Web-based application
# 1099    visualization,e-learning,timeline,spiral,Moodle
# 1100    syntax trees,visualization,educational software
# 1101   learning programming,intelligent tutoring system
#
#                  FirstLevel  \
# 0                     ['H']
# 1                 ['H' 'J']
# 2     ['A' 'D' 'H' 'J' 'K']
# 3             ['H' 'I' 'J']
# 4                     ['H']
# ...                     ...
# 1097                  ['K']
# 1098                  ['K']
# 1099              ['L' 'M']
# 1100              ['D' 'K']
# 1101          ['D' 'I' 'L']
#
#                                         Processed_Title  \
# 0                    process-ori commun structur integr
# 1     outcom interact small factor synchron learn on...
# 2                     knowledg share learn weblog space
# 3     manag knowledg architectur pre-built implement...
# 4     evalu visual transfer knowledg project map lon...
# ...                                                 ...
# 1097  digit inclus environ peopl virtual special edu...
# 1098               manag develop web learn style applic
# 1099                      spiral timelin support semant
# 1100           visual tree languag syntax cours process
# 1101  assist coala program environ learn distribut c...
#
#                                       Processed_Keyword  \
# 0     knowledg knowledge-intens gener wiki process-o...
# 1     assur profession studi empir learn train compu...
# 2     experience-bas system agent pedagog arrang lea...
# 3     manag filter knowledg inform collabor method i...
# 4     manag visual knowledg inform metaphor project ...
# ...                                                 ...
# 1097               environ person virtual disabl access
# 1098                         applic web-bas style learn
# 1099                moodl visual spiral timelin e-learn
# 1100                    educ visual tree syntax softwar
# 1101                system tutor learn intellig program
#
#                                           Processed_T_K
# 0     process-ori commun structur integr knowledg kn...
# 1     outcom interact small factor synchron learn on...
# 2     knowledg share learn weblog space experience-b...
# 3     manag knowledg architectur pre-built implement...
# 4     evalu visual transfer knowledg project map lon...
# ...                                                 ...
# 1097  digit inclus environ peopl virtual special edu...
# 1098  manag develop web learn style applic applic we...
# 1099  spiral timelin support semant moodl visual spi...
# 1100  visual tree languag syntax cours process educ ...
# 1101  assist coala program environ learn distribut c...
#
# [1102 rows x 7 columns]
