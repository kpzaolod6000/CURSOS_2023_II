# %% [markdown]
# # Read Data

# %%
import pandas as pd
import re
import operator

# %%
def is_number(s):
    try:
        float(s) if '.' in s else int(s)
        return True
    except ValueError:
        return False

# %%
def load_stop_words(stop_word_file):
    """
    Utility function to load stop words from a file and return as a list of words
    @param stop_word_file Path and file name of a file containing stop words.
    @return list A list of stop words.
    """
    stop_words = []
    for line in open(stop_word_file):
        if line.strip()[0:1] != "#":
            for word in line.split():  # in case more than one per line
                stop_words.append(word)
    return stop_words

# %%
def separate_words(text, min_word_return_size):
    """
    Utility function to return a list of all words that are have a length greater than a specified number of characters.
    @param text The text that must be split in to words.
    @param min_word_return_size The minimum no of characters a word must have to be included.
    """
    splitter = re.compile('[^a-zA-Z0-9_\\+\\-/]')
    words = []
    for single_word in splitter.split(text):
        current_word = single_word.strip().lower()
        #leave numbers in phrase, but don't count as words, since they tend to invalidate scores of their phrases
        if len(current_word) > min_word_return_size and current_word != '' and not is_number(current_word):
            words.append(current_word)
    return words

# %%
def split_sentences(text):
    """
    Utility function to return a list of sentences.
    @param text The text that must be split in to sentences.
    """
    sentence_delimiters = re.compile(u'[.!?,;:\t\\\\"\\(\\)\\\'\u2019\u2013]|\\s\\-\\s')
    sentences = sentence_delimiters.split(text)
    return sentences

# %%
def build_stop_word_regex(stop_word_file_path):
    stop_word_list = load_stop_words(stop_word_file_path)
    stop_word_regex_list = []
    for word in stop_word_list:
        word_regex = r'\b' + word + r'(?![\w-])'  # added look ahead for hyphen
        stop_word_regex_list.append(word_regex)
    stop_word_pattern = re.compile('|'.join(stop_word_regex_list), re.IGNORECASE)
    return stop_word_pattern

# %%
def generate_candidate_keywords(sentence_list, stopword_pattern):
    phrase_list = []
    for s in sentence_list:
        tmp = re.sub(stopword_pattern, '|', s.strip())
        phrases = tmp.split("|")
        for phrase in phrases:
            phrase = phrase.strip().lower()
            if phrase != "":
                phrase_list.append(phrase)
    return phrase_list

# %%
def calculate_word_scores(phraseList):
    word_frequency = {}
    word_degree = {}
    for phrase in phraseList:
        word_list = separate_words(phrase, 0)
        word_list_length = len(word_list)
        word_list_degree = word_list_length - 1
        #if word_list_degree > 3: word_list_degree = 3 #exp.
        for word in word_list:
            word_frequency.setdefault(word, 0)
            word_frequency[word] += 1
            word_degree.setdefault(word, 0)
            word_degree[word] += word_list_degree  #orig.
            #word_degree[word] += 1/(word_list_length*1.0) #exp.
    for item in word_frequency:
        word_degree[item] = word_degree[item] + word_frequency[item]

    # Calculate Word scores = deg(w)/frew(w)
    word_score = {}
    for item in word_frequency:
        word_score.setdefault(item, 0)
        word_score[item] = word_degree[item] / (word_frequency[item] * 1.0)  #orig.
    #word_score[item] = word_frequency[item]/(word_degree[item] * 1.0) #exp.
    return word_score

# %%
def generate_candidate_keyword_scores(phrase_list, word_score):
    keyword_candidates = {}
    for phrase in phrase_list:
        keyword_candidates.setdefault(phrase, 0)
        word_list = separate_words(phrase, 0)
        candidate_score = 0
        for word in word_list:
            candidate_score += word_score[word]
        keyword_candidates[phrase] = candidate_score
    return keyword_candidates

# %%
class Rake(object):
    def __init__(self, stop_words_path):
        self.stop_words_path = stop_words_path
        self.__stop_words_pattern = build_stop_word_regex(stop_words_path)

    def run(self, text):
        sentence_list = split_sentences(text)

        phrase_list = generate_candidate_keywords(sentence_list, self.__stop_words_pattern)

        word_scores = calculate_word_scores(phrase_list)

        keyword_candidates = generate_candidate_keyword_scores(phrase_list, word_scores)

        # sorted_keywords = sorted(keyword_candidates.iteritems(), key=operator.itemgetter(1), reverse=True)
        sorted_keywords = sorted(keyword_candidates.items(), key=operator.itemgetter(1), reverse=True)
        
        return sorted_keywords

# %%
# if test:
#     text = "Compatibility of systems of linear constraints over the set of natural numbers. Criteria of compatibility of a system of linear Diophantine equations, strict inequations, and nonstrict inequations are considered. Upper bounds for components of a minimal set of solutions and algorithms of construction of minimal generating sets of solutions for all types of systems are given. These criteria and the corresponding algorithms for constructing a minimal supporting set of solutions can be used in solving all the considered types of systems and systems of mixed types."

#     # Split text into sentences
#     sentenceList = split_sentences(text)
#     #stoppath = "FoxStoplist.txt" #Fox stoplist contains "numbers", so it will not find "natural numbers" like in Table 1.1
#     stoppath = "SmartStoplist.txt"  #SMART stoplist misses some of the lower-scoring keywords in Figure 1.5, which means that the top 1/3 cuts off one of the 4.0 score words in Table 1.1
#     stopwordpattern = build_stop_word_regex(stoppath)

#     # generate candidate keywords
#     phraseList = generate_candidate_keywords(sentenceList, stopwordpattern)

#     # calculate individual word scores
#     wordscores = calculate_word_scores(phraseList)

#     # generate candidate keyword scores
#     keywordcandidates = generate_candidate_keyword_scores(phraseList, wordscores)
#     if debug: print(keywordcandidates)

#     # sortedKeywords = sorted(keywordcandidates.iteritems(), key=operator.itemgetter(1), reverse=True)
#     sortedKeywords = sorted(keywordcandidates, key=operator.itemgetter(1), reverse=True)

#     if debug: print(sortedKeywords)

#     totalKeywords = len(sortedKeywords)
#     if debug: print (totalKeywords)

#     # print (sortedKeywords[0:(totalKeywords / 3)])

#     rake = Rake("SmartStoplist.txt")
#     keywords = rake.run(text)
#     print (keywords)

# %%
df_grouped = pd.read_csv('data/dataClean/grouped_df.csv')

# %%
df_grouped
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords             FirstLevel
# 0     cooperative knowledge generation,knowledge  co...                  ['H']
# 1     professional training,workplace learning,compu...              ['H' 'J']
# 2     Experience-based Information System,wiki,weblo...  ['A' 'D' 'H' 'J' 'K']
# 3     modelling method,introduction method,context-a...          ['H' 'I' 'J']
# 4     knowledge visualization,information  visualiza...                  ['H']
# ...                                                 ...                    ...
# 1097  virtual environment,accessibility,persons with...                  ['K']
# 1098              learning styles,Web-based application                  ['K']
# 1099    visualization,e-learning,timeline,spiral,Moodle              ['L' 'M']
# 1100    syntax trees,visualization,educational software              ['D' 'K']
# 1101   learning programming,intelligent tutoring system          ['D' 'I' 'L']
#
# [1102 rows x 4 columns]

# %%
c_grouped_t = df_grouped['Title']
c_grouped_k = df_grouped['Keywords']

# %%
debug = False
test = True

# %%
def getWordsOfRakeAlgorithm(c_grouped):

    keywordsList = []
    i = 1
    for text in c_grouped:
        # text = "Compatibility of systems of linear constraints over the set of natural numbers. Criteria of compatibility of a system of linear Diophantine equations, strict inequations, and nonstrict inequations are considered. Upper bounds for components of a minimal set of solutions and algorithms of construction of minimal generating sets of solutions for all types of systems are given. These criteria and the corresponding algorithms for constructing a minimal supporting set of solutions can be used in solving all the considered types of systems and systems of mixed types."
        if debug: print(i)
        if debug: print(text)
        # Split text into sentences
        sentenceList = split_sentences(text)
       
        #stoppath = "FoxStoplist.txt" #Fox stoplist contains "numbers", so it will not find "natural numbers" like in Table 1.1
        stoppath = "SmartStoplist.txt"  #SMART stoplist misses some of the lower-scoring keywords in Figure 1.5, which means that the top 1/3 cuts off one of the 4.0 score words in Table 1.1
        stopwordpattern = build_stop_word_regex(stoppath)

        # generate candidate keywords
        phraseList = generate_candidate_keywords(sentenceList, stopwordpattern)

        # calculate individual word scores
        wordscores = calculate_word_scores(phraseList)

        # generate candidate keyword scores
        keywordcandidates = generate_candidate_keyword_scores(phraseList, wordscores)
        if debug: print("Keyword Candidates: ", keywordcandidates)

        # sortedKeywords = sorted(keywordcandidates.iteritems(), key=operator.itemgetter(1), reverse=True)
        sortedKeywords = sorted(keywordcandidates.items(), key=operator.itemgetter(1), reverse=True)

        if debug: print("Sorted Keywords: ", sortedKeywords)

        totalKeywords = len(sortedKeywords)
        if debug: print("Total Keywords: ", totalKeywords)

        # print (sortedKeywords[0:(totalKeywords / 3)])

        rake = Rake("SmartStoplist.txt")
        keywords = rake.run(text)
        # print (keywords)
        keywordsList.append(keywords)
        i += 1
    
    return keywordsList

# %% [markdown]
# ### Cleaned Title using Rake Algorithm

# %%
rakeTitle = getWordsOfRakeAlgorithm(list(c_grouped_t))

# %% [markdown]
# ### Cleaned Keyword using Rake Algorithm

# %%
rakeKeyword = getWordsOfRakeAlgorithm(list(c_grouped_k))

# %%
rakeKeyword

# %%
def setRakeInPreWords(rakeList):
    preWords = []
    for r_title in rakeList:
        print(r_title[0][0])
        preWords.append(r_title[0][0])
    return preWords

# %% [markdown]
# ### Rake Title

# %%
rakeTitle = setRakeInPreWords(rakeTitle)
# Out:
# process-oriented structures
# small groups learning synchronously online
# knowledge sharing
# implementing pre-built information spaces
# tube map visualization
# activity-based knowledge management approach
# integrate technological
# improving knowledge-intensive business processes
# knowledge management solutions
# modeling knowledge work
# knowledge infrastructure hierarchy model
# process oriented knowledge management
# non-blocking concurrent queue algorithm
# investigating atomicity
# asynchronous communication mechanism
# compensating business transactions
# atomic broadcast
# atomic manifesto
# software development
# first-class system provision
# semi-automatic visual subgroup mining
# visualizing recommendation flow
# high-dimensional data
# ubiquitous data mining
# visual data exploration
# uncertain dependencies
# explore highly structured temporal data
# scalable visual data exploration
# physically locating wireless intruders
# security level evaluation
# reduced distortion lsb coding
# cryptographic protocol intrusion detection
# sliding window protocol
# secure cryptographic hardware
# rsa-based certified delivery
# information source combinations space
# low-intrusive consistent disk checkpointing
# secured data transfer
# gossip codes
# information profiles
# deds control synthesis method
# complex systems development
# collaborative web browsing based
# language grounding problem
# hybrid method
# processing inconsistency
# web systems user interfaces
# provably efficient computational model
# time costs
# real-time control protocol
# automatic test data generation
# theoretical upper bound
# fine-grained transclusions
# fat cube topology
# test automation framework
# efficient verifiable shuffle based
# exploiting agent ontologies
# finite binary tree algorithm
# model checking
# fast t-decomposition algorithm
# draw free trees inside bounded simple polygons
# constructive approach
# hardware design
# implementation
# dynamic aop approach
# formal semantics
# building web service interfaces
# compiling nonâ­strict functional languages
# running lua scripts
# java jit technology
# signals
# equational specification
# purely functional language
# learning decision trees
# resource-aware mining
# network attack scenarios extraction
# web request streams
# evaluating trigger conditions
# dynamic data streams
# incremental rule learning
# positive roots
# constructive suprema
# uniform continuity theorem
# self-adjoint operators
# cellular automata universe
# iterated rational functions
# stone-yosida representation theorems
# axiomatic classes
# state space
# nonrandom sequences
# linear lattices
# quotient spaces
# constructive set theory
# constructing programs
# constructive aspects
# regular formal spaces
# functional dependencies
# continuity
# constructive results
# hausdorff measure
# mathematical objects determine
# intermediate
# constructive approach
# effective fine space
# modelling units
# semantic web technologies applied
# conceptual learning
# ubiquitous computing
# collaborative computer programming learning
# virtual objects
# learning activities
# support asynchronous collaborative learning tasks
# case studies
# integrating ontologies
# analyzing module diversity
# coordinating behavioral descriptions
# algebras
# autonomous dynamic component composition
# reo connector circuits
# component-based actor language
# personality-aware computer-human interfaces
# situated models
# user context aware delivery
# web-based training systems
# discovering student models
# adaptive user
# game-based learning
# classroom-based learning
# message-optimal distributed graph algorithm
# rapid prototyping environment
# securing web-based exams
# facilitating knowledge exchange
# knowledge centralization versus distribution
# pizzarotti case study
# ontology-based knowledge sharing system
# participative process introduction
# integrated technology perspective
# chaos knowledge coproduction
# organic perspectives
# supporting knowledge creation
# social capital
# determinism
# population
# systems
# complexity measures
# maximum element
# systems
# fredkin gate
# java simulator
# efficient family
# active membranes
# large croatian enterprises
# knowledge audit analysis
# semantic-based approach
# facilitating knowledge communication
# semantic web technologies
# research & development & transference process
# social network analysis
# sharing metadata
# modelling lexical databases
# search graph partitions
# concept lattices
# additive order diagrams
# duquenne-guigues base
# galois lattice theory
# applying interval logic specifications
# state models based
# enterprise information systems
# static global variable-ordering heuristic
# accelerate sat-based combinational equivalence checking
# improving sat-based bounded model checking
# efficient sat search heuristics
# signal correlation guided circuit-sat solver
# coupling-based testing
# multimedia software engineering
# composition contracts
# software dynamics
# web components
# developing multi-agent systems
# process construction
# multi-criteria preference analysis
# document-oriented approach
# digital libraries
# object-oriented embedded system development based
# symbolic approach
# fast two-stage lempel-ziv lossless numeric telemetry data compression
# hyperbolic 4d space
# full hash table search
# rewriting tissue
# formal model
# boolean functions
# geometric retrieval
# past temporal logic operators
# semantic integration
# coroutines
# relational model
# modular rewriting semantics
# implementing coordinated error recovery
# partial categorical multi-combinators
# net clr
# remote method invocation
# total functional programming
# drag-and-drop programming
# extensible environment
# improve reactive systems control
# poset labelled graphs
# mof-based metamodeling environment
# parametric verification
# platform modeling
# proof environment
# checking object system designs incrementally
# formally correct functional programs
# optimized temporal logic compilation
# case study
# real-time systems
# program checking
# fortran code optimization
# translation validation
# cross-disciplinary bibliography
# multimedia information repository
# future
# dynamic visual information
# fibonacci type coding
# cyclical structure converter
# heterogeneous audiovisual archives
# automatic discovery
# knowledge creation
# converging knowledge management
# strategy formulation process
# computational problem solving
# managing operation knowledge
# process-oriented knowledge structuring
# knowledge management
# post-nonaka knowledge management
# semantic grid
# scbs social capital benchmarking system
# pruning-based identification
# integrated personnel development
# individual knowledge
# ontology-based semantic match
# tool kit
# practical knowledge-based approach
# applying competence prerequisite structures
# identifying employee competencies
# integrative competence management
# simulated learning environments
# problematic european union member
# exact peripheral expertise awareness system
# organisational memory information systems
# monitoring temporal logic specifications combined
# graph transformation
# formal coalgebraic semantics
# information flow method
# automatically generated csp specifications
# embedded hardware description language
# state-based software components
# object-oriented action semantics specifications
# developing adaptive j2me applications
# distributed typed concurrent objects
# constant propagation
# reactive event-driven tuple space
# lazy cyclic reference counting
# aspect weaving strategies
# object oriented models
# asynchronous remote method invocation
# practical type inference
# dependently typed pattern matching
# parallel programming made simple
# structural case-based reasoning
# strong effects
# software maintenance
# experience base schema building blocks
# case-based reuse
# effective integration
# defining culture-bound user characteristics
# culture-sensitive knowledge management
# ontology-based knowledge retrieval
# ontology-based knowledge management systems
# managing organizational risk knowledge
# multiply hierarchical automaton semantics
# relativizing function classes
# software engineering process
# modeling spatial relations
# direct granularity conversions
# temporal reasoning
# structural symmetries detection
# propositional interval neighborhood temporal logics
# comparing farm maps
# modeling motion
# spatial accessibility reasoning
# reasoning
# inoteroperability testing approach
# introduce e-learning
# high level system design
# polynomial time-space complexity classes
# powerful model
# generation distributed component systems
# membrane computing
# fine computability
# democracy
# society caused
# bibliometric analysis
# mental model building
# intellectual capital management processes
# expert discovery
# fostering sustainable development
# ontology-based skills management
# fostering knowledge communication
# information overload
# efficient content-based
# topic map generation
# knowledge nodes
# instance cooperative memory
# usage-centered interface design
# automated retrieval
# software experience exploitation
# mobile user groups
# managing user focused access
# visualizing knowledge
# uml sequence diagrams
# bounded flooding routing algorithm
# heyting algebras
# interactive distance learning
# knowledge spaces
# unconstrained global optimization
# finding plagiarisms
# hd0l power series
# wordnet type synsets
# three-tier path-finder
# classifying spatial structures
# multiple dimensions
# reasoning
# autonomous mobile service robots
# mental models
# hyperlink structures based
# applying open hypermedia concepts
# structural computing
# interactive annotation
# hypermedia engineering
# context-sensitive hypertexts
# multimedia encyclopedia
# structured hypermedia documents
# hyperwave online employment service
# modelling agents
# synchronized context-free languages
# additive distances
# finding median partitions
# tree automata
# descriptional complexity
# simply normal numbers
# word operation closure
# shuffle decomposition
# codes defined
# finite automata
# finite-delay decodability
# infinite words
# single pentagonal tile
# symport rules
# finite automata
# disjunctive sequences
# constructing minimal acyclic deterministic finite automata
# rationally additive semirings
# disco toolset
# korrigan environment
# generating real
# declarative term graph attribution
# real-time analyzing
# open software architecture
# practical extension mechanism
# parameterized protocols
# modeling sequences
# diagram refinements
# efficient real-time model checking
# coalgebraic class specification language ccsl
# web-based in-service training system
# agent-oriented support environment
# synchronous efl writing environment
# collaborative learing discourse
# online writing platform
# message-minimizing load redistribution problem
# place/transition-net symmetry reduction method
# knowledge management
# computational geometry
# service management challenges
# computer science education
# 180 wrapped tubes
# graphics content
# issues
# teaching purposes
# internet
# content-based multimedia retrieval
# learning organization
# knowledge economy
# knowledge management
# discovering knowledge
# collaborative virtual environments
# metadata standards
# personal digital libraries
# soft spot
# siemens business services knowledge management framework
# knowledge society
# knowledge management
# systematic approach based
# teaching software engineering based
# transition
# ten years
# eclectic view
# vdm solo
# data distribution specification
# virtual university
# dt0l sequence equivalence problem
# messaging affect impression development
# neural abstract machine
# running sdl specifications
# automatic test sequence
# partial updates
# generalized forward simulation
# compiling abstract state machines
# abstract state machines
# abstract state machine specification
# generic np-hardness proof
# 21st century
# parikh matrix mapping
# efficient measure learning
# determinism
# collaborative tailoring
# simultaneous multithreaded processors
# price
# information society
# invisible workplace
# electronic structure computations
# continuous improvement
# design knowledge
# communicating x-machines systems
# conceptual model
# knowledge management
# rdbms-www interfaces
# protein folding algorithms
# light control case study
# light control case study
# light control case study
# light control case study
# light-control case study
# light control system
# efficient identification
# natural language
# kth-order nonhomomorphicity
# dynamic speculative thread partitioning
# switch blocking
# scheduled dataflow architecture
# real-time architectures
# grammar systems
# linear time
# active documents
# specification style
# cellular automata
# approximate quantified constraint solving
# switching map systems
# modeling information system behavior
# formal methods applied
# nondeterministic admissible interference
# pvs semantics
# formal specification
# motion planning problem
# functional reading
# verifying real-time systems
# ensuring termination
# weak inclusion systems
# lattice structure
# pi-calculus machine
# galois connections
# object-oriented algebraic specification
# quadratic pseudo-boolean functions
# monadic pavelka algebras
# enriched semiringal categories
# free-extendible prefix-free sets
# automorphism group
# n-valued lukasiewicz-moisil algebras
# canonical model construction
# computational complementarity
# sign
# simulating
# partially-ordered structures
# real world
# interaction-oriented tableau calculi
# automatic data restructuring
# average case performance
# group theoretical aspects
# floating point expansions
# multi-secret sharing schemes
# wireless communication environments
# probabilistic reasoning
# communicating stream x-machines systems
# issues related
# polynomial solution
# timed automata
# iterated case
# transformational approaches
# advanced fault tree modeling
# life time modelling
# bounded-weight error-correcting codes
# positive turing reductions
# multi-head surface mounting machines
# decision method
# information compression
# convex bodies
# algebraic solutions
# measurement uncertainty
# multimedia information products
# evaluating educational multimedia
# assessing computer-based knowledge-building communication processes
# shared design memory
# www-based learning systems
# perturbation simulations
# query order
# interactive electronic conference proceedings
# hypermedia webs assisted
# karp-lipton advice
# balanced pram simulations
# general nonperfect secret sharing schemes
# categorisation
# web search engines
# extensible web applications
# hybrid subdivision strategy
# relational database schema
# recovering structural design patterns
# database relation schema
# symbol ranking text compression
# programmable hardware
# extensible module types
# recursive abstract state machines
# constrained shortest path problem
# software development life cycle
# realistic programming languages
# formal specification
# asm specification
# correct compiler back-ends
# managing distributed data
# information technology
# organisational memories
# corporate memories
# complementary tools
# natural language documents
# supporting coordination
# informer text filtering agent
# automatic paperfolding sequences
# improving web-based training
# overflow detection logic
# cryptographic hash functions
# free space modeling
# highly nonlinear t-resilient functions
# monstr ii
# work-greedy assignment schemes
# stack filter design
# linear multisecret-sharing schemes
# multithreaded vliw architecture
# explicit forum
# kerberos authentication system
# abstract state machine semantics
# generalizing bias specifications
# structured parallel computation
# persistency
# constructive aspects
# strong reducibilities
# optimum extendible prefix codes
# minimal deterministic incomplete automata
# graph minor obstruction sets
# minor order obstructions
# representing variable-length codes
# invariance properties
# computably growing cantor sets
# completeness theorem
# sequential continuity
# imperfect information flow
# dortmund family
# optimal parallel algorithm
# constructing cryptographically strong substitution boxes
# integrated multimedia-based distance teaching
# design aspects -
# asic design
# media publishing
# heterogeneous information repositories
# monotone boolean functions
# disjunctive omega-words
# edge-flipping distance
# unified concept
# computer-supported human cooperation
# propagating partition-limited etol systems
# data compression
# delivering hypertext based courseware
# improving www-aided instruction
# curve fitting
# inexact information systems
# biological sequence comparison
# fundamental issues
# restricted splicing
# pseudosimple sets
# team cooperation
# maintaining referential integrity
# propagation characteristics
# network information system
# www
# internet gopher
# efficient distributed algorithm
# proving theorems
# digital libraries
# high-speed data path
# comparison
# error propagation
# lexicographic binary representation
# high radix on-line arithmetic
# directed interval arithmetic
# digit serial arithmetic
# formally correct implementation
# modular range reduction
# conditional tabled eco-grammar systems
# hypermedia objects
# software patents
# translation
# networked file systems
# personal computer
# aperiodic set
# contained hypermedia
# authoring
# constraint agents
# parikh prime words
# exploiting parallelism
# levels
# random string
# approximate quotient-digit estimation
# implementing erew work-optimally
# grammars based
# mediating scientific reasoning
# differential ziv-lempel text compression
# robust affine matching algorithm
# multi-objective genetic approach
# pareto-optimal hardware
# electronic hardware fault monitoring
# multi-objective evolutionary algorithms
# ds/cdma multiuser detection
# metric temporal logic
# reversible karatsuba
# exact domatic number problems
# health management utilizing pervasive technologies
# health monitoring
# real-time cardiac arrhythmias tele-assistance
# context-aware mobile medical devices
# behavioral monitoring technology
# collaborative biomedical research system
# pervasive multimodal tele-home healthcare system
# ubiquitous healthcare applications
# visualization services
# ambient intelligent environments
# reflective framework
# wireless sensor networks
# ambient intelligence applications
# ocp contextual information management system
# secure service discovery based
# web search engine monopoly
# modeling inheritance
# formal architectural description language based
# persian/arabic baffletext captcha
# logic programming languages
# generic process algebra
# java just-in-time compilers
# detecting bad smells
# program slicing
# visitor design pattern
# strong mobility
# object model
# expressing workflow patterns
# defining atomic composition
# type-safe versioned object query language
# large scale observation data
# data mining methods
# randomness
# pseudorandom number generation
# quantum computational cryptography
# formal languages implicitly represented
# randomized exponential-time algorithms
# randomized algorithms
# proving properties
# ridge orientation estimation
# fault tolerant neural predictors
# systems revisited
# interval constraint branching scheme
# constraint based methods
# process equivalences
# verifying real-time properties
# constructive failure
# crwl programs
# itp tool
# magic sets
# multi-adjoint logic programs
# plagiarism
# generalized hidden logics
# itai-rodeh leader election
# eliminating redundant join-set computations
# emerging communities shape
# distributed mutual exclusion algorithm
# structure causality relation
# user distributions algorithm
# fuzzy knowledge-base
# data-oriented web applications
# enum-based services
# proxy cache servers
# exact quality
# dynamic databases
# rule-based programming
# childhood acute lymphoid leukaemia
# analysing cropping systems
# geo-based interactive web portals
# neighborhood sequence
# student profile based flexible higher education
# mathematical models
# construction
# resource efficient maintenance
# graphical operating systems
# information theory approach
# human visual information processing
# primary school teachers
# kudo-mathuria time-release protocol
# optimal workflow structure
# complex it-based technological systems
# computer science
# medip-platform independent software system
# improve negotiations
# parameter estimation
# experience knowledge structure
# test point placement
# implementing rule-based automated price negotiation
# internet path behavior prediction
# hierarchical incomplete ordered partitions
# consensus determining
# auto response system
# sustainable memory system
# building immersive conversation environment
# real-time human proxy
# conversational knowledge circulation
# aes algorithm implementation
# robust motion estimation
# amcc self-timed microprocessor
# interleaved complementary sets
# performance evaluation
# partially reconfigurable implementation
# pipelining sequences
# formal methods
# formal methods
# floating-point verification
# model checking
# automated formal methods enter
# verification grand challenge
# formal methods
# software
# configure e-learning systems
# computing bounds
# emerging application development paradigm
# compile-time computation
# internet payment system
# cultural information system providing e-commerce web services
# access control
# achieving atomicity
# augment database management systems
# improving program correctness
# webquest framework
# educational modelling languages
# pipeline-scheduling simulator
# improving lo quality
# flexible educational units poeml
# creating online graduate engineering degrees
# handheld model editor
# designing collaborative learning environments
# mapping academic collaboration networks
# collaborative composition
# step mapping ims learning design
# modeling language
# constraint programming architectures
# object-oriented programming law conditions
# removing lalr
# aspect oriented programs
# visual language
# achieving reuse
# tabular abstractions
# concurrent lazy cyclic reference counting
# cyclic reference counting
# extensible languages
# higher-order lazy functional slicing
# closed worlds
# object-oriented action semantics
# web service selection based
# sophie choreography conceptual framework
# semantic-based skill management
# generative instructional engineering
# creating links
# reinforcement learning
# java programming courses
# information extraction application
# ehw approach
# hybrid fuzzy variable neighborhood particle swarm optimization algorithm
# genetic algorithm based recurrent fuzzy neural network modeling
# circuital implementation scheme
# computer forensics system based
# duplicate address detection
# adaptive hierarchical extension
# service routing
# energy-efficient voting-based clustering algorithm
# reactive ad hoc routing protocols
# compiling nonã‚â­strict functional languages
# constant size ciphertext hibe
# pedagogical natural deduction systems
# efficient access methods
# mobile sensemaking
# discrete particle swarm algorithm
# improved svm based
# machine learning-based keywords extraction
# immune gene expression programming
# spectral densest subgraph
# recent graph-theoretical contributions
# equivalent transformations
# gray code
# accepting networks
# constructing spanning trees
# treat unitarily
# graded sparse graphs
# asymptotic regularity
# -stable bipartite graphs
# spiking neural
# high-level structured interactive programs
# finite sets
# metric-entropy pairs
# signed networks
# topological grid graphs
# system level based
# self-evolving petri nets
# theoretical e-barter models
# perlman spanning tree protocol
# implementing ontology translation systems
# ontology-based content creation
# ranking rdf schema elements
# user keywords
# sewasie network
# support text mining
# asynchronous communication services
# supporting educators
# disconnected collaborative interaction
# integrating service-oriented mobile units
# pdas
# remote control approach
# evolving thematic clustering
# medieval document xml markup
# zoning mechanism applied
# off-line signature verification
# table-form extraction
# remove back-to-front interference
# arabic historical manuscripts
# binarize document images removing back-to-front interference
# progressive learning method
# optimistic fair exchange
# popular hash functions
# parallel key exchange
# oblivious transfer schemes
# bilateral unknown key-share attacks
# formal security definition
# certificateless public key encryption secure
# parallel formulations
# analyzing wiki-based networks
# linear time approximation algorithm
# success factors
# compensation models
# road networks based
# passive estimation
# communication bandwidth market
# bitstream access services
# enhancing zrtp
# broadband access
# optimal transit price negotiation
# dynamic bandwidth pricing
# normal copula model
# usability aspects
# communications ecosystem
# estimating traffic aggregation scenarios
# locally compact hausdorff spaces
# computable multi-functions
# subrecursive computability
# topological pressure
# bloch
# riemann integral
# optimal quadrature rules
# probabilistic computability
# weak limit spaces
# direct proof
# multiple explanations driven na&#239
# educational portal
# learning design solutions
# computer science education research literature
# formalizing agent-based english auctions
# ranking retrieval systems
# evaluating wireless communication systems resource allocation algorithms
# dynamic supply chain management
# ad hoc mobile networks
# structural performance evaluation
# query transformation based
# p2p data integration system
# futures market simulator
# model interpreter frameworks
# software product line techniques
# cots components based
# legacy information retrieval tool
# web services software architectures
# model-driven approach
# product derivation tool based
# develop web applications
# pre-apartness spaces
# binary methods programming
# custom specializers
# clim presentation types
# ambient object system
# common lisp
# qualitative temporal information
# nasdaq velocity
# supporting informal collaboration
# groupware user interfaces
# collaborative explicit plasticity framework
# space-design case study
# model transformation technology based
# testing website usability
# smart home
# ambient intelligence systems based
# weba
# large document collections
# guaranteeing seamless mobility
# meeting information management
# implementing multilayer perceptron
# digital journal
# learning object repository users
# searching
# macro design process
# formalizing media semantics
# content based retrieval
# information integration
# workflow language
# structure-based crawling
# data-intensiveweb pages
# exploring information extraction resilience
# recognising informative web page blocks
# software product lines
# abstract state machines
# timed abstract state machine language
# timed abstract state machines
# asm refinement preserving invariants
# service oriented architectures
# security protocols
# practical software adaptation techniques
# adaptation logic framework
# mismatching behavioural interfaces
# safe dynamic adaptation framework
# 0 multidevice user interfaces
# intelligence metasynthesis
# aps framework
# market microstructure patterns powering trading
# agent-based mobile payment systems
# efficient load distribution
# intelligent resource exchanges
# anti-crisis management
# prototype positioning system
# meta search agent system based
# tabu search
# multi-layer level set method
# fuzzy rule bases
# prize collecting steiner tree problem
# bus network optimization
# quantum-inspired evolutionary state assignment
# optimal sensor network layout
# mechanical design problems
# step swarm intelligence
# parallel strategies
# e-learning based
# intelligent decision support
# ibero-american countries
# interface development evaluation
# mobile phone adoption
# designing collaborative user interfaces
# accessible web applications
# cognitive ergonomics
# improving aeh courses
# spiral model
# domain modelling
# rich adaptive sequencing
# authoring social-aware tasks
# standards-based modelling approach
# authoring culture
# creating adaptive e-learning board games
# semantically annotated digital archives
# extensible characterisation languages
# crime scene representation
# author verification
# ultra low resolution words
# stacked dependency networks
# evaluation technique
# comparative aspects
# task modeling
# supporting featured user interface models
# prototyping-driven user interface specification
# gaze-based interaction
# displaying pictures
# relative virtual mouse controlled
# cves based
# design user interfaces
# museum web sites
# agent-based interactive systems
# interactive groupware systems
# spatial input task
# integrating dialog modeling
# adaptive hypermedia system applied
# align business processes
# parsing programs
# shortcut fusion
# lalr parser generator supporting conflict resolution
# high performance computer processor
# eliminating cycles
# exploring lua
# controlling aspect reentrancy
# extensible aspectj implementation
# raw types
# disentangling denotational semantics definitions
# formal action semantics
# algebraic laws
# adaptive educational hypermedia systems
# constructive notions
# information quality management maturity model
# treat unitarily
# online network-on-chip switch fault detection
# determining software investment lag
# adapting clinical ontologies
# business process models
# dynamic query optimization
# non-denumerable infinitary modal logic
# nonblocking concurrency
# weak functional dependencies
# model aries-based transaction processing
# global database design based
# semistructured data models
# formal framework
# coincidence ideals
# dynamic data warehouse design
# digital goods
# secure multimedia authentication
# heterogeneous multimedia networks
# topology change attack
# distributed denial-of-service attack traffic based
# danish newspapers
# providing multi source tag recommendations
# virtual 3d group interaction scripts
# modelling mailing list behaviour
# supporting composition
# structural coverage criteria
# fair non-repudiation protocol
# role based access control
# quadratic complexity bounds
# homomorphic cryptosystems
# dcm based orientation estimation algorithm
# ontology integration methodologies
# efficient data preprocessing procedure
# pareto-based multi-objective optimization algorithm
# multifaceted sequence patterns
# quantum-inspired immune algorithm
# robust road guidance sign recognition
# fingerprinting lexical contexts
# bayesian gene regulatory network inference optimization
# multi-sub-swarm particle swarm optimization
# scenario modeling framework
# personalized url re-ranking method
# agent migration
# access control infrastructure
# wireless sensor network
# full-round chess-64 cipher suitable
# protecting mobile tv multimedia content
# core security technologies
# pervasive palm vein authentication
# highly dynamic mobile ad hoc network
# neural network based vehicle classification system
# elementary computable topology
# finite-time computability preserving conversions
# symmetric hyperbolic systems
# effective tietze-urysohn theorem
# topological complexity
# representing measurement results
# fine-computable functions
# constructive urysohn universal metric space
# computable metric spaces
# np question
# ten thousand monkeys approach
# effective existence
# european perspective
# meta-modeling based approach
# learning objects pool
# aiml-based tutor
# virtual environment
# web application
# semantic spiral timelines
# language processing courses
# distributed computer assisted environment

# %%
rakeTitle
# Out:
# ['process-oriented structures',
#  'small groups learning synchronously online',
#  'knowledge sharing',
#  'implementing pre-built information spaces',
#  'tube map visualization',
#  'activity-based knowledge management approach',
#  'integrate technological',
#  'improving knowledge-intensive business processes',
#  'knowledge management solutions',
#  'modeling knowledge work',
#  'knowledge infrastructure hierarchy model',
#  'process oriented knowledge management',
#  'non-blocking concurrent queue algorithm',
#  'investigating atomicity',
#  'asynchronous communication mechanism',
#  'compensating business transactions',
#  'atomic broadcast',
#  'atomic manifesto',
#  'software development',
#  'first-class system provision',
#  'semi-automatic visual subgroup mining',
#  'visualizing recommendation flow',
#  'high-dimensional data',
#  'ubiquitous data mining',
#  'visual data exploration',
#  'uncertain dependencies',
#  'explore highly structured temporal data',
#  'scalable visual data exploration',
#  'physically locating wireless intruders',
#  'security level evaluation',
#  'reduced distortion lsb coding',
#  'cryptographic protocol intrusion detection',
#  'sliding window protocol',
#  'secure cryptographic hardware',
#  'rsa-based certified delivery',
#  'information source combinations space',
#  'low-intrusive consistent disk checkpointing',
#  'secured data transfer',
#  'gossip codes',
#  'information profiles',
#  'deds control synthesis method',
#  'complex systems development',
#  'collaborative web browsing based',
#  'language grounding problem',
#  'hybrid method',
#  'processing inconsistency',
#  'web systems user interfaces',
#  'provably efficient computational model',
#  'time costs',
#  'real-time control protocol',
#  'automatic test data generation',
#  'theoretical upper bound',
#  'fine-grained transclusions',
#  'fat cube topology',
#  'test automation framework',
#  'efficient verifiable shuffle based',
#  'exploiting agent ontologies',
#  'finite binary tree algorithm',
#  'model checking',
#  'fast t-decomposition algorithm',
#  'draw free trees inside bounded simple polygons',
#  'constructive approach',
#  'hardware design',
#  'implementation',
#  'dynamic aop approach',
#  'formal semantics',
#  'building web service interfaces',
#  'compiling nonâ\xadstrict functional languages',
#  'running lua scripts',
#  'java jit technology',
#  'signals',
#  'equational specification',
#  'purely functional language',
#  'learning decision trees',
#  'resource-aware mining',
#  'network attack scenarios extraction',
#  'web request streams',
#  'evaluating trigger conditions',
#  'dynamic data streams',
#  'incremental rule learning',
#  'positive roots',
#  'constructive suprema',
#  'uniform continuity theorem',
#  'self-adjoint operators',
#  'cellular automata universe',
#  'iterated rational functions',
#  'stone-yosida representation theorems',
#  'axiomatic classes',
#  'state space',
#  'nonrandom sequences',
#  'linear lattices',
#  'quotient spaces',
#  'constructive set theory',
#  'constructing programs',
#  'constructive aspects',
#  'regular formal spaces',
#  'functional dependencies',
#  'continuity',
#  'constructive results',
#  'hausdorff measure',
#  'mathematical objects determine',
#  'intermediate',
#  'constructive approach',
#  'effective fine space',
#  'modelling units',
#  'semantic web technologies applied',
#  'conceptual learning',
#  'ubiquitous computing',
#  'collaborative computer programming learning',
#  'virtual objects',
#  'learning activities',
#  'support asynchronous collaborative learning tasks',
#  'case studies',
#  'integrating ontologies',
#  'analyzing module diversity',
#  'coordinating behavioral descriptions',
#  'algebras',
#  'autonomous dynamic component composition',
#  'reo connector circuits',
#  'component-based actor language',
#  'personality-aware computer-human interfaces',
#  'situated models',
#  'user context aware delivery',
#  'web-based training systems',
#  'discovering student models',
#  'adaptive user',
#  'game-based learning',
#  'classroom-based learning',
#  'message-optimal distributed graph algorithm',
#  'rapid prototyping environment',
#  'securing web-based exams',
#  'facilitating knowledge exchange',
#  'knowledge centralization versus distribution',
#  'pizzarotti case study',
#  'ontology-based knowledge sharing system',
#  'participative process introduction',
#  'integrated technology perspective',
#  'chaos knowledge coproduction',
#  'organic perspectives',
#  'supporting knowledge creation',
#  'social capital',
#  'determinism',
#  'population',
#  'systems',
#  'complexity measures',
#  'maximum element',
#  'systems',
#  'fredkin gate',
#  'java simulator',
#  'efficient family',
#  'active membranes',
#  'large croatian enterprises',
#  'knowledge audit analysis',
#  'semantic-based approach',
#  'facilitating knowledge communication',
#  'semantic web technologies',
#  'research & development & transference process',
#  'social network analysis',
#  'sharing metadata',
#  'modelling lexical databases',
#  'search graph partitions',
#  'concept lattices',
#  'additive order diagrams',
#  'duquenne-guigues base',
#  'galois lattice theory',
#  'applying interval logic specifications',
#  'state models based',
#  'enterprise information systems',
#  'static global variable-ordering heuristic',
#  'accelerate sat-based combinational equivalence checking',
#  'improving sat-based bounded model checking',
#  'efficient sat search heuristics',
#  'signal correlation guided circuit-sat solver',
#  'coupling-based testing',
#  'multimedia software engineering',
#  'composition contracts',
#  'software dynamics',
#  'web components',
#  'developing multi-agent systems',
#  'process construction',
#  'multi-criteria preference analysis',
#  'document-oriented approach',
#  'digital libraries',
#  'object-oriented embedded system development based',
#  'symbolic approach',
#  'fast two-stage lempel-ziv lossless numeric telemetry data compression',
#  'hyperbolic 4d space',
#  'full hash table search',
#  'rewriting tissue',
#  'formal model',
#  'boolean functions',
#  'geometric retrieval',
#  'past temporal logic operators',
#  'semantic integration',
#  'coroutines',
#  'relational model',
#  'modular rewriting semantics',
#  'implementing coordinated error recovery',
#  'partial categorical multi-combinators',
#  'net clr',
#  'remote method invocation',
#  'total functional programming',
#  'drag-and-drop programming',
#  'extensible environment',
#  'improve reactive systems control',
#  'poset labelled graphs',
#  'mof-based metamodeling environment',
#  'parametric verification',
#  'platform modeling',
#  'proof environment',
#  'checking object system designs incrementally',
#  'formally correct functional programs',
#  'optimized temporal logic compilation',
#  'case study',
#  'real-time systems',
#  'program checking',
#  'fortran code optimization',
#  'translation validation',
#  'cross-disciplinary bibliography',
#  'multimedia information repository',
#  'future',
#  'dynamic visual information',
#  'fibonacci type coding',
#  'cyclical structure converter',
#  'heterogeneous audiovisual archives',
#  'automatic discovery',
#  'knowledge creation',
#  'converging knowledge management',
#  'strategy formulation process',
#  'computational problem solving',
#  'managing operation knowledge',
#  'process-oriented knowledge structuring',
#  'knowledge management',
#  'post-nonaka knowledge management',
#  'semantic grid',
#  'scbs social capital benchmarking system',
#  'pruning-based identification',
#  'integrated personnel development',
#  'individual knowledge',
#  'ontology-based semantic match',
#  'tool kit',
#  'practical knowledge-based approach',
#  'applying competence prerequisite structures',
#  'identifying employee competencies',
#  'integrative competence management',
#  'simulated learning environments',
#  'problematic european union member',
#  'exact peripheral expertise awareness system',
#  'organisational memory information systems',
#  'monitoring temporal logic specifications combined',
#  'graph transformation',
#  'formal coalgebraic semantics',
#  'information flow method',
#  'automatically generated csp specifications',
#  'embedded hardware description language',
#  'state-based software components',
#  'object-oriented action semantics specifications',
#  'developing adaptive j2me applications',
#  'distributed typed concurrent objects',
#  'constant propagation',
#  'reactive event-driven tuple space',
#  'lazy cyclic reference counting',
#  'aspect weaving strategies',
#  'object oriented models',
#  'asynchronous remote method invocation',
#  'practical type inference',
#  'dependently typed pattern matching',
#  'parallel programming made simple',
#  'structural case-based reasoning',
#  'strong effects',
#  'software maintenance',
#  'experience base schema building blocks',
#  'case-based reuse',
#  'effective integration',
#  'defining culture-bound user characteristics',
#  'culture-sensitive knowledge management',
#  'ontology-based knowledge retrieval',
#  'ontology-based knowledge management systems',
#  'managing organizational risk knowledge',
#  'multiply hierarchical automaton semantics',
#  'relativizing function classes',
#  'software engineering process',
#  'modeling spatial relations',
#  'direct granularity conversions',
#  'temporal reasoning',
#  'structural symmetries detection',
#  'propositional interval neighborhood temporal logics',
#  'comparing farm maps',
#  'modeling motion',
#  'spatial accessibility reasoning',
#  'reasoning',
#  'inoteroperability testing approach',
#  'introduce e-learning',
#  'high level system design',
#  'polynomial time-space complexity classes',
#  'powerful model',
#  'generation distributed component systems',
#  'membrane computing',
#  'fine computability',
#  'democracy',
#  'society caused',
#  'bibliometric analysis',
#  'mental model building',
#  'intellectual capital management processes',
#  'expert discovery',
#  'fostering sustainable development',
#  'ontology-based skills management',
#  'fostering knowledge communication',
#  'information overload',
#  'efficient content-based',
#  'topic map generation',
#  'knowledge nodes',
#  'instance cooperative memory',
#  'usage-centered interface design',
#  'automated retrieval',
#  'software experience exploitation',
#  'mobile user groups',
#  'managing user focused access',
#  'visualizing knowledge',
#  'uml sequence diagrams',
#  'bounded flooding routing algorithm',
#  'heyting algebras',
#  'interactive distance learning',
#  'knowledge spaces',
#  'unconstrained global optimization',
#  'finding plagiarisms',
#  'hd0l power series',
#  'wordnet type synsets',
#  'three-tier path-finder',
#  'classifying spatial structures',
#  'multiple dimensions',
#  'reasoning',
#  'autonomous mobile service robots',
#  'mental models',
#  'hyperlink structures based',
#  'applying open hypermedia concepts',
#  'structural computing',
#  'interactive annotation',
#  'hypermedia engineering',
#  'context-sensitive hypertexts',
#  'multimedia encyclopedia',
#  'structured hypermedia documents',
#  'hyperwave online employment service',
#  'modelling agents',
#  'synchronized context-free languages',
#  'additive distances',
#  'finding median partitions',
#  'tree automata',
#  'descriptional complexity',
#  'simply normal numbers',
#  'word operation closure',
#  'shuffle decomposition',
#  'codes defined',
#  'finite automata',
#  'finite-delay decodability',
#  'infinite words',
#  'single pentagonal tile',
#  'symport rules',
#  'finite automata',
#  'disjunctive sequences',
#  'constructing minimal acyclic deterministic finite automata',
#  'rationally additive semirings',
#  'disco toolset',
#  'korrigan environment',
#  'generating real',
#  'declarative term graph attribution',
#  'real-time analyzing',
#  'open software architecture',
#  'practical extension mechanism',
#  'parameterized protocols',
#  'modeling sequences',
#  'diagram refinements',
#  'efficient real-time model checking',
#  'coalgebraic class specification language ccsl',
#  'web-based in-service training system',
#  'agent-oriented support environment',
#  'synchronous efl writing environment',
#  'collaborative learing discourse',
#  'online writing platform',
#  'message-minimizing load redistribution problem',
#  'place/transition-net symmetry reduction method',
#  'knowledge management',
#  'computational geometry',
#  'service management challenges',
#  'computer science education',
#  '180 wrapped tubes',
#  'graphics content',
#  'issues',
#  'teaching purposes',
#  'internet',
#  'content-based multimedia retrieval',
#  'learning organization',
#  'knowledge economy',
#  'knowledge management',
#  'discovering knowledge',
#  'collaborative virtual environments',
#  'metadata standards',
#  'personal digital libraries',
#  'soft spot',
#  'siemens business services knowledge management framework',
#  'knowledge society',
#  'knowledge management',
#  'systematic approach based',
#  'teaching software engineering based',
#  'transition',
#  'ten years',
#  'eclectic view',
#  'vdm solo',
#  'data distribution specification',
#  'virtual university',
#  'dt0l sequence equivalence problem',
#  'messaging affect impression development',
#  'neural abstract machine',
#  'running sdl specifications',
#  'automatic test sequence',
#  'partial updates',
#  'generalized forward simulation',
#  'compiling abstract state machines',
#  'abstract state machines',
#  'abstract state machine specification',
#  'generic np-hardness proof',
#  '21st century',
#  'parikh matrix mapping',
#  'efficient measure learning',
#  'determinism',
#  'collaborative tailoring',
#  'simultaneous multithreaded processors',
#  'price',
#  'information society',
#  'invisible workplace',
#  'electronic structure computations',
#  'continuous improvement',
#  'design knowledge',
#  'communicating x-machines systems',
#  'conceptual model',
#  'knowledge management',
#  'rdbms-www interfaces',
#  'protein folding algorithms',
#  'light control case study',
#  'light control case study',
#  'light control case study',
#  'light control case study',
#  'light-control case study',
#  'light control system',
#  'efficient identification',
#  'natural language',
#  'kth-order nonhomomorphicity',
#  'dynamic speculative thread partitioning',
#  'switch blocking',
#  'scheduled dataflow architecture',
#  'real-time architectures',
#  'grammar systems',
#  'linear time',
#  'active documents',
#  'specification style',
#  'cellular automata',
#  'approximate quantified constraint solving',
#  'switching map systems',
#  'modeling information system behavior',
#  'formal methods applied',
#  'nondeterministic admissible interference',
#  'pvs semantics',
#  'formal specification',
#  'motion planning problem',
#  'functional reading',
#  'verifying real-time systems',
#  'ensuring termination',
#  'weak inclusion systems',
#  'lattice structure',
#  'pi-calculus machine',
#  'galois connections',
#  'object-oriented algebraic specification',
#  'quadratic pseudo-boolean functions',
#  'monadic pavelka algebras',
#  'enriched semiringal categories',
#  'free-extendible prefix-free sets',
#  'automorphism group',
#  'n-valued lukasiewicz-moisil algebras',
#  'canonical model construction',
#  'computational complementarity',
#  'sign',
#  'simulating',
#  'partially-ordered structures',
#  'real world',
#  'interaction-oriented tableau calculi',
#  'automatic data restructuring',
#  'average case performance',
#  'group theoretical aspects',
#  'floating point expansions',
#  'multi-secret sharing schemes',
#  'wireless communication environments',
#  'probabilistic reasoning',
#  'communicating stream x-machines systems',
#  'issues related',
#  'polynomial solution',
#  'timed automata',
#  'iterated case',
#  'transformational approaches',
#  'advanced fault tree modeling',
#  'life time modelling',
#  'bounded-weight error-correcting codes',
#  'positive turing reductions',
#  'multi-head surface mounting machines',
#  'decision method',
#  'information compression',
#  'convex bodies',
#  'algebraic solutions',
#  'measurement uncertainty',
#  'multimedia information products',
#  'evaluating educational multimedia',
#  'assessing computer-based knowledge-building communication processes',
#  'shared design memory',
#  'www-based learning systems',
#  'perturbation simulations',
#  'query order',
#  'interactive electronic conference proceedings',
#  'hypermedia webs assisted',
#  'karp-lipton advice',
#  'balanced pram simulations',
#  'general nonperfect secret sharing schemes',
#  'categorisation',
#  'web search engines',
#  'extensible web applications',
#  'hybrid subdivision strategy',
#  'relational database schema',
#  'recovering structural design patterns',
#  'database relation schema',
#  'symbol ranking text compression',
#  'programmable hardware',
#  'extensible module types',
#  'recursive abstract state machines',
#  'constrained shortest path problem',
#  'software development life cycle',
#  'realistic programming languages',
#  'formal specification',
#  'asm specification',
#  'correct compiler back-ends',
#  'managing distributed data',
#  'information technology',
#  'organisational memories',
#  'corporate memories',
#  'complementary tools',
#  'natural language documents',
#  'supporting coordination',
#  'informer text filtering agent',
#  'automatic paperfolding sequences',
#  'improving web-based training',
#  'overflow detection logic',
#  'cryptographic hash functions',
#  'free space modeling',
#  'highly nonlinear t-resilient functions',
#  'monstr ii',
#  'work-greedy assignment schemes',
#  'stack filter design',
#  'linear multisecret-sharing schemes',
#  'multithreaded vliw architecture',
#  'explicit forum',
#  'kerberos authentication system',
#  'abstract state machine semantics',
#  'generalizing bias specifications',
#  'structured parallel computation',
#  'persistency',
#  'constructive aspects',
#  'strong reducibilities',
#  'optimum extendible prefix codes',
#  'minimal deterministic incomplete automata',
#  'graph minor obstruction sets',
#  'minor order obstructions',
#  'representing variable-length codes',
#  'invariance properties',
#  'computably growing cantor sets',
#  'completeness theorem',
#  'sequential continuity',
#  'imperfect information flow',
#  'dortmund family',
#  'optimal parallel algorithm',
#  'constructing cryptographically strong substitution boxes',
#  'integrated multimedia-based distance teaching',
#  'design aspects -',
#  'asic design',
#  'media publishing',
#  'heterogeneous information repositories',
#  'monotone boolean functions',
#  'disjunctive omega-words',
#  'edge-flipping distance',
#  'unified concept',
#  'computer-supported human cooperation',
#  'propagating partition-limited etol systems',
#  'data compression',
#  'delivering hypertext based courseware',
#  'improving www-aided instruction',
#  'curve fitting',
#  'inexact information systems',
#  'biological sequence comparison',
#  'fundamental issues',
#  'restricted splicing',
#  'pseudosimple sets',
#  'team cooperation',
#  'maintaining referential integrity',
#  'propagation characteristics',
#  'network information system',
#  'www',
#  'internet gopher',
#  'efficient distributed algorithm',
#  'proving theorems',
#  'digital libraries',
#  'high-speed data path',
#  'comparison',
#  'error propagation',
#  'lexicographic binary representation',
#  'high radix on-line arithmetic',
#  'directed interval arithmetic',
#  'digit serial arithmetic',
#  'formally correct implementation',
#  'modular range reduction',
#  'conditional tabled eco-grammar systems',
#  'hypermedia objects',
#  'software patents',
#  'translation',
#  'networked file systems',
#  'personal computer',
#  'aperiodic set',
#  'contained hypermedia',
#  'authoring',
#  'constraint agents',
#  'parikh prime words',
#  'exploiting parallelism',
#  'levels',
#  'random string',
#  'approximate quotient-digit estimation',
#  'implementing erew work-optimally',
#  'grammars based',
#  'mediating scientific reasoning',
#  'differential ziv-lempel text compression',
#  'robust affine matching algorithm',
#  'multi-objective genetic approach',
#  'pareto-optimal hardware',
#  'electronic hardware fault monitoring',
#  'multi-objective evolutionary algorithms',
#  'ds/cdma multiuser detection',
#  'metric temporal logic',
#  'reversible karatsuba',
#  'exact domatic number problems',
#  'health management utilizing pervasive technologies',
#  'health monitoring',
#  'real-time cardiac arrhythmias tele-assistance',
#  'context-aware mobile medical devices',
#  'behavioral monitoring technology',
#  'collaborative biomedical research system',
#  'pervasive multimodal tele-home healthcare system',
#  'ubiquitous healthcare applications',
#  'visualization services',
#  'ambient intelligent environments',
#  'reflective framework',
#  'wireless sensor networks',
#  'ambient intelligence applications',
#  'ocp contextual information management system',
#  'secure service discovery based',
#  'web search engine monopoly',
#  'modeling inheritance',
#  'formal architectural description language based',
#  'persian/arabic baffletext captcha',
#  'logic programming languages',
#  'generic process algebra',
#  'java just-in-time compilers',
#  'detecting bad smells',
#  'program slicing',
#  'visitor design pattern',
#  'strong mobility',
#  'object model',
#  'expressing workflow patterns',
#  'defining atomic composition',
#  'type-safe versioned object query language',
#  'large scale observation data',
#  'data mining methods',
#  'randomness',
#  'pseudorandom number generation',
#  'quantum computational cryptography',
#  'formal languages implicitly represented',
#  'randomized exponential-time algorithms',
#  'randomized algorithms',
#  'proving properties',
#  'ridge orientation estimation',
#  'fault tolerant neural predictors',
#  'systems revisited',
#  'interval constraint branching scheme',
#  'constraint based methods',
#  'process equivalences',
#  'verifying real-time properties',
#  'constructive failure',
#  'crwl programs',
#  'itp tool',
#  'magic sets',
#  'multi-adjoint logic programs',
#  'plagiarism',
#  'generalized hidden logics',
#  'itai-rodeh leader election',
#  'eliminating redundant join-set computations',
#  'emerging communities shape',
#  'distributed mutual exclusion algorithm',
#  'structure causality relation',
#  'user distributions algorithm',
#  'fuzzy knowledge-base',
#  'data-oriented web applications',
#  'enum-based services',
#  'proxy cache servers',
#  'exact quality',
#  'dynamic databases',
#  'rule-based programming',
#  'childhood acute lymphoid leukaemia',
#  'analysing cropping systems',
#  'geo-based interactive web portals',
#  'neighborhood sequence',
#  'student profile based flexible higher education',
#  'mathematical models',
#  'construction',
#  'resource efficient maintenance',
#  'graphical operating systems',
#  'information theory approach',
#  'human visual information processing',
#  'primary school teachers',
#  'kudo-mathuria time-release protocol',
#  'optimal workflow structure',
#  'complex it-based technological systems',
#  'computer science',
#  'medip-platform independent software system',
#  'improve negotiations',
#  'parameter estimation',
#  'experience knowledge structure',
#  'test point placement',
#  'implementing rule-based automated price negotiation',
#  'internet path behavior prediction',
#  'hierarchical incomplete ordered partitions',
#  'consensus determining',
#  'auto response system',
#  'sustainable memory system',
#  'building immersive conversation environment',
#  'real-time human proxy',
#  'conversational knowledge circulation',
#  'aes algorithm implementation',
#  'robust motion estimation',
#  'amcc self-timed microprocessor',
#  'interleaved complementary sets',
#  'performance evaluation',
#  'partially reconfigurable implementation',
#  'pipelining sequences',
#  'formal methods',
#  'formal methods',
#  'floating-point verification',
#  'model checking',
#  'automated formal methods enter',
#  'verification grand challenge',
#  'formal methods',
#  'software',
#  'configure e-learning systems',
#  'computing bounds',
#  'emerging application development paradigm',
#  'compile-time computation',
#  'internet payment system',
#  'cultural information system providing e-commerce web services',
#  'access control',
#  'achieving atomicity',
#  'augment database management systems',
#  'improving program correctness',
#  'webquest framework',
#  'educational modelling languages',
#  'pipeline-scheduling simulator',
#  'improving lo quality',
#  'flexible educational units poeml',
#  'creating online graduate engineering degrees',
#  'handheld model editor',
#  'designing collaborative learning environments',
#  'mapping academic collaboration networks',
#  'collaborative composition',
#  'step mapping ims learning design',
#  'modeling language',
#  'constraint programming architectures',
#  'object-oriented programming law conditions',
#  'removing lalr',
#  'aspect oriented programs',
#  'visual language',
#  'achieving reuse',
#  'tabular abstractions',
#  'concurrent lazy cyclic reference counting',
#  'cyclic reference counting',
#  'extensible languages',
#  'higher-order lazy functional slicing',
#  'closed worlds',
#  'object-oriented action semantics',
#  'web service selection based',
#  'sophie choreography conceptual framework',
#  'semantic-based skill management',
#  'generative instructional engineering',
#  'creating links',
#  'reinforcement learning',
#  'java programming courses',
#  'information extraction application',
#  'ehw approach',
#  'hybrid fuzzy variable neighborhood particle swarm optimization algorithm',
#  'genetic algorithm based recurrent fuzzy neural network modeling',
#  'circuital implementation scheme',
#  'computer forensics system based',
#  'duplicate address detection',
#  'adaptive hierarchical extension',
#  'service routing',
#  'energy-efficient voting-based clustering algorithm',
#  'reactive ad hoc routing protocols',
#  'compiling nonã‚â\xadstrict functional languages',
#  'constant size ciphertext hibe',
#  'pedagogical natural deduction systems',
#  'efficient access methods',
#  'mobile sensemaking',
#  'discrete particle swarm algorithm',
#  'improved svm based',
#  'machine learning-based keywords extraction',
#  'immune gene expression programming',
#  'spectral densest subgraph',
#  'recent graph-theoretical contributions',
#  'equivalent transformations',
#  'gray code',
#  'accepting networks',
#  'constructing spanning trees',
#  'treat unitarily',
#  'graded sparse graphs',
#  'asymptotic regularity',
#  '-stable bipartite graphs',
#  'spiking neural',
#  'high-level structured interactive programs',
#  'finite sets',
#  'metric-entropy pairs',
#  'signed networks',
#  'topological grid graphs',
#  'system level based',
#  'self-evolving petri nets',
#  'theoretical e-barter models',
#  'perlman spanning tree protocol',
#  'implementing ontology translation systems',
#  'ontology-based content creation',
#  'ranking rdf schema elements',
#  'user keywords',
#  'sewasie network',
#  'support text mining',
#  'asynchronous communication services',
#  'supporting educators',
#  'disconnected collaborative interaction',
#  'integrating service-oriented mobile units',
#  'pdas',
#  'remote control approach',
#  'evolving thematic clustering',
#  'medieval document xml markup',
#  'zoning mechanism applied',
#  'off-line signature verification',
#  'table-form extraction',
#  'remove back-to-front interference',
#  'arabic historical manuscripts',
#  'binarize document images removing back-to-front interference',
#  'progressive learning method',
#  'optimistic fair exchange',
#  'popular hash functions',
#  'parallel key exchange',
#  'oblivious transfer schemes',
#  'bilateral unknown key-share attacks',
#  'formal security definition',
#  'certificateless public key encryption secure',
#  'parallel formulations',
#  'analyzing wiki-based networks',
#  'linear time approximation algorithm',
#  'success factors',
#  'compensation models',
#  'road networks based',
#  'passive estimation',
#  'communication bandwidth market',
#  'bitstream access services',
#  'enhancing zrtp',
#  'broadband access',
#  'optimal transit price negotiation',
#  'dynamic bandwidth pricing',
#  'normal copula model',
#  'usability aspects',
#  'communications ecosystem',
#  'estimating traffic aggregation scenarios',
#  'locally compact hausdorff spaces',
#  'computable multi-functions',
#  'subrecursive computability',
#  'topological pressure',
#  'bloch',
#  'riemann integral',
#  'optimal quadrature rules',
#  'probabilistic computability',
#  'weak limit spaces',
#  'direct proof',
#  'multiple explanations driven na&#239',
#  'educational portal',
#  'learning design solutions',
#  'computer science education research literature',
#  'formalizing agent-based english auctions',
#  'ranking retrieval systems',
#  'evaluating wireless communication systems resource allocation algorithms',
#  'dynamic supply chain management',
#  'ad hoc mobile networks',
#  'structural performance evaluation',
#  'query transformation based',
#  'p2p data integration system',
#  'futures market simulator',
#  'model interpreter frameworks',
#  'software product line techniques',
#  'cots components based',
#  'legacy information retrieval tool',
#  'web services software architectures',
#  'model-driven approach',
#  'product derivation tool based',
#  'develop web applications',
#  'pre-apartness spaces',
#  'binary methods programming',
#  'custom specializers',
#  'clim presentation types',
#  'ambient object system',
#  'common lisp',
#  'qualitative temporal information',
#  'nasdaq velocity',
#  'supporting informal collaboration',
#  'groupware user interfaces',
#  'collaborative explicit plasticity framework',
#  'space-design case study',
#  'model transformation technology based',
#  'testing website usability',
#  'smart home',
#  'ambient intelligence systems based',
#  'weba',
#  'large document collections',
#  'guaranteeing seamless mobility',
#  'meeting information management',
#  'implementing multilayer perceptron',
#  'digital journal',
#  'learning object repository users',
#  'searching',
#  'macro design process',
#  'formalizing media semantics',
#  'content based retrieval',
#  'information integration',
#  'workflow language',
#  'structure-based crawling',
#  'data-intensiveweb pages',
#  'exploring information extraction resilience',
#  'recognising informative web page blocks',
#  'software product lines',
#  'abstract state machines',
#  'timed abstract state machine language',
#  'timed abstract state machines',
#  'asm refinement preserving invariants',
#  'service oriented architectures',
#  'security protocols',
#  'practical software adaptation techniques',
#  'adaptation logic framework',
#  'mismatching behavioural interfaces',
#  'safe dynamic adaptation framework',
#  '0 multidevice user interfaces',
#  'intelligence metasynthesis',
#  'aps framework',
#  'market microstructure patterns powering trading',
#  'agent-based mobile payment systems',
#  'efficient load distribution',
#  'intelligent resource exchanges',
#  'anti-crisis management',
#  'prototype positioning system',
#  'meta search agent system based',
#  'tabu search',
#  'multi-layer level set method',
#  'fuzzy rule bases',
#  'prize collecting steiner tree problem',
#  'bus network optimization',
#  'quantum-inspired evolutionary state assignment',
#  'optimal sensor network layout',
#  'mechanical design problems',
#  'step swarm intelligence',
#  'parallel strategies',
#  'e-learning based',
#  'intelligent decision support',
#  'ibero-american countries',
#  'interface development evaluation',
#  'mobile phone adoption',
#  'designing collaborative user interfaces',
#  'accessible web applications',
#  'cognitive ergonomics',
#  'improving aeh courses',
#  'spiral model',
#  'domain modelling',
#  'rich adaptive sequencing',
#  'authoring social-aware tasks',
#  'standards-based modelling approach',
#  'authoring culture',
#  'creating adaptive e-learning board games',
#  'semantically annotated digital archives',
#  'extensible characterisation languages',
#  'crime scene representation',
#  'author verification',
#  'ultra low resolution words',
#  'stacked dependency networks',
#  'evaluation technique',
#  'comparative aspects',
#  ...]

# %% [markdown]
# ### Rake Keyword

# %%
rakeKeyword = setRakeInPreWords(rakeKeyword)
# Out:
# cooperative knowledge generation
# computer-supported cooperative learning
# micro-didactical learning arrangement
# modelling method
# knowledge visualization
# knowledge management
# inter-organizational networked businesses
# knowledge modeling description language
# knowledge management
# knowledge management instrument
# knowledge management
# knowledge management service
# formal proof
# formal development method
# asynchronous communication
# ing transactions
# atomic broadcast
# formal methods
# software development
# transactional memory
# subgroup mining
# visualizing information flow
# grand tour methods
# data mining
# visual data exploration
# data mining
# interactive information visualization
# visual data exploration
# intrusion detection system
# public key infrastructure
# audio steganography
# cryptographic protocol abuse
# ad hoc network
# evolutionary computation
# certified delivery
# multi-agent systems
# digital  forensics
# data protection
# multimedia information system
# distributed databases
# discrete event dynamic systems
# software life cycle
# web browsing
# language grounding
# information retrieval
# inconsistent knowledge
# user interfaces
# spatiotemporal data modeling
# actor computations
# rtcp scalability
# automatic test data generation
# global routing
# xanalogical structure
# fat cube topology
# automated testing
# public-key system
# intelligent agent technology
# hash function
# actor model
# computable complexity measures
# computational geometry
# structural operational semantics
# hardware description languages
# virtual machines
# dynamic aspects
# memory management
# programming languages
# languages interoperability
# common language runtime
# dynamic compilation
# distributive laws
# executable semantics
# mobile computation
# incremental decision trees
# data mining
# network security
# web usage mining
# streaming time series
# data streams
# decision rules
# polynomial equations
# partially ordered set
# constructive mathematics
# computable functional analysis
# halting probability omega
# constructive analysis
# formal topology
# intuitionistic logic
# banach algebra
# algorithmic information theory
# lattice theory
# formal topology
# constructive set theory
# process algebra
# markov chains
# regular formal topologies
# functional dependencies
# constructive mathematics
# constructive mathematics
# iterated function system
# constructive analysis
# intuitionistic real analysis
# constructive geometry
# effective fine space
# educational modelling language
# hypermedia systems
# authoring tool
# ubiquitous computing
# computer programming teaching
# virtual object
# learning environments
# computer-supported collaborative learning
# web-based services
# learning objects
# selector namespaces
# process algebra
# software formal specification
# service oriented architecture
# probabilistic constraint automata
# actor model
# myers-briggs type indicator
# situated learning
# user context-aware retrieval
# user interface design
# learning objects
# user modeling
# collaborative learning
# learning
# distributed algorithm
# rapid prototyping
# web-based exam
# learning management system
# intellectual capital
# distributed knowledge management
# knowledge sharing community
# distributed participative process evolution
# enterprise content management
# case study
# knowledge nebula crystallizer
# knowledge management
# tacit knowledge
# membrane computing
# membrane computing
# membrane computing
# natural computing
# natural computing
# systems
# fredkin gate
# system
# bin packing problem
# natural computing
# strategic human resource management
# social network analysis
# skill matching
# knowledge communication
# case-based reasoning
# knowledge management
# social network analysis
# knowledge sharing
# formal concept analysis
# formal concept analysis
# concept lattices
# automatic diagram layout
# implication base
# autonomous mobile robotics
# on-the-fly model checking
# communicating sequential processes
# automated reasoning
# backtrack search
# static logic implications
# binary decision diagrams
# binary decision diagrams
# boolean equivalence checking
# object-oriented software
# multimedia systems
# architectural connectors
# data reverse engineering
# portal applications
# agent-oriented software engineering
# software process
# multi-criteria preference analysis
# domain-specific markup languages
# active document
# embedded system design
# process algebra
# neural networks
# cellular automata
# full table scatter storage techniques
# computational universality
# operational semantics
# boolean function
# multi-dimensional data structures
# temporal data warehouse
# information source integration
# control structures
# coordination models
# rewriting logic
# coordinated atomic actions
# functional programming
# language interoperability
# tactics definition language
# functional programming
# software development
# program transformation
# reactive systems
# architecture
# model driven architecture
# parametric verification
# model-based development
# theorem proving
# multi-object logic
# constructive program development
# temporal logic
# reliability
# formal verification
# implementation correctness
# dummy aliasing
# translation validation
# language independent communication
# language independent communication
# wearable pc
# visual languages
# cellular automata
# information source integration
# audiovisual archive
# named entity extraction
# distributed knowledge management
# knowledge management
# strategy process
# collaborative knowledge management architecture
# knowledge management system
# key word based search
# knowledge management
# knowledge management optimization factors
# knowledge engineering
# social capital
# knowledge management
# knowledge management system
# individual knowledge
# knowledge representation
# role construct repertory test
# human resource planning
# skill management
# knowledge space theory
# resource based view
# simulated learning environment
# skills management
# knowledge management
# competence management
# run-time execution monitoring
# domain-specific modeling languages
# system level design language
# admissible interference
# formal specification
# domain-specific languages
# software components
# formal semantics
# aspect-oriented programming
# distributed computing
# constant propagation
# distributed systems
# garbage collection
# aspect-oriented programming
# ocl
# asynchronous remote method invocation
# programming languages
# dependent types
# fuctional programming
# knowledge management
# knowledge management
# software maintenance
# schema building blocks
# software reuse
# knowledge strategy
# academic style
# decentral knowledge management
# information retrieval
# information retrieval
# risks management
# coordination
# polynomial-time hierarchy
# object-oriented software engineering
# elliptical route descriptions
# temporal constraints
# allen temporal relations
# medial axis transform
# interval temporal logic
# spatial structure analysis
# autonomous mobile robot navigation
# qualitative spatial reasoning
# qualitative spatial reasoning
# formal testing
# managed learning
# abstract state machines
# implicit computational  complexity
# knowledge management
# robust globally unique handles
# molecular computing
# computable analysis
# cyber ethics
# information society
# intellectual capital report
# search histories
# knowledge management
# knowledge management
# knowledge transfer
# skills management
# knowledge management
# knowledge management
# image data repository model
# topic maps
# distributed knowledge management
# cooperative memory relevance feedback
# user interface design
# information retrieval
# process improvement
# knowledge work processes
# knowledge portal
# digital video library
# formal semantics
# atm vp optimal route provision
# formal languages
# computer supported learning strategies
# european research funding
# affine arithmetic
# string tiling
# formal power series
# synset id
# search control rules
# object-based knowledge representation
# multi-dimensional spatial reasoning
# time
# robot teams human machine interface
# mental model
# software engineering
# open hypermedia
# structural computing
# content-based multimedia retrieval
# hypermedia engineering
# systemic functional linguistics
# natural language processing
# xml-based document notation
# online employment services
# multi-agent systems
# formal languages
# words
# categorical attributes
# tree automata
# descriptional complexity
# invariance properties
# word operation
# regular language
# petri nets
# finite automata
# decoding delay
# ultimately periodic infinite
# hyperbolic plane
# molecular computing
# finite automata
# dense sets
# minimal acyclic deterministic finite automata
# fixed point
# reactive systems
# computer-aided software engineering
# program synthesis
# declarative attribute grammars
# formal verification
# process control event diagram
# universal presburger arithmetic
# parameterized systems
# formal program derivation
# temporal logic
# interactive theorem proving
# binary methods
# training program assessment
# collaborative learning environment
# computer assisted language learning
# collaborative learning
# web-based  learning environments
# high performance computing
# petri nets
# knowledge management
# point set data base
# service management
# computer science
# surface reconstruction
# digital libraries
# software/program verification
# algorithm animation
# internet security
# content-based search
# multimedia information systems
# information society
# human resources
# information visualization
# computer supported collaborative work
# learning technology standardization
# information systems
# knowledge portal
# information systems
# knowledge management
# knowledge management
# test-case generation
# software engineering
# formal methods
# formal methods
# constructive mathematics
# reverse engineering
# high performance computing
# mixed mode teaching
# lindenmayer system
# ation processing model
# abstract state machines
# abstract state machines
# test sequence generation
# abstract state machine
# abstract state machines
# abstract state machines
# abstract state machines
# shared memory
# computational complexity
# hyperwave information server
# parikh matrix mapping
# learning theory
# alternating turing machines
# tailoring
# mpeg-2 video decompression
# reconfigurable computing
# information society
# information systems
# electronic structure computations
# operations support system
# knowledge based sysem
# communicating x-machine systems
# world wide web
# knowledge management
# server api
# protein folding
# light control
# formal verification
# real-time temporal logic
# requirements engineering
# light control system
# requirements engineering
# learning theory
# natural language
# boolean functions
# control structure performance
# competitive analysis
# multithreaded architectures
# real-time systems
# formal languages
# linear time
# web based teaching
# formal specification
# hyperbolic plane
# interval computation
# switching map systems
# petri nets
# comparative case study
# information flow properties
# open distributed systems
# formal specification
# motion planning
# logic programming
# algebraic specification methods
# functional programming
# category theory
# wajsberg algebra
# abstract machine
# galois connection
# behavioural equivalence
# pseudo-boolean functions
# monadic pavelka algebra
# abstract data type
# prefix-free set
# automorphism group
# n-valued lukasiewicz-moisil algebra
# substructural logics
# complementarity principles
# boolean logic
# splicing rule
# semiring
# random bits
# automated deduction
# normal form databases
# logic design
# reversible computing
# exact arithmetic
# secret sharing schemes
# wireless networks
# probabilistic reasoning
# communicating stream x-machines system
# picture language
# cellular automata
# timed automata
# dna computing
# fault tolerance
# fault tree
# computer generation
# error-correcting codes
# positive turing reductions
# multi-head surface mounting machine
# duration calculus
# post  canonical system
# interval arithmetic
# extended interval arithmetic
# co-ordinate measure machine
# content analysis
# design experiment
# collaborative learning
# shared design memory
# electronic learning systems
# rounding errors
# query order
# digital video  multimedia information systems-evaluation/methodology
# information retrieval
# computational complexity
# balanced workload
# secret sharing scheme
# information retrieval
# user interface  retrieval
# web dynamic pages
# adaptive integration software
# relation schema
# design patterns
# database relation schema
# text compression
# rapid prototyping
# extensible module types
# abstract state machines
# constrained shortest path problem
# abstract state machines
# abstract state machines
# abstract state machines
# abstract state machines
# abstract state machine
# information filtering
# knowledge work processes
# organisational memory
# corporate memory
# shared workspaces
# natural language processing
# coordination mechanisms
# text filtering
# uniform tag system
# evaluation techniques
# computer science education
# discretionary security policy
# free space
# boolean function
# term graph rewriting
# dependency graphs
# distributed computation
# error-correcting codes
# pram
# negative results
# abstract state machine
# abstract state machines
# interval arithmetic
# categorical data type
# term rewriting system
# dirichlet problem
# chaitin
# optimum extendible prefix code
# incomplete automata
# order logic
# graph minors
# variable-length codes
# invariance properties
# computable maps
# kripke models
# sequential continuity
# arrow logic
# hypermedia model
# computational learning theory
# differential attack
# integrated electronic documents
# distance education
# asic design
# multimedia development
# distributed agent system
# monotone boolean functions
# number representations
# edge-flipping operation
# distance teaching
# computer supported cooperative work
# parallel rewriting systems
# recursive code
# parallel computing
# multimedia information systems [evaluation/methodology
# computer algebra systems
# linguistic approach
# biological sequence comparison
# term graph rewriting
# dna recombination
# extensionally bounded function
# formal languages
# distributed information system
# boolean functions
# information system
# world-wide web
# distributed information systems
# distributed graph algorithms
# differential geometry
# digital libraries
# high speed multipliers
# networked information systems
# floating point arithmetic
# computer arithmetic
# on-line arithmetic
# interval algebraic manipulation
# redundant digit sets
# computer arithmetic
# computer arithmetic
# artificial life
# distributed hypermedia
# software patents
# term graph rewriting
# networked file systems
# electronic assistants
# discrete mathematics
# hypermedia data modeling
# electronic courseware
# distributed problem solving
# context free languages
# parallel constraint satisfaction
# access control
# blank-endmarker complexity
# approximate digit estimates
# shared memory
# shuffle operation
# computers
# text compression
# affine matching
# multi-objective optimization
# genetic algorithms
# genetic programming
# circuit design problems
# code division multiple access
# formal specification
# reversible computing
# exact domatic number
# human information processing
# multiagent systems
# wireless ecg sensor
# mobile devices
# smart-home technology
# computerized patient records
# pervasive computing
# ubiquitous computing
# ubiquitous computing
# intelligent environments
# ambient intelligence
# wireless sensor networks
# ambient intelligence
# semantic web
# service discovery protocol
# web mining
# algebraic specification
# component based software engineering
# completely automated public turing test
# dynamic compilation
# process algebra
# dynamic compilation
# aspect oriented software development
# program slicing
# context free grammar
# mobile computation
# object model
# workflow patterns
# nonsequential automata
# object-oriented database management systems
# particle filter
# data mining
# security
# random number generation
# computational cryptography
# binary decision diagrams
# exact computation
# randomized complexity classes
# behavioural specifications
# gabor filter
# data compression
# dna computing
# interval constraint
# constraint handling rule grammars
# concurrent process equivalences
# timed concurrent constraint paradigm
# constructive failure
# functional logic programming
# inductive theorem proving
# logic programming
# fuzzy logic programming
# similarity detection
# behavioral equivalence relation
# distributed computing
# compiler optimization
# collaborative work
# mutual exclusion
# petri nets
# user distribution
# fuzzy datalog
# mvc design pattern
# 164 telephone number
# proxy cache server
# image classification
# data-flow languages
# java
# seasonal decomposition time series method
# crop model
# web-based services
# database retrieval
# feature driven model construction
# nonlinear differential equation
# image processing
# ad hoc networks
# graphical operating systems
# parameter estimation
# visual information processing
# information society
# time-release cryptography
# network synthesis
# production information engineering
# computer science
# medical image processing
# negotiation thread
# system identification
# knowledge representation formalism
# discrete event system
# electronic commerce transaction
# network behavior prediction
# hierarchical incomplete ordered partition
# consensus theory
# speech interface
# sustainable knowledge globe
# conversational locomotion network
# avatar-based communication
# knowledge acquisition
# dynamic total reconfiguration
# real-time image processing
# asynchronous microprocessor
# compression techniques
# image processing
# dynamic reconfiguration
# loop pipelining
# formal methods
# formal methods
# formal methods
# formal methods
# formal methods
# verification grand challenge
# formal methods
# formal methods
# learning scenario
# real root isolation
# web 2
# polytime computable functions
# payment systems
# integrated information system
# access control
# web services
# databases
# exception handling
# education technologies
# ims ld
# forbidden latency list
# learning objects
# educational modeling language
# online degree
# handheld devices
# collaborative learning
# human factors
# collaborative learning
# ims learning design
# specification language
# nt programming
# programming law conditions
# lalr parsing
# aspect-oriented programming
# visual programming
# dynamic aspects
# spreadsheet languages
# concurrent garbage collection
# memory management
# application programming interfaces
# program slicing
# open world approaches
# formal semantics
# web service selecti
# semantic services
# skill management
# competence development programmes
# citation index
# reinforcement learning
# information science education
# named entity extraction
# evolvable hardware
# particle swarm optimization
# recurrent fuzzy neural network
# analog signal processing circuit
# artificial immune systems
# manet
# ad hoc routing
# ad hoc network
# sensor network
# mobile ad hoc networks
# languages interoperability
# hierarchical identity-based encryption
# mathematical logic
# video databases
# computer supported learning
# polygonal approximation
# support vector machine
# support vector machine
# gene expression programming
# densest subgraph
# polycyclic aromatic hydrocarbons
# sequential behaviours
# gray code
# evolutionary processor
# minimum spanning tree
# generalized wajsberg algebra
# computational geometry
# metric fixed point theory
# fully indecomposable matrix
# membrane computing
# distributed termination protocols
# balancing signed graphs
# modular lattice
# graph theory
# topological grid graph
# hardware software co-design
# petri nets
# formal methods
# formal methods
# ontology language
# semantic web
# schema ranking
# semantic web
# distributed databases
# semantic web
# synchronous collaboration
# semantic web services
# interactive situation model
# web services platform
# electronic meetings
# collaboration scripts
# text segmentation
# medieval documents
# character recognition
# signature verification
# table-form recognition
# document engineering
# arabic historical color manuscript image
# document engineering
# conditional discriminant analysis
# public key cryptography
# cryptography
# key exchange
# oblivious transfer
# bilateral unknown key-share resilience
# authenticated key exchange
# malicious kgc attack
# elliptic curve cryptography
# social software
# ruler folding problem
# user generated content
# interactive advertising
# continuous nearest neighbor
# passive performance measurements
# bandwidth market
# bitstream access service
# computational puzzle
# web-based multimedia services
# interdomain prices
# network economics
# communications networks
# zrtp
# business objective
# network planning
# riesz representation theorem
# computable analysis
# lower elementary functions
# hift dynamical systems
# computability
# weak analysis
# real computational complexity
# computable analysis
# higher type computation
# fan theorem
# case-based reasoning
# server-side java technology
# educational modelling languages
# computer science education
# multi-agent system
# distributed information retrieval
# dynamic channel allocation algorithms
# supply chain management
# knowledge discovery agent
# multi-agent system
# semantic social network
# agent system
# reinforcement learning
# software architecture
# software product line
# cots selection
# reverse engineering
# software architecture
# aspect oriented software development
# software product lines
# web applications
# pre-apartness spaces
# binary methods
# generic function
# common lisp
# context-oriented programming
# object-relational mapping
# temporal reasoning
# stock market data analysis
# real-time interaction
# model based design
# model-based approach
# model-driven development
# automatic code generation
# usabaipo heuristic method
# ubiquitous computing
# collaborative model
# human computer interaction
# support vector machines
# finite truncated model
# meeting information system
# neural networks
# decision making
# community building
# search engines
# instructional design support tool
# multimedia semantics
# social media platform
# information extraction
# web information systems
# web crawling
# web page classification
# information extraction
# information extraction
# asm
# abstract state machines
# abstract state machines
# abstract state machine
# abstract state machines
# process mediation
# protocol goal
# software composition
# software adaptation
# behavioural interfaces
# extended state machines
# adaptation techniques
# open complex intelligent systems
# web browsing assistant
# market microstructure pattern
# mobile agent
# divided cache scope
# multi-agent planning
# city traffic modelling
# fingerprinting method
# information searching
# graphics hardware
# curve evolution
# genetic fuzzy systems
# prize collecting steiner tree problem
# bus network scheduling problem
# finite state machine
# sensor networks
# genetic algorithm
# feature selection problem
# vlsi cell placement
# multi-agent system
# decision support systems
# human-computer interaction
# cognitive ergonomics
# computer-supported cooperative work
# computer interaction
# development supporting tools
# user interface design
# adaptive educational hypermedia
# adaptive educational hypermedia
# intelligent tutoring systems
# ims learning design
# hypermedia authoring
# semantic web
# adaptive educational hypermedia
# game based learning
# document image analysis
# digital libraries
# neural networks
# author verification
# ultra low resolution text recognition
# document structuring
# document image processing
# image processing
# task modeling
# group awareness
# user interface design
# eye tracking
# intelligent user interface
# human computer interaction
# collaborative virtual environments
# workflow information systems
# virtual visit
# human-computer interaction
# model-based development
# user interfaces
# model-based user interface design
# interactive learning environments
# business process modeling
# presentation-oriented editing
# shortcut fusion
# automatic conflict removal
# instruction scheduling
# garbage collection
# preemptive multithreading
# aspect-oriented programming
# aspect-oriented programming
# aspect-oriented programming
# programming languages
# unified modeling language
# software product lines
# adaptive hypermedia system
# constructive
# information quality management maturity model
# mv algebra
# functional fault model
# software development
# clinical ontologies
# business processes
# access limitations
# infinitary modal logic
# shared memory
# weak functional dependency
# abstract state machines
# database design
# semistructured data
# oltp-olap specification frame
# complex values
# abstract state machine
# content superdistribution
# design principle
# multimedia communication networks
# file sharing application
# network monitoring
# business models
# digital resources
# collaboration patterns
# open source projects
# aspect-oriented programming
# test adequacy criteria
# intellectual property rights contracts
# role based access control
# real root isolation
# probability encryption
# orientation estimation
# ontology integration
# support vector clustering
# offspring generation scheme
# computation-oriented pattern definition model
# hybrid flow shop scheduling
# sign detection
# golden ontology
# genetic algorithms
# particle swarm optimization
# multi-agent system
# user browsing
# mobile agent
# access control infrastructure
# wireless sensor network
# block cipher
# digital rights management
# intelligent security framework
# vascular pattern
# mobile ad hoc networks
# neural network
# computable analysis
# sliding block functions
# hyperbolic system
# computable analysis
# type-2 theory
# computable analysis
# fine-computable function
# urysohn universal space
# computable metric space
# bss machines
# ordinary differential equations
# computatable functional analysis
# e-learning territories
# model-driven development
# learning objects repository
# intelligent tutoring systems
# virtual environment
# learning styles
# visualization
# syntax trees
# intelligent tutoring system

# %%
rakeKeyword
# Out:
# ['generation community cooperative knowledge wiki structure process',
#  'cooperative learning workplace training assurance study empirical professional quality',
#  'information system agent learning weblog pedagogical space wiki arrangement',
#  'filtering collaborative management business method introduction modelling knowledge ontology information process retrieval',
#  'communication visualization visual storytelling management metaphor project knowledge information',
#  'knowledge management workflow',
#  'networked collaborative management business network knowledge',
#  'management business knowledge modeling description language process',
#  'research market management business knowledge software tool enterprise process',
#  'activity management business stance instrument knowledge theory modeling work infrastructure process',
#  'management system knowledge data base information',
#  'service management knowledge process',
#  'refinement prover formal atomicity proof concurrency',
#  'observability refinement formal atomicity method development',
#  'communication atomicity verification relaxation algebra process asynchronous',
#  'formal ing semantics compensation specification method transaction language',
#  'system replication broadcast quorum atomic isolation',
#  'programming formal atomicity hardware method dependability transaction language',
#  'atomicity software development transaction monitor ocl uml concurrency',
#  'atomicity coherence transactional cache memory',
#  'visualization analysis subgroup mining data',
#  'visualizing reputation social network flow information',
#  'visual grand curve tour analysis method clustering andrew data exploratory',
#  'data visualization mining icon',
#  'exploration visual segment mining connecting data',
#  'decision incompletely diagram mining minimization function',
#  'domain visualization temporal medical interactive data information',
#  'exploration visualization visual technique data multiresolution',
#  'intrusion system wireless antenna detection',
#  'public key security evaluation policy fuzzy technique infrastructure',
#  'audio lsb steganography coding data hiding',
#  'protocol intrusion cryptographic security computer detection abuse',
#  'ad routing hoc protocol performance communication network dsr secure group',
#  'algorithm genetic computation cryptography evolutionary',
#  'certified fair protocol exchange security delivery',
#  'system agent information quality',
#  'consistency system backup operating digital file snapshot forensics checkpointing',
#  'management algorithm key security pad secrecy protection theory data information perfect',
#  'system multimedia digital coding theory library information',
#  'database market manager game strategy distributed theory information resource',
#  'control ded system event dynamic synthesis discrete',
#  'life complex adaptable system cycle software architecture',
#  'collaborative web browsing ontology work',
#  'cognitive communication grounding agent formula satisfaction language modal logic',
#  'rosa adaptive system web mining recommendation information personalization retrieval',
#  'consensus method knowledge conflict inconsistent',
#  'hybrid consensus user system adaptation method interface',
#  'database high dimensionality query structure spatiotemporal modeling range data',
#  'parallel constraint execution computation time actor implementation',
#  'communication protocol rtcp management multimedia scalability distributed',
#  'generation testing algorithm genetic flow software automatic data test',
#  'routing algorithm circuit cad global integrated',
#  'authoring xanalogical system multimedia transclusions application structure hypermedia publishing',
#  'interconnection fat cube communication network router collective architecture topology',
#  'testing formal automated specification software',
#  'privacy system verifiable paillier huffles',
#  'b2c agent ontology technology intelligent',
#  'tree uowhf binary function hash',
#  'system modular verification reactive abstraction checking actor technique model',
#  'entropy complexity computable parsing measure',
#  'free computational tree geometry skeleton graph straight annealing simulated drawing',
#  'programming semantics modularity structural action operational language',
#  'programming generation hardware circuit structure description functional arithmetic language logic',
#  'coroutines closure virtual machine ables compiler hash',
#  'mop lua reflection aspect dynamic aop',
#  'collection management garbage semantics finalization memory',
#  'programming formal web semantics service language',
#  'programming net functional virtual haskell interoperability language machine compiler',
#  'bytecodes virtual runtime common language machine compiler',
#  'optimization dynamic compilation compiler',
#  'dataflow computation comonads function law stream distributive',
#  'formal analysis semantics equational specification executable program',
#  'programming computation haskell functional language mobile',
#  'drift decision tree incremental concept data stream',
#  'computing mining clustering data stream',
#  'resolution intrusion security network detection logic',
#  'analysis web mining browsing pattern usage semantic',
#  'prediction trigger qos streaming time series service quality model',
#  'algorithm mining data stream change',
#  'drift decision classification learning incremental concept rule data stream',
#  'root polynomial positive equation bound',
#  'set supremum constructive mathematics ordered partially',
#  'uniform constructive mathematics reverse continuity',
#  'computable functional analysis',
#  'cellular automaton omega probability halting',
#  'rational analysis constructive function iteration',
#  'riesz formal constructive mathematics space axiom choice topology',
#  'logic ultrapower filter kripke ultraproduct prime disjoint saturated iterated bisimulation intuitionistic union model',
#  'element hermitian constructive mathematics banach positive state space algebra',
#  'randomness set algorithmic binary theory sequence information random',
#  'analysis proof decidability theory lattice',
#  'locale formal constructive predicativit quotient coequalisers topology',
#  'principle set partial constructive realizability combinatory theory brouwerian algebra',
#  'constructive determinism process algebra',
#  'markov chain constructive',
#  'regular formal relation positivity space real topology',
#  'compl axiomatisation functional attribute dependency',
#  'continuity constructive mathematics',
#  'constructive operator mathematics hilbert theory space',
#  'simple attractor system function deterministic cantor hausdorff space language iterated fractal measure',
#  'rational analysis constructive function iteration',
#  'intermediate real intuitionistic theorem',
#  'geometry constructive ordered sylvester conjecture',
#  'weakly fine computability effective function limiting space recursion sequence',
#  'collaborative unit learning modelling object educational language',
#  'system multimedia web xml service hypermedia semantic',
#  'learning conceptual interactive tool authoring exercise',
#  'aware interaction computing context ubiquitous implicit rfid',
#  'programming animation collaborative learning simulation computer teaching program',
#  'lcm learning web ims object virtual lom tool museum service scorm authoring campus',
#  'cognitive environment learning diagnosis tool library tracing error authoring model',
#  'collaborative computing learning domotics pda mobile',
#  'multimedia computer internet service education',
#  'metadata collaborative annotation learning object ontology',
#  'virtual module package classboxes java selector ruby namespaces class',
#  'coordination modular expressiveness embedding process algebra',
#  'formal composition specification object software',
#  'autonomous code manipulation aspect intermediate dynamic common service net language runtime architecture assertive programming oriented web composition component weaving',
#  'markov decision probabilistic constraint coordination reo composition automaton bisimulation process',
#  'system modular rebeca verification reactive actor component model',
#  'type interaction indicator mbti',
#  'learning metadata elearning situated',
#  'user learning object ontology retrieval',
#  'user management design interaction training knowledge factor pattern interface',
#  'user context learning object',
#  'adaptive user learning elearning modeling cscl model',
#  'motivation collaborative learning game education constructivism',
#  'learning teaching personalisation',
#  'directed task algorithm constraint graph scheduling distributed precedence',
#  'performance system embedded prediction flow rapid scheduling prototyping data',
#  'assessment fraud security exam supervision prevention',
#  'community management system network learning practice broker',
#  'organizational mental market community retrospective capital rationality bounded knowledge practice intellectual constructivism model',
#  'community management knowledge distributed node',
#  'community sharing web knowledge semantic',
#  'participative evolution learning indigo introduction improvement distributed inspection process',
#  'community management content intranet extranet knowledge practice enterprise technology information personalization',
#  'siemens community volkswagen telekom practice deutsche case study wiko net expert',
#  'crystallizer community management nebula organic knowledge livingom practice liquidization perspective crystallization',
#  'community management discovery web knowledge practice visualisation semantic',
#  'trust community etiquette social norm tacit knowledge sociability explicit practice online capital',
#  'computational system computing membrane completeness determinism',
#  'computability differentiation computing membrane division cell turing bonding',
#  'communication antiport evolution system computing membrane symport',
#  'natural computing entropy system',
#  'system computing membrane maximum natural',
#  'universality inhibitor system promoter',
#  'reversibility gate system fredkin conservative logic',
#  'simulation java system parallelism',
#  'recognizer system complexity problem computing membrane bin packing clip class',
#  'natural computing membrane distributed',
#  'human competitive management integration knowledge advantage strategic resource',
#  'audit analysis social network flow map knowledge inventory',
#  'knowledge skill elicitation description matching logic',
#  'communication visualization interaction joint knowledge evasion refusal disavowal',
#  'management reasoning web knowledge semantic',
#  'research management analysis knowledge development university process',
#  'research sharing management community social analysis network collaboration knowledge strategy sustainability practice distributed implementation localisation expert applied',
#  'metadata agreement knowledge sharing',
#  'database formal relation analysis lexical concept semantic',
#  'formal analysis bipartite graph search concept breadth',
#  'information web mining concept credo lattice retrieval',
#  'diagram automatic layout lattice',
#  'base implication computational complexity',
#  'mobile autonomous visual formal analysis localization landmark computer vision concept robotics galois lattice orientation',
#  'interval fil graphical tableau logic temporal future method buechi specification automaton verification automatic checking gil model',
#  'formal mac hine method communicating sequential abstract notation uml process',
#  'formal set reasoning heuristic automated specification theory otter',
#  'ordering partitioning decision formal heuristic sat search bdds backtrack cnf variable verification',
#  'equivalence formula sat boolean implication static checking propositional satisfiability combinational cec logic',
#  'decision reachability analysis diagram bounded sat bdds binary checking satisfiability bmc model',
#  'dag decision diagram heuristic bounded binary checking state satisfiability machine model',
#  'equivalence boolean checking atpg satisfiability',
#  'software coverage testing',
#  'multimedia framework system component',
#  'interaction computing coordination composition web architectural connector software architecture service',
#  'rewriting engineering reverse migration rule data pattern',
#  'portlets portal web development application service',
#  'agent system methodology engineering software intelligent',
#  'design software method process',
#  'resolution negotiation inconsistency management analysis winwin requirement preference conflict',
#  'evolution modular software development processor markup approach language xml maintenance',
#  'list repository search conceptual library document black white active visualization future annotation knowledge digital hyperwave link searching',
#  'system design embedded object_oriented application_specific processor synthesis highlevel instruction',
#  'protocol formal method noninterference bisimulation symbolic process algebra',
#  'neural prediction network compression lossless',
#  'cellular hyperbolic plane automaton',
#  'table root mod full cyclic scatter primitive storage collision strategy prime residue technique group hash',
#  'computational system rewriting grammar tissue universality matrix',
#  'operational semantics',
#  'function decomposition boolean equation',
#  'indexing system grid file structure data spatial model',
#  'database temporal warehouse relational algebra data logic',
#  'interschema integration source xml information property',
#  'control coroutines lua generator structure language',
#  'coordination coalgebra relation model',
#  'programming rewriting semantics modularity ml concurrent language logic',
#  'programming handling separation exception concern coordinated distributed action atomic',
#  'programming substitution combinators explicit functional categorical',
#  'language reflection scripting interoperability',
#  'middleware programming tactic distributed language definition',
#  'programming functional',
#  'programming visual environment design software development redwood tool snippet',
#  'programming transformation framework refactoring tool java generative program',
#  'system design modular reactive action concurrency',
#  'graph refinement abstraction architecture',
#  'driven computing graph transformation architecture model',
#  'protocol timed verification parametric',
#  'graph transformation computation verification software development model',
#  'refinement proving theorem',
#  'model temporal system design modelling object verification checking logic',
#  'programming ultra reasoning constructive equational transformation specification development heapsort functional program',
#  'temporal simulation verification logic',
#  'reliability verification',
#  'formal capture constraint diagram requirement specification verification',
#  'generation program code checking generator architecture correctness implementation compiler certificate',
#  'aliasing dummy optimization verification alias',
#  'sgi validation translation voc optimizing optimization condition verification global rule pro permutation compiler',
#  'communication independent visual sign map archiving interactive language constructed information retrieval',
#  'constructed communication independent visual multimedia converging archiving language technology information retrieval',
#  'future societal computer implication pc technology display wearable',
#  'communication visual multimedia movie map archiving dynamic interactive language information abstract retrieval',
#  'hyperbolic cellular plane automaton tiltings',
#  'system cooperative interschema integration source information property',
#  'user archive profile engine search query semantic thesaurus mpeg audiovisual faethon personalization',
#  'corpus management relation entity knowledge mining map text topic extraction named semantic',
#  'management complexity structuration knowledge practice cognitivism distributed theory communites heterogeneity evolutionary semantic constructivism',
#  'management training knowledge scenario',
#  'signal filter strategy weak process',
#  'research collaborative management algorithmic flow knowledge measurement opencps architecture',
#  'metal industry management system knowledge kaon ontology',
#  'carrier context search map navigator topic structure bearer key browsing process domain word visualization based engine knowledge assistant modeling management business tool base',
#  'benefit management knowledge measurement balanced scorecard',
#  'workplace knowledge optimization factor km worker ashen demand',
#  'planning production jess knowledge engineering rule ontology xml base workflow',
#  'capital capability management social resource knowledge intellectual cluster benchmarking',
#  'management pruning computing knowledge structural ontology',
#  'management system project pilot knowledge skill development competence personnel',
#  'customer integration knowledge explicit intuition collective individual process capital',
#  'management matchmaking knowledge skill representation ontology',
#  'repertory learning measurement role organisational theory personal construct test',
#  'database human management planning updating project skill resource',
#  'management elearning skill hypermedia personalised',
#  'human repertory management competency grid knowledge skill development theory space approach case study technique resource',
#  'profiling based transfer management knowledge skill view competence resource',
#  'environment assessment learning knowledge skill solving structure simulated problem',
#  'portugal management training skill export education',
#  'management groupware knowledge expertise awareness',
#  'organisation management knowledge competence ontology organisational memory group',
#  'logic temporal system execution rapid prototyping checking monitoring model',
#  'formal graph computing transformation specification grammar modeling architecture language',
#  'coalgebra formal system design algebraic semantics specification behavior level denotational language',
#  'admissible protocol denial service bisimulation interference',
#  'formal translator csp specification grammar uml model',
#  'hardware embedded description language',
#  'semantics software coalgebra component',
#  'formal semantics specification action',
#  'programming separation software concern aop application architecture adaptability',
#  'computing distributed mobile resource',
#  'analysis code graph predicated optimization ia',
#  'programming system distributed space tuple',
#  'reference collection management counting garbage cycle memory',
#  'programming',
#  'xmi xmlshema ocl xml uml',
#  'programming method distributed invocation remote asynchronous',
#  'programming polymorphic type inference recursion language',
#  'dependent type dml pattern matching',
#  'programming parallelism petri fuctional net language',
#  'management reasoning web knowledge ontology xml semantic',
#  'leadership management corporate knowledge culture',
#  'management knowledge software ontology maintenance',
#  'repository reuse management building knowledge block schema base experience',
#  'reuse reasoning casebased software retrieval',
#  'check project integration business knowledge strategy measurement km diagnostics',
#  'dimension user academic discourse cultural learning evaluation style software adaptivity modeling structure',
#  'decentral management bosch knowledge index culture',
#  'management retrieval knowledge representation ontology information logic',
#  'refinement query ontology information retrieval',
#  'planning knowledge risk management',
#  'coordination fibration iwim automaton',
#  'hierarchy separation oracle function class',
#  'user modelling engineering software experimental study interface intelligent',
#  'human cognition system navigation description elliptical perspective route spatial',
#  'temporal constraint granularity abstraction time',
#  'interval approximate temporal possibility relation reasoning fuzzy theory allen necessity measure',
#  'transform medial reasoning axis shape representation recognition spatial qualitative',
#  'interval tableau temporal system axiomatic logic',
#  'agronomy classification reasoning analysis graph description structure hierarchical spatial logic',
#  'programming autonomous temporal reasoning constraint integration qualitative navigation robot mobile spatial logic',
#  'reasoning biology bayesian molecular spatial accessibility qualitative',
#  'rcc gi reasoning spatial data semantic qualitative',
#  'protocol testing formal compliance interoperability wap',
#  'wbt managed constructionist learning',
#  'system analysis design method computation specification state machine abstract model',
#  'computational complexity predicative recursion implicit class',
#  'document management agent system knowledge data base information intelligent',
#  'dinopolis middleware componentware system relation network handle object aspect distributed java globally component transparency unique robust',
#  'hierarchy chomsky computing rewriting membrane molecular splicing',
#  'computable analysis walsh',
#  'legislation cyber speech freedom ethic internet',
#  'mobility society telecommunication internet technology information',
#  'network knowledge map intellectual relational report capital',
#  'information history search informatics legal retrieval',
#  'capability management situated learning prior knowledge absorptive interchange dynamic intellectual organisational capacity capital',
#  'management collaboration knowledge natural distributed language acquisition',
#  'transfer sustainable network knowledge recycling agency company development taxonomy',
#  'skill rdf ontology management',
#  'knowledge transfer tool management',
#  'ignorance overload management agent knowledge positive intelligent information',
#  'database repository query image operation data model',
#  'corpus management relation knowledge mining map text topic semantic',
#  'management context knowledge epistemology distributed node',
#  'based instance user cooperative feedback learning relevance query modeling memory information expansion retrieval',
#  'call user management design interaction knowledge pattern center interface',
#  'retrieval thesaurus internet information gazetteer',
#  'learning improvement systematic process experience',
#  'management system knowledge work information process',
#  'portal integration knowledge ontology information',
#  'visualization metadata collage video summarization digital extraction library',
#  'formal method pvs semantics uml',
#  'routing system management network vp atm qos optimal hierarchical route provision',
#  'language lattice formal automaton',
#  'communication based mediated web training learning strategy computer supported',
#  'research funding computing web grid knowledge european technology semantic',
#  'interval algorithm inclusion optimization function global arithmetic affine bound branch',
#  'similarity string search plagiarism tiling token',
#  'formal system power d0l lindenmayer series',
#  'synset wordnet id cluster',
#  'island control finding search rule route',
#  'analysi relation classification reification knowledge topological representation landscape',
#  'reasoning disjunction spatial qualitative',
#  'interval time granularity',
#  'human hmi autonomous team telerobotics scheduling job service machine xml robot mobile problem interface',
#  'mental animation presentation dynamic model',
#  'system methodology engineering software development language hypermedia',
#  'system support trail navigation hypermedia open',
#  'computing structural architecture hypermedia open',
#  'system multimedia web mpeg hypermedia service xml semantic retrieval',
#  'programming design engineering hypermedia functional technique',
#  'coherence relation context linguistics modelling systemic functional hypertext authoring',
#  'information software development natural language processing retrieval',
#  'document structuring hypermedia notation',
#  'negotiation employment online interactive service',
#  'formal system coordination pattern model',
#  'computational decision formal complexity synchronized grammar language problem',
#  'word',
#  'partitioning shannon entropy algorithm genetic partition index clustering gini median attribute categorical',
#  'tree set product automaton complete',
#  'formal nondeterminism complexity ambiguity cellular parser automaton pushdown descriptional software reliability language finite',
#  'randomness invariance property',
#  'residual closure operation dense base',
#  'regular nx decomposition product src language shuffle img',
#  'net formal code petri language',
#  'finite automaton synchronization',
#  'regular transducer delay decodability decoding decidability channel language unique',
#  'disjunctive ultimately word uniformly periodic recurrent infinite random',
#  'hyperbolic plane tiling',
#  'computational antiport computing membrane symport molecular universality',
#  'domain synchronization complexity composition automaton function functional finite',
#  'entropy set complexity subword dense language',
#  'minimal algorithm acyclic construction automaton deterministic finite',
#  'power semiring complete series point iteration fixed',
#  'tla animation formal system specification reactive tool time real',
#  'software library engineering',
#  'reusable proof software synthesis program',
#  'generation term graph grammar declarative attribute traversal program',
#  'formal system analysis verification checking model',
#  'logic control formal diagram event verification development checking tool controller process model',
#  'decision integer universal formal verification augmentation lemma affnization presburger speculation arithmetic procedure',
#  'system parameterized ws1s verification abstraction checking model',
#  'programming derivation equivalence formal system modelling relview relational algebra class program',
#  'tla refinement temporal diagram verification abstraction logic',
#  'logic proving temporal program algebraic structured invariant proof optimization specification verification checking interactive correctness technique theorem model',
#  'coalgebra method specification binary modal logic',
#  'distance assessment system learning training teacher education program',
#  'situation environment history collaborative learning learner personal coordinator',
#  'call corpus voice learning learner transmission computer assisted language',
#  'visual collaborative learning representational language bias',
#  'writin call corpus environment linguistics learning efl',
#  'performance parallel load computing high balancing processor',
#  'computational complexity petri net symmetry',
#  'environmental knowledge poverty world information',
#  'computational combinatorial geometry set skeleton triangulation polygonal point data base',
#  'management network telecommunication ip service',
#  'woman computer curriculum breadth education science',
#  'surface geometry design reconstruction differential',
#  'graphical document graphic computer digital electronic recognition library pattern information',
#  'reusable transformation verification software synthesis compiler program',
#  'animation algorithm system multimedia annotation capturing presentation education recording authoring',
#  'internet security',
#  'database management search knowledge mpeg retrieval',
#  'automation system social multimedia behavioral office science information',
#  'sustainable economy european society knowledge development information union',
#  'human superorganisms management system knowledge organization resource',
#  'visualization visual management interaction content knowledge medium digital library information paradigm',
#  'environment collaborative management capture knowl computer virtual edge supported information work',
#  'learning metadata standardization technology',
#  'management system knowledge digital library information personalization',
#  'portal knowledge ontology',
#  'management information knowledge system',
#  'cognitive management creativity learning elearning knowledge',
#  'knowledge management',
#  'refinement generation testing formal method calculus',
#  'engineering software method formal',
#  'formal method semantics vdl operational denotational language vdm definition',
#  'formal method engineering software support tool vdm',
#  'logic constructive topos modelling mathematics theory vdm intuitionistic',
#  'programming semantics engineering reverse denotational slicing algebra',
#  'performance distribution parallel computing high architecture distributed memory data',
#  'computer virtual mode material university delivery mixed education teaching',
#  'equivalence system decidability lindenmayer problem',
#  'nonverbal communication cue social messaging frequency ation development impression duration processing inform model',
#  'neural network computation distributed state machine abstract',
#  'formal sdl semantics specification fdt asm description state language machine technique abstract',
#  'generation testing formal method test state machine sequence abstract',
#  'synchronous asml thesis parallelism partial update asm state machine abstract submachines',
#  'proving diagram dynamic theorem logic refinement commuting proof state cerification data transition machine refine compiler system interactive ment abstract simulation correctness forward',
#  'falko state machine abstract',
#  'logic specification dynamic state foundation language machine abstract modal',
#  'cache shared multiprocessor memory',
#  'computational complexity graph education',
#  'transclusion hyperwave server information',
#  'injectivity matrix parikh mapping',
#  'learning theory',
#  'computational counting complexity alternating computation theory machine turing class',
#  'cscw tailoring groupware',
#  'simultaneous control multithreading multimedia smt video speculation mpeg extension decompression',
#  'routing complexity computing reconfigurable fpga hardware resource',
#  'information society complexity',
#  'management system computing society computer education information',
#  'chemistry academic undergraduate computing computation curriculum electronic structure',
#  'collaborative system embedded methodology knowledge operation portfolio continuous management business improvement reverse tool os education model',
#  'scientific visualization visual system based construction knowledge language information',
#  'communication system communicating concurrent channel',
#  'hierarchy focus model wide glass context web teleportation search visualisation navigation conceptual world structuring hypermedia treeworld relevance',
#  'visualization management system environmetal knowledge data base information',
#  'gateway sql performance server cgi www java rdbms api',
#  'algorithm approximation folding hp protein lattice model',
#  'light refinement control requirement asm case study',
#  'formal requirement specification verification engineering software tool technique',
#  'formal temporal requirement specification problem logic',
#  'refinement formal system embedded requirement specification engineering',
#  'light control formal system execution requirement specification simulation prototyping modeling language',
#  'engineering requirement pvs specification',
#  'learning theory',
#  'par production alignment mdl sing compression language multiple syntax mml natural unification information',
#  'nonhomomorphicity boolean function cryptanalysis cryptography',
#  'control performance analysis design architecture aid multiprocessor structure',
#  'performance competitive synchronization analysis algorithm lock spinning producer_consumer blocking time waiting',
#  'decoupled superscalars dataflow latency architecture memory multithreaded',
#  'system multithreading rapid msparc prototyping',
#  'regulated programmed formal system rewriting grammar language',
#  'computational complexity time linear incompleteness',
#  'wbt based management web elearning knowledge teaching',
#  'notation specification formal structure',
#  'hyperbolic cellular plane automaton tessellation',
#  'interval computational constraint computation uncertainty logic',
#  'horseshoe system smale map henon switching baker',
#  'generation system code petri constraint behavior dynamic net information',
#  'protocol leader formal comparative election network method standard study case concurrency',
#  'information model noninterferen program security flow specification verification confidentiality intransitive technique property ce',
#  'formal system method pvs specification distributed uml open',
#  'pre formal invariant modelling specification heapsort dependency',
#  'complex geometry planning path optimisation motion',
#  'programming program transformation method embedding functional algebraic logic',
#  'formal system method specification verification algebraic',
#  'programming analysis interpretation termination functional abstract',
#  'theory category logic',
#  'monoid mv residuated wajsberg boolean lattice center algebra',
#  'graphical img process semantics calculus representation src concurrent net machine multiset abstract',
#  'connection frequent set item closure support galois extended',
#  'behavioural equivalence coherence hidden algebra',
#  'set horn boolean binary optimization function truth',
#  'monadic pavelka algebra',
#  'category parallel semiringal type network enriched relation mixed program data abstract algebra',
#  'kraft set inequality',
#  'graph hypercube permutation automorphism group',
#  'mvn algebra',
#  'logic relevant semantics substructural implication strict canonical linear model',
#  'principle graph complementarity automaton shift sofic finite',
#  'logic boolean thought language algebra',
#  'system universal computation rule splicing model',
#  'semiring',
#  'randomness source extractor function random hash bit',
#  'tableau transformation automated proof presentation search calculus deduction',
#  'instantiated database set solution restructuring form structure data hierarchical normal',
#  'algorithm analysis design simulation logic',
#  'reversible computing theory permutation group',
#  'computational geometry precision exact division arithmetic multiple floating point library expansion',
#  'randomness sharing security scheme secret data cryptography',
#  'computing network caching www wireless mobile proxy',
#  'probabilistic reasoning alignment compression multiple unification information',
#  'testing system communicating specification software state language matrix processing stream',
#  'language synchronisation picture product',
#  'hyperbolic complexity cellular plane automaton theory',
#  'parallel decomposition automaton timed partition state clock',
#  'language computing tree dna',
#  'fault transformation specification tolerance verification failure model',
#  'markov tree cision fault shannon diagram petri binary approach net de',
#  'life generation uniform composition method computer ratio time procedure',
#  'solution algorithm code heuristic exact experimental',
#  'np computational complexity positive turing reduction',
#  'surface algorithm genetic pcb time machine mounting assembly',
#  'tableau method automated calculus duration deduction',
#  'multiple theory canonical machine turing alignment paradigm',
#  'interval commutative body quasilinear semigroups isomorphic operation embedding space arithmetic convex minkowski',
#  'interval solution transformation equation extended arithmetic algebraic',
#  'interval computing modelling mathematical uncertainty machine measure',
#  'analysis multimedia content evaluation application review',
#  'multimedia methodology design evaluation computer curriculum education science',
#  'collaborative reasoning analysis learning implication piagetian theory conditional transcript',
#  'organizational system design learning evaluation shared memory information',
#  'system assessment learning educational electronic',
#  'rounding method polynomial chebyshev evaluation perturbation error',
#  'hierarchy commutative order separation complexity computation polynomial query ordered downward class',
#  'proceeding conference multimedia medium map video digital electronic navigation hypermedia hypertext information publishing',
#  'neural network navigation hypertext information retrieval',
#  'computational complexity',
#  'coated tree mesh ocpc workload simulation shared balanced memory moving randomized erew thread',
#  'nonperfect scheme secret sharing',
#  'categorisation web search text navigation hypertext information retrieval',
#  'visualization user document presentation result ranking interface information retrieval',
#  'web page dynamic cgi language scripting',
#  'adaptive integration quadrature software cubature',
#  'system relation key inference schema',
#  'design search engineering reverse template pattern',
#  'database relation key automated schema deduction',
#  'shannon compression symbol ranking text',
#  'programmable rapid prototyping hardware pc coprocessor logic',
#  'deref type borland oberon chill pascal object parameter language extensible assignment passing module',
#  'computation distributed recursion state machine concurrency abstract',
#  'abstract constrained shortest path verification software state machine problem',
#  'programming refinement documentation code program requirement specification verification stepwise inspection checking state machine technique abstract model',
#  'programming visual formalism design modular montage specification state language machine abstract',
#  'programming reference oberon montage specification state language machine manual abstract',
#  'programming refinement documentation code stepwise inspection state machine technique abstract',
#  'semantics verification generator operational state machine compiler abstract',
#  'filtering probabilistic system reasoning gathering internet information model',
#  'knowledg filtering information management corporate knowledge memory technology work process',
#  'argumentation collaborative participatory management design system knowledge organisational memory',
#  'management corporate knowledge case study memory',
#  'groupware design workspace shared cscw workflow',
#  'generation formalism method knowledge acquisition artificial natural representation intelligence language interface processing',
#  'management system coordination knowledge mechanism cscw',
#  'filtering spreading feedback network text activation semantic relevance',
#  'system uniform automatic paperfolding sequence tag',
#  'courseware learning training evaluation technique teaching',
#  'correctness testing proof computer arithmetic education science overflow',
#  'database control security policy access discretionary application cryptography data',
#  'free placement space algorithm',
#  'nonlinearity boolean function resiliency cryptology',
#  'monstr rewriting term graph intermediate language semantic model',
#  'parallelism graph allocation scheduling processor dependency assignment',
#  'filter algorithm genetic computation image distributed stack processing',
#  'code cryptosystems theory information',
#  'multithreading pram chaining vliw',
#  'research forum result fnr negative failure progress culture',
#  'refinement protocol formal distribution gurevich key security method specification verification kerberos state machine abstract',
#  'basic formal system documentation sdl specification telecommunication semantic executable foundation state machine abstract',
#  'interval arithmetic specification',
#  'type parallel algorithm methodology evaluation query text software development data structured categorical',
#  'system persistency term rewriting modularity confluence',
#  'bishop dirichlet constructive mathematics hilbert space problem',
#  'set chaitin number',
#  'kraft huffman tree optimum prefix code extendible inequality',
#  'minimality automaton incomplete',
#  'order monadic decidability',
#  'hierarchy set graph obstruction polynomial minor',
#  'code representation encoders',
#  'randomness invariance property',
#  'computability set computable infinite closed map cantor sequence measure',
#  'computability model kripke operator completeness intermediate jump logic',
#  'mapping constructive mathematics pointwise sequential continuity linear',
#  'communication agent flow operator arrow belief modal information logic',
#  'structuring hypermedia system model',
#  'equivalence computational parallel learning query theory optimal membership dfa',
#  'substitution attack box cryptography permutation linear differential',
#  'distance document multimedia computer engineering electronic integrated technology information teaching',
#  'distance television design film educational instructional',
#  'free thesis design linux circuit software asic unix diploma integrated pc',
#  'distance system multimedia medium development online publishing teaching',
#  'information system agent knowledge distributed gathering internet broker data retrieval',
#  'complexity network boolean function monotone combinational measure',
#  'word disjunctiveness rational invariant normality representation number property period',
#  'distance rotation triangulation flip operation',
#  'distance cai web educational software www cscw cbt hyperwave authoring teaching',
#  'groupware cooperative computer classroom electronic case study supported education science work',
#  'formal parallel system rewriting language',
#  'redundancy recursive code string decomposition coding efficiency synchronisation',
#  'programming courseware parallel computing computer vision online',
#  'document system multimedia design web literacy computer preparation education hypertext science',
#  'interval model validation approximation interpolation system manipulation computer verification square enzyme uncertainty',
#  'approximate system reasoning quantifier implication linguistic fuzzy approach number information',
#  'biological comparison dna fpga hardware vlsi sequence',
#  'monstr rewriting term graph intermediate language semantic model',
#  'hierarchy recombination regulated chomsky system rewriting family dna genetics molecular language abstract splicing',
#  'set bounded effectivization completeness function extensionally pseudosimple',
#  'formal system grammar language team',
#  'gopher link consistency system hypertext scalability distributed www internet information',
#  'nonlinearity propagation encryption boolean sac function cryptography characteristic',
#  'graphical system interaction visualisation internet hypermedia information',
#  'history cultural web society aspect www sgml',
#  'gopher system distributed internet information',
#  'algorithm graph biconnected distributed',
#  'mechanic proving geometry system decomposition polynomial triangular elimination differential',
#  'learning cbt support digital electronic instructional cai technology library teaching',
#  'algorithm public design high key speed hardware multiplier testability cryptography',
#  'networked system xanadu www internet hypermedia information',
#  'propagation numerical partial method equation floating point arithmetic finite error difference differential',
#  'rational system continued lexicographic computer theory arithmetic number fraction',
#  'precision vliw arithmetic credible reliable accurate',
#  'interval analysis manipulation computer arithmetic algebraic error',
#  'interval digit set continued computation computer representation arithmetic redundant number fraction',
#  'ieee handling exception computer standard implementation arithmetic',
#  'computer function elementary range arithmetic reduction',
#  'grammar life artificial system',
#  'networked multimedia query home image distributed navigation store hypermedia',
#  'gif unisys debate patent software internet compuserve lzw',
#  'serialisability monstr rewriting term graph network simulation concurrency process',
#  'networked performance system load cache balancing file distributed',
#  'command voice agent prediction pad search electronic assistant message',
#  'cube tile wang automaton mathematics tiling sequential theory discrete machine aperiodic',
#  'link automatic modeling data hypermedia maintenance',
#  'distance courseware whiteboard electronic hypermedia teaching',
#  'negotiation cooperation constraint coordination strategy multiagent solving distributed feature signed problem',
#  'free word formal mapping context parikh language problem',
#  'ai parallel qsim constraint satisfaction distributed',
#  'anonymous control authentication security access big',
#  'complexity chaitin string random',
#  'approximate estimate digit radix high division',
#  'coated tree simulation shared memory mesh randomized erew',
#  'system chomsky grammar operation shuffle',
#  'education',
#  'quantisation lz compression text coding arithmetic vector',
#  'registration understanding image fusion matching affine information spatial',
#  'algorithm mapping simulation optimization evolutionary',
#  'evolvable algorithm genetic optimisation hardware cryptography',
#  'programming computational decision fault neural tree genetic network intelligence electronic monitoring hardware',
#  'filter leapfrog algorithm electronics design genetic method circuit optimization classical search amplifier operational evolutionary pattern transconductance problem',
#  'algorithm genetic code computation division multiple multiuser detection evolutionary access',
#  'formal temporal assertion system alternating automaton specification verification reactive time series monitoring logic',
#  'reversible computing circuit operation arithmetic multiplier',
#  'hierarchy minimal uncolorability exact boolean completeness number domatic',
#  'human information issue system device societal processing portable health technology expert pervasive',
#  'environment system smart artificial multiagent intelligence',
#  'embedded sensor diagnosis arrhythmia automatic telemedicine wireless cardiac ecg',
#  'agent computing device telemedicine technology mobile',
#  'behavioral telemedicine care monitoring service technology provision',
#  'cancer computerized record privacy patient security natural processing electronic confidentiality health language bioinformatics',
#  'jini agent computing home healthcare pervasive',
#  'privacy computing ubiquitous healthcare quality',
#  'mosaic visualization aware interaction computing context ubiquitous implicit information rfid',
#  'environment privacy context intelligence awareness intelligent ambience',
#  'middleware computing ambient smart intelligence space pervasive',
#  'design network sensor modular node wireless architecture hardware',
#  'middleware computing ambient aspect intelligence component pervasive',
#  'hybrid merging decision web rule architecture information semantic',
#  'trust protocol security network discovery service',
#  'issue social engine web search mining information retrieval',
#  'computation specification coercion inheritance algebraic symbolic',
#  'formal temporal type software mixed language logic engineering data transition graphical based system architectural glue notation abstract specification description component symbolic',
#  'human security automated captcha optical turing persian public text recognition arabic internet character baffletext completely',
#  'optimization dynamic compilation compiler',
#  'coalgebra coinduction process algebra',
#  'optimization dynamic compilation compiler',
#  'oriented aspectj aspect software development refactoring language',
#  'programming analysis functional slicing program',
#  'free context method grammar aspect visitor invocation language pattern essential sequence',
#  'mobility programming computation strong functional haskell mobile',
#  'object virtual interoperability machine model',
#  'programming web language service pattern workflow',
#  'nonsequential semantics automaton uml',
#  'database management type system semantics query operational language',
#  'filter particle simulation fusion science data',
#  'instance exception mining unexpectedness interestingness rule data pattern',
#  'cryptography randomness security',
#  'generation method simulation pseudorandom twister carlo number mersenne random monte',
#  'cryptography computing quantum computational',
#  'randomness computational decision formal testing complexity algorithm diagram sublinear bdds binary boolean function branching language bps property program',
# ...
#  'design learning object instructional ontology quality',
#  'separation flexibility educational concern modeling language',
#  'degree graduate webct online education',
#  'handheld simulation device modelling',
#  'collaborative design learning game cscl model',
#  'communication human network factor',
#  'synchronous collaborative interaction computing learning uting comp pervasive mobile',
#  'mapping design learning ims integration moodle',
#  'programming requirement specification language',
#  'constrai programming reuse nt software architecture',
#  'programming condition refactoring law logic',
#  'lalr parsing methodology conflict',
#  'programming optimized weaving advice compilation',
#  'programming visual demonstration',
#  'lua reusability aspect dynamic aop heterogeneity',
#  'programming spreadsheet abstraction recursion structure language lazy',
#  'reference collection management counting garbage concurrent memory',
#  'reference permanent collection management counting graph cyclic garbage tenured object memory',
#  'language programming application interface',
#  'programming analysis functional slicing program',
#  'constrained type system polymorphism closed inference overloading world approach open',
#  'semantics action formal',
#  'selecti algorithm management web knowledge service quality resource',
#  'service semantic choreography',
#  'management creation knowledge skill representation competence description logic',
#  'programme design learning engineering development competence instructional',
#  'similarity link future annotation citation index',
#  'approximation reinforcement learning function generalization attention',
#  'education information science computer',
#  'corpus system entity stacking transformation combination extraction named',
#  'emergent communication evolvable algorithm genetic hardware',
#  'quadratic particle optimization variable neighborhood search swarm assignment problem',
#  'algorithm neural genetic network ph neutralization fuzzy recurrent modeling process',
#  'signal neural design cellular network analog circuit processing evolutionary dac',
#  'system security network computer artificial immune forensics',
#  'autoconfiguration manet olsr',
#  'ad routing hoc network adaptation scalability clustering wireless',
#  'flooding bandwidth network qos interference relay olsr ad control optimized hoc',
#  'voting aggregation network sensor clustering data head',
#  'ad distance routing hoc protocol performance load energy network evaluation balancing caching efficiency node vector mobile',
#  'programming net functional virtual haskell interoperability language machine compiler',
#  'bilinear encryption pairing standard hierarchical model',
#  'constructive mathematics calculus natural deduction typed negationless logic',
#  'database computational geometry video structure data',
#  'proximity collaborative computing learning computer supported mobile',
#  'pso sigmoid approximation polygonal centroid function',
#  'metric riemannian similarity support machine vector',
#  'metadata keywords learning support extraction machine vector',
#  'programming system algorithm mining gene immune expression rule artifical evolutionary data',
#  'densest eigenvalue independence graph subgraph number',
#  'isoarithmic resonance polycyclic matchings hydrocarbon clar factor benzenoids kekul aromatic polyhexes structure perfect',
#  'behavioural category mealy automaton final sequential theory moore semiautomata',
#  'gray code',
#  'complexity network processor machine turing evolutionary class',
#  'steiner tree spanning approximation heuristic ratio minimum',
#  'hertz hsalmankhan175jek generalized mv nm residuated bl algebra wajsberg heyting pocrim lattice',
#  'computational geometry matroid game pebble theory rigidity hypergraph',
#  'metric nonexpansive proof mining function asymptotic regularity theory halpern point iteration fixed',
#  'stable fully kronecker set graph irreducible support indecomposable bipartite total adjacency matching perfect product boolean elementary matrix cover',
#  'astrocyte neural system computing membrane spiking',
#  'programming register protocol voice system agapia termination distributed interactive typing language',
#  'graph signed balancing',
#  'metric modular entropy lattice',
#  'graph theory geodesic connectivity',
#  'coefficient shortness graph grid topological connectedness hamiltonian',
#  'software coverification hardware slicing program',
#  'evolution petri reflection software net',
#  'formal method web service',
#  'protocol formal network rebeca method modular verification',
#  'language translation odedialect ontology',
#  'metadata annotation web ontology extraction information semantic',
#  'visualization web ranking schema semantic',
#  'web interoperability querying information semantic retrieval',
#  'database mediator management knowledge query distributed ontology application internet language',
#  'life corese annotation web nlp ontology science semantic',
#  'cscw notification synchronous groupware collaboration simulation architecture',
#  'collaborative system discovery web learning semantic ontology tool service cscl',
#  'situation working collaborative learning workspace shared interactive nomadic model',
#  'middleware col laboration groupware unit web platform service mobile scenario',
#  'middleware meeting electronic pattern',
#  'script design collaboration integration learning architecture',
#  'text clustering segmentation',
#  'document digitalization medieval web tagging preparation xml semantic',
#  'zoning confusion metaclasses measurement recognition mechanism character feature matrix',
#  'pattern recognition signature verification',
#  'ta da document handwritten recognition segmentation extraction',
#  'document bleeding engineering interference',
#  'light normalisation maximum restoration image segmentation arabic historical color manuscript likelihood intensity',
#  'document bleeding engineering show interference',
#  'analysis discriminant symbol recognition conditional',
#  'fair protocol exchange public key security cryptography',
#  'cryptography security authentication',
#  'randomness exchange key security graph notion',
#  'commerce transfer privacy oblivious protection electronic',
#  'bilateral unknown key authenticated agreement resilience model',
#  'anonymous exchange key roaming authenticated',
#  'certificateless encryption attack standard kgc malicious model',
#  'fast curve field cryptographic algorithm koblitz arithmetic finite elliptic cryptography',
#  'analysis social network collaboration knowledge software wiki work',
#  'ruler carpenter algorithm approximation folding problem',
#  'user analysis content weblog generated blogging',
#  'classification compensation advertising interactive model',
#  'neighbor road network nearest continuous pine voronoi',
#  'traffic performance user analysis behaviour measurement passive internet quality experience',
#  'market design network bandwidth allocation resource',
#  'cost telric bitstream service queuing priority quality access model',
#  'call computational voip delay zrtp eigenvectors srtp puzzle',
#  'multimedia ict divide digital service broadband access',
#  'learning game price interdomain information stability incomplete',
#  'curve multiplexing network bandwidth reaction cost economics pricing effective competition contract demand statistical provision',
#  'communication analysis network risk reliability',
#  'security zrtp',
#  'objective holistic analysis business modelling happiness service ecosystem quality experience',
#  'traffic planning network modeling scenario',
#  'riesz analysis computable representation hausdorff space topology theorem',
#  'analysis computable flowchart abstraction realization',
#  'constant computable grzegorczyk liouville function euler lower',
#  'computability type system physic topological pressure dynamical statistical hift',
#  'bloch constant computability algorithm',
#  'hierarchy analysis counting weak integral riemann',
#  'computational complexity quadrature rule real',
#  'probabilistic analysis computable computation measure',
#  'higher filter type category computation topological equilogical space weak limit convenient',
#  'nig lemma fan brouwer theorem',
#  'na bayes classification reasoning mining text explanation data pattern',
#  'portal web engine development java technology',
#  'reusable unit design learning modelling framework educational conceptual interoperability language process',
#  'statistical publication computer gender education reporting bias science',
#  'formal system specification auction english process algebra',
#  'system ranking distributed information retrieval',
#  'negotiation communication agent algorithm system methodology simulation allocation strategy dynamic wireless channel resource',
#  'market management agent simulation software electronic chain supply trading',
#  'ad table routing hoc reducing agent aodv network discovery knowledge overhead',
#  'metric performance system evaluation',
#  'propagation social network query ontology alignment semantic',
#  'system agent integration computation data',
#  'reinforcement learning simulation market',
#  'system engineering software architecture',
#  'maintenance reuse gateway system embedded decomposition product mining line software component hardware feature model',
#  'requirement optimization software selection cot model',
#  'reuse system knowledge engineering understanding legacy reverse',
#  'mismatch web architectural style software acme architecture service',
#  'driven oriented transformation aspect concern software development architecture crosscutting mda model',
#  'programming derivation product line software development tool generative',
#  'business product web line application service process',
#  'efremovi property space',
#  'method lisp binary object common orientation',
#  'metaobject protocol lisp specializer function generic',
#  'metaobject protocol type presentation lisp common clim',
#  'programming ambient subjective multiple intelligence dispatch',
#  'mapping lisp common smalltalk',
#  'temporal relation reasoning lisp algebra',
#  'graphical visualization user market analysis stock nasdaq force velocity data interface information',
#  'groupware interaction awareness',
#  'based groupware design interaction model',
#  'groupware approach plasticity awareness',
#  'cscw development groupware',
#  'generation code interaction transformation requirement usability automatic compiler sketch model',
#  'cognitive metric heuristic context method usability evaluation walkthrough usabaipo',
#  'programming computing ambient adaptation smart home ubiquitous automatic intelligence natural',
#  'task collaborative computing ambient context ubiquitous intelligence modeling awareness model',
#  'human website interaction usability evaluation computer engineering accessibility',
#  'classification learning knowledge support text selection representation preprocessing data machine feature vector information retrieval',
#  'reattempt mobility markovian seamless truncated finite model',
#  'visualization system electron meeting multimodal extraction information retrieval',
#  'multilayer neural network core perceptron programmable fpga fuzzy ip configurable hardware vhdl logic',
#  'metadata decision making annotation network web scholarly',
#  'repository reuse metadata community sharing building computing learning object structural',
#  'privacy engine web search pagerank ethic bias information personalization',
#  'based collaborative design production web training knowledge modelling support instructional tool taxonomy authoring semantic',
#  'multimedia entertainment semantics search digital ontology semantic',
#  'social content web medium platform mpeg',
#  'web extraction assistant application information',
#  'wrapper automation system web mining data information',
#  'wrapper distance web crawling hidden',
#  'classification web page clustering extraction data',
#  'ontology extraction data information',
#  'visual informative extraction block information',
#  'ahead composition verification asm feature',
#  'metamodelling engineering simulator asm state language machine abstract',
#  'formal system embedded method specification verification state machine abstract',
#  'simulation timed predicate state machine abstract logic',
#  'precondition proving diagram dynamic purse logic theorem refinement security commuting state data machine weakest electronic interactive mondex abstract simulation forward',
#  'discovery mediation composition service process workflow',
#  'protocol inductive goal method verification threat model',
#  'communication reuse coordination adaptation composition modularity measurement software coupling architecture',
#  'programming adaptation software component logic',
#  'behavioural programming validation system mismatch adaptation composition component interface transition',
#  'programming interaction adaptation specification cc pattern software state extended machine uml',
#  'engineering technique adaptation web',
#  'complex system knowledge open intelligence processing intelligent',
#  'agent learning incremental method web software browsing assistant statistical',
#  'market agent mining surveillance data pattern microstructure',
#  'security wpki trusted mobile',
#  'algorithm load content cache network balancing caching divided delivery scope',
#  'agent planning case study report deployment',
#  'traffic system modelling optimization city ligh',
#  'lb tree decision positioning method fingerprinting',
#  'semantiization ontology searching information meta',
#  'shop graphic flow search salesman tabu hardware traveling',
#  'layer curve set evolution image level termination segmentation criterion',
#  'system classification genetic network learning bayesian fuzzy machine logic',
#  'steiner tree algorithm prize collecting transgenetic evolutionary problem',
#  'hybrid bus algorithm genetic network optimization scheduling problem',
#  'quantum computation state machine finite assignment problem',
#  'network sensor optimization multiobjective metaheuristics',
#  'genetic optimization search algorithm',
#  'set rough particle optimization ant selection intelligence colony theory feature swarm problem',
#  'simulated combinatorial evolution parallel stochastic computing optimization cell cluster vlsi placement metaheuristics',
#  'system emergence intelligence recommendation swarm',
#  'decision bayes system intervention error individuating diagnostic ds support rate base information theorem',
#  'interaction',
#  'cognitive interface ergonomics evaluation',
#  'variety phone interaction cooperative mediating determining factor sociology breath work usage mobile marketing intensity',
#  'human user interaction computing computer ubiquitous cscw interface mobile',
#  'supporting web engineering development tool application accessibility process',
#  'cognitive ergonomics user design interface',
#  'adaptive mining support educational application data hypermedia authoring',
#  'rdf adaptive metadata desktop evaluation educational adding caf hypermedia authoring semantic',
#  'domain system ontology modeling tutoring intelligent authoring model',
#  'design graph learning ims translation sequencing',
#  'task computing collaboration ambient scheduling intelligence space hypermedia authoring active',
#  'activity adaptive metadata user design learning web elearning pedagogy modelling object educational standard template guideline semantic',
#  'adaptive cultural system cae educational education hypermedia culture',
#  'adaptive environment based learning game tool authoring',
#  'document analysis mining image software understanding digital architecture library',
#  'conversion planning content preservation format characterisation evaluation digital migration file language xml library',
#  'svm neural classification network crime scene feature',
#  'author pattern recognition verification',
#  'resolution indexation analysis document ultra web low image text recognition hmms retrieval',
#  'document stacking network structuring dependency',
#  'document binarization evaluation image processing',
#  'grid image cluster processing',
#  ...]

# %% [markdown]
# ## Joining Title and Keywords

# %%
def joinTitleKeyword(titleArr, keywordArr):
    joinArr = []
    for item1, item2 in zip(titleArr, keywordArr):
        joinArr.append(item1+" "+ item2)
    return joinArr

# %%
# joinArr = joinTitleKeyword(titleArrClean, rakeKeyword)
joinArr = joinTitleKeyword(rakeTitle, rakeKeyword)

# %%
# for i in range(len(titleArrClean)):
#     print("words title: ",titleArrClean[i], "\nwords keyword: ", rakeKeyword[i], "\nwords joined: ", joinArr[i])

for i in range(len(rakeTitle)):
    print("words title: ",rakeTitle[i], "\nwords keyword: ", rakeKeyword[i], "\nwords joined: ", joinArr[i])
# Out:
# words title:  process-oriented structures
# words keyword:  cooperative knowledge generation
# words joined:  process-oriented structures cooperative knowledge generation
# words title:  small groups learning synchronously online
# words keyword:  computer-supported cooperative learning
# words joined:  small groups learning synchronously online computer-supported cooperative learning
# words title:  knowledge sharing
# words keyword:  micro-didactical learning arrangement
# words joined:  knowledge sharing micro-didactical learning arrangement
# words title:  implementing pre-built information spaces
# words keyword:  modelling method
# words joined:  implementing pre-built information spaces modelling method
# words title:  tube map visualization
# words keyword:  knowledge visualization
# words joined:  tube map visualization knowledge visualization
# words title:  activity-based knowledge management approach
# words keyword:  knowledge management
# words joined:  activity-based knowledge management approach knowledge management
# words title:  integrate technological
# words keyword:  inter-organizational networked businesses
# words joined:  integrate technological inter-organizational networked businesses
# words title:  improving knowledge-intensive business processes
# words keyword:  knowledge modeling description language
# words joined:  improving knowledge-intensive business processes knowledge modeling description language
# words title:  knowledge management solutions
# words keyword:  knowledge management
# words joined:  knowledge management solutions knowledge management
# words title:  modeling knowledge work
# words keyword:  knowledge management instrument
# words joined:  modeling knowledge work knowledge management instrument
# words title:  knowledge infrastructure hierarchy model
# words keyword:  knowledge management
# words joined:  knowledge infrastructure hierarchy model knowledge management
# words title:  process oriented knowledge management
# words keyword:  knowledge management service
# words joined:  process oriented knowledge management knowledge management service
# words title:  non-blocking concurrent queue algorithm
# words keyword:  formal proof
# words joined:  non-blocking concurrent queue algorithm formal proof
# words title:  investigating atomicity
# words keyword:  formal development method
# words joined:  investigating atomicity formal development method
# words title:  asynchronous communication mechanism
# words keyword:  asynchronous communication
# words joined:  asynchronous communication mechanism asynchronous communication
# words title:  compensating business transactions
# words keyword:  ing transactions
# words joined:  compensating business transactions ing transactions
# words title:  atomic broadcast
# words keyword:  atomic broadcast
# words joined:  atomic broadcast atomic broadcast
# words title:  atomic manifesto
# words keyword:  formal methods
# words joined:  atomic manifesto formal methods
# words title:  software development
# words keyword:  software development
# words joined:  software development software development
# words title:  first-class system provision
# words keyword:  transactional memory
# words joined:  first-class system provision transactional memory
# words title:  semi-automatic visual subgroup mining
# words keyword:  subgroup mining
# words joined:  semi-automatic visual subgroup mining subgroup mining
# words title:  visualizing recommendation flow
# words keyword:  visualizing information flow
# words joined:  visualizing recommendation flow visualizing information flow
# words title:  high-dimensional data
# words keyword:  grand tour methods
# words joined:  high-dimensional data grand tour methods
# words title:  ubiquitous data mining
# words keyword:  data mining
# words joined:  ubiquitous data mining data mining
# words title:  visual data exploration
# words keyword:  visual data exploration
# words joined:  visual data exploration visual data exploration
# words title:  uncertain dependencies
# words keyword:  data mining
# words joined:  uncertain dependencies data mining
# words title:  explore highly structured temporal data
# words keyword:  interactive information visualization
# words joined:  explore highly structured temporal data interactive information visualization
# words title:  scalable visual data exploration
# words keyword:  visual data exploration
# words joined:  scalable visual data exploration visual data exploration
# words title:  physically locating wireless intruders
# words keyword:  intrusion detection system
# words joined:  physically locating wireless intruders intrusion detection system
# words title:  security level evaluation
# words keyword:  public key infrastructure
# words joined:  security level evaluation public key infrastructure
# words title:  reduced distortion lsb coding
# words keyword:  audio steganography
# words joined:  reduced distortion lsb coding audio steganography
# words title:  cryptographic protocol intrusion detection
# words keyword:  cryptographic protocol abuse
# words joined:  cryptographic protocol intrusion detection cryptographic protocol abuse
# words title:  sliding window protocol
# words keyword:  ad hoc network
# words joined:  sliding window protocol ad hoc network
# words title:  secure cryptographic hardware
# words keyword:  evolutionary computation
# words joined:  secure cryptographic hardware evolutionary computation
# words title:  rsa-based certified delivery
# words keyword:  certified delivery
# words joined:  rsa-based certified delivery certified delivery
# words title:  information source combinations space
# words keyword:  multi-agent systems
# words joined:  information source combinations space multi-agent systems
# words title:  low-intrusive consistent disk checkpointing
# words keyword:  digital  forensics
# words joined:  low-intrusive consistent disk checkpointing digital  forensics
# words title:  secured data transfer
# words keyword:  data protection
# words joined:  secured data transfer data protection
# words title:  gossip codes
# words keyword:  multimedia information system
# words joined:  gossip codes multimedia information system
# words title:  information profiles
# words keyword:  distributed databases
# words joined:  information profiles distributed databases
# words title:  deds control synthesis method
# words keyword:  discrete event dynamic systems
# words joined:  deds control synthesis method discrete event dynamic systems
# words title:  complex systems development
# words keyword:  software life cycle
# words joined:  complex systems development software life cycle
# words title:  collaborative web browsing based
# words keyword:  web browsing
# words joined:  collaborative web browsing based web browsing
# words title:  language grounding problem
# words keyword:  language grounding
# words joined:  language grounding problem language grounding
# words title:  hybrid method
# words keyword:  information retrieval
# words joined:  hybrid method information retrieval
# words title:  processing inconsistency
# words keyword:  inconsistent knowledge
# words joined:  processing inconsistency inconsistent knowledge
# words title:  web systems user interfaces
# words keyword:  user interfaces
# words joined:  web systems user interfaces user interfaces
# words title:  provably efficient computational model
# words keyword:  spatiotemporal data modeling
# words joined:  provably efficient computational model spatiotemporal data modeling
# words title:  time costs
# words keyword:  actor computations
# words joined:  time costs actor computations
# words title:  real-time control protocol
# words keyword:  rtcp scalability
# words joined:  real-time control protocol rtcp scalability
# words title:  automatic test data generation
# words keyword:  automatic test data generation
# words joined:  automatic test data generation automatic test data generation
# words title:  theoretical upper bound
# words keyword:  global routing
# words joined:  theoretical upper bound global routing
# words title:  fine-grained transclusions
# words keyword:  xanalogical structure
# words joined:  fine-grained transclusions xanalogical structure
# words title:  fat cube topology
# words keyword:  fat cube topology
# words joined:  fat cube topology fat cube topology
# words title:  test automation framework
# words keyword:  automated testing
# words joined:  test automation framework automated testing
# words title:  efficient verifiable shuffle based
# words keyword:  public-key system
# words joined:  efficient verifiable shuffle based public-key system
# words title:  exploiting agent ontologies
# words keyword:  intelligent agent technology
# words joined:  exploiting agent ontologies intelligent agent technology
# words title:  finite binary tree algorithm
# words keyword:  hash function
# words joined:  finite binary tree algorithm hash function
# words title:  model checking
# words keyword:  actor model
# words joined:  model checking actor model
# words title:  fast t-decomposition algorithm
# words keyword:  computable complexity measures
# words joined:  fast t-decomposition algorithm computable complexity measures
# words title:  draw free trees inside bounded simple polygons
# words keyword:  computational geometry
# words joined:  draw free trees inside bounded simple polygons computational geometry
# words title:  constructive approach
# words keyword:  structural operational semantics
# words joined:  constructive approach structural operational semantics
# words title:  hardware design
# words keyword:  hardware description languages
# words joined:  hardware design hardware description languages
# words title:  implementation
# words keyword:  virtual machines
# words joined:  implementation virtual machines
# words title:  dynamic aop approach
# words keyword:  dynamic aspects
# words joined:  dynamic aop approach dynamic aspects
# words title:  formal semantics
# words keyword:  memory management
# words joined:  formal semantics memory management
# words title:  building web service interfaces
# words keyword:  programming languages
# words joined:  building web service interfaces programming languages
# words title:  compiling nonâ­strict functional languages
# words keyword:  languages interoperability
# words joined:  compiling nonâ­strict functional languages languages interoperability
# words title:  running lua scripts
# words keyword:  common language runtime
# words joined:  running lua scripts common language runtime
# words title:  java jit technology
# words keyword:  dynamic compilation
# words joined:  java jit technology dynamic compilation
# words title:  signals
# words keyword:  distributive laws
# words joined:  signals distributive laws
# words title:  equational specification
# words keyword:  executable semantics
# words joined:  equational specification executable semantics
# words title:  purely functional language
# words keyword:  mobile computation
# words joined:  purely functional language mobile computation
# words title:  learning decision trees
# words keyword:  incremental decision trees
# words joined:  learning decision trees incremental decision trees
# words title:  resource-aware mining
# words keyword:  data mining
# words joined:  resource-aware mining data mining
# words title:  network attack scenarios extraction
# words keyword:  network security
# words joined:  network attack scenarios extraction network security
# words title:  web request streams
# words keyword:  web usage mining
# words joined:  web request streams web usage mining
# words title:  evaluating trigger conditions
# words keyword:  streaming time series
# words joined:  evaluating trigger conditions streaming time series
# words title:  dynamic data streams
# words keyword:  data streams
# words joined:  dynamic data streams data streams
# words title:  incremental rule learning
# words keyword:  decision rules
# words joined:  incremental rule learning decision rules
# words title:  positive roots
# words keyword:  polynomial equations
# words joined:  positive roots polynomial equations
# words title:  constructive suprema
# words keyword:  partially ordered set
# words joined:  constructive suprema partially ordered set
# words title:  uniform continuity theorem
# words keyword:  constructive mathematics
# words joined:  uniform continuity theorem constructive mathematics
# words title:  self-adjoint operators
# words keyword:  computable functional analysis
# words joined:  self-adjoint operators computable functional analysis
# words title:  cellular automata universe
# words keyword:  halting probability omega
# words joined:  cellular automata universe halting probability omega
# words title:  iterated rational functions
# words keyword:  constructive analysis
# words joined:  iterated rational functions constructive analysis
# words title:  stone-yosida representation theorems
# words keyword:  formal topology
# words joined:  stone-yosida representation theorems formal topology
# words title:  axiomatic classes
# words keyword:  intuitionistic logic
# words joined:  axiomatic classes intuitionistic logic
# words title:  state space
# words keyword:  banach algebra
# words joined:  state space banach algebra
# words title:  nonrandom sequences
# words keyword:  algorithmic information theory
# words joined:  nonrandom sequences algorithmic information theory
# words title:  linear lattices
# words keyword:  lattice theory
# words joined:  linear lattices lattice theory
# words title:  quotient spaces
# words keyword:  formal topology
# words joined:  quotient spaces formal topology
# words title:  constructive set theory
# words keyword:  constructive set theory
# words joined:  constructive set theory constructive set theory
# words title:  constructing programs
# words keyword:  process algebra
# words joined:  constructing programs process algebra
# words title:  constructive aspects
# words keyword:  markov chains
# words joined:  constructive aspects markov chains
# words title:  regular formal spaces
# words keyword:  regular formal topologies
# words joined:  regular formal spaces regular formal topologies
# words title:  functional dependencies
# words keyword:  functional dependencies
# words joined:  functional dependencies functional dependencies
# words title:  continuity
# words keyword:  constructive mathematics
# words joined:  continuity constructive mathematics
# words title:  constructive results
# words keyword:  constructive mathematics
# words joined:  constructive results constructive mathematics
# words title:  hausdorff measure
# words keyword:  iterated function system
# words joined:  hausdorff measure iterated function system
# words title:  mathematical objects determine
# words keyword:  constructive analysis
# words joined:  mathematical objects determine constructive analysis
# words title:  intermediate
# words keyword:  intuitionistic real analysis
# words joined:  intermediate intuitionistic real analysis
# words title:  constructive approach
# words keyword:  constructive geometry
# words joined:  constructive approach constructive geometry
# words title:  effective fine space
# words keyword:  effective fine space
# words joined:  effective fine space effective fine space
# words title:  modelling units
# words keyword:  educational modelling language
# words joined:  modelling units educational modelling language
# words title:  semantic web technologies applied
# words keyword:  hypermedia systems
# words joined:  semantic web technologies applied hypermedia systems
# words title:  conceptual learning
# words keyword:  authoring tool
# words joined:  conceptual learning authoring tool
# words title:  ubiquitous computing
# words keyword:  ubiquitous computing
# words joined:  ubiquitous computing ubiquitous computing
# words title:  collaborative computer programming learning
# words keyword:  computer programming teaching
# words joined:  collaborative computer programming learning computer programming teaching
# words title:  virtual objects
# words keyword:  virtual object
# words joined:  virtual objects virtual object
# words title:  learning activities
# words keyword:  learning environments
# words joined:  learning activities learning environments
# words title:  support asynchronous collaborative learning tasks
# words keyword:  computer-supported collaborative learning
# words joined:  support asynchronous collaborative learning tasks computer-supported collaborative learning
# words title:  case studies
# words keyword:  web-based services
# words joined:  case studies web-based services
# words title:  integrating ontologies
# words keyword:  learning objects
# words joined:  integrating ontologies learning objects
# words title:  analyzing module diversity
# words keyword:  selector namespaces
# words joined:  analyzing module diversity selector namespaces
# words title:  coordinating behavioral descriptions
# words keyword:  process algebra
# words joined:  coordinating behavioral descriptions process algebra
# words title:  algebras
# words keyword:  software formal specification
# words joined:  algebras software formal specification
# words title:  autonomous dynamic component composition
# words keyword:  service oriented architecture
# words joined:  autonomous dynamic component composition service oriented architecture
# words title:  reo connector circuits
# words keyword:  probabilistic constraint automata
# words joined:  reo connector circuits probabilistic constraint automata
# words title:  component-based actor language
# words keyword:  actor model
# words joined:  component-based actor language actor model
# words title:  personality-aware computer-human interfaces
# words keyword:  myers-briggs type indicator
# words joined:  personality-aware computer-human interfaces myers-briggs type indicator
# words title:  situated models
# words keyword:  situated learning
# words joined:  situated models situated learning
# words title:  user context aware delivery
# words keyword:  user context-aware retrieval
# words joined:  user context aware delivery user context-aware retrieval
# words title:  web-based training systems
# words keyword:  user interface design
# words joined:  web-based training systems user interface design
# words title:  discovering student models
# words keyword:  learning objects
# words joined:  discovering student models learning objects
# words title:  adaptive user
# words keyword:  user modeling
# words joined:  adaptive user user modeling
# words title:  game-based learning
# words keyword:  collaborative learning
# words joined:  game-based learning collaborative learning
# words title:  classroom-based learning
# words keyword:  learning
# words joined:  classroom-based learning learning
# words title:  message-optimal distributed graph algorithm
# words keyword:  distributed algorithm
# words joined:  message-optimal distributed graph algorithm distributed algorithm
# words title:  rapid prototyping environment
# words keyword:  rapid prototyping
# words joined:  rapid prototyping environment rapid prototyping
# words title:  securing web-based exams
# words keyword:  web-based exam
# words joined:  securing web-based exams web-based exam
# words title:  facilitating knowledge exchange
# words keyword:  learning management system
# words joined:  facilitating knowledge exchange learning management system
# words title:  knowledge centralization versus distribution
# words keyword:  intellectual capital
# words joined:  knowledge centralization versus distribution intellectual capital
# words title:  pizzarotti case study
# words keyword:  distributed knowledge management
# words joined:  pizzarotti case study distributed knowledge management
# words title:  ontology-based knowledge sharing system
# words keyword:  knowledge sharing community
# words joined:  ontology-based knowledge sharing system knowledge sharing community
# words title:  participative process introduction
# words keyword:  distributed participative process evolution
# words joined:  participative process introduction distributed participative process evolution
# words title:  integrated technology perspective
# words keyword:  enterprise content management
# words joined:  integrated technology perspective enterprise content management
# words title:  chaos knowledge coproduction
# words keyword:  case study
# words joined:  chaos knowledge coproduction case study
# words title:  organic perspectives
# words keyword:  knowledge nebula crystallizer
# words joined:  organic perspectives knowledge nebula crystallizer
# words title:  supporting knowledge creation
# words keyword:  knowledge management
# words joined:  supporting knowledge creation knowledge management
# words title:  social capital
# words keyword:  tacit knowledge
# words joined:  social capital tacit knowledge
# words title:  determinism
# words keyword:  membrane computing
# words joined:  determinism membrane computing
# words title:  population
# words keyword:  membrane computing
# words joined:  population membrane computing
# words title:  systems
# words keyword:  membrane computing
# words joined:  systems membrane computing
# words title:  complexity measures
# words keyword:  natural computing
# words joined:  complexity measures natural computing
# words title:  maximum element
# words keyword:  natural computing
# words joined:  maximum element natural computing
# words title:  systems
# words keyword:  systems
# words joined:  systems systems
# words title:  fredkin gate
# words keyword:  fredkin gate
# words joined:  fredkin gate fredkin gate
# words title:  java simulator
# words keyword:  system
# words joined:  java simulator system
# words title:  efficient family
# words keyword:  bin packing problem
# words joined:  efficient family bin packing problem
# words title:  active membranes
# words keyword:  natural computing
# words joined:  active membranes natural computing
# words title:  large croatian enterprises
# words keyword:  strategic human resource management
# words joined:  large croatian enterprises strategic human resource management
# words title:  knowledge audit analysis
# words keyword:  social network analysis
# words joined:  knowledge audit analysis social network analysis
# words title:  semantic-based approach
# words keyword:  skill matching
# words joined:  semantic-based approach skill matching
# words title:  facilitating knowledge communication
# words keyword:  knowledge communication
# words joined:  facilitating knowledge communication knowledge communication
# words title:  semantic web technologies
# words keyword:  case-based reasoning
# words joined:  semantic web technologies case-based reasoning
# words title:  research & development & transference process
# words keyword:  knowledge management
# words joined:  research & development & transference process knowledge management
# words title:  social network analysis
# words keyword:  social network analysis
# words joined:  social network analysis social network analysis
# words title:  sharing metadata
# words keyword:  knowledge sharing
# words joined:  sharing metadata knowledge sharing
# words title:  modelling lexical databases
# words keyword:  formal concept analysis
# words joined:  modelling lexical databases formal concept analysis
# words title:  search graph partitions
# words keyword:  formal concept analysis
# words joined:  search graph partitions formal concept analysis
# words title:  concept lattices
# words keyword:  concept lattices
# words joined:  concept lattices concept lattices
# words title:  additive order diagrams
# words keyword:  automatic diagram layout
# words joined:  additive order diagrams automatic diagram layout
# words title:  duquenne-guigues base
# words keyword:  implication base
# words joined:  duquenne-guigues base implication base
# words title:  galois lattice theory
# words keyword:  autonomous mobile robotics
# words joined:  galois lattice theory autonomous mobile robotics
# words title:  applying interval logic specifications
# words keyword:  on-the-fly model checking
# words joined:  applying interval logic specifications on-the-fly model checking
# words title:  state models based
# words keyword:  communicating sequential processes
# words joined:  state models based communicating sequential processes
# words title:  enterprise information systems
# words keyword:  automated reasoning
# words joined:  enterprise information systems automated reasoning
# words title:  static global variable-ordering heuristic
# words keyword:  backtrack search
# words joined:  static global variable-ordering heuristic backtrack search
# words title:  accelerate sat-based combinational equivalence checking
# words keyword:  static logic implications
# words joined:  accelerate sat-based combinational equivalence checking static logic implications
# words title:  improving sat-based bounded model checking
# words keyword:  binary decision diagrams
# words joined:  improving sat-based bounded model checking binary decision diagrams
# words title:  efficient sat search heuristics
# words keyword:  binary decision diagrams
# words joined:  efficient sat search heuristics binary decision diagrams
# words title:  signal correlation guided circuit-sat solver
# words keyword:  boolean equivalence checking
# words joined:  signal correlation guided circuit-sat solver boolean equivalence checking
# words title:  coupling-based testing
# words keyword:  object-oriented software
# words joined:  coupling-based testing object-oriented software
# words title:  multimedia software engineering
# words keyword:  multimedia systems
# words joined:  multimedia software engineering multimedia systems
# words title:  composition contracts
# words keyword:  architectural connectors
# words joined:  composition contracts architectural connectors
# words title:  software dynamics
# words keyword:  data reverse engineering
# words joined:  software dynamics data reverse engineering
# words title:  web components
# words keyword:  portal applications
# words joined:  web components portal applications
# words title:  developing multi-agent systems
# words keyword:  agent-oriented software engineering
# words joined:  developing multi-agent systems agent-oriented software engineering
# words title:  process construction
# words keyword:  software process
# words joined:  process construction software process
# words title:  multi-criteria preference analysis
# words keyword:  multi-criteria preference analysis
# words joined:  multi-criteria preference analysis multi-criteria preference analysis
# words title:  document-oriented approach
# words keyword:  domain-specific markup languages
# words joined:  document-oriented approach domain-specific markup languages
# words title:  digital libraries
# words keyword:  active document
# words joined:  digital libraries active document
# words title:  object-oriented embedded system development based
# words keyword:  embedded system design
# words joined:  object-oriented embedded system development based embedded system design
# words title:  symbolic approach
# words keyword:  process algebra
# words joined:  symbolic approach process algebra
# words title:  fast two-stage lempel-ziv lossless numeric telemetry data compression
# words keyword:  neural networks
# words joined:  fast two-stage lempel-ziv lossless numeric telemetry data compression neural networks
# words title:  hyperbolic 4d space
# words keyword:  cellular automata
# words joined:  hyperbolic 4d space cellular automata
# words title:  full hash table search
# words keyword:  full table scatter storage techniques
# words joined:  full hash table search full table scatter storage techniques
# words title:  rewriting tissue
# words keyword:  computational universality
# words joined:  rewriting tissue computational universality
# words title:  formal model
# words keyword:  operational semantics
# words joined:  formal model operational semantics
# words title:  boolean functions
# words keyword:  boolean function
# words joined:  boolean functions boolean function
# words title:  geometric retrieval
# words keyword:  multi-dimensional data structures
# words joined:  geometric retrieval multi-dimensional data structures
# words title:  past temporal logic operators
# words keyword:  temporal data warehouse
# words joined:  past temporal logic operators temporal data warehouse
# words title:  semantic integration
# words keyword:  information source integration
# words joined:  semantic integration information source integration
# words title:  coroutines
# words keyword:  control structures
# words joined:  coroutines control structures
# words title:  relational model
# words keyword:  coordination models
# words joined:  relational model coordination models
# words title:  modular rewriting semantics
# words keyword:  rewriting logic
# words joined:  modular rewriting semantics rewriting logic
# words title:  implementing coordinated error recovery
# words keyword:  coordinated atomic actions
# words joined:  implementing coordinated error recovery coordinated atomic actions
# words title:  partial categorical multi-combinators
# words keyword:  functional programming
# words joined:  partial categorical multi-combinators functional programming
# words title:  net clr
# words keyword:  language interoperability
# words joined:  net clr language interoperability
# words title:  remote method invocation
# words keyword:  tactics definition language
# words joined:  remote method invocation tactics definition language
# words title:  total functional programming
# words keyword:  functional programming
# words joined:  total functional programming functional programming
# words title:  drag-and-drop programming
# words keyword:  software development
# words joined:  drag-and-drop programming software development
# words title:  extensible environment
# words keyword:  program transformation
# words joined:  extensible environment program transformation
# words title:  improve reactive systems control
# words keyword:  reactive systems
# words joined:  improve reactive systems control reactive systems
# words title:  poset labelled graphs
# words keyword:  architecture
# words joined:  poset labelled graphs architecture
# words title:  mof-based metamodeling environment
# words keyword:  model driven architecture
# words joined:  mof-based metamodeling environment model driven architecture
# words title:  parametric verification
# words keyword:  parametric verification
# words joined:  parametric verification parametric verification
# words title:  platform modeling
# words keyword:  model-based development
# words joined:  platform modeling model-based development
# words title:  proof environment
# words keyword:  theorem proving
# words joined:  proof environment theorem proving
# words title:  checking object system designs incrementally
# words keyword:  multi-object logic
# words joined:  checking object system designs incrementally multi-object logic
# words title:  formally correct functional programs
# words keyword:  constructive program development
# words joined:  formally correct functional programs constructive program development
# words title:  optimized temporal logic compilation
# words keyword:  temporal logic
# words joined:  optimized temporal logic compilation temporal logic
# words title:  case study
# words keyword:  reliability
# words joined:  case study reliability
# words title:  real-time systems
# words keyword:  formal verification
# words joined:  real-time systems formal verification
# words title:  program checking
# words keyword:  implementation correctness
# words joined:  program checking implementation correctness
# words title:  fortran code optimization
# words keyword:  dummy aliasing
# words joined:  fortran code optimization dummy aliasing
# words title:  translation validation
# words keyword:  translation validation
# words joined:  translation validation translation validation
# words title:  cross-disciplinary bibliography
# words keyword:  language independent communication
# words joined:  cross-disciplinary bibliography language independent communication
# words title:  multimedia information repository
# words keyword:  language independent communication
# words joined:  multimedia information repository language independent communication
# words title:  future
# words keyword:  wearable pc
# words joined:  future wearable pc
# words title:  dynamic visual information
# words keyword:  visual languages
# words joined:  dynamic visual information visual languages
# words title:  fibonacci type coding
# words keyword:  cellular automata
# words joined:  fibonacci type coding cellular automata
# words title:  cyclical structure converter
# words keyword:  information source integration
# words joined:  cyclical structure converter information source integration
# words title:  heterogeneous audiovisual archives
# words keyword:  audiovisual archive
# words joined:  heterogeneous audiovisual archives audiovisual archive
# words title:  automatic discovery
# words keyword:  named entity extraction
# words joined:  automatic discovery named entity extraction
# words title:  knowledge creation
# words keyword:  distributed knowledge management
# words joined:  knowledge creation distributed knowledge management
# words title:  converging knowledge management
# words keyword:  knowledge management
# words joined:  converging knowledge management knowledge management
# words title:  strategy formulation process
# words keyword:  strategy process
# words joined:  strategy formulation process strategy process
# words title:  computational problem solving
# words keyword:  collaborative knowledge management architecture
# words joined:  computational problem solving collaborative knowledge management architecture
# words title:  managing operation knowledge
# words keyword:  knowledge management system
# words joined:  managing operation knowledge knowledge management system
# words title:  process-oriented knowledge structuring
# words keyword:  key word based search
# words joined:  process-oriented knowledge structuring key word based search
# words title:  knowledge management
# words keyword:  knowledge management
# words joined:  knowledge management knowledge management
# words title:  post-nonaka knowledge management
# words keyword:  knowledge management optimization factors
# words joined:  post-nonaka knowledge management knowledge management optimization factors
# words title:  semantic grid
# words keyword:  knowledge engineering
# words joined:  semantic grid knowledge engineering
# words title:  scbs social capital benchmarking system
# words keyword:  social capital
# words joined:  scbs social capital benchmarking system social capital
# words title:  pruning-based identification
# words keyword:  knowledge management
# words joined:  pruning-based identification knowledge management
# words title:  integrated personnel development
# words keyword:  knowledge management system
# words joined:  integrated personnel development knowledge management system
# words title:  individual knowledge
# words keyword:  individual knowledge
# words joined:  individual knowledge individual knowledge
# words title:  ontology-based semantic match
# words keyword:  knowledge representation
# words joined:  ontology-based semantic match knowledge representation
# words title:  tool kit
# words keyword:  role construct repertory test
# words joined:  tool kit role construct repertory test
# words title:  practical knowledge-based approach
# words keyword:  human resource planning
# words joined:  practical knowledge-based approach human resource planning
# words title:  applying competence prerequisite structures
# words keyword:  skill management
# words joined:  applying competence prerequisite structures skill management
# words title:  identifying employee competencies
# words keyword:  knowledge space theory
# words joined:  identifying employee competencies knowledge space theory
# words title:  integrative competence management
# words keyword:  resource based view
# words joined:  integrative competence management resource based view
# words title:  simulated learning environments
# words keyword:  simulated learning environment
# words joined:  simulated learning environments simulated learning environment
# words title:  problematic european union member
# words keyword:  skills management
# words joined:  problematic european union member skills management
# words title:  exact peripheral expertise awareness system
# words keyword:  knowledge management
# words joined:  exact peripheral expertise awareness system knowledge management
# words title:  organisational memory information systems
# words keyword:  competence management
# words joined:  organisational memory information systems competence management
# words title:  monitoring temporal logic specifications combined
# words keyword:  run-time execution monitoring
# words joined:  monitoring temporal logic specifications combined run-time execution monitoring
# words title:  graph transformation
# words keyword:  domain-specific modeling languages
# words joined:  graph transformation domain-specific modeling languages
# words title:  formal coalgebraic semantics
# words keyword:  system level design language
# words joined:  formal coalgebraic semantics system level design language
# words title:  information flow method
# words keyword:  admissible interference
# words joined:  information flow method admissible interference
# words title:  automatically generated csp specifications
# words keyword:  formal specification
# words joined:  automatically generated csp specifications formal specification
# words title:  embedded hardware description language
# words keyword:  domain-specific languages
# words joined:  embedded hardware description language domain-specific languages
# words title:  state-based software components
# words keyword:  software components
# words joined:  state-based software components software components
# words title:  object-oriented action semantics specifications
# words keyword:  formal semantics
# words joined:  object-oriented action semantics specifications formal semantics
# words title:  developing adaptive j2me applications
# words keyword:  aspect-oriented programming
# words joined:  developing adaptive j2me applications aspect-oriented programming
# words title:  distributed typed concurrent objects
# words keyword:  distributed computing
# words joined:  distributed typed concurrent objects distributed computing
# words title:  constant propagation
# words keyword:  constant propagation
# words joined:  constant propagation constant propagation
# words title:  reactive event-driven tuple space
# words keyword:  distributed systems
# words joined:  reactive event-driven tuple space distributed systems
# words title:  lazy cyclic reference counting
# words keyword:  garbage collection
# words joined:  lazy cyclic reference counting garbage collection
# words title:  aspect weaving strategies
# words keyword:  aspect-oriented programming
# words joined:  aspect weaving strategies aspect-oriented programming
# words title:  object oriented models
# words keyword:  ocl
# words joined:  object oriented models ocl
# words title:  asynchronous remote method invocation
# words keyword:  asynchronous remote method invocation
# words joined:  asynchronous remote method invocation asynchronous remote method invocation
# words title:  practical type inference
# words keyword:  programming languages
# words joined:  practical type inference programming languages
# words title:  dependently typed pattern matching
# words keyword:  dependent types
# words joined:  dependently typed pattern matching dependent types
# words title:  parallel programming made simple
# words keyword:  fuctional programming
# words joined:  parallel programming made simple fuctional programming
# words title:  structural case-based reasoning
# words keyword:  knowledge management
# words joined:  structural case-based reasoning knowledge management
# words title:  strong effects
# words keyword:  knowledge management
# words joined:  strong effects knowledge management
# words title:  software maintenance
# words keyword:  software maintenance
# words joined:  software maintenance software maintenance
# words title:  experience base schema building blocks
# words keyword:  schema building blocks
# words joined:  experience base schema building blocks schema building blocks
# words title:  case-based reuse
# words keyword:  software reuse
# words joined:  case-based reuse software reuse
# words title:  effective integration
# words keyword:  knowledge strategy
# words joined:  effective integration knowledge strategy
# words title:  defining culture-bound user characteristics
# words keyword:  academic style
# words joined:  defining culture-bound user characteristics academic style
# words title:  culture-sensitive knowledge management
# words keyword:  decentral knowledge management
# words joined:  culture-sensitive knowledge management decentral knowledge management
# words title:  ontology-based knowledge retrieval
# words keyword:  information retrieval
# words joined:  ontology-based knowledge retrieval information retrieval
# words title:  ontology-based knowledge management systems
# words keyword:  information retrieval
# words joined:  ontology-based knowledge management systems information retrieval
# words title:  managing organizational risk knowledge
# words keyword:  risks management
# words joined:  managing organizational risk knowledge risks management
# words title:  multiply hierarchical automaton semantics
# words keyword:  coordination
# words joined:  multiply hierarchical automaton semantics coordination
# words title:  relativizing function classes
# words keyword:  polynomial-time hierarchy
# words joined:  relativizing function classes polynomial-time hierarchy
# words title:  software engineering process
# words keyword:  object-oriented software engineering
# words joined:  software engineering process object-oriented software engineering
# words title:  modeling spatial relations
# words keyword:  elliptical route descriptions
# words joined:  modeling spatial relations elliptical route descriptions
# words title:  direct granularity conversions
# words keyword:  temporal constraints
# words joined:  direct granularity conversions temporal constraints
# words title:  temporal reasoning
# words keyword:  allen temporal relations
# words joined:  temporal reasoning allen temporal relations
# words title:  structural symmetries detection
# words keyword:  medial axis transform
# words joined:  structural symmetries detection medial axis transform
# words title:  propositional interval neighborhood temporal logics
# words keyword:  interval temporal logic
# words joined:  propositional interval neighborhood temporal logics interval temporal logic
# words title:  comparing farm maps
# words keyword:  spatial structure analysis
# words joined:  comparing farm maps spatial structure analysis
# words title:  modeling motion
# words keyword:  autonomous mobile robot navigation
# words joined:  modeling motion autonomous mobile robot navigation
# words title:  spatial accessibility reasoning
# words keyword:  qualitative spatial reasoning
# words joined:  spatial accessibility reasoning qualitative spatial reasoning
# words title:  reasoning
# words keyword:  qualitative spatial reasoning
# words joined:  reasoning qualitative spatial reasoning
# words title:  inoteroperability testing approach
# words keyword:  formal testing
# words joined:  inoteroperability testing approach formal testing
# words title:  introduce e-learning
# words keyword:  managed learning
# words joined:  introduce e-learning managed learning
# words title:  high level system design
# words keyword:  abstract state machines
# words joined:  high level system design abstract state machines
# words title:  polynomial time-space complexity classes
# words keyword:  implicit computational  complexity
# words joined:  polynomial time-space complexity classes implicit computational  complexity
# words title:  powerful model
# words keyword:  knowledge management
# words joined:  powerful model knowledge management
# words title:  generation distributed component systems
# words keyword:  robust globally unique handles
# words joined:  generation distributed component systems robust globally unique handles
# words title:  membrane computing
# words keyword:  molecular computing
# words joined:  membrane computing molecular computing
# words title:  fine computability
# words keyword:  computable analysis
# words joined:  fine computability computable analysis
# words title:  democracy
# words keyword:  cyber ethics
# words joined:  democracy cyber ethics
# words title:  society caused
# words keyword:  information society
# words joined:  society caused information society
# words title:  bibliometric analysis
# words keyword:  intellectual capital report
# words joined:  bibliometric analysis intellectual capital report
# words title:  mental model building
# words keyword:  search histories
# words joined:  mental model building search histories
# words title:  intellectual capital management processes
# words keyword:  knowledge management
# words joined:  intellectual capital management processes knowledge management
# words title:  expert discovery
# words keyword:  knowledge management
# words joined:  expert discovery knowledge management
# words title:  fostering sustainable development
# words keyword:  knowledge transfer
# words joined:  fostering sustainable development knowledge transfer
# words title:  ontology-based skills management
# words keyword:  skills management
# words joined:  ontology-based skills management skills management
# words title:  fostering knowledge communication
# words keyword:  knowledge management
# words joined:  fostering knowledge communication knowledge management
# words title:  information overload
# words keyword:  knowledge management
# words joined:  information overload knowledge management
# words title:  efficient content-based
# words keyword:  image data repository model
# words joined:  efficient content-based image data repository model
# words title:  topic map generation
# words keyword:  topic maps
# words joined:  topic map generation topic maps
# words title:  knowledge nodes
# words keyword:  distributed knowledge management
# words joined:  knowledge nodes distributed knowledge management
# words title:  instance cooperative memory
# words keyword:  cooperative memory relevance feedback
# words joined:  instance cooperative memory cooperative memory relevance feedback
# words title:  usage-centered interface design
# words keyword:  user interface design
# words joined:  usage-centered interface design user interface design
# words title:  automated retrieval
# words keyword:  information retrieval
# words joined:  automated retrieval information retrieval
# words title:  software experience exploitation
# words keyword:  process improvement
# words joined:  software experience exploitation process improvement
# words title:  mobile user groups
# words keyword:  knowledge work processes
# words joined:  mobile user groups knowledge work processes
# words title:  managing user focused access
# words keyword:  knowledge portal
# words joined:  managing user focused access knowledge portal
# words title:  visualizing knowledge
# words keyword:  digital video library
# words joined:  visualizing knowledge digital video library
# words title:  uml sequence diagrams
# words keyword:  formal semantics
# words joined:  uml sequence diagrams formal semantics
# words title:  bounded flooding routing algorithm
# words keyword:  atm vp optimal route provision
# words joined:  bounded flooding routing algorithm atm vp optimal route provision
# words title:  heyting algebras
# words keyword:  formal languages
# words joined:  heyting algebras formal languages
# words title:  interactive distance learning
# words keyword:  computer supported learning strategies
# words joined:  interactive distance learning computer supported learning strategies
# words title:  knowledge spaces
# words keyword:  european research funding
# words joined:  knowledge spaces european research funding
# words title:  unconstrained global optimization
# words keyword:  affine arithmetic
# words joined:  unconstrained global optimization affine arithmetic
# words title:  finding plagiarisms
# words keyword:  string tiling
# words joined:  finding plagiarisms string tiling
# words title:  hd0l power series
# words keyword:  formal power series
# words joined:  hd0l power series formal power series
# words title:  wordnet type synsets
# ...
# words title:  stacked dependency networks
# words keyword:  document structuring
# words joined:  stacked dependency networks document structuring
# words title:  evaluation technique
# words keyword:  document image processing
# words joined:  evaluation technique document image processing
# words title:  comparative aspects
# words keyword:  image processing
# words joined:  comparative aspects image processing
# words title:  task modeling
# words keyword:  task modeling
# words joined:  task modeling task modeling
# words title:  supporting featured user interface models
# words keyword:  group awareness
# words joined:  supporting featured user interface models group awareness
# words title:  prototyping-driven user interface specification
# words keyword:  user interface design
# words joined:  prototyping-driven user interface specification user interface design
# words title:  gaze-based interaction
# words keyword:  eye tracking
# words joined:  gaze-based interaction eye tracking
# words title:  displaying pictures
# words keyword:  intelligent user interface
# words joined:  displaying pictures intelligent user interface
# words title:  relative virtual mouse controlled
# words keyword:  human computer interaction
# words joined:  relative virtual mouse controlled human computer interaction
# words title:  cves based
# words keyword:  collaborative virtual environments
# words joined:  cves based collaborative virtual environments
# words title:  design user interfaces
# words keyword:  workflow information systems
# words joined:  design user interfaces workflow information systems
# words title:  museum web sites
# words keyword:  virtual visit
# words joined:  museum web sites virtual visit
# words title:  agent-based interactive systems
# words keyword:  human-computer interaction
# words joined:  agent-based interactive systems human-computer interaction
# words title:  interactive groupware systems
# words keyword:  model-based development
# words joined:  interactive groupware systems model-based development
# words title:  spatial input task
# words keyword:  user interfaces
# words joined:  spatial input task user interfaces
# words title:  integrating dialog modeling
# words keyword:  model-based user interface design
# words joined:  integrating dialog modeling model-based user interface design
# words title:  adaptive hypermedia system applied
# words keyword:  interactive learning environments
# words joined:  adaptive hypermedia system applied interactive learning environments
# words title:  align business processes
# words keyword:  business process modeling
# words joined:  align business processes business process modeling
# words title:  parsing programs
# words keyword:  presentation-oriented editing
# words joined:  parsing programs presentation-oriented editing
# words title:  shortcut fusion
# words keyword:  shortcut fusion
# words joined:  shortcut fusion shortcut fusion
# words title:  lalr parser generator supporting conflict resolution
# words keyword:  automatic conflict removal
# words joined:  lalr parser generator supporting conflict resolution automatic conflict removal
# words title:  high performance computer processor
# words keyword:  instruction scheduling
# words joined:  high performance computer processor instruction scheduling
# words title:  eliminating cycles
# words keyword:  garbage collection
# words joined:  eliminating cycles garbage collection
# words title:  exploring lua
# words keyword:  preemptive multithreading
# words joined:  exploring lua preemptive multithreading
# words title:  controlling aspect reentrancy
# words keyword:  aspect-oriented programming
# words joined:  controlling aspect reentrancy aspect-oriented programming
# words title:  extensible aspectj implementation
# words keyword:  aspect-oriented programming
# words joined:  extensible aspectj implementation aspect-oriented programming
# words title:  raw types
# words keyword:  aspect-oriented programming
# words joined:  raw types aspect-oriented programming
# words title:  disentangling denotational semantics definitions
# words keyword:  programming languages
# words joined:  disentangling denotational semantics definitions programming languages
# words title:  formal action semantics
# words keyword:  unified modeling language
# words joined:  formal action semantics unified modeling language
# words title:  algebraic laws
# words keyword:  software product lines
# words joined:  algebraic laws software product lines
# words title:  adaptive educational hypermedia systems
# words keyword:  adaptive hypermedia system
# words joined:  adaptive educational hypermedia systems adaptive hypermedia system
# words title:  constructive notions
# words keyword:  constructive
# words joined:  constructive notions constructive
# words title:  information quality management maturity model
# words keyword:  information quality management maturity model
# words joined:  information quality management maturity model information quality management maturity model
# words title:  treat unitarily
# words keyword:  mv algebra
# words joined:  treat unitarily mv algebra
# words title:  online network-on-chip switch fault detection
# words keyword:  functional fault model
# words joined:  online network-on-chip switch fault detection functional fault model
# words title:  determining software investment lag
# words keyword:  software development
# words joined:  determining software investment lag software development
# words title:  adapting clinical ontologies
# words keyword:  clinical ontologies
# words joined:  adapting clinical ontologies clinical ontologies
# words title:  business process models
# words keyword:  business processes
# words joined:  business process models business processes
# words title:  dynamic query optimization
# words keyword:  access limitations
# words joined:  dynamic query optimization access limitations
# words title:  non-denumerable infinitary modal logic
# words keyword:  infinitary modal logic
# words joined:  non-denumerable infinitary modal logic infinitary modal logic
# words title:  nonblocking concurrency
# words keyword:  shared memory
# words joined:  nonblocking concurrency shared memory
# words title:  weak functional dependencies
# words keyword:  weak functional dependency
# words joined:  weak functional dependencies weak functional dependency
# words title:  model aries-based transaction processing
# words keyword:  abstract state machines
# words joined:  model aries-based transaction processing abstract state machines
# words title:  global database design based
# words keyword:  database design
# words joined:  global database design based database design
# words title:  semistructured data models
# words keyword:  semistructured data
# words joined:  semistructured data models semistructured data
# words title:  formal framework
# words keyword:  oltp-olap specification frame
# words joined:  formal framework oltp-olap specification frame
# words title:  coincidence ideals
# words keyword:  complex values
# words joined:  coincidence ideals complex values
# words title:  dynamic data warehouse design
# words keyword:  abstract state machine
# words joined:  dynamic data warehouse design abstract state machine
# words title:  digital goods
# words keyword:  content superdistribution
# words joined:  digital goods content superdistribution
# words title:  secure multimedia authentication
# words keyword:  design principle
# words joined:  secure multimedia authentication design principle
# words title:  heterogeneous multimedia networks
# words keyword:  multimedia communication networks
# words joined:  heterogeneous multimedia networks multimedia communication networks
# words title:  topology change attack
# words keyword:  file sharing application
# words joined:  topology change attack file sharing application
# words title:  distributed denial-of-service attack traffic based
# words keyword:  network monitoring
# words joined:  distributed denial-of-service attack traffic based network monitoring
# words title:  danish newspapers
# words keyword:  business models
# words joined:  danish newspapers business models
# words title:  providing multi source tag recommendations
# words keyword:  digital resources
# words joined:  providing multi source tag recommendations digital resources
# words title:  virtual 3d group interaction scripts
# words keyword:  collaboration patterns
# words joined:  virtual 3d group interaction scripts collaboration patterns
# words title:  modelling mailing list behaviour
# words keyword:  open source projects
# words joined:  modelling mailing list behaviour open source projects
# words title:  supporting composition
# words keyword:  aspect-oriented programming
# words joined:  supporting composition aspect-oriented programming
# words title:  structural coverage criteria
# words keyword:  test adequacy criteria
# words joined:  structural coverage criteria test adequacy criteria
# words title:  fair non-repudiation protocol
# words keyword:  intellectual property rights contracts
# words joined:  fair non-repudiation protocol intellectual property rights contracts
# words title:  role based access control
# words keyword:  role based access control
# words joined:  role based access control role based access control
# words title:  quadratic complexity bounds
# words keyword:  real root isolation
# words joined:  quadratic complexity bounds real root isolation
# words title:  homomorphic cryptosystems
# words keyword:  probability encryption
# words joined:  homomorphic cryptosystems probability encryption
# words title:  dcm based orientation estimation algorithm
# words keyword:  orientation estimation
# words joined:  dcm based orientation estimation algorithm orientation estimation
# words title:  ontology integration methodologies
# words keyword:  ontology integration
# words joined:  ontology integration methodologies ontology integration
# words title:  efficient data preprocessing procedure
# words keyword:  support vector clustering
# words joined:  efficient data preprocessing procedure support vector clustering
# words title:  pareto-based multi-objective optimization algorithm
# words keyword:  offspring generation scheme
# words joined:  pareto-based multi-objective optimization algorithm offspring generation scheme
# words title:  multifaceted sequence patterns
# words keyword:  computation-oriented pattern definition model
# words joined:  multifaceted sequence patterns computation-oriented pattern definition model
# words title:  quantum-inspired immune algorithm
# words keyword:  hybrid flow shop scheduling
# words joined:  quantum-inspired immune algorithm hybrid flow shop scheduling
# words title:  robust road guidance sign recognition
# words keyword:  sign detection
# words joined:  robust road guidance sign recognition sign detection
# words title:  fingerprinting lexical contexts
# words keyword:  golden ontology
# words joined:  fingerprinting lexical contexts golden ontology
# words title:  bayesian gene regulatory network inference optimization
# words keyword:  genetic algorithms
# words joined:  bayesian gene regulatory network inference optimization genetic algorithms
# words title:  multi-sub-swarm particle swarm optimization
# words keyword:  particle swarm optimization
# words joined:  multi-sub-swarm particle swarm optimization particle swarm optimization
# words title:  scenario modeling framework
# words keyword:  multi-agent system
# words joined:  scenario modeling framework multi-agent system
# words title:  personalized url re-ranking method
# words keyword:  user browsing
# words joined:  personalized url re-ranking method user browsing
# words title:  agent migration
# words keyword:  mobile agent
# words joined:  agent migration mobile agent
# words title:  access control infrastructure
# words keyword:  access control infrastructure
# words joined:  access control infrastructure access control infrastructure
# words title:  wireless sensor network
# words keyword:  wireless sensor network
# words joined:  wireless sensor network wireless sensor network
# words title:  full-round chess-64 cipher suitable
# words keyword:  block cipher
# words joined:  full-round chess-64 cipher suitable block cipher
# words title:  protecting mobile tv multimedia content
# words keyword:  digital rights management
# words joined:  protecting mobile tv multimedia content digital rights management
# words title:  core security technologies
# words keyword:  intelligent security framework
# words joined:  core security technologies intelligent security framework
# words title:  pervasive palm vein authentication
# words keyword:  vascular pattern
# words joined:  pervasive palm vein authentication vascular pattern
# words title:  highly dynamic mobile ad hoc network
# words keyword:  mobile ad hoc networks
# words joined:  highly dynamic mobile ad hoc network mobile ad hoc networks
# words title:  neural network based vehicle classification system
# words keyword:  neural network
# words joined:  neural network based vehicle classification system neural network
# words title:  elementary computable topology
# words keyword:  computable analysis
# words joined:  elementary computable topology computable analysis
# words title:  finite-time computability preserving conversions
# words keyword:  sliding block functions
# words joined:  finite-time computability preserving conversions sliding block functions
# words title:  symmetric hyperbolic systems
# words keyword:  hyperbolic system
# words joined:  symmetric hyperbolic systems hyperbolic system
# words title:  effective tietze-urysohn theorem
# words keyword:  computable analysis
# words joined:  effective tietze-urysohn theorem computable analysis
# words title:  topological complexity
# words keyword:  type-2 theory
# words joined:  topological complexity type-2 theory
# words title:  representing measurement results
# words keyword:  computable analysis
# words joined:  representing measurement results computable analysis
# words title:  fine-computable functions
# words keyword:  fine-computable function
# words joined:  fine-computable functions fine-computable function
# words title:  constructive urysohn universal metric space
# words keyword:  urysohn universal space
# words joined:  constructive urysohn universal metric space urysohn universal space
# words title:  computable metric spaces
# words keyword:  computable metric space
# words joined:  computable metric spaces computable metric space
# words title:  np question
# words keyword:  bss machines
# words joined:  np question bss machines
# words title:  ten thousand monkeys approach
# words keyword:  ordinary differential equations
# words joined:  ten thousand monkeys approach ordinary differential equations
# words title:  effective existence
# words keyword:  computatable functional analysis
# words joined:  effective existence computatable functional analysis
# words title:  european perspective
# words keyword:  e-learning territories
# words joined:  european perspective e-learning territories
# words title:  meta-modeling based approach
# words keyword:  model-driven development
# words joined:  meta-modeling based approach model-driven development
# words title:  learning objects pool
# words keyword:  learning objects repository
# words joined:  learning objects pool learning objects repository
# words title:  aiml-based tutor
# words keyword:  intelligent tutoring systems
# words joined:  aiml-based tutor intelligent tutoring systems
# words title:  virtual environment
# words keyword:  virtual environment
# words joined:  virtual environment virtual environment
# words title:  web application
# words keyword:  learning styles
# words joined:  web application learning styles
# words title:  semantic spiral timelines
# words keyword:  visualization
# words joined:  semantic spiral timelines visualization
# words title:  language processing courses
# words keyword:  syntax trees
# words joined:  language processing courses syntax trees
# words title:  distributed computer assisted environment
# words keyword:  intelligent tutoring system
# words joined:  distributed computer assisted environment intelligent tutoring system

# %% [markdown]
# ## Set New Title and Keyword Processing

# %%
df_data = pd.DataFrame() 

columns_to_copy = ['ID','Title','Keywords','FirstLevel']

# Copy the specified columns from df1 to df2
for column in columns_to_copy:
    df_data[column] = df_grouped[column].copy()

# %%
df_data
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords             FirstLevel
# 0     cooperative knowledge generation,knowledge  co...                  ['H']
# 1     professional training,workplace learning,compu...              ['H' 'J']
# 2     Experience-based Information System,wiki,weblo...  ['A' 'D' 'H' 'J' 'K']
# 3     modelling method,introduction method,context-a...          ['H' 'I' 'J']
# 4     knowledge visualization,information  visualiza...                  ['H']
# ...                                                 ...                    ...
# 1097  virtual environment,accessibility,persons with...                  ['K']
# 1098              learning styles,Web-based application                  ['K']
# 1099    visualization,e-learning,timeline,spiral,Moodle              ['L' 'M']
# 1100    syntax trees,visualization,educational software              ['D' 'K']
# 1101   learning programming,intelligent tutoring system          ['D' 'I' 'L']
#
# [1102 rows x 4 columns]

# %%
# df_data['Processed_Title'] = titleArrClean
# df_data['Processed_Keyword'] = rakeKeyword
# df_data['Processed_T_K'] = joinArr

df_data['Processed_Title'] = rakeTitle
df_data['Processed_Keyword'] = rakeKeyword
df_data['Processed_T_K'] = joinArr

# %%
df_data
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords  \
# 0     cooperative knowledge generation,knowledge  co...
# 1     professional training,workplace learning,compu...
# 2     Experience-based Information System,wiki,weblo...
# 3     modelling method,introduction method,context-a...
# 4     knowledge visualization,information  visualiza...
# ...                                                 ...
# 1097  virtual environment,accessibility,persons with...
# 1098              learning styles,Web-based application
# 1099    visualization,e-learning,timeline,spiral,Moodle
# 1100    syntax trees,visualization,educational software
# 1101   learning programming,intelligent tutoring system
#
#                  FirstLevel                             Processed_Title  \
# 0                     ['H']                 process-oriented structures
# 1                 ['H' 'J']  small groups learning synchronously online
# 2     ['A' 'D' 'H' 'J' 'K']                           knowledge sharing
# 3             ['H' 'I' 'J']   implementing pre-built information spaces
# 4                     ['H']                      tube map visualization
# ...                     ...                                         ...
# 1097                  ['K']                         virtual environment
# 1098                  ['K']                             web application
# 1099              ['L' 'M']                   semantic spiral timelines
# 1100              ['D' 'K']                 language processing courses
# 1101          ['D' 'I' 'L']   distributed computer assisted environment
#
#                             Processed_Keyword  \
# 0            cooperative knowledge generation
# 1     computer-supported cooperative learning
# 2       micro-didactical learning arrangement
# 3                            modelling method
# 4                     knowledge visualization
# ...                                       ...
# 1097                      virtual environment
# 1098                          learning styles
# 1099                            visualization
# 1100                             syntax trees
# 1101              intelligent tutoring system
#
#                                           Processed_T_K
# 0     process-oriented structures cooperative knowle...
# 1     small groups learning synchronously online com...
# 2     knowledge sharing micro-didactical learning ar...
# 3     implementing pre-built information spaces mode...
# 4        tube map visualization knowledge visualization
# ...                                                 ...
# 1097            virtual environment virtual environment
# 1098                    web application learning styles
# 1099            semantic spiral timelines visualization
# 1100           language processing courses syntax trees
# 1101  distributed computer assisted environment inte...
#
# [1102 rows x 7 columns]

# %% [markdown]
# # Load in CSV

# %%
import os

# %%
output = os.path.join("data/dataClean/", "df_Processed_Data.csv")
df_data.to_csv(output, index=False)

# %%
df_Processed_Data = pd.read_csv('data/dataClean/df_Processed_Data.csv')
df_Processed_Data
# Out:
#         ID                                              Title  \
# 0        1  Integration of Communities into Process-Orient...
# 1        3  Small Groups Learning Synchronously Online at ...
# 2        4  Using Weblogs for Knowledge Sharing and Learni...
# 3        5  Modelling and Implementing Pre-built Informati...
# 4        6  Tube Map Visualization: Evaluation of a Novel ...
# ...    ...                                                ...
# 1097  1473  Eduquito: Virtual Environment for Digital Incl...
# 1098  1474  Development of a Web Application for Managemen...
# 1099  1475  Semantic Spiral Timelines Used as Support for ...
# 1100  1476  Visualization of Syntax Trees for Language Pro...
# 1101  1477  Learning to Program with COALA, a Distributed ...
#
#                                                Keywords  \
# 0     cooperative knowledge generation,knowledge  co...
# 1     professional training,workplace learning,compu...
# 2     Experience-based Information System,wiki,weblo...
# 3     modelling method,introduction method,context-a...
# 4     knowledge visualization,information  visualiza...
# ...                                                 ...
# 1097  virtual environment,accessibility,persons with...
# 1098              learning styles,Web-based application
# 1099    visualization,e-learning,timeline,spiral,Moodle
# 1100    syntax trees,visualization,educational software
# 1101   learning programming,intelligent tutoring system
#
#                  FirstLevel                             Processed_Title  \
# 0                     ['H']                 process-oriented structures
# 1                 ['H' 'J']  small groups learning synchronously online
# 2     ['A' 'D' 'H' 'J' 'K']                           knowledge sharing
# 3             ['H' 'I' 'J']   implementing pre-built information spaces
# 4                     ['H']                      tube map visualization
# ...                     ...                                         ...
# 1097                  ['K']                         virtual environment
# 1098                  ['K']                             web application
# 1099              ['L' 'M']                   semantic spiral timelines
# 1100              ['D' 'K']                 language processing courses
# 1101          ['D' 'I' 'L']   distributed computer assisted environment
#
#                             Processed_Keyword  \
# 0            cooperative knowledge generation
# 1     computer-supported cooperative learning
# 2       micro-didactical learning arrangement
# 3                            modelling method
# 4                     knowledge visualization
# ...                                       ...
# 1097                      virtual environment
# 1098                          learning styles
# 1099                            visualization
# 1100                             syntax trees
# 1101              intelligent tutoring system
#
#                                           Processed_T_K
# 0     process-oriented structures cooperative knowle...
# 1     small groups learning synchronously online com...
# 2     knowledge sharing micro-didactical learning ar...
# 3     implementing pre-built information spaces mode...
# 4        tube map visualization knowledge visualization
# ...                                                 ...
# 1097            virtual environment virtual environment
# 1098                    web application learning styles
# 1099            semantic spiral timelines visualization
# 1100           language processing courses syntax trees
# 1101  distributed computer assisted environment inte...
#
# [1102 rows x 7 columns]

# %%
print(df_Processed_Data.iloc[1097]['Title'])
print(df_Processed_Data.iloc[1097]['Keywords'])
print(df_Processed_Data.iloc[1097]['Processed_Title'])
print(df_Processed_Data.iloc[1097]['Processed_Keyword'])
print(df_Processed_Data.iloc[1097]['Processed_T_K'])
# Out:
# Eduquito: Virtual Environment for Digital Inclusion of People with Special Educational Needs
# virtual environment,accessibility,persons with disabilities
# virtual environment
# virtual environment
# virtual environment virtual environment
